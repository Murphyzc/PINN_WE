# %% [markdown]
# # NACA0012

# %% [markdown]
# ## 无量纲化
# 来流条件：
# $$p_0 = 75446 Pa ,\quad \rho_0 = 1.248 kg/m^3, \quad u_0 = 203.65 m/s, \quad Ma = 0.7, \quad T = 283.24 $$

# %% [markdown]
# $$ L_\inf = 1m,\quad p^* = \frac{p}{\rho_\infty u_\infty^2} = 1.458, u_\infty = 1,\rho_\infty = 1 , T^* = T/T_{\infty}$$

# %% [markdown]
# $$ \mu^* = \frac{\mu}{\mu_\infty}, \quad T^* = \frac{T}{T_\infty}, \quad e^* = \frac{e}{v_\infty}, Re = \frac{\rho_\infty u_\infty L}{\mu_\infty}, M = \frac{u_\infty}{\sqrt{\gamma RT_\infty}}, Pr = \frac{c_p \mu}{k} $$

# %% [markdown]
# $$ p^* = (\gamma -1) \rho^* e^*, T^* = \frac{\gamma M^2 p^*}{\rho^*}$$

# %% [markdown]
# ## NS equation

# %% [markdown]
# $$\frac{\partial {\bf u}}{\partial t} + \frac{\partial { \bf f}}{\partial x} +\frac{\partial { \bf g }}{\partial y} = \frac{\partial {\bf s_x}}{\partial x} + \frac{\partial {\bf s_y}}{\partial y} $$

# %% [markdown]
# $${\bf u} = (\rho,\rho u,\rho v, E)^T$$, $$ {\bf f} = (\rho u, \rho u^2,\rho u v,(E+p)u)^T $$
# $${\bf g} = (\rho v, \rho u v,\rho v^2+p, (E+p)v)^T$$
# $${\bf s_x} = \frac{1}{Re}(0,\tau_{xx},\tau_{xy},\tau_{xx}u+\tau_{xy}v-q_x)^T$$
# $${\bf s_y} = \frac{1}{Re}(0,\tau_{yx},\tau_{yy},\tau_{yx}u+\tau_{yy}v-q_y)^T$$
#
# $$ E = \rho e + \frac{1}{2}\rho(u^2 +v^2) $$
# $$ e = \frac{1}{\gamma -1} \frac{p}{\rho}$$
# $$ p = \rho R T$$
# $$\tau_{xx} = 2/3\mu(2u_x - v_y)$$
# $$\tau_{yy} = 2/3\mu(2v_y - u_x)$$
# $$\tau_{xy} =\tau_{yx} = \mu (u_y + v_x)$$
# $$q_x = -\frac{c_p \mu}{Pr Re}\frac{\partial T}{\partial x}$$
# $$q_y = -\frac{c_p \mu}{Pr Re}\frac{\partial T}{\partial y}$$
#
# $$ p = \rho R T$$

# %% [markdown]
# ## 简化
# $$ U2_t = (\rho u)_t = \rho_t u+u_t \rho$$
# $$ p_t = \rho_t R T + \rho R T_t $$
# $$ U3_t = E_t = 1/(\gamma -1) p_t + 1/2 \rho_t (u^2 + v^2) + \rho (uu_t + vv_t) $$
# $$ F1_x = \rho_x u + \rho u_x $$
# $$ F2_x = \rho_x u^2 + 2\rho u u_x$$
# $$ F3_x = \rho_x uv + \rho u v_x + \rho u_x v$$
# $$ F4_x = (E_x +p_x) u + (E + p) u_x v$$
#
# $$ S1_{xx} = 0 $$
# $$ S2_{xx} = \frac{1}{Re} \left(2/3\mu_x(2u_x -v_y) + 2/3 \mu (2u_{xx} -v_{xy})\right) $$
# $$ S3_{xx} = \frac{1}{Re} \left(\mu_x(u_y +v_x) + \mu (u_{xy} +v_{xx})\right) $$
# $$ S4_{xx} =  S2_{xx} u + S3_{xx} v + \tau_{xx} u_x +\tau_{xy}v_x + q_{xx}  $$

# %% [markdown]
# $$ q_{xx} = \frac{c_P}{Pr Re}  (\mu_x T_x + \mu T_{xx})$$

# %% [markdown]
# ## 粘性系数
#
# $$\mu = \frac{\mu_0}{T_0^{3/2}} T^{3/2}\frac{T_0+S}{T+S}$$

# %% [markdown]
# $$\mu_x = \frac{\mu_0(T_0 +S) }{T_0^{3/2}} \frac{\sqrt{T}(T+3S)}{2(T+S)^2} T_x$$

# %% [markdown]
# ## 非守恒NS
#
# $$\frac{\partial \rho}{\partial t} + u \frac{\partial \rho}{\partial x} + v{\partial \rho}{\partial y} + \rho \Delta = 0 $$
# $$ \rho(\frac{\partial u}{\partial t} + u\frac{\partial u}{\partial x} + u\frac{\partial u}{\partial x} + \frac{\partial p}{\partial x} = \frac{\mu}{\Re}(4/3 v_{yy} - 2/3 u_{xy} +v_{xy}+u_{yy}+4/3 u_{xx}-2/3v_{xy})

# %% [markdown]
# ## 数据

# %% [markdown]
# $$ y= \pm 0.594689181 \cdot (0.298222773 \cdot \sqrt{x} - 0.127125232 \cdot x \\ - 0.357907906 \cdot x^2 + 0.291984971 \cdot x^3 - 0.105174606 \cdot x^4 )
# $$

# %%
def Naca0012data(x):
    a = 0.594689181
    b = 0.298222773  
    c = 0.127125232 
    d = 0.357907906 
    e = 0.291984971 
    f = 0.105174606 
    y1 = a*(b*np.sqrt(x) - c*x-d*x**2+e*x**3 - f*x**4)
    y2 = -y1
    dy1 =  a*(0.5*b/np.sqrt(x) - c - 2*d*x +3*e*x**2 - 4*f*x**3)
    dy2 = -a*(0.5*b/np.sqrt(x) - c - 2*d*x +3*e*x**2 - 4*f*x**3)
    return y1,y2,dy1,dy2

# %% [markdown]
# ## solver

# %%
import torch
import torch.nn as nn
import numpy as np
import time
import scipy.io
import matplotlib.pyplot as plt
from numpy import arange, meshgrid
#
from smt.sampling_methods import LHS
# Seeds
torch.manual_seed(123)
np.random.seed(123)
def train(epoch):
    model.train()
    def closure():
        optimizer.zero_grad()                                                     # Optimizer
        loss_pde = model.loss_pde(x_int_train)                                    # Loss function of PDE
        loss_ic = model.loss_ic(x_ic_train, rho_ic_train,u_ic_train,v_ic_train,p_ic_train)   # Loss function of IC
        loss_bdL = model.loss_bc(x_bcL_train, rho_bcL_train,u_bcL_train,v_bcL_train,p_bcL_train)   # Loss function of IC
       # loss_bdR = model.loss_bc1(x_bcR_train,rho_bcR_train,u_bcR_train,v_bcR_train,p_bcR_train)   # Loss function of IC
        #loss_cut = model.loss_bc1(x_cut_train,rho_cut_train,u_cut_train,v_cut_train,p_cut_train) 
        loss_bdI = model.bd_B(x_bcI_train, sin_bcI_train,cos_bcI_train)  

        loss_ib = loss_ic  +  loss_bdI #+loss_bdL
        loss = loss_pde + 10*loss_ib

        # Print iteration, loss of PDE and ICs
        print(f'epoch {epoch} loss_pde:{loss_pde:.8f}, loss_ib:{loss_ib:.8f}')
        loss.backward()
        return loss

    # Optimize loss function
    loss = optimizer.step(closure)
    loss_value = loss.item() if not isinstance(loss, float) else loss
    # Print total loss
    print(f'epoch {epoch}: loss {loss_value:.6f}')
    
# Calculate gradients using torch.autograd.grad
def gradients(outputs, inputs):
    return torch.autograd.grad(outputs, inputs,grad_outputs=torch.ones_like(outputs), create_graph=True)

# Convert torch tensor into np.array
def to_numpy(input):
    if isinstance(input, torch.Tensor):
        return input.detach().cpu().numpy()
    elif isinstance(input, np.ndarray):
        return input
    else:
        raise TypeError('Unknown type of input, expected torch.Tensor or ' \
                        'np.ndarray, but got {}'.format(type(input)))
def IC(x):
    N =x.shape[0]
    rho_init = np.zeros((x.shape[0]))                                              # rho - initial condition
    u_init = np.zeros((x.shape[0]))                                                # u - initial condition
    v_init = np.zeros((x.shape[0]))                                                # u - initial condition
    p_init = np.zeros((x.shape[0]))                                                # p - initial condition
    
    gamma = 1.4
    rho1 = 1.0
    p1 =  1.458
    v1 = 0.0
    u1 = 1.0
    
    rho2 = 1.0
    p2 = 1.
    v2 = 0.0
    #u1 = ms*npsqrt(gamma)
    u2 = 0.0
    # rho, p - initial condition
    for i in range(N):
        rho_init[i] = rho1
        u_init[i] =   u1
        v_init[i] =  v1
        p_init[i] =  p1
    return rho_init, u_init, v_init,p_init

def BC_L(x):
    N =x.shape[0]
    rho_init = np.zeros((x.shape[0]))                                              # rho - initial condition
    u_init = np.zeros((x.shape[0]))                                                # u - initial condition
    v_init = np.zeros((x.shape[0]))                                                # u - initial condition
    p_init = np.zeros((x.shape[0]))                                                # p - initial condition
    
    gamma = 1.4
    #u1 = ms*npsqrt(gamma)
    # rho, p - initial condition
    rho1 = 1.00
    p1 =  1.458
    v1 = 0.0
    u1 = 1.0
    for i in range(N):
        rho_init[i] = rho1
        u_init[i] =  u1
        v_init[i] =  v1
        p_init[i] =  p1
    return rho_init, u_init, v_init,p_init
def BC_R(x):
    N =x.shape[0]
    rho_init = np.zeros((x.shape[0]))                                              # rho - initial condition
    u_init = np.zeros((x.shape[0]))                                                # u - initial condition
    v_init = np.zeros((x.shape[0]))                                                # u - initial condition
    p_init = np.zeros((x.shape[0]))                                                # p - initial condition
    
    gamma = 1.4
    ms = 2.0
    rho1 = 1.0
    p1 = 1.0
    v1 = 0.0
    u1 = 0
    # rho, p - initial condition
    for i in range(N):
        rho_init[i] = rho1
        u_init[i] = u1
        v_init[i] = v1
        p_init[i] = p1

    return rho_init, u_init, v_init,p_init
def BC_Cut(x):
    N =x.shape[0]
    rho_init = np.zeros((x.shape[0]))
    u_init = np.zeros((x.shape[0]))
    v_init = np.zeros((x.shape[0]))
    p_init = np.zeros((x.shape[0]))
    
    gamma = 1.4
    ms = 2.0
    rho1 = 1.0
    p1 = 1.0
    v1 = 0.0
    u1 = 0
    # rho, p - initial condition
    for i in range(N):
        rho_init[i] = 10.01
        u_init[i] =  0
        v_init[i] = 0
        p_init[i] = 10.01

    return rho_init, u_init, v_init,p_init
    
class DNN(nn.Module):

    def __init__(self):
        super(DNN, self).__init__()
        self.net = nn.Sequential()                                                  # Define neural network
        self.net.add_module('Linear_layer_1', nn.Linear(3, 90))                     # First linear layer
        self.net.add_module('Tanh_layer_1', nn.Tanh())                              # First activation Layer

        for num in range(2, 6):                                                     # Number of layers (2 through 7)
            self.net.add_module('Linear_layer_%d' % (num), nn.Linear(90, 90))       # Linear layer
            self.net.add_module('Tanh_layer_%d' % (num), nn.Tanh())                 # Activation Layer
        self.net.add_module('Linear_layer_final', nn.Linear(90, 4))                 # Output Layer

    # Forward Feed
    def forward(self, x):
        return self.net(x)

    def bd_B(self,x,sin,cos):
        yb = self.net(x)
        rhob,pb,ub,vb = yb[:, 0:1], yb[:, 1:2], yb[:, 2:3],yb[:,3:]
        drhob_g = gradients(rhob, x)[0]                                      # Gradient [u_t, u_x]
        rhob_x, rhob_y = drhob_g[:, 1:2], drhob_g[:, 2:3]                            # Partial derivatives u_t, u_x
        dub_g = gradients(ub, x)[0]                                      # Gradient [u_t, u_x]
        ub_x, ub_y = dub_g[:, 1:2], dub_g[:, 2:3]                            # Partial derivatives u_t, u_x
        dvb_g = gradients(vb, x)[0]                                      # Gradient [u_t, u_x]
        vb_x, vb_y = dvb_g[:, 1:2], dvb_g[:, 2:3]                            # Partial derivatives u_t, u_x
        dpb_g = gradients(pb, x)[0]                                      # Gradient [p_t, p_x]
        pb_x, pb_y = dpb_g[:, 1:2], dpb_g[:, 2:3]                            # Partial derivatives p_t, p_x
        
        deltau = ub_x + vb_y
        lam = 0.1*(abs(deltau) - deltau) + 1
        #lam = (deltau) - deltau) + 1
        
        fb = (((ub*cos + vb*sin)/lam)**2).mean() +\
            (((pb_x*cos + pb_y*sin)/lam)**2).mean() +\
            (((rhob_x*cos + rhob_y*sin)/lam)**2).mean()
        return fb
    def bd_OY(self,x):
        y = self.net(x)
        rho,p,u,v = y[:, 0:1], y[:, 1:2], y[:, 2:3],y[:,3:]
        
        drho_g = gradients(rho, x)[0]                                  # Gradient [rho_t, rho_x]
        rho_x,rho_y = drho_g[:, :1], drho_g[:, 1:2]                    # Partial derivatives rho_t, rho_x
        du_g = gradients(u, x)[0]                                      # Gradient [u_t, u_x]
        u_x, u_y = du_g[:, :1], du_g[:, 1:2]                            # Partial derivatives u_t, u_x
        dv_g = gradients(v, x)[0]                                      # Gradient [u_t, u_x]
        v_x, v_y = dv_g[:, :1], dv_g[:, 1:2]                            # Partial derivatives u_t, u_x
        dp_g = gradients(p, x)[0]                                      # Gradient [p_t, p_x]
        p_x, p_y = dp_g[:, :1], dp_g[:, 1:2]                            # Partial derivatives p_t, p_x
        
        deltau = u_x + v_y
        lam = 0.1*(abs(deltau) - deltau) + 1
        
        f = ((( u_y)/lam)**2).mean() +\
            ((( v_y)/lam)**2).mean() +\
            ((( p_y)/lam)**2).mean() +\
            ((( rho_y)/lam)**2).mean()
        return f
    
    def bd_OX(self,x):
        y = self.net(x)
        rho,p,u,v = y[:, 0:1], y[:, 1:2], y[:, 2:3],y[:,3:]
        
        drho_g = gradients(rho, x)[0]                                  # Gradient [rho_t, rho_x]
        rho_x,rho_y = drho_g[:, :1], drho_g[:, 1:2]                    # Partial derivatives rho_t, rho_x
        du_g = gradients(u, x)[0]                                      # Gradient [u_t, u_x]
        u_x, u_y = du_g[:, :1], du_g[:, 1:2]                            # Partial derivatives u_t, u_x
        dv_g = gradients(v, x)[0]                                      # Gradient [u_t, u_x]
        v_x, v_y = dv_g[:, :1], dv_g[:, 1:2]                            # Partial derivatives u_t, u_x
        dp_g = gradients(p, x)[0]                                      # Gradient [p_t, p_x]
        p_x, p_y = dp_g[:, :1], dp_g[:, 1:2]                            # Partial derivatives p_t, p_x
        
        deltau = u_x + v_y
        lam = 0.1*(abs(deltau) - deltau) + 1
        
        f = ((( u_x)/lam)**2).mean() +\
            ((( v_x)/lam)**2).mean() +\
            ((( p_x)/lam)**2).mean() +\
            ((( rho_x)/lam)**2).mean()
        return f
     
    # Loss function for PDE
    def loss_pde(self, x):
        
       # yL = self.net(x_intL_train)
       # yR = self.net(x_intR_train)
       # yU = self.net(x_intU_train)
       # yD = self.net(x_intD_train)
       # rhoL,pL,uL,vL = yL[:, 0:1], yL[:, 1:2], yL[:, 2:3],yL[:,3:]
       # rhoR,pR,uR,vR = yR[:, 0:1], yR[:, 1:2], yR[:, 2:3],yR[:,3:]
       # rhoU,pU,uU,vU = yU[:, 0:1], yU[:, 1:2], yU[:, 2:3],yU[:,3:]
       # rhoD,pD,uD,vD = yD[:, 0:1], yD[:, 1:2], yD[:, 2:3],yD[:,3:]
        y = self.net(x)
        gamma = 1.4                                                    # Heat Capacity Ratio
        epsilon = 1e-5
        rho,T,u,v = y[:, 0:1], y[:, 1:2], y[:, 2:3],y[:,3:]
        
        drho_g = gradients(rho,x)[0]
        rho_t,rho_x,rho_y = drho_g[:, :1],drho_g[:,1:2],drho_g[:,2:3]
        dT_g = gradients(T,x)[0]
        T_t,T_x,T_y = dT_g[:, :1],dT_g[:,1:2],dT_g[:,2:3]
        du_g = gradients(u,x)[0]
        u_t,u_x,u_y = du_g[:, :1],du_g[:,1:2],du_g[:,2:3]
        dv_g = gradients(v,x)[0]
        v_t,v_x,v_y = dv_g[:, :1],dv_g[:,1:2],dv_g[:,2:3]
        dux_g = gradients(u_x,x)[0]
        u_xx,u_xy = dux_g[:,1:2],dux_g[:,2:3]
        duy_g = gradients(u_y,x)[0]
        u_yy = duy_g[:,2:3]
        dvx_g = gradients(v_x,x)[0]
        v_xx,v_xy = dvx_g[:,1:2],dvx_g[:,2:3]
        dvy_g = gradients(v_y,x)[0]
        v_yy = dvy_g[:,2:3]
        
        Re = 500
        Pr = 0.72
        R = 287
        
        Ma = 0.7
        gamma = 1.4
        
        p = 1/gamma/Ma**2 *rho *T
        e =  p/(gamma - 1)
        E = rho*e + 0.5*rho*(u**2+v**2)
        
        p_t = 1/(gamma*Ma**2)*(rho_t*T+T_t*rho)
        p_x = 1/(gamma*Ma**2)*(rho_x*T+T_x*rho)
        p_y = 1/(gamma*Ma**2)*(rho_y*T+T_y*rho)
        E_y = rho_y*e + rho*p_y/(gamma -1) + 0.5*rho_y*(u**2+v**2) + \
               rho*(u_y*u + v_y*v)
        
        U1_t = rho_t
        U2_t = rho_t*u + rho*u_t
        U3_t = rho_t*v + rho*v_t
        U4_t = rho_t*e + rho*p_t/(gamma -1) + 0.5*rho_t*(u**2+v**2) + \
               rho*(u_t*u + v_t*v)
            
        
        f1_x = rho_x*u + u_x*rho
        f2_x = rho_x*u**2 + 2*rho*u*u_x + p_x
        f3_x = rho_x*u*v + rho*u_x*v + rho*u*v_x
        f4_x = u_x*(E+p) +u*(E_x + p_x)
        
        g1_y = rho_y*u + u_y*rho
        g2_y = rho_y*u**2 + 2*rho*u*u_y + p_y
        g3_y = rho_y*u*v + rho*u_y*v + rho*u*v_y
        g4_y = u_y*(E+p) +u*(E_y + p_y)
        
        
        
        
        rhoE = p/(gamma - 1) +0.5*rho*(u**2+v**2)
        
        f1 = rho*u
        f2 = rho*u*u+p
        f3 = rho*u*v
        f4 = (rhoE+p)*u
        
        g1 = rho*v
        g2 = rho*v*u
        g3 = rho*v*v + p
        g4 = (rhoE+p)*v
        
        drho_g = gradients(rho,x)[0]
        U1_t = drho_g[:, :1]
        dU2_g = gradients(f1,x)[0]
        U2_t = dU2_g[:, :1]
        dU3_g = gradients(g1,x)[0]
        U3_t = dU3_g[:, :1]
        dU4_g = gradients(rhoE,x)[0]
        U4_t = dU4_g[:, :1]
        
        df1_g = gradients(f1, x)[0]                                  # Gradient [rho_t, rho_x]
        f1_x = df1_g[:, 1:2]
        df2_g = gradients(f2, x)[0]                                      # Gradient [u_t, u_x]
        f2_x = df2_g[:, 1:2]
        df3_g = gradients(f3, x)[0]                                      # Gradient [u_t, u_x]
        f3_x = df3_g[:, 1:2]
        df4_g = gradients(f4, x)[0]                                      # Gradient [u_t, u_x]
        f4_x = df4_g[:, 1:2]
        
        dg1_g = gradients(g1, x)[0]                                  # Gradient [rho_t, rho_x]
        g1_y = dg1_g[:, 2:3]
        dg2_g = gradients(g2, x)[0]                                      # Gradient [u_t, u_x]
        g2_y = dg2_g[:, 2:3]
        dg3_g = gradients(g3, x)[0]                                      # Gradient [u_t, u_x]
        g3_y = dg3_g[:, 2:3]
        dg4_g = gradients(g4, x)[0]                                      # Gradient [u_t, u_x]
        g4_y = dg4_g[:, 2:3]
        
        
        du_g = gradients(u, x)[0]                                
        u_x = du_g[:, 1:2]         
        dv_g = gradients(v, x)[0]                    
        v_y = dv_g[:, 2:3]         
        
      #  rho,p,u,v = y[:, 0:1], y[:, 1:2], y[:, 2:3],y[:,3:]
      #  gamma = 1.4                                                    # Heat Capacity Ratio
      #  epsilon = 1e-5
      #  s = torch.log((abs(p)+epsilon)/(abs(rho)+epsilon)**1.4)
      #  eta = -rho*s
      #  phi1 = -rho*u*s
      #  phi2 = -rho*v*s
      #  
      #  drho_g = gradients(rho, x)[0]                                  # Gradient [rho_t, rho_x]
      #  rho_t, rho_x,rho_y = drho_g[:, :1], drho_g[:, 1:2],drho_g[:,2:]
      #  du_g = gradients(u, x)[0]                                      # Gradient [u_t, u_x]
      #  u_t, u_x, u_y = du_g[:, :1], du_g[:, 1:2], du_g[:,2:]                            # Partial derivatives u_t, u_x
      #  dv_g = gradients(v, x)[0]                                      # Gradient [u_t, u_x]
      #  v_t, v_x, v_y = dv_g[:, :1], dv_g[:, 1:2], dv_g[:,2:]                            # Partial derivatives u_t, u_x
      #  
      #  E = p/0.4 + 0.5*rho*(u**2+v**2)
      #  EL = pL/0.4 + 0.5*rhoL*(uL**2+vL**2)
      #  ER = pR/0.4 + 0.5*rhoR*(uR**2+vR**2)
      #  EU = pU/0.4 + 0.5*rhoU*(uU**2+vU**2)
      #  ED = pD/0.4 + 0.5*rhoD*(uD**2+vD**2)
      #  dE_g = gradients(E, x)[0]                                      # Gradient [u_t, u_x]
      #  E_t = dE_g[:, :1]
      #  
      #  
      #  deta_g = gradients(eta, x)[0]                                      # Gradient [p_t, p_x]
      #  eta_t, eta_x,eta_y = deta_g[:, :1], deta_g[:, 1:2],deta_g[2:3]                            # Partial derivatives p_t, p_x
      #  dphi1_g = gradients(phi1, x)[0]                                      # Gradient [p_t, p_x]
      #  dphi2_g = gradients(phi2, x)[0]                                      # Gradient [p_t, p_x]
      #  phi1_t, phi1_x,phi1_y = dphi1_g[:, :1], dphi1_g[:, 1:2],dphi1_g[:,2:3]                           # Partial derivatives p_t, p_x
      #  phi2_t, phi2_x,phi2_y = dphi2_g[:, :1], dphi2_g[:, 1:2],dphi2_g[:,2:3]                           # Partial derivatives p_t, p_x
        
        d = np.random.rand()
        deltau = u_x + v_y
        nab = abs(deltau) - deltau
        
        #a = np.sqrt(1.4*p/rho)
       # q = 0.01*(rho*deltau**2)
        
        d = 1.0
        lam = d*(0.1*nab) + 1
        #lam = d + 1
       # lam = 1/lam
        
        f = (((U1_t + f1_x+g1_y )/lam)**2).mean() +\
            (((U2_t + f2_x+g2_y )/lam)**2).mean() +\
            (((U3_t + f3_x+g3_y )/lam)**2).mean() +\
            (((U4_t + f4_x+g4_y )/lam)**2).mean()

      #  p = p+q
        
      #  dp_g = gradients(p, x)[0]                                      # Gradient [p_t, p_x]
      #  p_t, p_x, p_y = dp_g[:, :1], dp_g[:, 1:2], dp_g[:,2:]                            # Partial derivatives p_t, p_x
      #  
      #  s1 = rho_t + (rhoR*uR - rhoL*uL)/0.02 +  (rhoU*uU - rhoD*uD)/0.02 
      #  s2 = u*rho_t + u_t*rho + (rhoR*uR*uR +pR - rhoL*uL*uL-pL)/0.02 \
      #       +(rhoU*uU*vU - rhoD*uD*vD)/0.02 
      #  s3 = v*rho_t + v_t*rho + (rhoU*vU*vU +pU - rhoD*vD*vD-pD)/0.02 \
      #       +(rhoR*uR*vR - rhoL*uL*vL)/0.02 
      #  s4 = E_t + ((ER+pR)*uR - (EL+pL)*uL)/0.02 + ((EU+pU)*vU - (ED+pD)*vD)/0.02 
      #  
      #  du_gg = gradients(u_x, x)[0]                                      # Gradient [u_t, u_x]
      #  u_xx, u_xy = du_gg[:, :1], du_gg[:, 1:2]                            # Partial derivatives u_t, u_x
      #  
      #  dv_gg = gradients(v_y, x)[0]                                      # Gradient [u_t, u_x]
      #  v_yx, v_yy = dv_gg[:, :1], dv_gg[:, 1:2]                            # Partial derivatives u_t, u_x
      #  
      #  vis = -0.1*(u_xx + v_yy)
#
      #  f = (((rho_t+rho*deltau+u*rho_x + v*rho_y)/lam)**2).mean() +\
      #      (((rho*u_t+rho*u*u_x+rho*v*u_y+p_x +rho*vis)/lam)**2).mean() +\
      #      (((rho*v_t+rho*u*v_x+rho*v*v_y+p_y +rho*vis)/lam)**2).mean() +\
      #      (((p_t+u*p_x+v*p_y+1.4*p*deltau +rho*vis)/lam)**2).mean() + \
      #      ((abs(s1)+s1)**2).mean() +\
      #      ((abs(s3)+s3)**2).mean() +\
      #      ((abs(s2)+s2)**2).mean() +\
      #      ((abs(s4)+s4)**2).mean()
      #      #(((abs(eta_t+phi1_x + phi2_y)+eta_t+phi1_x+ phi2_y))**2).mean()
    #
      #      #((abs(rho-1) - (rho-1))**2).mean()   + \
      #      #((abs(p-0.7) - (p-0.7))**2).mean() +\
        return f

    # Loss function for initial condition
    def loss_ic(self, x_ic, rho_ic, u_ic, v_ic,p_ic):
        U_ic = self.net(x_ic)                                                      # Initial condition
        rho_ic_nn, p_ic_nn,u_ic_nn,v_ic_nn = U_ic[:, 0], U_ic[:, 1], U_ic[:, 2],U_ic[:,3]            # rho, u, p - initial condition

        # Loss function for the initial condition
        loss_ics = ((u_ic_nn - u_ic) ** 2).mean() + \
               ((rho_ic_nn- rho_ic) ** 2).mean()  + \
               ((p_ic_nn - p_ic) ** 2).mean() +\
               ((v_ic_nn - v_ic) ** 2).mean()

        return loss_ics

    def loss_bc(self, x_ic, rho_ic, u_ic, v_ic,p_ic):
        U_ic = self.net(x_ic)                                                      # Initial condition
        rho_ic_nn, p_ic_nn,u_ic_nn,v_ic_nn = U_ic[:, 0], U_ic[:, 1], U_ic[:, 2],U_ic[:,3]            # rho, u, p - initial condition

        # Loss function for the initial condition
        loss_ics = ((u_ic_nn - u_ic) ** 2).mean() + \
               ((rho_ic_nn- rho_ic) ** 2).mean()  + \
               ((p_ic_nn - p_ic) ** 2).mean() +\
               ((v_ic_nn - v_ic) ** 2).mean()

        return loss_ics
    def loss_bc1(self, x_ic, rho_ic, u_ic, v_ic,p_ic):
        U_ic = self.net(x_ic)                                                      # Initial condition
        rho_ic_nn, p_ic_nn,u_ic_nn,v_ic_nn = U_ic[:, 0], U_ic[:, 1], U_ic[:, 2],U_ic[:,3]            # rho, u, p - initial condition

        # Loss function for the initial condition
        loss_ics = ((rho_ic_nn- rho_ic) ** 2).mean()  + \
               ((p_ic_nn - p_ic) ** 2).mean() 

        return loss_ics

def BD_naca0012(t,xb,yb,n):
    x = np.zeros((2*n,3)) 
    sin = np.zeros((2*n,1)) 
    cos = np.zeros((2*n,1)) 

    for i in range(n):
        xd = np.random.rand()
        yd1,yd2,dy1,dy2 = Naca0012data(xd)
        
        x[i,0] = np.random.rand()*t
        x[i,1] = xb + xd
        x[i,2] = yb  + yd1
        cos[i,0] = -dy1/np.sqrt(dy1**2 + 1)
        sin[i,0] =   1/np.sqrt(dy1**2 + 1)
    for i in range(n):
        xd = np.random.rand()
        yd1,yd2,dy1,dy2 = Naca0012data(xd)
        
        x[i+n,0] = np.random.rand()*t
        x[i+n,1] = xb + xd
        x[i+n,2] = yb  + yd2
        cos[i+n,0] = -dy2/np.sqrt(dy2**2 + 1)
        sin[i+n,0] =  1/np.sqrt(dy2**2 + 1)
    return x, sin,cos
def BD_circle(t,xc,yc,r,n):
    x = np.zeros((n,3)) 
    sin = np.zeros((n,1)) 
    cos = np.zeros((n,1)) 

    for i in range(n):
        the = 2*np.random.rand()*np.pi
        xd = np.cos(the + np.pi/2)
        yd = np.sin(the + np.pi/2)
        x[i,0] = np.random.rand()*t
        x[i,1] = xc  + xd*r
        x[i,2] = yc  + yd*r
        cos[i,0] = xd 
        sin[i,0] = yd
        #cos[i,0] = 1
        #sin[i,0] = 0
    return x, sin,cos

def Pertur(x, dx):
    N =x.shape[0]
    xL = np.zeros((N,3))
    xR = np.zeros((N,3))
    xU = np.zeros((N,3))
    xD = np.zeros((N,3))
    
    for i in range(N):
        xL[i,0] = x[i,0]
        xR[i,0] = x[i,0]
        xU[i,0] = x[i,0]
        xD[i,0] = x[i,0]
        
        
        xL[i,1] = x[i,1] - dx
        xR[i,1] = x[i,1] + dx
        xU[i,1] = x[i,1]
        xD[i,1] = x[i,1]
        
        xL[i,2] = x[i,2] 
        xR[i,2] = x[i,2]
        xU[i,2] = x[i,2] + dx
        xD[i,2] = x[i,2] - dx
        
    return xL,xR,xU,xD
    
    
    
def BD_BackCorner(t,n):
    
    x = np.zeros((n,3)) 
    x2 = np.zeros((n,3)) 
    sin = np.zeros((n,1)) 
    sin2 = np.zeros((n,1)) 
    cos = np.zeros((n,1)) 
    cos2 = np.zeros((n,1)) 
    
    for i in range(n):
        x[i,0] = np.random.rand()*t
        x[i,1] = np.random.rand()*0.3 + 0.2
        x[i,2] = 1.5
        sin[i] = 1
        cos[i] = 0
    for i in range(n):
        x2[i,0] = np.random.rand()*t
        x2[i,1] = np.random.rand()*0.5
        x2[i,2] = 1.5
        sin2[i] = 1
        cos2[i] = 0
    x = np.vstack((x,x2))
    sin = np.vstack((sin,sin2))
    cos = np.vstack((cos,cos2))
    
    for i in range(n):
        x2[i,0] = np.random.rand()*t
        x2[i,1] = 0.5
        x2[i,2] = np.random.rand()*1.5
        sin2[i] = 0
        cos2[i] = 1
        
    x = np.vstack((x,x2))
    sin = np.vstack((sin,sin2))
    cos = np.vstack((cos,cos2))
    
    for i in range(n):
        x2[i,0] = np.random.rand()*t
        x2[i,1] = 0.5
        x2[i,2] = np.random.rand()*0.3 + 1.2
        sin2[i] = 0
        cos2[i] = 1
        
    x = np.vstack((x,x2))
    sin = np.vstack((sin,sin2))
    cos = np.vstack((cos,cos2))
        
    return x,sin,cos

# Solve Euler equations using PINNs
# def main():
  # Initialization
#device = torch.device('cuda')                                          # Run on CPU
device = torch.device('cuda')                                          # Run on CPU
lr = 0.001                                                           # Learning rate
num_ib = 1000                                                # Random sampled points from IC0
num_int = 10000                                                # Random sampled points in interior
Tend = 0.4
Lx = 2.0
Ly = 1.0
rx = 0.5
ry = 0.50
rd = 0.25


xlimits = np.array([[0.,Tend],[0.0, Lx], [0,Ly]])  #interal
sampling = LHS(xlimits=xlimits)
x_int_train = sampling(num_int)

#xlimits = np.array([[0.,Tend],[0.5, 2], [0.5,2]])  #interal
#sampling = LHS(xlimits=xlimits)
#x_int1_train = sampling(num_int)
#x_int_train =  np.vstack((x_int_train,x_int1_train))

A = []
for i in range(num_int):
    x = x_int_train[i,1]
    y = x_int_train[i,2]
    if ((x - rx)>0 and (x-rx)<1):
        y1,y2,dy1,dy2 = Naca0012data(x-rx)
        if ((y-ry)>y2 and (y-ry)<y1):
            A.append(i)
x_int_train = np.delete(x_int_train,A,axis=0)

#xlimits = np.array([[0.0, Tend], [1.0, 4.0], [0.2,1.0]])
#sampling = LHS(xlimits=xlimits)
#x_int_train_add = sampling(3*num_int)
#x_int_train = np.vstack((x_int_train,x_int_train_add))

#x_intL_train,x_intR_train,x_intU_train,x_intD_train = Pertur(x_int_train, 0.01)

xlimits = np.array([[0.,0.0],[0.0,Lx], [0.0,Ly]])  #interal
sampling = LHS(xlimits=xlimits)
x_ic_train = sampling(num_ib)
A = []
for i in range(num_ib):
    x = x_ic_train[i,1]
    y = x_ic_train[i,2]
    if ((x - rx)>0 and (x-rx)<1):
        y1,y2,dy1,dy2 = Naca0012data(x-rx)
        if ((y-ry)>y2 and (y-ry)<y1):
            A.append(i)
x_ic_train = np.delete(x_ic_train,A,axis=0)


#xlimits = np.array([[0.0, 0.0], [1.0, 4.0], [0.2,1.0]])
#sampling = LHS(xlimits=xlimits)
#x_ic_train_add = sampling(3*num_int)
#x_ic_train = np.vstack((x_ic_train,x_ic_train_add))


xlimits = np.array([[0.0,Tend],[0.0, 0.0], [0.0,Ly]])
sampling = LHS(xlimits=xlimits)
x_bcL_train =  sampling(num_ib)
#
#xlimits = np.array([[0.0,Tend], [Lx, Lx], [0.0,Ly]])
#sampling = LHS(xlimits=xlimits)
#x_bcR_train =  sampling(num_ib)
#
#
#xlimits = np.array([[0.0,Tend],[0.0, Lx], [Ly,Ly]])
#sampling = LHS(xlimits=xlimits)
#x_bcU_train =  sampling(num_ib)
#
#xlimits = np.array([[0.0,Tend], [0.0, Lx], [0.0,0.0]])
#sampling = LHS(xlimits=xlimits)
#x_bcD_train =  sampling(num_ib)                                           # Vectorized whole domain

#xlimits = np.array([[0.0,0.0],[0.0, Lx], [0.0,Ly]])
#sampling = LHS(xlimits=xlimits)
#x_ic_train =  sampling(num_ib)
#A = []
#for i in range(num_ib):
#    x = x_ic_train[i,1]
#    y = x_ic_train[i,2]
#    if ((x-rx)**2 + (y-ry)**2 ) < rd**2:
#        A.append(i)
#x_ic_train = np.delete(x_ic_train,A,axis=0)


x_bcI_train,sin_bcI_train,cos_bcI_train = BD_naca0012(Tend,rx,ry,num_ib)
#x_bcI_train,sin_bcI_train,cos_bcI_train = BD_circle(Tend,rx,ry,rd,num_ib)
#x_bcI_train,sin_bcI_train,cos_bcI_train = BD_BackCorner(Tend,num_ib)

rho_bcL_train, u_bcL_train,v_bcL_train, p_bcL_train = BC_L(x_bcL_train)  
#rho_bcR_train, u_bcR_train,v_bcR_train, p_bcR_train = BC_L(x_bcR_train)  
#rho_cut_train, u_cut_train,v_cut_train, p_cut_train = BC_Cut(x_cut_train)  
rho_ic_train, u_ic_train,v_ic_train, p_ic_train = IC(x_ic_train)  


x_int_train = torch.tensor(x_int_train, requires_grad=True, dtype=torch.float32).to(device)
#x_intL_train = torch.tensor(x_intL_train,dtype=torch.float32).to(device)
#x_intR_train = torch.tensor(x_intR_train,dtype=torch.float32).to(device)
#x_intU_train = torch.tensor(x_intU_train,dtype=torch.float32).to(device)
#x_intD_train = torch.tensor(x_intD_train,dtype=torch.float32).to(device)

rho_bcL_train = torch.tensor(rho_bcL_train, dtype=torch.float32).to(device)
u_bcL_train = torch.tensor(u_bcL_train, dtype=torch.float32).to(device)
v_bcL_train = torch.tensor(v_bcL_train, dtype=torch.float32).to(device)
p_bcL_train = torch.tensor(p_bcL_train, dtype=torch.float32).to(device)

#rho_bcR_train = torch.tensor(rho_bcR_train, dtype=torch.float32).to(device)
#u_bcR_train = torch.tensor(u_bcR_train, dtype=torch.float32).to(device)
#v_bcR_train = torch.tensor(v_bcR_train, dtype=torch.float32).to(device)
#p_bcR_train = torch.tensor(p_bcR_train, dtype=torch.float32).to(device)
#
#x_bcD_train = torch.tensor(x_bcD_train,requires_grad=True, dtype=torch.float32).to(device)
#x_bcU_train = torch.tensor(x_bcU_train, requires_grad=True, dtype=torch.float32).to(device)
#x_bcR_train = torch.tensor(x_bcR_train, requires_grad=True, dtype=torch.float32).to(device)
x_bcL_train = torch.tensor(x_bcL_train, dtype=torch.float32).to(device)
x_bcI_train = torch.tensor(x_bcI_train, requires_grad=True, dtype=torch.float32).to(device)
sin_bcI_train = torch.tensor(sin_bcI_train, dtype=torch.float32).to(device)
cos_bcI_train = torch.tensor(cos_bcI_train, dtype=torch.float32).to(device)

#rho_cut_train = torch.tensor(rho_cut_train, dtype=torch.float32).to(device)
#u_cut_train = torch.tensor(u_cut_train, dtype=torch.float32).to(device)
#v_cut_train = torch.tensor(v_cut_train, dtype=torch.float32).to(device)
#p_cut_train = torch.tensor(p_cut_train, dtype=torch.float32).to(device)
#x_cut_train = torch.tensor(x_cut_train, dtype=torch.float32).to(device)

rho_ic_train = torch.tensor(rho_ic_train, dtype=torch.float32).to(device)
u_ic_train = torch.tensor(u_ic_train, dtype=torch.float32).to(device)
v_ic_train = torch.tensor(v_ic_train, dtype=torch.float32).to(device)
p_ic_train = torch.tensor(p_ic_train, dtype=torch.float32).to(device)
x_ic_train = torch.tensor(x_ic_train, dtype=torch.float32).to(device)


#model = DNN().to(device)

#optimizer = torch.optim.LBFGS(model.parameters(),lr=lr,max_iter=500)
#rho_ic_train.clone().detach().requires_grad_(True)
#u_ic_train.clone().detach().requires_grad_(True)
# Initialize neural network

print('Start training...')
# Out:
# Start training...

# %%
plt.figure()
plt.scatter(x_bc[:,1],x_bc[:,2])
#plt.pcolor(x_grid[:,0,:],y_grid[:,0,:],ue)
#plt.colorbar(x_grid[:,0,:],y_grid[:,0,:],ue)
#plt.scatter(x_int_train[:,1],)
#plt.pcolor(x[:],u[:,1])
#plt.pcolor(x[:],u[:,2])
ax = plt.gca()
ax.set_aspect(1)
plt.show()

# %%
model = DNN().to(device)

# %%
lr = 0.001
#optimizer = torch.optim.LBFGS(model.parameters(),lr=lr,max_iter=500)
optimizer = torch.optim.Adam(model.parameters(), lr=lr)
#scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer_Adam,gamma=0.995)
#optimizer = torch.optim.LBFGS(model.parameters(),lr=0.5,max_iter=20)
#optimizer_LBFGS = torch.optim.LBFGS(model.parameters(), lr=0.01, max_iter=50000)

# %%
epochs = 10000
tic = time.time()
for epoch in range(1, epochs+1):
    train(epoch)
toc = time.time()
print(f'Total training time: {toc - tic}')
# Out:
# epoch 1 loss_pde:0.00178309, loss_ib:3.49998498
# epoch 1: loss 35.001633
# epoch 2 loss_pde:0.00169636, loss_ib:3.02585912
# epoch 2: loss 30.260286
# epoch 3 loss_pde:0.00444889, loss_ib:2.55717134
# epoch 3: loss 25.576160
# epoch 4 loss_pde:0.01713872, loss_ib:2.06827855
# epoch 4: loss 20.699924
# epoch 5 loss_pde:0.05833724, loss_ib:1.55737102
# epoch 5: loss 15.632048
# epoch 6 loss_pde:0.17001729, loss_ib:1.04486811
# epoch 6: loss 10.618698
# epoch 7 loss_pde:0.42658380, loss_ib:0.57798374
# epoch 7: loss 6.206421
# epoch 8 loss_pde:0.89412093, loss_ib:0.22915606
# epoch 8: loss 3.185682
# epoch 9 loss_pde:1.43860257, loss_ib:0.07138803
# epoch 9: loss 2.152483
# epoch 10 loss_pde:1.58204603, loss_ib:0.11248512
# epoch 10: loss 2.706897
# epoch 11 loss_pde:1.15647507, loss_ib:0.25119507
# epoch 11: loss 3.668426
# epoch 12 loss_pde:0.66702086, loss_ib:0.34873515
# epoch 12: loss 4.154372
# epoch 13 loss_pde:0.43436050, loss_ib:0.34325260
# epoch 13: loss 3.866887
# epoch 14 loss_pde:0.41384351, loss_ib:0.26301500
# epoch 14: loss 3.043993
# epoch 15 loss_pde:0.47819671, loss_ib:0.16082446
# epoch 15: loss 2.086441
# epoch 16 loss_pde:0.53801286, loss_ib:0.07891460
# epoch 16: loss 1.327159
# epoch 17 loss_pde:0.55575079, loss_ib:0.03800794
# epoch 17: loss 0.935830
# epoch 18 loss_pde:0.52735072, loss_ib:0.03776290
# epoch 18: loss 0.904980
# epoch 19 loss_pde:0.46428403, loss_ib:0.06377588
# epoch 19: loss 1.102043
# epoch 20 loss_pde:0.38271639, loss_ib:0.09718440
# epoch 20: loss 1.354560
# epoch 21 loss_pde:0.29767832, loss_ib:0.12261856
# epoch 21: loss 1.523864
# epoch 22 loss_pde:0.22040558, loss_ib:0.13203877
# epoch 22: loss 1.540793
# epoch 23 loss_pde:0.15797374, loss_ib:0.12469486
# epoch 23: loss 1.404922
# epoch 24 loss_pde:0.11397417, loss_ib:0.10495254
# epoch 24: loss 1.163500
# epoch 25 loss_pde:0.08905502, loss_ib:0.07955359
# epoch 25: loss 0.884591
# epoch 26 loss_pde:0.08099517, loss_ib:0.05527978
# epoch 26: loss 0.633793
# epoch 27 loss_pde:0.08488467, loss_ib:0.03727358
# epoch 27: loss 0.457620
# epoch 28 loss_pde:0.09401238, loss_ib:0.02808768
# epoch 28: loss 0.374889
# epoch 29 loss_pde:0.10182017, loss_ib:0.02760321
# epoch 29: loss 0.377852
# epoch 30 loss_pde:0.10401619, loss_ib:0.03354805
# epoch 30: loss 0.439497
# epoch 31 loss_pde:0.09959327, loss_ib:0.04240216
# epoch 31: loss 0.523615
# epoch 32 loss_pde:0.09022897, loss_ib:0.05045625
# epoch 32: loss 0.594791
# epoch 33 loss_pde:0.07870133, loss_ib:0.05483034
# epoch 33: loss 0.627005
# epoch 34 loss_pde:0.06743654, loss_ib:0.05422890
# epoch 34: loss 0.609726
# epoch 35 loss_pde:0.05785059, loss_ib:0.04916294
# epoch 35: loss 0.549480
# epoch 36 loss_pde:0.05041142, loss_ib:0.04152391
# epoch 36: loss 0.465650
# epoch 37 loss_pde:0.04499891, loss_ib:0.03372625
# epoch 37: loss 0.382261
# epoch 38 loss_pde:0.04123360, loss_ib:0.02782237
# epoch 38: loss 0.319457
# epoch 39 loss_pde:0.03866830, loss_ib:0.02491696
# epoch 39: loss 0.287838
# epoch 40 loss_pde:0.03687129, loss_ib:0.02500489
# epoch 40: loss 0.286920
# epoch 41 loss_pde:0.03546041, loss_ib:0.02718002
# epoch 41: loss 0.307261
# epoch 42 loss_pde:0.03412969, loss_ib:0.03006787
# epoch 42: loss 0.334808
# epoch 43 loss_pde:0.03268307, loss_ib:0.03231723
# epoch 43: loss 0.355855
# epoch 44 loss_pde:0.03106657, loss_ib:0.03301098
# epoch 44: loss 0.361176
# epoch 45 loss_pde:0.02937611, loss_ib:0.03189539
# epoch 45: loss 0.348330
# epoch 46 loss_pde:0.02781974, loss_ib:0.02937614
# epoch 46: loss 0.321581
# epoch 47 loss_pde:0.02663445, loss_ib:0.02629371
# epoch 47: loss 0.289572
# epoch 48 loss_pde:0.02598930, loss_ib:0.02359460
# epoch 48: loss 0.261935
# epoch 49 loss_pde:0.02590288, loss_ib:0.02197802
# epoch 49: loss 0.245683
# epoch 50 loss_pde:0.02621453, loss_ib:0.02167443
# epoch 50: loss 0.242959
# epoch 51 loss_pde:0.02663643, loss_ib:0.02243514
# epoch 51: loss 0.250988
# epoch 52 loss_pde:0.02685596, loss_ib:0.02369444
# epoch 52: loss 0.263800
# epoch 53 loss_pde:0.02663864, loss_ib:0.02481871
# epoch 53: loss 0.274826
# epoch 54 loss_pde:0.02588824, loss_ib:0.02533629
# epoch 54: loss 0.279251
# epoch 55 loss_pde:0.02464708, loss_ib:0.02507357
# epoch 55: loss 0.275383
# epoch 56 loss_pde:0.02305054, loss_ib:0.02417119
# epoch 56: loss 0.264762
# epoch 57 loss_pde:0.02126752, loss_ib:0.02299245
# epoch 57: loss 0.251192
# epoch 58 loss_pde:0.01945362, loss_ib:0.02196291
# epoch 58: loss 0.239083
# epoch 59 loss_pde:0.01772760, loss_ib:0.02139978
# epoch 59: loss 0.231725
# epoch 60 loss_pde:0.01616683, loss_ib:0.02139729
# epoch 60: loss 0.230140
# epoch 61 loss_pde:0.01481196, loss_ib:0.02181545
# epoch 61: loss 0.232966
# epoch 62 loss_pde:0.01367363, loss_ib:0.02237221
# epoch 62: loss 0.237396
# epoch 63 loss_pde:0.01273885, loss_ib:0.02278612
# epoch 63: loss 0.240600
# epoch 64 loss_pde:0.01197734, loss_ib:0.02289390
# epoch 64: loss 0.240916
# epoch 65 loss_pde:0.01134929, loss_ib:0.02269143
# epoch 65: loss 0.238264
# epoch 66 loss_pde:0.01081445, loss_ib:0.02229850
# epoch 66: loss 0.233799
# epoch 67 loss_pde:0.01034019, loss_ib:0.02188196
# epoch 67: loss 0.229160
# epoch 68 loss_pde:0.00990636, loss_ib:0.02158136
# epoch 68: loss 0.225720
# epoch 69 loss_pde:0.00950575, loss_ib:0.02146367
# epoch 69: loss 0.224142
# epoch 70 loss_pde:0.00913994, loss_ib:0.02151418
# epoch 70: loss 0.224282
# epoch 71 loss_pde:0.00881251, loss_ib:0.02165824
# epoch 71: loss 0.225395
# epoch 72 loss_pde:0.00852276, loss_ib:0.02180137
# epoch 72: loss 0.226536
# epoch 73 loss_pde:0.00826227, loss_ib:0.02186993
# epoch 73: loss 0.226962
# epoch 74 loss_pde:0.00801512, loss_ib:0.02183514
# epoch 74: loss 0.226366
# epoch 75 loss_pde:0.00776141, loss_ib:0.02171332
# epoch 75: loss 0.224895
# epoch 76 loss_pde:0.00748318, loss_ib:0.02154904
# epoch 76: loss 0.222974
# epoch 77 loss_pde:0.00717088, loss_ib:0.02139403
# epoch 77: loss 0.221111
# epoch 78 loss_pde:0.00682759, loss_ib:0.02129038
# epoch 78: loss 0.219731
# epoch 79 loss_pde:0.00646901, loss_ib:0.02125891
# epoch 79: loss 0.219058
# epoch 80 loss_pde:0.00611835, loss_ib:0.02129276
# epoch 80: loss 0.219046
# epoch 81 loss_pde:0.00579856, loss_ib:0.02135955
# epoch 81: loss 0.219394
# epoch 82 loss_pde:0.00552545, loss_ib:0.02141542
# epoch 82: loss 0.219680
# epoch 83 loss_pde:0.00530434, loss_ib:0.02142614
# epoch 83: loss 0.219566
# epoch 84 loss_pde:0.00513049, loss_ib:0.02138316
# epoch 84: loss 0.218962
# epoch 85 loss_pde:0.00499230, loss_ib:0.02130487
# epoch 85: loss 0.218041
# epoch 86 loss_pde:0.00487520, loss_ib:0.02122353
# epoch 86: loss 0.217110
# epoch 87 loss_pde:0.00476492, loss_ib:0.02116749
# epoch 87: loss 0.216440
# epoch 88 loss_pde:0.00464946, loss_ib:0.02114907
# epoch 88: loss 0.216140
# epoch 89 loss_pde:0.00452014, loss_ib:0.02116228
# epoch 89: loss 0.216143
# epoch 90 loss_pde:0.00437186, loss_ib:0.02118855
# epoch 90: loss 0.216257
# epoch 91 loss_pde:0.00420314, loss_ib:0.02120701
# epoch 91: loss 0.216273
# epoch 92 loss_pde:0.00401582, loss_ib:0.02120451
# epoch 92: loss 0.216061
# epoch 93 loss_pde:0.00381455, loss_ib:0.02118118
# epoch 93: loss 0.215626
# epoch 94 loss_pde:0.00360595, loss_ib:0.02114843
# epoch 94: loss 0.215090
# epoch 95 loss_pde:0.00339758, loss_ib:0.02112114
# epoch 95: loss 0.214609
# epoch 96 loss_pde:0.00319696, loss_ib:0.02110911
# epoch 96: loss 0.214288
# epoch 97 loss_pde:0.00301075, loss_ib:0.02111297
# epoch 97: loss 0.214140
# epoch 98 loss_pde:0.00284409, loss_ib:0.02112562
# epoch 98: loss 0.214100
# epoch 99 loss_pde:0.00270003, loss_ib:0.02113704
# epoch 99: loss 0.214070
# epoch 100 loss_pde:0.00257911, loss_ib:0.02113935
# epoch 100: loss 0.213973
# epoch 101 loss_pde:0.00247921, loss_ib:0.02113019
# epoch 101: loss 0.213781
# epoch 102 loss_pde:0.00239580, loss_ib:0.02111307
# epoch 102: loss 0.213526
# epoch 103 loss_pde:0.00232279, loss_ib:0.02109476
# epoch 103: loss 0.213270
# epoch 104 loss_pde:0.00225388, loss_ib:0.02108119
# epoch 104: loss 0.213066
# epoch 105 loss_pde:0.00218414, loss_ib:0.02107454
# epoch 105: loss 0.212929
# epoch 106 loss_pde:0.00211120, loss_ib:0.02107307
# epoch 106: loss 0.212842
# epoch 107 loss_pde:0.00203565, loss_ib:0.02107326
# epoch 107: loss 0.212768
# epoch 108 loss_pde:0.00196016, loss_ib:0.02107194
# epoch 108: loss 0.212680
# epoch 109 loss_pde:0.00188804, loss_ib:0.02106745
# epoch 109: loss 0.212563
# epoch 110 loss_pde:0.00182197, loss_ib:0.02105979
# epoch 110: loss 0.212420
# epoch 111 loss_pde:0.00176326, loss_ib:0.02105032
# epoch 111: loss 0.212266
# epoch 112 loss_pde:0.00171195, loss_ib:0.02104107
# epoch 112: loss 0.212123
# epoch 113 loss_pde:0.00166714, loss_ib:0.02103376
# epoch 113: loss 0.212005
# epoch 114 loss_pde:0.00162748, loss_ib:0.02102893
# epoch 114: loss 0.211917
# epoch 115 loss_pde:0.00159149, loss_ib:0.02102583
# epoch 115: loss 0.211850
# epoch 116 loss_pde:0.00155783, loss_ib:0.02102290
# epoch 116: loss 0.211787
# epoch 117 loss_pde:0.00152539, loss_ib:0.02101880
# epoch 117: loss 0.211713
# epoch 118 loss_pde:0.00149340, loss_ib:0.02101303
# epoch 118: loss 0.211624
# epoch 119 loss_pde:0.00146141, loss_ib:0.02100619
# epoch 119: loss 0.211523
# epoch 120 loss_pde:0.00142927, loss_ib:0.02099958
# epoch 120: loss 0.211425
# epoch 121 loss_pde:0.00139708, loss_ib:0.02099436
# epoch 121: loss 0.211341
# epoch 122 loss_pde:0.00136508, loss_ib:0.02099080
# epoch 122: loss 0.211273
# epoch 123 loss_pde:0.00133360, loss_ib:0.02098824
# epoch 123: loss 0.211216
# epoch 124 loss_pde:0.00130293, loss_ib:0.02098561
# epoch 124: loss 0.211159
# epoch 125 loss_pde:0.00127330, loss_ib:0.02098220
# epoch 125: loss 0.211095
# epoch 126 loss_pde:0.00124486, loss_ib:0.02097794
# epoch 126: loss 0.211024
# epoch 127 loss_pde:0.00121772, loss_ib:0.02097331
# epoch 127: loss 0.210951
# epoch 128 loss_pde:0.00119203, loss_ib:0.02096890
# epoch 128: loss 0.210881
# epoch 129 loss_pde:0.00116791, loss_ib:0.02096511
# epoch 129: loss 0.210819
# epoch 130 loss_pde:0.00114551, loss_ib:0.02096190
# epoch 130: loss 0.210765
# epoch 131 loss_pde:0.00112494, loss_ib:0.02095893
# epoch 131: loss 0.210714
# epoch 132 loss_pde:0.00110630, loss_ib:0.02095573
# epoch 132: loss 0.210664
# epoch 133 loss_pde:0.00108965, loss_ib:0.02095204
# epoch 133: loss 0.210610
# epoch 134 loss_pde:0.00107492, loss_ib:0.02094788
# epoch 134: loss 0.210554
# epoch 135 loss_pde:0.00106193, loss_ib:0.02094351
# epoch 135: loss 0.210497
# epoch 136 loss_pde:0.00105042, loss_ib:0.02093918
# epoch 136: loss 0.210442
# epoch 137 loss_pde:0.00104008, loss_ib:0.02093505
# epoch 137: loss 0.210391
# epoch 138 loss_pde:0.00103062, loss_ib:0.02093112
# epoch 138: loss 0.210342
# epoch 139 loss_pde:0.00102179, loss_ib:0.02092727
# epoch 139: loss 0.210294
# epoch 140 loss_pde:0.00101345, loss_ib:0.02092335
# epoch 140: loss 0.210247
# epoch 141 loss_pde:0.00100546, loss_ib:0.02091928
# epoch 141: loss 0.210198
# epoch 142 loss_pde:0.00099770, loss_ib:0.02091513
# epoch 142: loss 0.210149
# epoch 143 loss_pde:0.00099009, loss_ib:0.02091098
# epoch 143: loss 0.210100
# epoch 144 loss_pde:0.00098259, loss_ib:0.02090691
# epoch 144: loss 0.210052
# epoch 145 loss_pde:0.00097519, loss_ib:0.02090298
# epoch 145: loss 0.210005
# epoch 146 loss_pde:0.00096795, loss_ib:0.02089916
# epoch 146: loss 0.209960
# epoch 147 loss_pde:0.00096092, loss_ib:0.02089537
# epoch 147: loss 0.209915
# epoch 148 loss_pde:0.00095414, loss_ib:0.02089154
# epoch 148: loss 0.209870
# epoch 149 loss_pde:0.00094762, loss_ib:0.02088761
# epoch 149: loss 0.209824
# epoch 150 loss_pde:0.00094131, loss_ib:0.02088359
# epoch 150: loss 0.209777
# epoch 151 loss_pde:0.00093512, loss_ib:0.02087957
# epoch 151: loss 0.209731
# epoch 152 loss_pde:0.00092900, loss_ib:0.02087561
# epoch 152: loss 0.209685
# epoch 153 loss_pde:0.00092294, loss_ib:0.02087172
# epoch 153: loss 0.209640
# epoch 154 loss_pde:0.00091697, loss_ib:0.02086788
# epoch 154: loss 0.209596
# epoch 155 loss_pde:0.00091115, loss_ib:0.02086399
# epoch 155: loss 0.209551
# epoch 156 loss_pde:0.00090555, loss_ib:0.02086006
# epoch 156: loss 0.209506
# epoch 157 loss_pde:0.00090020, loss_ib:0.02085605
# epoch 157: loss 0.209461
# epoch 158 loss_pde:0.00089510, loss_ib:0.02085202
# epoch 158: loss 0.209415
# epoch 159 loss_pde:0.00089024, loss_ib:0.02084800
# epoch 159: loss 0.209370
# epoch 160 loss_pde:0.00088561, loss_ib:0.02084399
# epoch 160: loss 0.209325
# epoch 161 loss_pde:0.00088124, loss_ib:0.02083998
# epoch 161: loss 0.209281
# epoch 162 loss_pde:0.00087715, loss_ib:0.02083596
# epoch 162: loss 0.209237
# epoch 163 loss_pde:0.00087339, loss_ib:0.02083191
# epoch 163: loss 0.209192
# epoch 164 loss_pde:0.00086997, loss_ib:0.02082783
# epoch 164: loss 0.209148
# epoch 165 loss_pde:0.00086686, loss_ib:0.02082372
# epoch 165: loss 0.209104
# epoch 166 loss_pde:0.00086402, loss_ib:0.02081961
# epoch 166: loss 0.209060
# epoch 167 loss_pde:0.00086138, loss_ib:0.02081552
# epoch 167: loss 0.209017
# epoch 168 loss_pde:0.00085887, loss_ib:0.02081146
# epoch 168: loss 0.208973
# epoch 169 loss_pde:0.00085645, loss_ib:0.02080741
# epoch 169: loss 0.208931
# epoch 170 loss_pde:0.00085410, loss_ib:0.02080338
# epoch 170: loss 0.208888
# epoch 171 loss_pde:0.00085181, loss_ib:0.02079936
# epoch 171: loss 0.208845
# epoch 172 loss_pde:0.00084959, loss_ib:0.02079536
# epoch 172: loss 0.208803
# epoch 173 loss_pde:0.00084743, loss_ib:0.02079139
# epoch 173: loss 0.208761
# epoch 174 loss_pde:0.00084531, loss_ib:0.02078743
# epoch 174: loss 0.208720
# epoch 175 loss_pde:0.00084322, loss_ib:0.02078352
# epoch 175: loss 0.208678
# epoch 176 loss_pde:0.00084116, loss_ib:0.02077963
# epoch 176: loss 0.208637
# epoch 177 loss_pde:0.00083915, loss_ib:0.02077577
# epoch 177: loss 0.208597
# epoch 178 loss_pde:0.00083721, loss_ib:0.02077192
# epoch 178: loss 0.208556
# epoch 179 loss_pde:0.00083536, loss_ib:0.02076809
# epoch 179: loss 0.208516
# epoch 180 loss_pde:0.00083362, loss_ib:0.02076428
# epoch 180: loss 0.208476
# epoch 181 loss_pde:0.00083199, loss_ib:0.02076049
# epoch 181: loss 0.208437
# epoch 182 loss_pde:0.00083047, loss_ib:0.02075672
# epoch 182: loss 0.208398
# epoch 183 loss_pde:0.00082905, loss_ib:0.02075298
# epoch 183: loss 0.208359
# epoch 184 loss_pde:0.00082774, loss_ib:0.02074926
# epoch 184: loss 0.208320
# epoch 185 loss_pde:0.00082654, loss_ib:0.02074555
# epoch 185: loss 0.208282
# epoch 186 loss_pde:0.00082548, loss_ib:0.02074186
# epoch 186: loss 0.208244
# epoch 187 loss_pde:0.00082457, loss_ib:0.02073818
# epoch 187: loss 0.208206
# epoch 188 loss_pde:0.00082382, loss_ib:0.02073452
# epoch 188: loss 0.208169
# epoch 189 loss_pde:0.00082324, loss_ib:0.02073087
# epoch 189: loss 0.208132
# epoch 190 loss_pde:0.00082281, loss_ib:0.02072724
# epoch 190: loss 0.208095
# epoch 191 loss_pde:0.00082253, loss_ib:0.02072362
# epoch 191: loss 0.208059
# epoch 192 loss_pde:0.00082239, loss_ib:0.02072002
# epoch 192: loss 0.208023
# epoch 193 loss_pde:0.00082238, loss_ib:0.02071643
# epoch 193: loss 0.207987
# epoch 194 loss_pde:0.00082251, loss_ib:0.02071286
# epoch 194: loss 0.207951
# epoch 195 loss_pde:0.00082274, loss_ib:0.02070930
# epoch 195: loss 0.207916
# epoch 196 loss_pde:0.00082307, loss_ib:0.02070577
# epoch 196: loss 0.207881
# epoch 197 loss_pde:0.00082348, loss_ib:0.02070226
# epoch 197: loss 0.207846
# epoch 198 loss_pde:0.00082397, loss_ib:0.02069877
# epoch 198: loss 0.207812
# epoch 199 loss_pde:0.00082451, loss_ib:0.02069530
# epoch 199: loss 0.207778
# epoch 200 loss_pde:0.00082513, loss_ib:0.02069185
# epoch 200: loss 0.207744
# epoch 201 loss_pde:0.00082583, loss_ib:0.02068842
# epoch 201: loss 0.207710
# epoch 202 loss_pde:0.00082663, loss_ib:0.02068501
# epoch 202: loss 0.207677
# epoch 203 loss_pde:0.00082753, loss_ib:0.02068162
# epoch 203: loss 0.207644
# epoch 204 loss_pde:0.00082853, loss_ib:0.02067824
# epoch 204: loss 0.207611
# epoch 205 loss_pde:0.00082964, loss_ib:0.02067488
# epoch 205: loss 0.207578
# epoch 206 loss_pde:0.00083086, loss_ib:0.02067154
# epoch 206: loss 0.207546
# epoch 207 loss_pde:0.00083219, loss_ib:0.02066821
# epoch 207: loss 0.207514
# epoch 208 loss_pde:0.00083363, loss_ib:0.02066489
# epoch 208: loss 0.207483
# epoch 209 loss_pde:0.00083520, loss_ib:0.02066159
# epoch 209: loss 0.207451
# epoch 210 loss_pde:0.00083688, loss_ib:0.02065830
# epoch 210: loss 0.207420
# epoch 211 loss_pde:0.00083870, loss_ib:0.02065503
# epoch 211: loss 0.207389
# epoch 212 loss_pde:0.00084063, loss_ib:0.02065176
# epoch 212: loss 0.207358
# epoch 213 loss_pde:0.00084268, loss_ib:0.02064851
# epoch 213: loss 0.207328
# epoch 214 loss_pde:0.00084483, loss_ib:0.02064528
# epoch 214: loss 0.207298
# epoch 215 loss_pde:0.00084710, loss_ib:0.02064205
# epoch 215: loss 0.207268
# epoch 216 loss_pde:0.00084946, loss_ib:0.02063884
# epoch 216: loss 0.207238
# epoch 217 loss_pde:0.00085192, loss_ib:0.02063565
# epoch 217: loss 0.207208
# epoch 218 loss_pde:0.00085448, loss_ib:0.02063247
# epoch 218: loss 0.207179
# epoch 219 loss_pde:0.00085713, loss_ib:0.02062930
# epoch 219: loss 0.207150
# epoch 220 loss_pde:0.00085987, loss_ib:0.02062614
# epoch 220: loss 0.207121
# epoch 221 loss_pde:0.00086270, loss_ib:0.02062300
# epoch 221: loss 0.207093
# epoch 222 loss_pde:0.00086561, loss_ib:0.02061988
# epoch 222: loss 0.207064
# epoch 223 loss_pde:0.00086861, loss_ib:0.02061676
# epoch 223: loss 0.207036
# epoch 224 loss_pde:0.00087170, loss_ib:0.02061366
# epoch 224: loss 0.207008
# epoch 225 loss_pde:0.00087487, loss_ib:0.02061057
# epoch 225: loss 0.206981
# epoch 226 loss_pde:0.00087814, loss_ib:0.02060749
# epoch 226: loss 0.206953
# epoch 227 loss_pde:0.00088148, loss_ib:0.02060443
# epoch 227: loss 0.206926
# epoch 228 loss_pde:0.00088492, loss_ib:0.02060137
# epoch 228: loss 0.206899
# epoch 229 loss_pde:0.00088845, loss_ib:0.02059833
# epoch 229: loss 0.206872
# epoch 230 loss_pde:0.00089207, loss_ib:0.02059530
# epoch 230: loss 0.206845
# epoch 231 loss_pde:0.00089579, loss_ib:0.02059228
# epoch 231: loss 0.206819
# epoch 232 loss_pde:0.00089960, loss_ib:0.02058926
# epoch 232: loss 0.206792
# epoch 233 loss_pde:0.00090352, loss_ib:0.02058626
# epoch 233: loss 0.206766
# epoch 234 loss_pde:0.00090752, loss_ib:0.02058327
# epoch 234: loss 0.206740
# epoch 235 loss_pde:0.00091163, loss_ib:0.02058028
# epoch 235: loss 0.206714
# epoch 236 loss_pde:0.00091581, loss_ib:0.02057731
# epoch 236: loss 0.206689
# epoch 237 loss_pde:0.00092009, loss_ib:0.02057434
# epoch 237: loss 0.206663
# epoch 238 loss_pde:0.00092445, loss_ib:0.02057139
# epoch 238: loss 0.206638
# epoch 239 loss_pde:0.00092888, loss_ib:0.02056844
# epoch 239: loss 0.206613
# epoch 240 loss_pde:0.00093340, loss_ib:0.02056550
# epoch 240: loss 0.206588
# epoch 241 loss_pde:0.00093800, loss_ib:0.02056258
# epoch 241: loss 0.206564
# epoch 242 loss_pde:0.00094267, loss_ib:0.02055966
# epoch 242: loss 0.206539
# epoch 243 loss_pde:0.00094742, loss_ib:0.02055675
# epoch 243: loss 0.206515
# epoch 244 loss_pde:0.00095224, loss_ib:0.02055385
# epoch 244: loss 0.206491
# epoch 245 loss_pde:0.00095714, loss_ib:0.02055096
# epoch 245: loss 0.206467
# epoch 246 loss_pde:0.00096212, loss_ib:0.02054807
# epoch 246: loss 0.206443
# epoch 247 loss_pde:0.00096717, loss_ib:0.02054520
# epoch 247: loss 0.206419
# epoch 248 loss_pde:0.00097230, loss_ib:0.02054233
# epoch 248: loss 0.206396
# epoch 249 loss_pde:0.00097750, loss_ib:0.02053947
# epoch 249: loss 0.206372
# epoch 250 loss_pde:0.00098278, loss_ib:0.02053662
# epoch 250: loss 0.206349
# epoch 251 loss_pde:0.00098814, loss_ib:0.02053378
# epoch 251: loss 0.206326
# epoch 252 loss_pde:0.00099357, loss_ib:0.02053094
# epoch 252: loss 0.206303
# epoch 253 loss_pde:0.00099907, loss_ib:0.02052811
# epoch 253: loss 0.206280
# epoch 254 loss_pde:0.00100466, loss_ib:0.02052529
# epoch 254: loss 0.206258
# epoch 255 loss_pde:0.00101032, loss_ib:0.02052247
# epoch 255: loss 0.206235
# epoch 256 loss_pde:0.00101605, loss_ib:0.02051966
# epoch 256: loss 0.206213
# epoch 257 loss_pde:0.00102186, loss_ib:0.02051686
# epoch 257: loss 0.206190
# epoch 258 loss_pde:0.00102774, loss_ib:0.02051406
# epoch 258: loss 0.206168
# epoch 259 loss_pde:0.00103369, loss_ib:0.02051128
# epoch 259: loss 0.206146
# epoch 260 loss_pde:0.00103971, loss_ib:0.02050849
# epoch 260: loss 0.206125
# epoch 261 loss_pde:0.00104579, loss_ib:0.02050572
# epoch 261: loss 0.206103
# epoch 262 loss_pde:0.00105194, loss_ib:0.02050295
# epoch 262: loss 0.206081
# epoch 263 loss_pde:0.00105816, loss_ib:0.02050019
# epoch 263: loss 0.206060
# epoch 264 loss_pde:0.00106445, loss_ib:0.02049743
# epoch 264: loss 0.206039
# epoch 265 loss_pde:0.00107080, loss_ib:0.02049468
# epoch 265: loss 0.206018
# epoch 266 loss_pde:0.00107721, loss_ib:0.02049193
# epoch 266: loss 0.205997
# epoch 267 loss_pde:0.00108369, loss_ib:0.02048920
# epoch 267: loss 0.205976
# epoch 268 loss_pde:0.00109024, loss_ib:0.02048647
# epoch 268: loss 0.205955
# epoch 269 loss_pde:0.00109685, loss_ib:0.02048374
# epoch 269: loss 0.205934
# epoch 270 loss_pde:0.00110352, loss_ib:0.02048102
# epoch 270: loss 0.205914
# epoch 271 loss_pde:0.00111027, loss_ib:0.02047830
# epoch 271: loss 0.205893
# epoch 272 loss_pde:0.00111707, loss_ib:0.02047560
# epoch 272: loss 0.205873
# epoch 273 loss_pde:0.00112394, loss_ib:0.02047289
# epoch 273: loss 0.205853
# epoch 274 loss_pde:0.00113088, loss_ib:0.02047020
# epoch 274: loss 0.205833
# epoch 275 loss_pde:0.00113788, loss_ib:0.02046750
# epoch 275: loss 0.205813
# epoch 276 loss_pde:0.00114494, loss_ib:0.02046481
# epoch 276: loss 0.205793
# epoch 277 loss_pde:0.00115207, loss_ib:0.02046213
# epoch 277: loss 0.205773
# epoch 278 loss_pde:0.00115926, loss_ib:0.02045945
# epoch 278: loss 0.205754
# epoch 279 loss_pde:0.00116651, loss_ib:0.02045678
# epoch 279: loss 0.205734
# epoch 280 loss_pde:0.00117382, loss_ib:0.02045412
# epoch 280: loss 0.205715
# epoch 281 loss_pde:0.00118119, loss_ib:0.02045146
# epoch 281: loss 0.205696
# epoch 282 loss_pde:0.00118862, loss_ib:0.02044880
# epoch 282: loss 0.205677
# epoch 283 loss_pde:0.00119611, loss_ib:0.02044615
# epoch 283: loss 0.205658
# epoch 284 loss_pde:0.00120366, loss_ib:0.02044350
# epoch 284: loss 0.205639
# epoch 285 loss_pde:0.00121127, loss_ib:0.02044086
# epoch 285: loss 0.205620
# epoch 286 loss_pde:0.00121894, loss_ib:0.02043823
# epoch 286: loss 0.205601
# epoch 287 loss_pde:0.00122666, loss_ib:0.02043560
# epoch 287: loss 0.205583
# epoch 288 loss_pde:0.00123445, loss_ib:0.02043297
# epoch 288: loss 0.205564
# epoch 289 loss_pde:0.00124229, loss_ib:0.02043035
# epoch 289: loss 0.205546
# epoch 290 loss_pde:0.00125019, loss_ib:0.02042774
# epoch 290: loss 0.205528
# epoch 291 loss_pde:0.00125815, loss_ib:0.02042513
# epoch 291: loss 0.205509
# epoch 292 loss_pde:0.00126616, loss_ib:0.02042252
# epoch 292: loss 0.205491
# epoch 293 loss_pde:0.00127424, loss_ib:0.02041992
# epoch 293: loss 0.205473
# epoch 294 loss_pde:0.00128237, loss_ib:0.02041733
# epoch 294: loss 0.205456
# epoch 295 loss_pde:0.00129056, loss_ib:0.02041473
# epoch 295: loss 0.205438
# epoch 296 loss_pde:0.00129880, loss_ib:0.02041215
# epoch 296: loss 0.205420
# epoch 297 loss_pde:0.00130710, loss_ib:0.02040957
# epoch 297: loss 0.205403
# epoch 298 loss_pde:0.00131546, loss_ib:0.02040699
# epoch 298: loss 0.205385
# epoch 299 loss_pde:0.00132387, loss_ib:0.02040442
# epoch 299: loss 0.205368
# epoch 300 loss_pde:0.00133234, loss_ib:0.02040186
# epoch 300: loss 0.205351
# epoch 301 loss_pde:0.00134086, loss_ib:0.02039930
# epoch 301: loss 0.205334
# epoch 302 loss_pde:0.00134943, loss_ib:0.02039674
# epoch 302: loss 0.205317
# epoch 303 loss_pde:0.00135806, loss_ib:0.02039419
# epoch 303: loss 0.205300
# epoch 304 loss_pde:0.00136674, loss_ib:0.02039164
# epoch 304: loss 0.205283
# epoch 305 loss_pde:0.00137548, loss_ib:0.02038910
# epoch 305: loss 0.205266
# epoch 306 loss_pde:0.00138427, loss_ib:0.02038656
# epoch 306: loss 0.205250
# epoch 307 loss_pde:0.00139311, loss_ib:0.02038403
# epoch 307: loss 0.205233
# epoch 308 loss_pde:0.00140200, loss_ib:0.02038151
# epoch 308: loss 0.205217
# epoch 309 loss_pde:0.00141095, loss_ib:0.02037898
# epoch 309: loss 0.205201
# epoch 310 loss_pde:0.00141994, loss_ib:0.02037647
# epoch 310: loss 0.205185
# epoch 311 loss_pde:0.00142899, loss_ib:0.02037396
# epoch 311: loss 0.205169
# epoch 312 loss_pde:0.00143809, loss_ib:0.02037146
# epoch 312: loss 0.205153
# epoch 313 loss_pde:0.00144724, loss_ib:0.02036895
# epoch 313: loss 0.205137
# epoch 314 loss_pde:0.00145644, loss_ib:0.02036646
# epoch 314: loss 0.205121
# epoch 315 loss_pde:0.00146569, loss_ib:0.02036397
# epoch 315: loss 0.205105
# epoch 316 loss_pde:0.00147499, loss_ib:0.02036148
# epoch 316: loss 0.205090
# epoch 317 loss_pde:0.00148434, loss_ib:0.02035900
# epoch 317: loss 0.205074
# epoch 318 loss_pde:0.00149374, loss_ib:0.02035653
# epoch 318: loss 0.205059
# epoch 319 loss_pde:0.00150318, loss_ib:0.02035406
# epoch 319: loss 0.205044
# epoch 320 loss_pde:0.00151267, loss_ib:0.02035159
# epoch 320: loss 0.205029
# epoch 321 loss_pde:0.00152221, loss_ib:0.02034914
# epoch 321: loss 0.205014
# epoch 322 loss_pde:0.00153180, loss_ib:0.02034668
# epoch 322: loss 0.204999
# epoch 323 loss_pde:0.00154143, loss_ib:0.02034424
# epoch 323: loss 0.204984
# epoch 324 loss_pde:0.00155110, loss_ib:0.02034180
# epoch 324: loss 0.204969
# epoch 325 loss_pde:0.00156082, loss_ib:0.02033936
# epoch 325: loss 0.204954
# epoch 326 loss_pde:0.00157059, loss_ib:0.02033693
# epoch 326: loss 0.204940
# epoch 327 loss_pde:0.00158040, loss_ib:0.02033451
# epoch 327: loss 0.204925
# epoch 328 loss_pde:0.00159025, loss_ib:0.02033209
# epoch 328: loss 0.204911
# epoch 329 loss_pde:0.00160014, loss_ib:0.02032967
# epoch 329: loss 0.204897
# epoch 330 loss_pde:0.00161008, loss_ib:0.02032727
# epoch 330: loss 0.204883
# epoch 331 loss_pde:0.00162006, loss_ib:0.02032487
# epoch 331: loss 0.204869
# epoch 332 loss_pde:0.00163007, loss_ib:0.02032247
# epoch 332: loss 0.204855
# epoch 333 loss_pde:0.00164013, loss_ib:0.02032008
# epoch 333: loss 0.204841
# epoch 334 loss_pde:0.00165023, loss_ib:0.02031770
# epoch 334: loss 0.204827
# epoch 335 loss_pde:0.00166036, loss_ib:0.02031532
# epoch 335: loss 0.204814
# epoch 336 loss_pde:0.00167054, loss_ib:0.02031296
# epoch 336: loss 0.204800
# epoch 337 loss_pde:0.00168075, loss_ib:0.02031059
# epoch 337: loss 0.204787
# epoch 338 loss_pde:0.00169100, loss_ib:0.02030823
# epoch 338: loss 0.204773
# epoch 339 loss_pde:0.00170128, loss_ib:0.02030588
# epoch 339: loss 0.204760
# epoch 340 loss_pde:0.00171160, loss_ib:0.02030354
# epoch 340: loss 0.204747
# epoch 341 loss_pde:0.00172195, loss_ib:0.02030120
# epoch 341: loss 0.204734
# epoch 342 loss_pde:0.00173234, loss_ib:0.02029887
# epoch 342: loss 0.204721
# epoch 343 loss_pde:0.00174275, loss_ib:0.02029654
# epoch 343: loss 0.204708
# epoch 344 loss_pde:0.00175320, loss_ib:0.02029423
# epoch 344: loss 0.204695
# epoch 345 loss_pde:0.00176368, loss_ib:0.02029192
# epoch 345: loss 0.204683
# epoch 346 loss_pde:0.00177419, loss_ib:0.02028961
# epoch 346: loss 0.204670
# epoch 347 loss_pde:0.00178473, loss_ib:0.02028731
# epoch 347: loss 0.204658
# epoch 348 loss_pde:0.00179530, loss_ib:0.02028502
# epoch 348: loss 0.204646
# epoch 349 loss_pde:0.00180590, loss_ib:0.02028274
# epoch 349: loss 0.204633
# epoch 350 loss_pde:0.00181652, loss_ib:0.02028046
# epoch 350: loss 0.204621
# epoch 351 loss_pde:0.00182717, loss_ib:0.02027819
# epoch 351: loss 0.204609
# epoch 352 loss_pde:0.00183784, loss_ib:0.02027593
# epoch 352: loss 0.204597
# epoch 353 loss_pde:0.00184854, loss_ib:0.02027368
# epoch 353: loss 0.204585
# epoch 354 loss_pde:0.00185926, loss_ib:0.02027144
# epoch 354: loss 0.204574
# epoch 355 loss_pde:0.00187000, loss_ib:0.02026920
# epoch 355: loss 0.204562
# epoch 356 loss_pde:0.00188076, loss_ib:0.02026696
# epoch 356: loss 0.204550
# epoch 357 loss_pde:0.00189154, loss_ib:0.02026474
# epoch 357: loss 0.204539
# epoch 358 loss_pde:0.00190234, loss_ib:0.02026253
# epoch 358: loss 0.204528
# epoch 359 loss_pde:0.00191316, loss_ib:0.02026032
# epoch 359: loss 0.204516
# epoch 360 loss_pde:0.00192400, loss_ib:0.02025812
# epoch 360: loss 0.204505
# epoch 361 loss_pde:0.00193485, loss_ib:0.02025593
# epoch 361: loss 0.204494
# epoch 362 loss_pde:0.00194571, loss_ib:0.02025374
# epoch 362: loss 0.204483
# epoch 363 loss_pde:0.00195659, loss_ib:0.02025157
# epoch 363: loss 0.204472
# epoch 364 loss_pde:0.00196748, loss_ib:0.02024940
# epoch 364: loss 0.204461
# epoch 365 loss_pde:0.00197838, loss_ib:0.02024724
# epoch 365: loss 0.204451
# epoch 366 loss_pde:0.00198930, loss_ib:0.02024509
# epoch 366: loss 0.204440
# epoch 367 loss_pde:0.00200022, loss_ib:0.02024295
# epoch 367: loss 0.204430
# epoch 368 loss_pde:0.00201115, loss_ib:0.02024081
# epoch 368: loss 0.204419
# epoch 369 loss_pde:0.00202209, loss_ib:0.02023869
# epoch 369: loss 0.204409
# epoch 370 loss_pde:0.00203303, loss_ib:0.02023657
# epoch 370: loss 0.204399
# epoch 371 loss_pde:0.00204398, loss_ib:0.02023447
# epoch 371: loss 0.204389
# epoch 372 loss_pde:0.00205493, loss_ib:0.02023237
# epoch 372: loss 0.204379
# epoch 373 loss_pde:0.00206589, loss_ib:0.02023028
# epoch 373: loss 0.204369
# epoch 374 loss_pde:0.00207684, loss_ib:0.02022820
# epoch 374: loss 0.204359
# epoch 375 loss_pde:0.00208780, loss_ib:0.02022612
# epoch 375: loss 0.204349
# epoch 376 loss_pde:0.00209875, loss_ib:0.02022406
# epoch 376: loss 0.204339
# epoch 377 loss_pde:0.00210970, loss_ib:0.02022201
# epoch 377: loss 0.204330
# epoch 378 loss_pde:0.00212065, loss_ib:0.02021996
# epoch 378: loss 0.204320
# epoch 379 loss_pde:0.00213160, loss_ib:0.02021793
# epoch 379: loss 0.204311
# epoch 380 loss_pde:0.00214254, loss_ib:0.02021590
# epoch 380: loss 0.204302
# epoch 381 loss_pde:0.00215347, loss_ib:0.02021389
# epoch 381: loss 0.204292
# epoch 382 loss_pde:0.00216439, loss_ib:0.02021188
# epoch 382: loss 0.204283
# epoch 383 loss_pde:0.00217531, loss_ib:0.02020988
# epoch 383: loss 0.204274
# epoch 384 loss_pde:0.00218621, loss_ib:0.02020790
# epoch 384: loss 0.204265
# epoch 385 loss_pde:0.00219711, loss_ib:0.02020592
# epoch 385: loss 0.204256
# epoch 386 loss_pde:0.00220799, loss_ib:0.02020395
# epoch 386: loss 0.204248
# epoch 387 loss_pde:0.00221886, loss_ib:0.02020199
# epoch 387: loss 0.204239
# epoch 388 loss_pde:0.00222971, loss_ib:0.02020004
# epoch 388: loss 0.204230
# epoch 389 loss_pde:0.00224055, loss_ib:0.02019811
# epoch 389: loss 0.204222
# epoch 390 loss_pde:0.00225136, loss_ib:0.02019618
# epoch 390: loss 0.204213
# epoch 391 loss_pde:0.00226216, loss_ib:0.02019426
# epoch 391: loss 0.204205
# epoch 392 loss_pde:0.00227294, loss_ib:0.02019235
# epoch 392: loss 0.204196
# epoch 393 loss_pde:0.00228370, loss_ib:0.02019046
# epoch 393: loss 0.204188
# epoch 394 loss_pde:0.00229444, loss_ib:0.02018857
# epoch 394: loss 0.204180
# epoch 395 loss_pde:0.00230516, loss_ib:0.02018669
# epoch 395: loss 0.204172
# epoch 396 loss_pde:0.00231585, loss_ib:0.02018482
# epoch 396: loss 0.204164
# epoch 397 loss_pde:0.00232651, loss_ib:0.02018297
# epoch 397: loss 0.204156
# epoch 398 loss_pde:0.00233715, loss_ib:0.02018112
# epoch 398: loss 0.204148
# epoch 399 loss_pde:0.00234776, loss_ib:0.02017928
# epoch 399: loss 0.204141
# epoch 400 loss_pde:0.00235835, loss_ib:0.02017746
# epoch 400: loss 0.204133
# epoch 401 loss_pde:0.00236890, loss_ib:0.02017565
# epoch 401: loss 0.204125
# epoch 402 loss_pde:0.00237942, loss_ib:0.02017384
# epoch 402: loss 0.204118
# epoch 403 loss_pde:0.00238991, loss_ib:0.02017205
# epoch 403: loss 0.204110
# epoch 404 loss_pde:0.00240037, loss_ib:0.02017026
# epoch 404: loss 0.204103
# epoch 405 loss_pde:0.00241079, loss_ib:0.02016849
# epoch 405: loss 0.204096
# epoch 406 loss_pde:0.00242118, loss_ib:0.02016673
# epoch 406: loss 0.204089
# epoch 407 loss_pde:0.00243153, loss_ib:0.02016498
# epoch 407: loss 0.204081
# epoch 408 loss_pde:0.00244185, loss_ib:0.02016324
# epoch 408: loss 0.204074
# epoch 409 loss_pde:0.00245212, loss_ib:0.02016152
# epoch 409: loss 0.204067
# epoch 410 loss_pde:0.00246236, loss_ib:0.02015980
# epoch 410: loss 0.204060
# epoch 411 loss_pde:0.00247256, loss_ib:0.02015809
# epoch 411: loss 0.204053
# epoch 412 loss_pde:0.00248272, loss_ib:0.02015639
# epoch 412: loss 0.204047
# epoch 413 loss_pde:0.00249283, loss_ib:0.02015471
# epoch 413: loss 0.204040
# epoch 414 loss_pde:0.00250290, loss_ib:0.02015303
# epoch 414: loss 0.204033
# epoch 415 loss_pde:0.00251293, loss_ib:0.02015137
# epoch 415: loss 0.204027
# epoch 416 loss_pde:0.00252291, loss_ib:0.02014972
# epoch 416: loss 0.204020
# epoch 417 loss_pde:0.00253285, loss_ib:0.02014808
# epoch 417: loss 0.204014
# epoch 418 loss_pde:0.00254274, loss_ib:0.02014645
# epoch 418: loss 0.204007
# epoch 419 loss_pde:0.00255258, loss_ib:0.02014483
# epoch 419: loss 0.204001
# epoch 420 loss_pde:0.00256238, loss_ib:0.02014322
# epoch 420: loss 0.203995
# epoch 421 loss_pde:0.00257212, loss_ib:0.02014163
# epoch 421: loss 0.203988
# epoch 422 loss_pde:0.00258182, loss_ib:0.02014004
# epoch 422: loss 0.203982
# epoch 423 loss_pde:0.00259146, loss_ib:0.02013847
# epoch 423: loss 0.203976
# epoch 424 loss_pde:0.00260106, loss_ib:0.02013691
# epoch 424: loss 0.203970
# epoch 425 loss_pde:0.00261060, loss_ib:0.02013535
# epoch 425: loss 0.203964
# epoch 426 loss_pde:0.00262009, loss_ib:0.02013381
# epoch 426: loss 0.203958
# epoch 427 loss_pde:0.00262952, loss_ib:0.02013228
# epoch 427: loss 0.203952
# epoch 428 loss_pde:0.00263890, loss_ib:0.02013076
# epoch 428: loss 0.203947
# epoch 429 loss_pde:0.00264823, loss_ib:0.02012925
# epoch 429: loss 0.203941
# epoch 430 loss_pde:0.00265750, loss_ib:0.02012776
# epoch 430: loss 0.203935
# epoch 431 loss_pde:0.00266671, loss_ib:0.02012627
# epoch 431: loss 0.203929
# epoch 432 loss_pde:0.00267587, loss_ib:0.02012479
# epoch 432: loss 0.203924
# epoch 433 loss_pde:0.00268496, loss_ib:0.02012333
# epoch 433: loss 0.203918
# epoch 434 loss_pde:0.00269400, loss_ib:0.02012188
# epoch 434: loss 0.203913
# epoch 435 loss_pde:0.00270299, loss_ib:0.02012044
# epoch 435: loss 0.203907
# epoch 436 loss_pde:0.00271191, loss_ib:0.02011901
# epoch 436: loss 0.203902
# epoch 437 loss_pde:0.00272077, loss_ib:0.02011759
# epoch 437: loss 0.203897
# epoch 438 loss_pde:0.00272957, loss_ib:0.02011618
# epoch 438: loss 0.203891
# epoch 439 loss_pde:0.00273831, loss_ib:0.02011478
# epoch 439: loss 0.203886
# epoch 440 loss_pde:0.00274699, loss_ib:0.02011340
# epoch 440: loss 0.203881
# epoch 441 loss_pde:0.00275561, loss_ib:0.02011202
# epoch 441: loss 0.203876
# epoch 442 loss_pde:0.00276416, loss_ib:0.02011066
# epoch 442: loss 0.203871
# epoch 443 loss_pde:0.00277265, loss_ib:0.02010930
# epoch 443: loss 0.203866
# epoch 444 loss_pde:0.00278108, loss_ib:0.02010796
# epoch 444: loss 0.203861
# epoch 445 loss_pde:0.00278945, loss_ib:0.02010662
# epoch 445: loss 0.203856
# epoch 446 loss_pde:0.00279775, loss_ib:0.02010530
# epoch 446: loss 0.203851
# epoch 447 loss_pde:0.00280599, loss_ib:0.02010399
# epoch 447: loss 0.203846
# epoch 448 loss_pde:0.00281416, loss_ib:0.02010269
# epoch 448: loss 0.203841
# epoch 449 loss_pde:0.00282227, loss_ib:0.02010140
# epoch 449: loss 0.203836
# epoch 450 loss_pde:0.00283031, loss_ib:0.02010012
# epoch 450: loss 0.203832
# epoch 451 loss_pde:0.00283829, loss_ib:0.02009885
# epoch 451: loss 0.203827
# epoch 452 loss_pde:0.00284620, loss_ib:0.02009760
# epoch 452: loss 0.203822
# epoch 453 loss_pde:0.00285404, loss_ib:0.02009635
# epoch 453: loss 0.203818
# epoch 454 loss_pde:0.00286182, loss_ib:0.02009511
# epoch 454: loss 0.203813
# epoch 455 loss_pde:0.00286954, loss_ib:0.02009388
# epoch 455: loss 0.203808
# epoch 456 loss_pde:0.00287718, loss_ib:0.02009267
# epoch 456: loss 0.203804
# epoch 457 loss_pde:0.00288476, loss_ib:0.02009146
# epoch 457: loss 0.203799
# epoch 458 loss_pde:0.00289228, loss_ib:0.02009027
# epoch 458: loss 0.203795
# epoch 459 loss_pde:0.00289973, loss_ib:0.02008908
# epoch 459: loss 0.203790
# epoch 460 loss_pde:0.00290711, loss_ib:0.02008790
# epoch 460: loss 0.203786
# epoch 461 loss_pde:0.00291442, loss_ib:0.02008673
# epoch 461: loss 0.203782
# epoch 462 loss_pde:0.00292167, loss_ib:0.02008558
# epoch 462: loss 0.203777
# epoch 463 loss_pde:0.00292885, loss_ib:0.02008443
# epoch 463: loss 0.203773
# epoch 464 loss_pde:0.00293596, loss_ib:0.02008330
# epoch 464: loss 0.203769
# epoch 465 loss_pde:0.00294300, loss_ib:0.02008217
# epoch 465: loss 0.203765
# epoch 466 loss_pde:0.00294998, loss_ib:0.02008106
# epoch 466: loss 0.203761
# epoch 467 loss_pde:0.00295689, loss_ib:0.02007995
# epoch 467: loss 0.203756
# epoch 468 loss_pde:0.00296374, loss_ib:0.02007885
# epoch 468: loss 0.203752
# epoch 469 loss_pde:0.00297052, loss_ib:0.02007777
# epoch 469: loss 0.203748
# epoch 470 loss_pde:0.00297723, loss_ib:0.02007669
# epoch 470: loss 0.203744
# epoch 471 loss_pde:0.00298387, loss_ib:0.02007562
# epoch 471: loss 0.203740
# epoch 472 loss_pde:0.00299045, loss_ib:0.02007456
# epoch 472: loss 0.203736
# epoch 473 loss_pde:0.00299696, loss_ib:0.02007351
# epoch 473: loss 0.203732
# epoch 474 loss_pde:0.00300340, loss_ib:0.02007248
# epoch 474: loss 0.203728
# epoch 475 loss_pde:0.00300978, loss_ib:0.02007144
# epoch 475: loss 0.203724
# epoch 476 loss_pde:0.00301609, loss_ib:0.02007042
# epoch 476: loss 0.203720
# epoch 477 loss_pde:0.00302234, loss_ib:0.02006941
# epoch 477: loss 0.203716
# epoch 478 loss_pde:0.00302851, loss_ib:0.02006841
# epoch 478: loss 0.203713
# epoch 479 loss_pde:0.00303463, loss_ib:0.02006741
# epoch 479: loss 0.203709
# epoch 480 loss_pde:0.00304068, loss_ib:0.02006642
# epoch 480: loss 0.203705
# epoch 481 loss_pde:0.00304666, loss_ib:0.02006545
# epoch 481: loss 0.203701
# epoch 482 loss_pde:0.00305258, loss_ib:0.02006448
# epoch 482: loss 0.203697
# epoch 483 loss_pde:0.00305843, loss_ib:0.02006352
# epoch 483: loss 0.203694
# epoch 484 loss_pde:0.00306423, loss_ib:0.02006257
# epoch 484: loss 0.203690
# epoch 485 loss_pde:0.00306995, loss_ib:0.02006163
# epoch 485: loss 0.203686
# epoch 486 loss_pde:0.00307561, loss_ib:0.02006070
# epoch 486: loss 0.203683
# epoch 487 loss_pde:0.00308121, loss_ib:0.02005977
# epoch 487: loss 0.203679
# epoch 488 loss_pde:0.00308675, loss_ib:0.02005885
# epoch 488: loss 0.203675
# epoch 489 loss_pde:0.00309222, loss_ib:0.02005794
# epoch 489: loss 0.203672
# epoch 490 loss_pde:0.00309763, loss_ib:0.02005704
# epoch 490: loss 0.203668
# epoch 491 loss_pde:0.00310298, loss_ib:0.02005615
# epoch 491: loss 0.203664
# epoch 492 loss_pde:0.00310826, loss_ib:0.02005527
# epoch 492: loss 0.203661
# epoch 493 loss_pde:0.00311349, loss_ib:0.02005439
# epoch 493: loss 0.203657
# epoch 494 loss_pde:0.00311865, loss_ib:0.02005352
# epoch 494: loss 0.203654
# epoch 495 loss_pde:0.00312375, loss_ib:0.02005266
# epoch 495: loss 0.203650
# epoch 496 loss_pde:0.00312880, loss_ib:0.02005181
# epoch 496: loss 0.203647
# epoch 497 loss_pde:0.00313378, loss_ib:0.02005096
# epoch 497: loss 0.203643
# epoch 498 loss_pde:0.00313870, loss_ib:0.02005012
# epoch 498: loss 0.203640
# epoch 499 loss_pde:0.00314356, loss_ib:0.02004929
# epoch 499: loss 0.203636
# epoch 500 loss_pde:0.00314837, loss_ib:0.02004847
# epoch 500: loss 0.203633
# epoch 501 loss_pde:0.00315312, loss_ib:0.02004765
# epoch 501: loss 0.203630
# epoch 502 loss_pde:0.00315780, loss_ib:0.02004685
# epoch 502: loss 0.203626
# epoch 503 loss_pde:0.00316243, loss_ib:0.02004605
# epoch 503: loss 0.203623
# epoch 504 loss_pde:0.00316701, loss_ib:0.02004525
# epoch 504: loss 0.203620
# epoch 505 loss_pde:0.00317152, loss_ib:0.02004446
# epoch 505: loss 0.203616
# epoch 506 loss_pde:0.00317598, loss_ib:0.02004368
# epoch 506: loss 0.203613
# epoch 507 loss_pde:0.00318039, loss_ib:0.02004291
# epoch 507: loss 0.203609
# epoch 508 loss_pde:0.00318474, loss_ib:0.02004215
# epoch 508: loss 0.203606
# epoch 509 loss_pde:0.00318903, loss_ib:0.02004139
# epoch 509: loss 0.203603
# epoch 510 loss_pde:0.00319327, loss_ib:0.02004063
# epoch 510: loss 0.203600
# epoch 511 loss_pde:0.00319746, loss_ib:0.02003989
# epoch 511: loss 0.203596
# epoch 512 loss_pde:0.00320159, loss_ib:0.02003915
# epoch 512: loss 0.203593
# epoch 513 loss_pde:0.00320567, loss_ib:0.02003842
# epoch 513: loss 0.203590
# epoch 514 loss_pde:0.00320970, loss_ib:0.02003769
# epoch 514: loss 0.203587
# epoch 515 loss_pde:0.00321367, loss_ib:0.02003697
# epoch 515: loss 0.203583
# epoch 516 loss_pde:0.00321760, loss_ib:0.02003626
# epoch 516: loss 0.203580
# epoch 517 loss_pde:0.00322147, loss_ib:0.02003555
# epoch 517: loss 0.203577
# epoch 518 loss_pde:0.00322529, loss_ib:0.02003485
# epoch 518: loss 0.203574
# epoch 519 loss_pde:0.00322906, loss_ib:0.02003415
# epoch 519: loss 0.203571
# epoch 520 loss_pde:0.00323279, loss_ib:0.02003346
# epoch 520: loss 0.203567
# epoch 521 loss_pde:0.00323646, loss_ib:0.02003278
# epoch 521: loss 0.203564
# epoch 522 loss_pde:0.00324009, loss_ib:0.02003210
# epoch 522: loss 0.203561
# epoch 523 loss_pde:0.00324366, loss_ib:0.02003143
# epoch 523: loss 0.203558
# epoch 524 loss_pde:0.00324719, loss_ib:0.02003076
# epoch 524: loss 0.203555
# epoch 525 loss_pde:0.00325067, loss_ib:0.02003010
# epoch 525: loss 0.203552
# epoch 526 loss_pde:0.00325411, loss_ib:0.02002945
# epoch 526: loss 0.203549
# epoch 527 loss_pde:0.00325750, loss_ib:0.02002880
# epoch 527: loss 0.203545
# epoch 528 loss_pde:0.00326084, loss_ib:0.02002815
# epoch 528: loss 0.203542
# epoch 529 loss_pde:0.00326414, loss_ib:0.02002751
# epoch 529: loss 0.203539
# epoch 530 loss_pde:0.00326739, loss_ib:0.02002688
# epoch 530: loss 0.203536
# epoch 531 loss_pde:0.00327060, loss_ib:0.02002625
# epoch 531: loss 0.203533
# epoch 532 loss_pde:0.00327377, loss_ib:0.02002563
# epoch 532: loss 0.203530
# epoch 533 loss_pde:0.00327689, loss_ib:0.02002501
# epoch 533: loss 0.203527
# epoch 534 loss_pde:0.00327997, loss_ib:0.02002440
# epoch 534: loss 0.203524
# epoch 535 loss_pde:0.00328300, loss_ib:0.02002379
# epoch 535: loss 0.203521
# epoch 536 loss_pde:0.00328600, loss_ib:0.02002319
# epoch 536: loss 0.203518
# epoch 537 loss_pde:0.00328895, loss_ib:0.02002259
# epoch 537: loss 0.203515
# epoch 538 loss_pde:0.00329187, loss_ib:0.02002200
# epoch 538: loss 0.203512
# epoch 539 loss_pde:0.00329474, loss_ib:0.02002141
# epoch 539: loss 0.203509
# epoch 540 loss_pde:0.00329757, loss_ib:0.02002082
# epoch 540: loss 0.203506
# epoch 541 loss_pde:0.00330037, loss_ib:0.02002024
# epoch 541: loss 0.203503
# epoch 542 loss_pde:0.00330312, loss_ib:0.02001967
# epoch 542: loss 0.203500
# epoch 543 loss_pde:0.00330584, loss_ib:0.02001910
# epoch 543: loss 0.203497
# epoch 544 loss_pde:0.00330852, loss_ib:0.02001853
# epoch 544: loss 0.203494
# epoch 545 loss_pde:0.00331116, loss_ib:0.02001797
# epoch 545: loss 0.203491
# epoch 546 loss_pde:0.00331377, loss_ib:0.02001741
# epoch 546: loss 0.203488
# epoch 547 loss_pde:0.00331634, loss_ib:0.02001686
# epoch 547: loss 0.203485
# epoch 548 loss_pde:0.00331887, loss_ib:0.02001631
# epoch 548: loss 0.203482
# epoch 549 loss_pde:0.00332137, loss_ib:0.02001576
# epoch 549: loss 0.203479
# epoch 550 loss_pde:0.00332383, loss_ib:0.02001522
# epoch 550: loss 0.203476
# epoch 551 loss_pde:0.00332626, loss_ib:0.02001469
# epoch 551: loss 0.203473
# epoch 552 loss_pde:0.00332865, loss_ib:0.02001415
# epoch 552: loss 0.203470
# epoch 553 loss_pde:0.00333101, loss_ib:0.02001362
# epoch 553: loss 0.203467
# epoch 554 loss_pde:0.00333333, loss_ib:0.02001310
# epoch 554: loss 0.203464
# epoch 555 loss_pde:0.00333563, loss_ib:0.02001257
# epoch 555: loss 0.203461
# epoch 556 loss_pde:0.00333789, loss_ib:0.02001206
# epoch 556: loss 0.203458
# epoch 557 loss_pde:0.00334012, loss_ib:0.02001155
# epoch 557: loss 0.203456
# epoch 558 loss_pde:0.00334232, loss_ib:0.02001103
# epoch 558: loss 0.203453
# epoch 559 loss_pde:0.00334448, loss_ib:0.02001053
# epoch 559: loss 0.203450
# epoch 560 loss_pde:0.00334662, loss_ib:0.02001002
# epoch 560: loss 0.203447
# epoch 561 loss_pde:0.00334873, loss_ib:0.02000952
# epoch 561: loss 0.203444
# epoch 562 loss_pde:0.00335080, loss_ib:0.02000903
# epoch 562: loss 0.203441
# epoch 563 loss_pde:0.00335285, loss_ib:0.02000853
# epoch 563: loss 0.203438
# epoch 564 loss_pde:0.00335487, loss_ib:0.02000804
# epoch 564: loss 0.203435
# epoch 565 loss_pde:0.00335686, loss_ib:0.02000755
# epoch 565: loss 0.203432
# epoch 566 loss_pde:0.00335882, loss_ib:0.02000707
# epoch 566: loss 0.203430
# epoch 567 loss_pde:0.00336075, loss_ib:0.02000659
# epoch 567: loss 0.203427
# epoch 568 loss_pde:0.00336266, loss_ib:0.02000611
# epoch 568: loss 0.203424
# epoch 569 loss_pde:0.00336454, loss_ib:0.02000564
# epoch 569: loss 0.203421
# epoch 570 loss_pde:0.00336640, loss_ib:0.02000517
# epoch 570: loss 0.203418
# epoch 571 loss_pde:0.00336822, loss_ib:0.02000470
# epoch 571: loss 0.203415
# epoch 572 loss_pde:0.00337003, loss_ib:0.02000423
# epoch 572: loss 0.203412
# epoch 573 loss_pde:0.00337180, loss_ib:0.02000377
# epoch 573: loss 0.203410
# epoch 574 loss_pde:0.00337355, loss_ib:0.02000331
# epoch 574: loss 0.203407
# epoch 575 loss_pde:0.00337528, loss_ib:0.02000286
# epoch 575: loss 0.203404
# epoch 576 loss_pde:0.00337698, loss_ib:0.02000240
# epoch 576: loss 0.203401
# epoch 577 loss_pde:0.00337866, loss_ib:0.02000195
# epoch 577: loss 0.203398
# epoch 578 loss_pde:0.00338032, loss_ib:0.02000150
# epoch 578: loss 0.203395
# epoch 579 loss_pde:0.00338195, loss_ib:0.02000105
# epoch 579: loss 0.203392
# epoch 580 loss_pde:0.00338356, loss_ib:0.02000061
# epoch 580: loss 0.203390
# epoch 581 loss_pde:0.00338515, loss_ib:0.02000017
# epoch 581: loss 0.203387
# epoch 582 loss_pde:0.00338671, loss_ib:0.01999973
# epoch 582: loss 0.203384
# epoch 583 loss_pde:0.00338826, loss_ib:0.01999930
# epoch 583: loss 0.203381
# epoch 584 loss_pde:0.00338978, loss_ib:0.01999887
# epoch 584: loss 0.203378
# epoch 585 loss_pde:0.00339128, loss_ib:0.01999843
# epoch 585: loss 0.203376
# epoch 586 loss_pde:0.00339276, loss_ib:0.01999800
# epoch 586: loss 0.203373
# epoch 587 loss_pde:0.00339422, loss_ib:0.01999758
# epoch 587: loss 0.203370
# epoch 588 loss_pde:0.00339566, loss_ib:0.01999715
# epoch 588: loss 0.203367
# epoch 589 loss_pde:0.00339708, loss_ib:0.01999673
# epoch 589: loss 0.203364
# epoch 590 loss_pde:0.00339849, loss_ib:0.01999631
# epoch 590: loss 0.203362
# epoch 591 loss_pde:0.00339987, loss_ib:0.01999589
# epoch 591: loss 0.203359
# epoch 592 loss_pde:0.00340123, loss_ib:0.01999548
# epoch 592: loss 0.203356
# epoch 593 loss_pde:0.00340258, loss_ib:0.01999506
# epoch 593: loss 0.203353
# epoch 594 loss_pde:0.00340390, loss_ib:0.01999465
# epoch 594: loss 0.203350
# epoch 595 loss_pde:0.00340521, loss_ib:0.01999425
# epoch 595: loss 0.203348
# epoch 596 loss_pde:0.00340650, loss_ib:0.01999384
# epoch 596: loss 0.203345
# epoch 597 loss_pde:0.00340778, loss_ib:0.01999343
# epoch 597: loss 0.203342
# epoch 598 loss_pde:0.00340904, loss_ib:0.01999303
# epoch 598: loss 0.203339
# epoch 599 loss_pde:0.00341028, loss_ib:0.01999263
# epoch 599: loss 0.203337
# epoch 600 loss_pde:0.00341150, loss_ib:0.01999223
# epoch 600: loss 0.203334
# epoch 601 loss_pde:0.00341271, loss_ib:0.01999183
# epoch 601: loss 0.203331
# epoch 602 loss_pde:0.00341390, loss_ib:0.01999144
# epoch 602: loss 0.203328
# epoch 603 loss_pde:0.00341508, loss_ib:0.01999104
# epoch 603: loss 0.203325
# epoch 604 loss_pde:0.00341624, loss_ib:0.01999065
# epoch 604: loss 0.203323
# epoch 605 loss_pde:0.00341738, loss_ib:0.01999026
# epoch 605: loss 0.203320
# epoch 606 loss_pde:0.00341851, loss_ib:0.01998987
# epoch 606: loss 0.203317
# epoch 607 loss_pde:0.00341963, loss_ib:0.01998948
# epoch 607: loss 0.203314
# epoch 608 loss_pde:0.00342073, loss_ib:0.01998910
# epoch 608: loss 0.203312
# epoch 609 loss_pde:0.00342182, loss_ib:0.01998872
# epoch 609: loss 0.203309
# epoch 610 loss_pde:0.00342290, loss_ib:0.01998833
# epoch 610: loss 0.203306
# epoch 611 loss_pde:0.00342396, loss_ib:0.01998795
# epoch 611: loss 0.203303
# epoch 612 loss_pde:0.00342501, loss_ib:0.01998757
# epoch 612: loss 0.203301
# epoch 613 loss_pde:0.00342604, loss_ib:0.01998719
# epoch 613: loss 0.203298
# epoch 614 loss_pde:0.00342706, loss_ib:0.01998682
# epoch 614: loss 0.203295
# epoch 615 loss_pde:0.00342807, loss_ib:0.01998644
# epoch 615: loss 0.203293
# epoch 616 loss_pde:0.00342906, loss_ib:0.01998607
# epoch 616: loss 0.203290
# epoch 617 loss_pde:0.00343005, loss_ib:0.01998570
# epoch 617: loss 0.203287
# epoch 618 loss_pde:0.00343102, loss_ib:0.01998533
# epoch 618: loss 0.203284
# epoch 619 loss_pde:0.00343198, loss_ib:0.01998496
# epoch 619: loss 0.203282
# epoch 620 loss_pde:0.00343293, loss_ib:0.01998459
# epoch 620: loss 0.203279
# epoch 621 loss_pde:0.00343387, loss_ib:0.01998422
# epoch 621: loss 0.203276
# epoch 622 loss_pde:0.00343480, loss_ib:0.01998386
# epoch 622: loss 0.203273
# epoch 623 loss_pde:0.00343571, loss_ib:0.01998349
# epoch 623: loss 0.203271
# epoch 624 loss_pde:0.00343662, loss_ib:0.01998313
# epoch 624: loss 0.203268
# epoch 625 loss_pde:0.00343751, loss_ib:0.01998277
# epoch 625: loss 0.203265
# epoch 626 loss_pde:0.00343840, loss_ib:0.01998241
# epoch 626: loss 0.203263
# epoch 627 loss_pde:0.00343927, loss_ib:0.01998205
# epoch 627: loss 0.203260
# epoch 628 loss_pde:0.00344013, loss_ib:0.01998170
# epoch 628: loss 0.203257
# epoch 629 loss_pde:0.00344099, loss_ib:0.01998134
# epoch 629: loss 0.203254
# epoch 630 loss_pde:0.00344183, loss_ib:0.01998098
# epoch 630: loss 0.203252
# epoch 631 loss_pde:0.00344267, loss_ib:0.01998063
# epoch 631: loss 0.203249
# epoch 632 loss_pde:0.00344349, loss_ib:0.01998027
# epoch 632: loss 0.203246
# epoch 633 loss_pde:0.00344431, loss_ib:0.01997992
# epoch 633: loss 0.203244
# epoch 634 loss_pde:0.00344512, loss_ib:0.01997957
# epoch 634: loss 0.203241
# epoch 635 loss_pde:0.00344592, loss_ib:0.01997922
# epoch 635: loss 0.203238
# epoch 636 loss_pde:0.00344671, loss_ib:0.01997887
# epoch 636: loss 0.203235
# epoch 637 loss_pde:0.00344749, loss_ib:0.01997853
# epoch 637: loss 0.203233
# epoch 638 loss_pde:0.00344826, loss_ib:0.01997818
# epoch 638: loss 0.203230
# epoch 639 loss_pde:0.00344903, loss_ib:0.01997783
# epoch 639: loss 0.203227
# epoch 640 loss_pde:0.00344979, loss_ib:0.01997748
# epoch 640: loss 0.203225
# epoch 641 loss_pde:0.00345054, loss_ib:0.01997714
# epoch 641: loss 0.203222
# epoch 642 loss_pde:0.00345128, loss_ib:0.01997680
# epoch 642: loss 0.203219
# epoch 643 loss_pde:0.00345202, loss_ib:0.01997645
# ...
# epoch 9794 loss_pde:0.01210837, loss_ib:0.00373121
# epoch 9794: loss 0.049421
# epoch 9795 loss_pde:0.01226162, loss_ib:0.00367911
# epoch 9795: loss 0.049053
# epoch 9796 loss_pde:0.01242401, loss_ib:0.00357449
# epoch 9796: loss 0.048169
# epoch 9797 loss_pde:0.01228938, loss_ib:0.00348045
# epoch 9797: loss 0.047094
# epoch 9798 loss_pde:0.01204345, loss_ib:0.00357563
# epoch 9798: loss 0.047800
# epoch 9799 loss_pde:0.01220998, loss_ib:0.00368968
# epoch 9799: loss 0.049107
# epoch 9800 loss_pde:0.01200873, loss_ib:0.00370199
# epoch 9800: loss 0.049029
# epoch 9801 loss_pde:0.01245946, loss_ib:0.00357648
# epoch 9801: loss 0.048224
# epoch 9802 loss_pde:0.01236762, loss_ib:0.00341247
# epoch 9802: loss 0.046492
# epoch 9803 loss_pde:0.01226504, loss_ib:0.00329950
# epoch 9803: loss 0.045260
# epoch 9804 loss_pde:0.01216719, loss_ib:0.00327229
# epoch 9804: loss 0.044890
# epoch 9805 loss_pde:0.01225439, loss_ib:0.00330360
# epoch 9805: loss 0.045290
# epoch 9806 loss_pde:0.01279895, loss_ib:0.00332732
# epoch 9806: loss 0.046072
# epoch 9807 loss_pde:0.01261626, loss_ib:0.00340902
# epoch 9807: loss 0.046707
# epoch 9808 loss_pde:0.01348544, loss_ib:0.00335032
# epoch 9808: loss 0.046989
# epoch 9809 loss_pde:0.01299961, loss_ib:0.00339560
# epoch 9809: loss 0.046956
# epoch 9810 loss_pde:0.01418237, loss_ib:0.00325645
# epoch 9810: loss 0.046747
# epoch 9811 loss_pde:0.01370182, loss_ib:0.00330476
# epoch 9811: loss 0.046749
# epoch 9812 loss_pde:0.01510946, loss_ib:0.00321978
# epoch 9812: loss 0.047307
# epoch 9813 loss_pde:0.01560673, loss_ib:0.00328703
# epoch 9813: loss 0.048477
# epoch 9814 loss_pde:0.01735689, loss_ib:0.00329142
# epoch 9814: loss 0.050271
# epoch 9815 loss_pde:0.01848039, loss_ib:0.00336625
# epoch 9815: loss 0.052143
# epoch 9816 loss_pde:0.02033522, loss_ib:0.00337748
# epoch 9816: loss 0.054110
# epoch 9817 loss_pde:0.02076645, loss_ib:0.00347699
# epoch 9817: loss 0.055536
# epoch 9818 loss_pde:0.02221656, loss_ib:0.00347375
# epoch 9818: loss 0.056954
# epoch 9819 loss_pde:0.02129577, loss_ib:0.00363820
# epoch 9819: loss 0.057678
# epoch 9820 loss_pde:0.02184551, loss_ib:0.00356749
# epoch 9820: loss 0.057520
# epoch 9821 loss_pde:0.01895113, loss_ib:0.00368137
# epoch 9821: loss 0.055765
# epoch 9822 loss_pde:0.01781332, loss_ib:0.00346024
# epoch 9822: loss 0.052416
# epoch 9823 loss_pde:0.01433125, loss_ib:0.00342506
# epoch 9823: loss 0.048582
# epoch 9824 loss_pde:0.01303340, loss_ib:0.00326897
# epoch 9824: loss 0.045723
# epoch 9825 loss_pde:0.01199784, loss_ib:0.00327969
# epoch 9825: loss 0.044795
# epoch 9826 loss_pde:0.01209693, loss_ib:0.00335643
# epoch 9826: loss 0.045661
# epoch 9827 loss_pde:0.01338520, loss_ib:0.00335487
# epoch 9827: loss 0.046934
# epoch 9828 loss_pde:0.01336508, loss_ib:0.00342458
# epoch 9828: loss 0.047611
# epoch 9829 loss_pde:0.01399853, loss_ib:0.00331558
# epoch 9829: loss 0.047154
# epoch 9830 loss_pde:0.01281564, loss_ib:0.00332496
# epoch 9830: loss 0.046065
# epoch 9831 loss_pde:0.01235414, loss_ib:0.00327581
# epoch 9831: loss 0.045112
# epoch 9832 loss_pde:0.01172250, loss_ib:0.00330508
# epoch 9832: loss 0.044773
# epoch 9833 loss_pde:0.01174272, loss_ib:0.00333075
# epoch 9833: loss 0.045050
# epoch 9834 loss_pde:0.01231054, loss_ib:0.00330464
# epoch 9834: loss 0.045357
# epoch 9835 loss_pde:0.01236005, loss_ib:0.00330721
# epoch 9835: loss 0.045432
# epoch 9836 loss_pde:0.01271921, loss_ib:0.00323200
# epoch 9836: loss 0.045039
# epoch 9837 loss_pde:0.01223686, loss_ib:0.00322105
# epoch 9837: loss 0.044447
# epoch 9838 loss_pde:0.01197688, loss_ib:0.00319814
# epoch 9838: loss 0.043958
# epoch 9839 loss_pde:0.01175145, loss_ib:0.00320721
# epoch 9839: loss 0.043824
# epoch 9840 loss_pde:0.01168429, loss_ib:0.00323767
# epoch 9840: loss 0.044061
# epoch 9841 loss_pde:0.01211237, loss_ib:0.00323316
# epoch 9841: loss 0.044444
# epoch 9842 loss_pde:0.01221342, loss_ib:0.00325325
# epoch 9842: loss 0.044746
# epoch 9843 loss_pde:0.01245550, loss_ib:0.00323042
# epoch 9843: loss 0.044760
# epoch 9844 loss_pde:0.01232122, loss_ib:0.00322333
# epoch 9844: loss 0.044555
# epoch 9845 loss_pde:0.01209907, loss_ib:0.00321502
# epoch 9845: loss 0.044249
# epoch 9846 loss_pde:0.01213963, loss_ib:0.00318999
# epoch 9846: loss 0.044040
# epoch 9847 loss_pde:0.01189886, loss_ib:0.00320896
# epoch 9847: loss 0.043988
# epoch 9848 loss_pde:0.01232326, loss_ib:0.00317525
# epoch 9848: loss 0.044076
# epoch 9849 loss_pde:0.01212242, loss_ib:0.00320843
# epoch 9849: loss 0.044207
# epoch 9850 loss_pde:0.01248846, loss_ib:0.00318070
# epoch 9850: loss 0.044295
# epoch 9851 loss_pde:0.01219386, loss_ib:0.00321009
# epoch 9851: loss 0.044295
# epoch 9852 loss_pde:0.01229487, loss_ib:0.00319417
# epoch 9852: loss 0.044237
# epoch 9853 loss_pde:0.01202202, loss_ib:0.00321603
# epoch 9853: loss 0.044182
# epoch 9854 loss_pde:0.01209940, loss_ib:0.00321200
# epoch 9854: loss 0.044219
# epoch 9855 loss_pde:0.01200566, loss_ib:0.00323958
# epoch 9855: loss 0.044401
# epoch 9856 loss_pde:0.01226448, loss_ib:0.00324781
# epoch 9856: loss 0.044743
# epoch 9857 loss_pde:0.01226128, loss_ib:0.00329901
# epoch 9857: loss 0.045251
# epoch 9858 loss_pde:0.01266296, loss_ib:0.00332274
# epoch 9858: loss 0.045890
# epoch 9859 loss_pde:0.01257824, loss_ib:0.00341214
# epoch 9859: loss 0.046700
# epoch 9860 loss_pde:0.01309917, loss_ib:0.00344268
# epoch 9860: loss 0.047526
# epoch 9861 loss_pde:0.01295148, loss_ib:0.00355027
# epoch 9861: loss 0.048454
# epoch 9862 loss_pde:0.01373131, loss_ib:0.00353172
# epoch 9862: loss 0.049048
# epoch 9863 loss_pde:0.01365555, loss_ib:0.00358420
# epoch 9863: loss 0.049498
# epoch 9864 loss_pde:0.01490020, loss_ib:0.00344940
# epoch 9864: loss 0.049394
# epoch 9865 loss_pde:0.01491011, loss_ib:0.00343651
# epoch 9865: loss 0.049275
# epoch 9866 loss_pde:0.01674503, loss_ib:0.00327737
# epoch 9866: loss 0.049519
# epoch 9867 loss_pde:0.01689240, loss_ib:0.00334276
# epoch 9867: loss 0.050320
# epoch 9868 loss_pde:0.01936476, loss_ib:0.00329146
# epoch 9868: loss 0.052279
# epoch 9869 loss_pde:0.01990319, loss_ib:0.00347778
# epoch 9869: loss 0.054681
# epoch 9870 loss_pde:0.02303137, loss_ib:0.00355453
# epoch 9870: loss 0.058577
# epoch 9871 loss_pde:0.02372404, loss_ib:0.00383136
# epoch 9871: loss 0.062038
# epoch 9872 loss_pde:0.02667926, loss_ib:0.00398794
# epoch 9872: loss 0.066559
# epoch 9873 loss_pde:0.02575025, loss_ib:0.00410361
# epoch 9873: loss 0.066786
# epoch 9874 loss_pde:0.02566899, loss_ib:0.00393795
# epoch 9874: loss 0.065049
# epoch 9875 loss_pde:0.02116801, loss_ib:0.00368326
# epoch 9875: loss 0.058001
# epoch 9876 loss_pde:0.01726558, loss_ib:0.00343730
# epoch 9876: loss 0.051639
# epoch 9877 loss_pde:0.01310932, loss_ib:0.00343181
# epoch 9877: loss 0.047427
# epoch 9878 loss_pde:0.01163418, loss_ib:0.00353410
# epoch 9878: loss 0.046975
# epoch 9879 loss_pde:0.01249742, loss_ib:0.00373397
# epoch 9879: loss 0.049837
# epoch 9880 loss_pde:0.01406694, loss_ib:0.00385054
# epoch 9880: loss 0.052572
# epoch 9881 loss_pde:0.01563715, loss_ib:0.00380050
# epoch 9881: loss 0.053642
# epoch 9882 loss_pde:0.01474964, loss_ib:0.00357894
# epoch 9882: loss 0.050539
# epoch 9883 loss_pde:0.01355331, loss_ib:0.00333125
# epoch 9883: loss 0.046866
# epoch 9884 loss_pde:0.01199376, loss_ib:0.00335869
# epoch 9884: loss 0.045581
# epoch 9885 loss_pde:0.01164517, loss_ib:0.00353377
# epoch 9885: loss 0.046983
# epoch 9886 loss_pde:0.01248144, loss_ib:0.00373596
# epoch 9886: loss 0.049841
# epoch 9887 loss_pde:0.01273670, loss_ib:0.00387239
# epoch 9887: loss 0.051461
# epoch 9888 loss_pde:0.01290585, loss_ib:0.00384105
# epoch 9888: loss 0.051316
# epoch 9889 loss_pde:0.01200544, loss_ib:0.00361745
# epoch 9889: loss 0.048180
# epoch 9890 loss_pde:0.01157480, loss_ib:0.00334018
# epoch 9890: loss 0.044977
# epoch 9891 loss_pde:0.01180576, loss_ib:0.00332291
# epoch 9891: loss 0.045035
# epoch 9892 loss_pde:0.01176055, loss_ib:0.00356199
# epoch 9892: loss 0.047380
# epoch 9893 loss_pde:0.01254863, loss_ib:0.00367862
# epoch 9893: loss 0.049335
# epoch 9894 loss_pde:0.01194899, loss_ib:0.00372599
# epoch 9894: loss 0.049209
# epoch 9895 loss_pde:0.01166759, loss_ib:0.00358500
# epoch 9895: loss 0.047518
# epoch 9896 loss_pde:0.01139534, loss_ib:0.00337770
# epoch 9896: loss 0.045172
# epoch 9897 loss_pde:0.01143247, loss_ib:0.00326947
# epoch 9897: loss 0.044127
# epoch 9898 loss_pde:0.01229259, loss_ib:0.00327347
# epoch 9898: loss 0.045027
# epoch 9899 loss_pde:0.01179416, loss_ib:0.00343083
# epoch 9899: loss 0.046102
# epoch 9900 loss_pde:0.01196930, loss_ib:0.00340794
# epoch 9900: loss 0.046049
# epoch 9901 loss_pde:0.01145463, loss_ib:0.00336427
# epoch 9901: loss 0.045097
# epoch 9902 loss_pde:0.01139906, loss_ib:0.00327806
# epoch 9902: loss 0.044180
# epoch 9903 loss_pde:0.01187016, loss_ib:0.00320205
# epoch 9903: loss 0.043891
# epoch 9904 loss_pde:0.01173885, loss_ib:0.00323839
# epoch 9904: loss 0.044123
# epoch 9905 loss_pde:0.01217541, loss_ib:0.00322085
# epoch 9905: loss 0.044384
# epoch 9906 loss_pde:0.01161205, loss_ib:0.00326437
# epoch 9906: loss 0.044256
# epoch 9907 loss_pde:0.01159454, loss_ib:0.00323409
# epoch 9907: loss 0.043935
# epoch 9908 loss_pde:0.01163256, loss_ib:0.00320467
# epoch 9908: loss 0.043679
# epoch 9909 loss_pde:0.01160960, loss_ib:0.00320523
# epoch 9909: loss 0.043662
# epoch 9910 loss_pde:0.01209013, loss_ib:0.00316430
# epoch 9910: loss 0.043733
# epoch 9911 loss_pde:0.01177296, loss_ib:0.00319584
# epoch 9911: loss 0.043731
# epoch 9912 loss_pde:0.01195256, loss_ib:0.00316719
# epoch 9912: loss 0.043624
# epoch 9913 loss_pde:0.01164608, loss_ib:0.00318535
# epoch 9913: loss 0.043500
# epoch 9914 loss_pde:0.01160405, loss_ib:0.00318569
# epoch 9914: loss 0.043461
# epoch 9915 loss_pde:0.01176490, loss_ib:0.00317607
# epoch 9915: loss 0.043526
# epoch 9916 loss_pde:0.01166528, loss_ib:0.00320270
# epoch 9916: loss 0.043692
# epoch 9917 loss_pde:0.01211438, loss_ib:0.00317688
# epoch 9917: loss 0.043883
# epoch 9918 loss_pde:0.01187144, loss_ib:0.00322363
# epoch 9918: loss 0.044108
# epoch 9919 loss_pde:0.01217486, loss_ib:0.00322285
# epoch 9919: loss 0.044403
# epoch 9920 loss_pde:0.01195768, loss_ib:0.00330326
# epoch 9920: loss 0.044990
# epoch 9921 loss_pde:0.01209997, loss_ib:0.00338733
# epoch 9921: loss 0.045973
# epoch 9922 loss_pde:0.01208381, loss_ib:0.00357477
# epoch 9922: loss 0.047831
# epoch 9923 loss_pde:0.01230546, loss_ib:0.00377157
# epoch 9923: loss 0.050021
# epoch 9924 loss_pde:0.01273457, loss_ib:0.00403527
# epoch 9924: loss 0.053087
# epoch 9925 loss_pde:0.01301958, loss_ib:0.00406754
# epoch 9925: loss 0.053695
# epoch 9926 loss_pde:0.01346034, loss_ib:0.00391673
# epoch 9926: loss 0.052628
# epoch 9927 loss_pde:0.01330581, loss_ib:0.00351381
# epoch 9927: loss 0.048444
# epoch 9928 loss_pde:0.01248335, loss_ib:0.00328661
# epoch 9928: loss 0.045349
# epoch 9929 loss_pde:0.01233697, loss_ib:0.00328939
# epoch 9929: loss 0.045231
# epoch 9930 loss_pde:0.01255263, loss_ib:0.00353022
# epoch 9930: loss 0.047855
# epoch 9931 loss_pde:0.01395505, loss_ib:0.00388086
# epoch 9931: loss 0.052764
# epoch 9932 loss_pde:0.01611753, loss_ib:0.00409538
# epoch 9932: loss 0.057071
# epoch 9933 loss_pde:0.01729099, loss_ib:0.00420284
# epoch 9933: loss 0.059319
# epoch 9934 loss_pde:0.01966743, loss_ib:0.00351883
# epoch 9934: loss 0.054856
# epoch 9935 loss_pde:0.01916980, loss_ib:0.00335713
# epoch 9935: loss 0.052741
# epoch 9936 loss_pde:0.02180882, loss_ib:0.00360454
# epoch 9936: loss 0.057854
# epoch 9937 loss_pde:0.02432588, loss_ib:0.00388500
# epoch 9937: loss 0.063176
# epoch 9938 loss_pde:0.02906914, loss_ib:0.00371234
# epoch 9938: loss 0.066192
# epoch 9939 loss_pde:0.02998043, loss_ib:0.00355360
# epoch 9939: loss 0.065516
# epoch 9940 loss_pde:0.02865195, loss_ib:0.00339365
# epoch 9940: loss 0.062588
# epoch 9941 loss_pde:0.02328560, loss_ib:0.00355181
# epoch 9941: loss 0.058804
# epoch 9942 loss_pde:0.01974884, loss_ib:0.00352552
# epoch 9942: loss 0.055004
# epoch 9943 loss_pde:0.01586359, loss_ib:0.00350845
# epoch 9943: loss 0.050948
# epoch 9944 loss_pde:0.01511318, loss_ib:0.00327844
# epoch 9944: loss 0.047898
# epoch 9945 loss_pde:0.01355363, loss_ib:0.00332301
# epoch 9945: loss 0.046784
# epoch 9946 loss_pde:0.01352455, loss_ib:0.00349220
# epoch 9946: loss 0.048447
# epoch 9947 loss_pde:0.01597666, loss_ib:0.00345456
# epoch 9947: loss 0.050522
# epoch 9948 loss_pde:0.01531627, loss_ib:0.00349744
# epoch 9948: loss 0.050291
# epoch 9949 loss_pde:0.01468783, loss_ib:0.00327132
# epoch 9949: loss 0.047401
# epoch 9950 loss_pde:0.01186955, loss_ib:0.00323676
# epoch 9950: loss 0.044237
# epoch 9951 loss_pde:0.01153421, loss_ib:0.00327143
# epoch 9951: loss 0.044249
# epoch 9952 loss_pde:0.01376802, loss_ib:0.00328433
# epoch 9952: loss 0.046611
# epoch 9953 loss_pde:0.01368356, loss_ib:0.00343164
# epoch 9953: loss 0.048000
# epoch 9954 loss_pde:0.01396832, loss_ib:0.00332831
# epoch 9954: loss 0.047251
# epoch 9955 loss_pde:0.01226637, loss_ib:0.00333462
# epoch 9955: loss 0.045613
# epoch 9956 loss_pde:0.01203354, loss_ib:0.00327781
# epoch 9956: loss 0.044812
# epoch 9957 loss_pde:0.01303998, loss_ib:0.00319306
# epoch 9957: loss 0.044971
# epoch 9958 loss_pde:0.01242003, loss_ib:0.00326494
# epoch 9958: loss 0.045069
# epoch 9959 loss_pde:0.01310647, loss_ib:0.00318357
# epoch 9959: loss 0.044942
# epoch 9960 loss_pde:0.01236048, loss_ib:0.00323334
# epoch 9960: loss 0.044694
# epoch 9961 loss_pde:0.01233891, loss_ib:0.00319276
# epoch 9961: loss 0.044267
# epoch 9962 loss_pde:0.01205902, loss_ib:0.00317157
# epoch 9962: loss 0.043775
# epoch 9963 loss_pde:0.01158657, loss_ib:0.00320800
# epoch 9963: loss 0.043667
# epoch 9964 loss_pde:0.01231384, loss_ib:0.00318913
# epoch 9964: loss 0.044205
# epoch 9965 loss_pde:0.01237443, loss_ib:0.00324751
# epoch 9965: loss 0.044850
# epoch 9966 loss_pde:0.01277682, loss_ib:0.00320775
# epoch 9966: loss 0.044854
# epoch 9967 loss_pde:0.01205738, loss_ib:0.00321838
# epoch 9967: loss 0.044241
# epoch 9968 loss_pde:0.01179652, loss_ib:0.00319372
# epoch 9968: loss 0.043734
# epoch 9969 loss_pde:0.01163174, loss_ib:0.00321230
# epoch 9969: loss 0.043755
# epoch 9970 loss_pde:0.01176725, loss_ib:0.00322921
# epoch 9970: loss 0.044059
# epoch 9971 loss_pde:0.01195398, loss_ib:0.00322254
# epoch 9971: loss 0.044179
# epoch 9972 loss_pde:0.01160558, loss_ib:0.00324700
# epoch 9972: loss 0.044076
# epoch 9973 loss_pde:0.01190246, loss_ib:0.00320852
# epoch 9973: loss 0.043988
# epoch 9974 loss_pde:0.01160443, loss_ib:0.00324904
# epoch 9974: loss 0.044095
# epoch 9975 loss_pde:0.01203200, loss_ib:0.00322900
# epoch 9975: loss 0.044322
# epoch 9976 loss_pde:0.01186504, loss_ib:0.00327714
# epoch 9976: loss 0.044636
# epoch 9977 loss_pde:0.01199045, loss_ib:0.00330069
# epoch 9977: loss 0.044997
# epoch 9978 loss_pde:0.01204160, loss_ib:0.00334590
# epoch 9978: loss 0.045501
# epoch 9979 loss_pde:0.01220852, loss_ib:0.00338578
# epoch 9979: loss 0.046066
# epoch 9980 loss_pde:0.01239750, loss_ib:0.00344176
# epoch 9980: loss 0.046815
# epoch 9981 loss_pde:0.01327207, loss_ib:0.00345627
# epoch 9981: loss 0.047835
# epoch 9982 loss_pde:0.01385526, loss_ib:0.00354259
# epoch 9982: loss 0.049281
# epoch 9983 loss_pde:0.01620313, loss_ib:0.00349617
# epoch 9983: loss 0.051165
# epoch 9984 loss_pde:0.01726761, loss_ib:0.00359872
# epoch 9984: loss 0.053255
# epoch 9985 loss_pde:0.02112051, loss_ib:0.00350729
# epoch 9985: loss 0.056193
# epoch 9986 loss_pde:0.02276638, loss_ib:0.00363519
# epoch 9986: loss 0.059118
# epoch 9987 loss_pde:0.02781788, loss_ib:0.00360492
# epoch 9987: loss 0.063867
# epoch 9988 loss_pde:0.02870577, loss_ib:0.00378453
# epoch 9988: loss 0.066551
# epoch 9989 loss_pde:0.03184301, loss_ib:0.00381818
# epoch 9989: loss 0.070025
# epoch 9990 loss_pde:0.02762982, loss_ib:0.00392971
# epoch 9990: loss 0.066927
# epoch 9991 loss_pde:0.02411786, loss_ib:0.00383030
# epoch 9991: loss 0.062421
# epoch 9992 loss_pde:0.01699064, loss_ib:0.00368694
# epoch 9992: loss 0.053860
# epoch 9993 loss_pde:0.01281160, loss_ib:0.00346315
# epoch 9993: loss 0.047443
# epoch 9994 loss_pde:0.01241757, loss_ib:0.00327624
# epoch 9994: loss 0.045180
# epoch 9995 loss_pde:0.01381681, loss_ib:0.00331534
# epoch 9995: loss 0.046970
# epoch 9996 loss_pde:0.01632207, loss_ib:0.00336912
# epoch 9996: loss 0.050013
# epoch 9997 loss_pde:0.01531224, loss_ib:0.00353436
# epoch 9997: loss 0.050656
# epoch 9998 loss_pde:0.01395171, loss_ib:0.00352650
# epoch 9998: loss 0.049217
# epoch 9999 loss_pde:0.01234627, loss_ib:0.00344453
# epoch 9999: loss 0.046792
# epoch 10000 loss_pde:0.01215319, loss_ib:0.00334922
# epoch 10000: loss 0.045645
# Total training time: 5116.871426105499

# %%
lr = 0.0001
#optimizer = torch.optim.LBFGS(model.parameters(),lr=lr,max_iter=500)
optimizer = torch.optim.Adam(model.parameters(), lr=lr)
#scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer_Adam,gamma=0.995)
#optimizer = torch.optim.LBFGS(model.parameters(),lr=0.1,max_iter=10)
#optimizer_LBFGS = torch.optim.LBFGS(model.parameters(), lr=0.01, max_iter=50000)

# %%
epochs = 2
tic = time.time()
for epoch in range(1, epochs+1):
    train(epoch)
toc = time.time()
print(f'Total training time: {toc - tic}')

# %%
lr = 0.0001
#optimizer = torch.optim.LBFGS(model.parameters(),lr=lr,max_iter=500)
#optimizer = torch.optim.Adam(model.parameters(), lr=lr)
#scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer_Adam,gamma=0.995)
optimizer = torch.optim.LBFGS(model.parameters(),lr=0.5,max_iter=20)
#optimizer_LBFGS = torch.optim.LBFGS(model.parameters(), lr=0.01, max_iter=50000)

# %%
epochs = 1000
tic = time.time()
for epoch in range(1, epochs+1):
    train(epoch)
toc = time.time()
print(f'Total training time: {toc - tic}')
# Out:
# epoch 1 loss_pde:0.01335710, loss_ib:0.00325727
# epoch 1 loss_pde:0.01574058, loss_ib:0.02544532
# epoch 1 loss_pde:0.01173196, loss_ib:0.00888387
# epoch 1 loss_pde:0.01140033, loss_ib:0.00463905
# epoch 1 loss_pde:0.01153454, loss_ib:0.00354573
# epoch 1 loss_pde:0.01160798, loss_ib:0.00326143
# epoch 1 loss_pde:0.01160833, loss_ib:0.00318515
# epoch 1 loss_pde:0.01157458, loss_ib:0.00316407
# epoch 1 loss_pde:0.01152876, loss_ib:0.00315840
# epoch 1 loss_pde:0.01147907, loss_ib:0.00315744
# epoch 1 loss_pde:0.01143168, loss_ib:0.00315792
# epoch 1 loss_pde:0.01139630, loss_ib:0.00315838
# epoch 1 loss_pde:0.01137766, loss_ib:0.00315822
# epoch 1 loss_pde:0.01136758, loss_ib:0.00315811
# epoch 1 loss_pde:0.01136351, loss_ib:0.00315788
# epoch 1 loss_pde:0.01135916, loss_ib:0.00315807
# epoch 1 loss_pde:0.01135969, loss_ib:0.00315774
# epoch 1 loss_pde:0.01136011, loss_ib:0.00315754
# epoch 1 loss_pde:0.01136036, loss_ib:0.00315739
# epoch 1 loss_pde:0.01136027, loss_ib:0.00315729
# epoch 1: loss 0.045930
# epoch 2 loss_pde:0.01135958, loss_ib:0.00315724
# epoch 2 loss_pde:0.01135792, loss_ib:0.00315721
# epoch 2 loss_pde:0.01135499, loss_ib:0.00315720
# epoch 2 loss_pde:0.01135150, loss_ib:0.00315709
# epoch 2 loss_pde:0.01134603, loss_ib:0.00315703
# epoch 2 loss_pde:0.01136793, loss_ib:0.00315482
# epoch 2 loss_pde:0.01135576, loss_ib:0.00315530
# epoch 2 loss_pde:0.01135006, loss_ib:0.00315545
# epoch 2 loss_pde:0.01134835, loss_ib:0.00315533
# epoch 2 loss_pde:0.01134941, loss_ib:0.00315499
# epoch 2 loss_pde:0.01135316, loss_ib:0.00315434
# epoch 2 loss_pde:0.01136042, loss_ib:0.00315326
# epoch 2 loss_pde:0.01137264, loss_ib:0.00315151
# epoch 2 loss_pde:0.01139095, loss_ib:0.00314894
# epoch 2 loss_pde:0.01142271, loss_ib:0.00314457
# epoch 2 loss_pde:0.01149017, loss_ib:0.00313645
# epoch 2 loss_pde:0.01151091, loss_ib:0.00313344
# epoch 2 loss_pde:0.01152981, loss_ib:0.00313068
# epoch 2 loss_pde:0.01154476, loss_ib:0.00312855
# epoch 2 loss_pde:0.01155553, loss_ib:0.00312704
# epoch 2: loss 0.042932
# epoch 3 loss_pde:0.01156509, loss_ib:0.00312566
# epoch 3 loss_pde:0.01157659, loss_ib:0.00312390
# epoch 3 loss_pde:0.01159335, loss_ib:0.00312122
# epoch 3 loss_pde:0.01161829, loss_ib:0.00311750
# epoch 3 loss_pde:0.01162581, loss_ib:0.00311607
# epoch 3 loss_pde:0.01162827, loss_ib:0.00311509
# epoch 3 loss_pde:0.01163083, loss_ib:0.00311417
# epoch 3 loss_pde:0.01162832, loss_ib:0.00311384
# epoch 3 loss_pde:0.01163402, loss_ib:0.00311273
# epoch 3 loss_pde:0.01163526, loss_ib:0.00311207
# epoch 3 loss_pde:0.01164542, loss_ib:0.00311019
# epoch 3 loss_pde:0.01165683, loss_ib:0.00310819
# epoch 3 loss_pde:0.01166785, loss_ib:0.00310618
# epoch 3 loss_pde:0.01168960, loss_ib:0.00310310
# epoch 3 loss_pde:0.01170234, loss_ib:0.00310107
# epoch 3 loss_pde:0.01171755, loss_ib:0.00309892
# epoch 3 loss_pde:0.01173650, loss_ib:0.00309610
# epoch 3 loss_pde:0.01175425, loss_ib:0.00309337
# epoch 3 loss_pde:0.01177292, loss_ib:0.00309020
# epoch 3 loss_pde:0.01179162, loss_ib:0.00308680
# epoch 3: loss 0.042822
# epoch 4 loss_pde:0.01180563, loss_ib:0.00308414
# epoch 4 loss_pde:0.01181657, loss_ib:0.00308207
# epoch 4 loss_pde:0.01183146, loss_ib:0.00307915
# epoch 4 loss_pde:0.01186303, loss_ib:0.00307391
# epoch 4 loss_pde:0.01188894, loss_ib:0.00306934
# epoch 4 loss_pde:0.01191848, loss_ib:0.00306487
# epoch 4 loss_pde:0.01194390, loss_ib:0.00306093
# epoch 4 loss_pde:0.01196562, loss_ib:0.00305741
# epoch 4 loss_pde:0.01198051, loss_ib:0.00305488
# epoch 4 loss_pde:0.01199429, loss_ib:0.00305247
# epoch 4 loss_pde:0.01200884, loss_ib:0.00304970
# epoch 4 loss_pde:0.01203484, loss_ib:0.00304558
# epoch 4 loss_pde:0.01204558, loss_ib:0.00304316
# epoch 4 loss_pde:0.01205861, loss_ib:0.00303985
# epoch 4 loss_pde:0.01207007, loss_ib:0.00303637
# epoch 4 loss_pde:0.01207520, loss_ib:0.00303432
# epoch 4 loss_pde:0.01208072, loss_ib:0.00303188
# epoch 4 loss_pde:0.01209699, loss_ib:0.00302786
# epoch 4 loss_pde:0.01212193, loss_ib:0.00302292
# epoch 4 loss_pde:0.01214894, loss_ib:0.00301837
# epoch 4: loss 0.042647
# epoch 5 loss_pde:0.01218311, loss_ib:0.00301284
# epoch 5 loss_pde:0.01222700, loss_ib:0.00300603
# epoch 5 loss_pde:0.01227393, loss_ib:0.00299865
# epoch 5 loss_pde:0.01233732, loss_ib:0.00298940
# epoch 5 loss_pde:0.01237456, loss_ib:0.00298332
# epoch 5 loss_pde:0.01242108, loss_ib:0.00297678
# epoch 5 loss_pde:0.01244175, loss_ib:0.00297309
# epoch 5 loss_pde:0.01247279, loss_ib:0.00296858
# epoch 5 loss_pde:0.01248699, loss_ib:0.00296582
# epoch 5 loss_pde:0.01251150, loss_ib:0.00296177
# epoch 5 loss_pde:0.01253097, loss_ib:0.00295791
# epoch 5 loss_pde:0.01256332, loss_ib:0.00295228
# epoch 5 loss_pde:0.01259587, loss_ib:0.00294635
# epoch 5 loss_pde:0.01262911, loss_ib:0.00294032
# epoch 5 loss_pde:0.01266268, loss_ib:0.00293460
# epoch 5 loss_pde:0.01267997, loss_ib:0.00293042
# epoch 5 loss_pde:0.01270920, loss_ib:0.00292491
# epoch 5 loss_pde:0.01270851, loss_ib:0.00292263
# epoch 5 loss_pde:0.01272797, loss_ib:0.00291853
# epoch 5 loss_pde:0.01271368, loss_ib:0.00291813
# epoch 5: loss 0.042311
# epoch 6 loss_pde:0.01272293, loss_ib:0.00291573
# epoch 6 loss_pde:0.01270700, loss_ib:0.00291607
# epoch 6 loss_pde:0.01269857, loss_ib:0.00291568
# epoch 6 loss_pde:0.01267740, loss_ib:0.00291653
# epoch 6 loss_pde:0.01265811, loss_ib:0.00291668
# epoch 6 loss_pde:0.01262347, loss_ib:0.00291766
# epoch 6 loss_pde:0.01260092, loss_ib:0.00291746
# epoch 6 loss_pde:0.01258073, loss_ib:0.00291676
# epoch 6 loss_pde:0.01257712, loss_ib:0.00291428
# epoch 6 loss_pde:0.01257671, loss_ib:0.00291123
# epoch 6 loss_pde:0.01259668, loss_ib:0.00290683
# epoch 6 loss_pde:0.01261255, loss_ib:0.00290335
# epoch 6 loss_pde:0.01263152, loss_ib:0.00290005
# epoch 6 loss_pde:0.01264562, loss_ib:0.00289747
# epoch 6 loss_pde:0.01265854, loss_ib:0.00289468
# epoch 6 loss_pde:0.01266787, loss_ib:0.00289180
# epoch 6 loss_pde:0.01268348, loss_ib:0.00288820
# epoch 6 loss_pde:0.01267396, loss_ib:0.00288747
# epoch 6 loss_pde:0.01267078, loss_ib:0.00288574
# epoch 6 loss_pde:0.01263268, loss_ib:0.00288762
# epoch 6: loss 0.041880
# epoch 7 loss_pde:0.01262147, loss_ib:0.00288744
# epoch 7 loss_pde:0.01259819, loss_ib:0.00288877
# epoch 7 loss_pde:0.01264118, loss_ib:0.00288387
# epoch 7 loss_pde:0.01261327, loss_ib:0.00288542
# epoch 7 loss_pde:0.01259660, loss_ib:0.00288582
# epoch 7 loss_pde:0.01258519, loss_ib:0.00288541
# epoch 7 loss_pde:0.01258447, loss_ib:0.00288386
# epoch 7 loss_pde:0.01258946, loss_ib:0.00288151
# epoch 7 loss_pde:0.01259944, loss_ib:0.00287809
# epoch 7 loss_pde:0.01259137, loss_ib:0.00287821
# epoch 7 loss_pde:0.01259971, loss_ib:0.00287461
# epoch 7 loss_pde:0.01260857, loss_ib:0.00287205
# epoch 7 loss_pde:0.01261319, loss_ib:0.00287033
# epoch 7 loss_pde:0.01261064, loss_ib:0.00286949
# epoch 7 loss_pde:0.01259964, loss_ib:0.00286930
# epoch 7 loss_pde:0.01258288, loss_ib:0.00286949
# epoch 7 loss_pde:0.01256304, loss_ib:0.00287000
# epoch 7 loss_pde:0.01253687, loss_ib:0.00287124
# epoch 7 loss_pde:0.01249484, loss_ib:0.00287390
# epoch 7 loss_pde:0.01247026, loss_ib:0.00287518
# epoch 7: loss 0.041496
# epoch 8 loss_pde:0.01245024, loss_ib:0.00287599
# epoch 8 loss_pde:0.01242463, loss_ib:0.00287713
# epoch 8 loss_pde:0.01241274, loss_ib:0.00287679
# epoch 8 loss_pde:0.01238979, loss_ib:0.00287753
# epoch 8 loss_pde:0.01238781, loss_ib:0.00287633
# epoch 8 loss_pde:0.01237894, loss_ib:0.00287580
# epoch 8 loss_pde:0.01237868, loss_ib:0.00287427
# epoch 8 loss_pde:0.01235934, loss_ib:0.00287494
# epoch 8 loss_pde:0.01235957, loss_ib:0.00287348
# epoch 8 loss_pde:0.01236059, loss_ib:0.00287216
# epoch 8 loss_pde:0.01235525, loss_ib:0.00287146
# epoch 8 loss_pde:0.01234857, loss_ib:0.00287086
# epoch 8 loss_pde:0.01233467, loss_ib:0.00287079
# epoch 8 loss_pde:0.01231619, loss_ib:0.00287080
# epoch 8 loss_pde:0.01227860, loss_ib:0.00287256
# epoch 8 loss_pde:0.01225759, loss_ib:0.00287344
# epoch 8 loss_pde:0.01223915, loss_ib:0.00287402
# epoch 8 loss_pde:0.01220613, loss_ib:0.00287601
# epoch 8 loss_pde:0.01217991, loss_ib:0.00287734
# epoch 8 loss_pde:0.01214039, loss_ib:0.00287992
# epoch 8: loss 0.041210
# epoch 9 loss_pde:0.01210062, loss_ib:0.00288214
# epoch 9 loss_pde:0.01202876, loss_ib:0.00288737
# epoch 9 loss_pde:0.01200091, loss_ib:0.00288880
# epoch 9 loss_pde:0.01197680, loss_ib:0.00288956
# epoch 9 loss_pde:0.01195842, loss_ib:0.00289004
# epoch 9 loss_pde:0.01195104, loss_ib:0.00288972
# epoch 9 loss_pde:0.01194449, loss_ib:0.00288941
# epoch 9 loss_pde:0.01194553, loss_ib:0.00288821
# epoch 9 loss_pde:0.01194277, loss_ib:0.00288711
# epoch 9 loss_pde:0.01195547, loss_ib:0.00288425
# epoch 9 loss_pde:0.01196018, loss_ib:0.00288216
# epoch 9 loss_pde:0.01197316, loss_ib:0.00287939
# epoch 9 loss_pde:0.01198659, loss_ib:0.00287676
# epoch 9 loss_pde:0.01199032, loss_ib:0.00287494
# epoch 9 loss_pde:0.01199523, loss_ib:0.00287297
# epoch 9 loss_pde:0.01198903, loss_ib:0.00287215
# epoch 9 loss_pde:0.01197718, loss_ib:0.00287173
# epoch 9 loss_pde:0.01195018, loss_ib:0.00287234
# epoch 9 loss_pde:0.01192436, loss_ib:0.00287240
# epoch 9 loss_pde:0.01187805, loss_ib:0.00287499
# epoch 9: loss 0.040922
# epoch 10 loss_pde:0.01184879, loss_ib:0.00287646
# epoch 10 loss_pde:0.01180798, loss_ib:0.00287877
# epoch 10 loss_pde:0.01177311, loss_ib:0.00288039
# epoch 10 loss_pde:0.01174426, loss_ib:0.00288132
# epoch 10 loss_pde:0.01171804, loss_ib:0.00288164
# epoch 10 loss_pde:0.01170925, loss_ib:0.00288031
# epoch 10 loss_pde:0.01170813, loss_ib:0.00287796
# epoch 10 loss_pde:0.01171934, loss_ib:0.00287478
# epoch 10 loss_pde:0.01174110, loss_ib:0.00287022
# epoch 10 loss_pde:0.01177180, loss_ib:0.00286460
# epoch 10 loss_pde:0.01179583, loss_ib:0.00286003
# epoch 10 loss_pde:0.01181883, loss_ib:0.00285616
# epoch 10 loss_pde:0.01182170, loss_ib:0.00285381
# epoch 10 loss_pde:0.01181727, loss_ib:0.00285193
# epoch 10 loss_pde:0.01179455, loss_ib:0.00285157
# epoch 10 loss_pde:0.01176526, loss_ib:0.00285202
# epoch 10 loss_pde:0.01172112, loss_ib:0.00285428
# epoch 10 loss_pde:0.01170488, loss_ib:0.00285374
# epoch 10 loss_pde:0.01166376, loss_ib:0.00285600
# epoch 10 loss_pde:0.01165029, loss_ib:0.00285565
# epoch 10: loss 0.040613
# epoch 11 loss_pde:0.01162792, loss_ib:0.00285556
# epoch 11 loss_pde:0.01162778, loss_ib:0.00285334
# epoch 11 loss_pde:0.01162748, loss_ib:0.00285049
# epoch 11 loss_pde:0.01164301, loss_ib:0.00284559
# epoch 11 loss_pde:0.01165209, loss_ib:0.00284116
# epoch 11 loss_pde:0.01167116, loss_ib:0.00283600
# epoch 11 loss_pde:0.01167190, loss_ib:0.00283333
# epoch 11 loss_pde:0.01166986, loss_ib:0.00283188
# epoch 11 loss_pde:0.01164350, loss_ib:0.00283271
# epoch 11 loss_pde:0.01160342, loss_ib:0.00283441
# epoch 11 loss_pde:0.01155867, loss_ib:0.00283716
# epoch 11 loss_pde:0.01150092, loss_ib:0.00284094
# epoch 11 loss_pde:0.01145157, loss_ib:0.00284363
# epoch 11 loss_pde:0.01140954, loss_ib:0.00284633
# epoch 11 loss_pde:0.01138508, loss_ib:0.00284721
# epoch 11 loss_pde:0.01136717, loss_ib:0.00284658
# epoch 11 loss_pde:0.01136362, loss_ib:0.00284501
# epoch 11 loss_pde:0.01137952, loss_ib:0.00284149
# epoch 11 loss_pde:0.01140080, loss_ib:0.00283779
# epoch 11 loss_pde:0.01141929, loss_ib:0.00283444
# epoch 11: loss 0.040184
# epoch 12 loss_pde:0.01144226, loss_ib:0.00283059
# epoch 12 loss_pde:0.01145195, loss_ib:0.00282804
# epoch 12 loss_pde:0.01146437, loss_ib:0.00282549
# epoch 12 loss_pde:0.01146436, loss_ib:0.00282418
# epoch 12 loss_pde:0.01146288, loss_ib:0.00282339
# epoch 12 loss_pde:0.01145279, loss_ib:0.00282328
# epoch 12 loss_pde:0.01143736, loss_ib:0.00282389
# epoch 12 loss_pde:0.01142280, loss_ib:0.00282461
# epoch 12 loss_pde:0.01140942, loss_ib:0.00282531
# epoch 12 loss_pde:0.01139800, loss_ib:0.00282579
# epoch 12 loss_pde:0.01138686, loss_ib:0.00282610
# epoch 12 loss_pde:0.01137733, loss_ib:0.00282599
# epoch 12 loss_pde:0.01135149, loss_ib:0.00282772
# epoch 12 loss_pde:0.01134364, loss_ib:0.00282712
# epoch 12 loss_pde:0.01134179, loss_ib:0.00282612
# epoch 12 loss_pde:0.01134276, loss_ib:0.00282487
# epoch 12 loss_pde:0.01134293, loss_ib:0.00282379
# epoch 12 loss_pde:0.01134226, loss_ib:0.00282280
# epoch 12 loss_pde:0.01133808, loss_ib:0.00282197
# epoch 12 loss_pde:0.01133931, loss_ib:0.00282057
# epoch 12: loss 0.039748
# epoch 13 loss_pde:0.01132852, loss_ib:0.00282038
# epoch 13 loss_pde:0.01132028, loss_ib:0.00282024
# epoch 13 loss_pde:0.01130924, loss_ib:0.00282017
# epoch 13 loss_pde:0.01129848, loss_ib:0.00282025
# epoch 13 loss_pde:0.01129036, loss_ib:0.00282022
# epoch 13 loss_pde:0.01127954, loss_ib:0.00282039
# epoch 13 loss_pde:0.01127208, loss_ib:0.00282012
# epoch 13 loss_pde:0.01126060, loss_ib:0.00282014
# epoch 13 loss_pde:0.01125290, loss_ib:0.00281964
# epoch 13 loss_pde:0.01123830, loss_ib:0.00281966
# epoch 13 loss_pde:0.01122990, loss_ib:0.00281903
# epoch 13 loss_pde:0.01121800, loss_ib:0.00281903
# epoch 13 loss_pde:0.01120476, loss_ib:0.00281952
# epoch 13 loss_pde:0.01118725, loss_ib:0.00282007
# epoch 13 loss_pde:0.01116278, loss_ib:0.00282100
# epoch 13 loss_pde:0.01113699, loss_ib:0.00282173
# epoch 13 loss_pde:0.01111000, loss_ib:0.00282231
# epoch 13 loss_pde:0.01109965, loss_ib:0.00282150
# epoch 13 loss_pde:0.01109190, loss_ib:0.00282110
# epoch 13 loss_pde:0.01109333, loss_ib:0.00281983
# epoch 13: loss 0.039532
# epoch 14 loss_pde:0.01110312, loss_ib:0.00281725
# epoch 14 loss_pde:0.01111250, loss_ib:0.00281429
# epoch 14 loss_pde:0.01114033, loss_ib:0.00280916
# epoch 14 loss_pde:0.01114135, loss_ib:0.00280753
# epoch 14 loss_pde:0.01115744, loss_ib:0.00280424
# epoch 14 loss_pde:0.01116359, loss_ib:0.00280190
# epoch 14 loss_pde:0.01116176, loss_ib:0.00280063
# epoch 14 loss_pde:0.01114998, loss_ib:0.00280067
# epoch 14 loss_pde:0.01113552, loss_ib:0.00280103
# epoch 14 loss_pde:0.01111569, loss_ib:0.00280178
# epoch 14 loss_pde:0.01109883, loss_ib:0.00280151
# epoch 14 loss_pde:0.01109982, loss_ib:0.00279915
# epoch 14 loss_pde:0.01109047, loss_ib:0.00279805
# epoch 14 loss_pde:0.01109998, loss_ib:0.00279603
# epoch 14 loss_pde:0.01111463, loss_ib:0.00279345
# epoch 14 loss_pde:0.01113104, loss_ib:0.00279059
# epoch 14 loss_pde:0.01115042, loss_ib:0.00278754
# epoch 14 loss_pde:0.01115292, loss_ib:0.00278539
# epoch 14 loss_pde:0.01114469, loss_ib:0.00278311
# epoch 14 loss_pde:0.01111863, loss_ib:0.00278330
# epoch 14: loss 0.039276
# epoch 15 loss_pde:0.01110122, loss_ib:0.00278344
# epoch 15 loss_pde:0.01107366, loss_ib:0.00278488
# epoch 15 loss_pde:0.01104422, loss_ib:0.00278675
# epoch 15 loss_pde:0.01101178, loss_ib:0.00278896
# epoch 15 loss_pde:0.01098047, loss_ib:0.00279088
# epoch 15 loss_pde:0.01094041, loss_ib:0.00279332
# epoch 15 loss_pde:0.01091192, loss_ib:0.00279442
# epoch 15 loss_pde:0.01088461, loss_ib:0.00279541
# epoch 15 loss_pde:0.01088172, loss_ib:0.00279416
# epoch 15 loss_pde:0.01088186, loss_ib:0.00279283
# epoch 15 loss_pde:0.01089942, loss_ib:0.00278993
# epoch 15 loss_pde:0.01091596, loss_ib:0.00278737
# epoch 15 loss_pde:0.01093319, loss_ib:0.00278474
# epoch 15 loss_pde:0.01094248, loss_ib:0.00278236
# epoch 15 loss_pde:0.01095671, loss_ib:0.00277900
# epoch 15 loss_pde:0.01092182, loss_ib:0.00278136
# epoch 15 loss_pde:0.01092830, loss_ib:0.00277955
# epoch 15 loss_pde:0.01092538, loss_ib:0.00277890
# epoch 15 loss_pde:0.01091656, loss_ib:0.00277904
# epoch 15 loss_pde:0.01090573, loss_ib:0.00277942
# epoch 15: loss 0.038936
# epoch 16 loss_pde:0.01089194, loss_ib:0.00277985
# epoch 16 loss_pde:0.01087468, loss_ib:0.00278009
# epoch 16 loss_pde:0.01085468, loss_ib:0.00278084
# epoch 16 loss_pde:0.01083989, loss_ib:0.00278028
# epoch 16 loss_pde:0.01082969, loss_ib:0.00277946
# epoch 16 loss_pde:0.01082157, loss_ib:0.00277827
# epoch 16 loss_pde:0.01081637, loss_ib:0.00277706
# epoch 16 loss_pde:0.01081023, loss_ib:0.00277599
# epoch 16 loss_pde:0.01080335, loss_ib:0.00277481
# epoch 16 loss_pde:0.01079606, loss_ib:0.00277359
# epoch 16 loss_pde:0.01078991, loss_ib:0.00277273
# epoch 16 loss_pde:0.01078158, loss_ib:0.00277171
# epoch 16 loss_pde:0.01077880, loss_ib:0.00277026
# epoch 16 loss_pde:0.01076637, loss_ib:0.00277023
# epoch 16 loss_pde:0.01076160, loss_ib:0.00276981
# epoch 16 loss_pde:0.01075858, loss_ib:0.00276941
# epoch 16 loss_pde:0.01074789, loss_ib:0.00276980
# epoch 16 loss_pde:0.01074449, loss_ib:0.00276946
# epoch 16 loss_pde:0.01073658, loss_ib:0.00276943
# epoch 16 loss_pde:0.01073129, loss_ib:0.00276878
# epoch 16: loss 0.038690
# epoch 17 loss_pde:0.01072025, loss_ib:0.00276868
# epoch 17 loss_pde:0.01071638, loss_ib:0.00276799
# epoch 17 loss_pde:0.01070801, loss_ib:0.00276766
# epoch 17 loss_pde:0.01070698, loss_ib:0.00276676
# epoch 17 loss_pde:0.01070066, loss_ib:0.00276630
# epoch 17 loss_pde:0.01070602, loss_ib:0.00276478
# epoch 17 loss_pde:0.01070223, loss_ib:0.00276415
# epoch 17 loss_pde:0.01069517, loss_ib:0.00276379
# epoch 17 loss_pde:0.01068852, loss_ib:0.00276352
# epoch 17 loss_pde:0.01068334, loss_ib:0.00276322
# epoch 17 loss_pde:0.01068066, loss_ib:0.00276262
# epoch 17 loss_pde:0.01068113, loss_ib:0.00276142
# epoch 17 loss_pde:0.01069230, loss_ib:0.00275882
# epoch 17 loss_pde:0.01070957, loss_ib:0.00275535
# epoch 17 loss_pde:0.01072635, loss_ib:0.00275269
# epoch 17 loss_pde:0.01073889, loss_ib:0.00275035
# epoch 17 loss_pde:0.01074973, loss_ib:0.00274802
# epoch 17 loss_pde:0.01075455, loss_ib:0.00274642
# epoch 17 loss_pde:0.01075685, loss_ib:0.00274510
# epoch 17 loss_pde:0.01075550, loss_ib:0.00274399
# epoch 17: loss 0.038407
# epoch 18 loss_pde:0.01075228, loss_ib:0.00274283
# epoch 18 loss_pde:0.01074026, loss_ib:0.00274259
# epoch 18 loss_pde:0.01073436, loss_ib:0.00274190
# epoch 18 loss_pde:0.01072138, loss_ib:0.00274206
# epoch 18 loss_pde:0.01070413, loss_ib:0.00274254
# epoch 18 loss_pde:0.01068487, loss_ib:0.00274322
# epoch 18 loss_pde:0.01066300, loss_ib:0.00274425
# epoch 18 loss_pde:0.01064422, loss_ib:0.00274496
# epoch 18 loss_pde:0.01062310, loss_ib:0.00274591
# epoch 18 loss_pde:0.01060466, loss_ib:0.00274649
# epoch 18 loss_pde:0.01058261, loss_ib:0.00274732
# epoch 18 loss_pde:0.01056932, loss_ib:0.00274768
# epoch 18 loss_pde:0.01055933, loss_ib:0.00274786
# epoch 18 loss_pde:0.01054640, loss_ib:0.00274836
# epoch 18 loss_pde:0.01053852, loss_ib:0.00274842
# epoch 18 loss_pde:0.01053251, loss_ib:0.00274850
# epoch 18 loss_pde:0.01052582, loss_ib:0.00274832
# epoch 18 loss_pde:0.01051537, loss_ib:0.00274799
# epoch 18 loss_pde:0.01051263, loss_ib:0.00274663
# epoch 18 loss_pde:0.01050649, loss_ib:0.00274571
# epoch 18: loss 0.038181
# epoch 19 loss_pde:0.01051827, loss_ib:0.00274306
# epoch 19 loss_pde:0.01052001, loss_ib:0.00274177
# epoch 19 loss_pde:0.01052337, loss_ib:0.00274012
# epoch 19 loss_pde:0.01052816, loss_ib:0.00273848
# epoch 19 loss_pde:0.01052939, loss_ib:0.00273737
# epoch 19 loss_pde:0.01052906, loss_ib:0.00273641
# epoch 19 loss_pde:0.01052273, loss_ib:0.00273596
# epoch 19 loss_pde:0.01050777, loss_ib:0.00273639
# epoch 19 loss_pde:0.01050218, loss_ib:0.00273621
# epoch 19 loss_pde:0.01048739, loss_ib:0.00273686
# epoch 19 loss_pde:0.01046351, loss_ib:0.00273828
# epoch 19 loss_pde:0.01043981, loss_ib:0.00273989
# epoch 19 loss_pde:0.01041949, loss_ib:0.00274135
# epoch 19 loss_pde:0.01040102, loss_ib:0.00274262
# epoch 19 loss_pde:0.01037725, loss_ib:0.00274415
# epoch 19 loss_pde:0.01035145, loss_ib:0.00274549
# epoch 19 loss_pde:0.01031733, loss_ib:0.00274741
# epoch 19 loss_pde:0.01029606, loss_ib:0.00274824
# epoch 19 loss_pde:0.01028179, loss_ib:0.00274870
# epoch 19 loss_pde:0.01027266, loss_ib:0.00274855
# epoch 19: loss 0.037949
# epoch 20 loss_pde:0.01026476, loss_ib:0.00274828
# epoch 20 loss_pde:0.01025969, loss_ib:0.00274778
# epoch 20 loss_pde:0.01025320, loss_ib:0.00274754
# epoch 20 loss_pde:0.01024859, loss_ib:0.00274731
# epoch 20 loss_pde:0.01024167, loss_ib:0.00274704
# epoch 20 loss_pde:0.01023226, loss_ib:0.00274640
# epoch 20 loss_pde:0.01021760, loss_ib:0.00274585
# epoch 20 loss_pde:0.01020626, loss_ib:0.00274520
# epoch 20 loss_pde:0.01020675, loss_ib:0.00274377
# epoch 20 loss_pde:0.01020344, loss_ib:0.00274283
# epoch 20 loss_pde:0.01020979, loss_ib:0.00274066
# epoch 20 loss_pde:0.01021374, loss_ib:0.00273855
# epoch 20 loss_pde:0.01022613, loss_ib:0.00273529
# epoch 20 loss_pde:0.01023207, loss_ib:0.00273242
# epoch 20 loss_pde:0.01023610, loss_ib:0.00273062
# epoch 20 loss_pde:0.01023661, loss_ib:0.00272938
# epoch 20 loss_pde:0.01023113, loss_ib:0.00272871
# epoch 20 loss_pde:0.01023734, loss_ib:0.00272671
# epoch 20 loss_pde:0.01023017, loss_ib:0.00272670
# epoch 20 loss_pde:0.01022198, loss_ib:0.00272634
# epoch 20: loss 0.037748
# epoch 21 loss_pde:0.01020812, loss_ib:0.00272640
# epoch 21 loss_pde:0.01019733, loss_ib:0.00272631
# epoch 21 loss_pde:0.01018733, loss_ib:0.00272623
# epoch 21 loss_pde:0.01017715, loss_ib:0.00272612
# epoch 21 loss_pde:0.01017491, loss_ib:0.00272507
# epoch 21 loss_pde:0.01016985, loss_ib:0.00272413
# epoch 21 loss_pde:0.01017449, loss_ib:0.00272250
# epoch 21 loss_pde:0.01019258, loss_ib:0.00271938
# epoch 21 loss_pde:0.01020313, loss_ib:0.00271736
# epoch 21 loss_pde:0.01022069, loss_ib:0.00271435
# epoch 21 loss_pde:0.01024072, loss_ib:0.00271089
# epoch 21 loss_pde:0.01027064, loss_ib:0.00270614
# epoch 21 loss_pde:0.01030564, loss_ib:0.00270091
# epoch 21 loss_pde:0.01032224, loss_ib:0.00269817
# epoch 21 loss_pde:0.01033627, loss_ib:0.00269535
# epoch 21 loss_pde:0.01033540, loss_ib:0.00269414
# epoch 21 loss_pde:0.01033505, loss_ib:0.00269334
# epoch 21 loss_pde:0.01032845, loss_ib:0.00269321
# epoch 21 loss_pde:0.01031628, loss_ib:0.00269337
# epoch 21 loss_pde:0.01029928, loss_ib:0.00269370
# epoch 21: loss 0.037472
# epoch 22 loss_pde:0.01027951, loss_ib:0.00269388
# epoch 22 loss_pde:0.01026133, loss_ib:0.00269375
# epoch 22 loss_pde:0.01024076, loss_ib:0.00269430
# epoch 22 loss_pde:0.01023502, loss_ib:0.00269390
# epoch 22 loss_pde:0.01023121, loss_ib:0.00269342
# epoch 22 loss_pde:0.01022815, loss_ib:0.00269278
# epoch 22 loss_pde:0.01023091, loss_ib:0.00269152
# epoch 22 loss_pde:0.01024317, loss_ib:0.00268946
# epoch 22 loss_pde:0.01024805, loss_ib:0.00268812
# epoch 22 loss_pde:0.01025371, loss_ib:0.00268674
# epoch 22 loss_pde:0.01025770, loss_ib:0.00268566
# epoch 22 loss_pde:0.01026119, loss_ib:0.00268477
# epoch 22 loss_pde:0.01026448, loss_ib:0.00268384
# epoch 22 loss_pde:0.01026896, loss_ib:0.00268255
# epoch 22 loss_pde:0.01027274, loss_ib:0.00268089
# epoch 22 loss_pde:0.01031825, loss_ib:0.00267658
# epoch 22 loss_pde:0.01030490, loss_ib:0.00267593
# epoch 22 loss_pde:0.01029459, loss_ib:0.00267572
# epoch 22 loss_pde:0.01028594, loss_ib:0.00267570
# epoch 22 loss_pde:0.01027961, loss_ib:0.00267565
# epoch 22: loss 0.037218
# epoch 23 loss_pde:0.01027402, loss_ib:0.00267560
# epoch 23 loss_pde:0.01026947, loss_ib:0.00267535
# epoch 23 loss_pde:0.01026169, loss_ib:0.00267513
# epoch 23 loss_pde:0.01026503, loss_ib:0.00267568
# epoch 23 loss_pde:0.01025410, loss_ib:0.00267460
# epoch 23 loss_pde:0.01024727, loss_ib:0.00267411
# epoch 23 loss_pde:0.01024299, loss_ib:0.00267375
# epoch 23 loss_pde:0.01023899, loss_ib:0.00267356
# epoch 23 loss_pde:0.01023620, loss_ib:0.00267336
# epoch 23 loss_pde:0.01023277, loss_ib:0.00267325
# epoch 23 loss_pde:0.01022954, loss_ib:0.00267301
# epoch 23 loss_pde:0.01021929, loss_ib:0.00267296
# epoch 23 loss_pde:0.01021649, loss_ib:0.00267174
# epoch 23 loss_pde:0.01020111, loss_ib:0.00267185
# epoch 23 loss_pde:0.01019790, loss_ib:0.00267153
# epoch 23 loss_pde:0.01020018, loss_ib:0.00267039
# epoch 23 loss_pde:0.01020016, loss_ib:0.00266973
# epoch 23 loss_pde:0.01020548, loss_ib:0.00266863
# epoch 23 loss_pde:0.01021214, loss_ib:0.00266727
# epoch 23 loss_pde:0.01022030, loss_ib:0.00266555
# epoch 23: loss 0.037030
# epoch 24 loss_pde:0.01023054, loss_ib:0.00266379
# epoch 24 loss_pde:0.01024009, loss_ib:0.00266204
# epoch 24 loss_pde:0.01024894, loss_ib:0.00266022
# epoch 24 loss_pde:0.01025430, loss_ib:0.00265876
# epoch 24 loss_pde:0.01026113, loss_ib:0.00265711
# epoch 24 loss_pde:0.01025806, loss_ib:0.00265635
# epoch 24 loss_pde:0.01025818, loss_ib:0.00265561
# epoch 24 loss_pde:0.01025204, loss_ib:0.00265514
# epoch 24 loss_pde:0.01024317, loss_ib:0.00265487
# epoch 24 loss_pde:0.01023204, loss_ib:0.00265503
# epoch 24 loss_pde:0.01022367, loss_ib:0.00265505
# epoch 24 loss_pde:0.01021237, loss_ib:0.00265539
# epoch 24 loss_pde:0.01021527, loss_ib:0.00265467
# epoch 24 loss_pde:0.01020998, loss_ib:0.00265446
# epoch 24 loss_pde:0.01020413, loss_ib:0.00265415
# epoch 24 loss_pde:0.01020253, loss_ib:0.00265344
# epoch 24 loss_pde:0.01020313, loss_ib:0.00265264
# epoch 24 loss_pde:0.01020706, loss_ib:0.00265159
# epoch 24 loss_pde:0.01021122, loss_ib:0.00265046
# epoch 24 loss_pde:0.01021782, loss_ib:0.00264887
# epoch 24: loss 0.036868
# epoch 25 loss_pde:0.01022441, loss_ib:0.00264730
# epoch 25 loss_pde:0.01022867, loss_ib:0.00264622
# epoch 25 loss_pde:0.01023345, loss_ib:0.00264520
# epoch 25 loss_pde:0.01023822, loss_ib:0.00264390
# epoch 25 loss_pde:0.01024643, loss_ib:0.00264216
# epoch 25 loss_pde:0.01025676, loss_ib:0.00264010
# epoch 25 loss_pde:0.01026857, loss_ib:0.00263778
# epoch 25 loss_pde:0.01028999, loss_ib:0.00263447
# epoch 25 loss_pde:0.01030162, loss_ib:0.00263220
# epoch 25 loss_pde:0.01031833, loss_ib:0.00262938
# epoch 25 loss_pde:0.01033229, loss_ib:0.00262686
# epoch 25 loss_pde:0.01034200, loss_ib:0.00262493
# epoch 25 loss_pde:0.01035491, loss_ib:0.00262276
# epoch 25 loss_pde:0.01036076, loss_ib:0.00262125
# epoch 25 loss_pde:0.01037146, loss_ib:0.00261898
# epoch 25 loss_pde:0.01037904, loss_ib:0.00261683
# epoch 25 loss_pde:0.01038096, loss_ib:0.00261527
# epoch 25 loss_pde:0.01038288, loss_ib:0.00261379
# epoch 25 loss_pde:0.01037785, loss_ib:0.00261311
# epoch 25 loss_pde:0.01036110, loss_ib:0.00261358
# epoch 25: loss 0.036697
# epoch 26 loss_pde:0.01035838, loss_ib:0.00261272
# epoch 26 loss_pde:0.01033915, loss_ib:0.00261366
# epoch 26 loss_pde:0.01033339, loss_ib:0.00261313
# epoch 26 loss_pde:0.01032040, loss_ib:0.00261327
# epoch 26 loss_pde:0.01031384, loss_ib:0.00261308
# epoch 26 loss_pde:0.01031186, loss_ib:0.00261259
# epoch 26 loss_pde:0.01030819, loss_ib:0.00261225
# epoch 26 loss_pde:0.01030560, loss_ib:0.00261172
# epoch 26 loss_pde:0.01029953, loss_ib:0.00261127
# epoch 26 loss_pde:0.01028647, loss_ib:0.00261125
# epoch 26 loss_pde:0.01027189, loss_ib:0.00261131
# epoch 26 loss_pde:0.01026249, loss_ib:0.00261142
# epoch 26 loss_pde:0.01024759, loss_ib:0.00261205
# epoch 26 loss_pde:0.01023497, loss_ib:0.00261255
# epoch 26 loss_pde:0.01022240, loss_ib:0.00261309
# epoch 26 loss_pde:0.01021123, loss_ib:0.00261342
# epoch 26 loss_pde:0.01019524, loss_ib:0.00261394
# epoch 26 loss_pde:0.01017827, loss_ib:0.00261434
# epoch 26 loss_pde:0.01017190, loss_ib:0.00261397
# epoch 26 loss_pde:0.01015946, loss_ib:0.00261379
# epoch 26: loss 0.036486
# epoch 27 loss_pde:0.01016067, loss_ib:0.00261226
# epoch 27 loss_pde:0.01016308, loss_ib:0.00261116
# epoch 27 loss_pde:0.01016869, loss_ib:0.00260957
# epoch 27 loss_pde:0.01017569, loss_ib:0.00260767
# epoch 27 loss_pde:0.01018720, loss_ib:0.00260522
# epoch 27 loss_pde:0.01019097, loss_ib:0.00260366
# epoch 27 loss_pde:0.01019119, loss_ib:0.00260251
# epoch 27 loss_pde:0.01018767, loss_ib:0.00260171
# epoch 27 loss_pde:0.01018491, loss_ib:0.00260101
# epoch 27 loss_pde:0.01017296, loss_ib:0.00260163
# epoch 27 loss_pde:0.01015840, loss_ib:0.00260247
# epoch 27 loss_pde:0.01013887, loss_ib:0.00260362
# epoch 27 loss_pde:0.01011197, loss_ib:0.00260534
# epoch 27 loss_pde:0.01009100, loss_ib:0.00260644
# epoch 27 loss_pde:0.01007509, loss_ib:0.00260730
# epoch 27 loss_pde:0.01006102, loss_ib:0.00260748
# epoch 27 loss_pde:0.01004752, loss_ib:0.00260746
# epoch 27 loss_pde:0.01004401, loss_ib:0.00260657
# epoch 27 loss_pde:0.01003694, loss_ib:0.00260606
# epoch 27 loss_pde:0.01004131, loss_ib:0.00260455
# epoch 27: loss 0.036283
# epoch 28 loss_pde:0.01004182, loss_ib:0.00260370
# epoch 28 loss_pde:0.01004078, loss_ib:0.00260296
# epoch 28 loss_pde:0.01003932, loss_ib:0.00260200
# epoch 28 loss_pde:0.01003648, loss_ib:0.00260108
# epoch 28 loss_pde:0.01003477, loss_ib:0.00260004
# epoch 28 loss_pde:0.01003455, loss_ib:0.00259870
# epoch 28 loss_pde:0.01003566, loss_ib:0.00259707
# epoch 28 loss_pde:0.01003676, loss_ib:0.00259562
# epoch 28 loss_pde:0.01004060, loss_ib:0.00259417
# epoch 28 loss_pde:0.01004207, loss_ib:0.00259312
# epoch 28 loss_pde:0.01004058, loss_ib:0.00259234
# epoch 28 loss_pde:0.01003920, loss_ib:0.00259132
# epoch 28 loss_pde:0.01003584, loss_ib:0.00259025
# epoch 28 loss_pde:0.01003799, loss_ib:0.00258828
# epoch 28 loss_pde:0.01003832, loss_ib:0.00258612
# epoch 28 loss_pde:0.01005353, loss_ib:0.00258309
# epoch 28 loss_pde:0.01005320, loss_ib:0.00258233
# epoch 28 loss_pde:0.01005483, loss_ib:0.00258138
# epoch 28 loss_pde:0.01005852, loss_ib:0.00258041
# epoch 28 loss_pde:0.01006433, loss_ib:0.00257925
# epoch 28: loss 0.036079
# epoch 29 loss_pde:0.01007551, loss_ib:0.00257738
# epoch 29 loss_pde:0.01010024, loss_ib:0.00257507
# epoch 29 loss_pde:0.01010672, loss_ib:0.00257330
# epoch 29 loss_pde:0.01011194, loss_ib:0.00257209
# epoch 29 loss_pde:0.01011803, loss_ib:0.00257096
# epoch 29 loss_pde:0.01012428, loss_ib:0.00256992
# epoch 29 loss_pde:0.01013102, loss_ib:0.00256889
# epoch 29 loss_pde:0.01013824, loss_ib:0.00256778
# epoch 29 loss_pde:0.01014788, loss_ib:0.00256622
# epoch 29 loss_pde:0.01016923, loss_ib:0.00256336
# epoch 29 loss_pde:0.01017828, loss_ib:0.00256164
# epoch 29 loss_pde:0.01018430, loss_ib:0.00256030
# epoch 29 loss_pde:0.01018814, loss_ib:0.00255921
# epoch 29 loss_pde:0.01018996, loss_ib:0.00255846
# epoch 29 loss_pde:0.01019082, loss_ib:0.00255787
# epoch 29 loss_pde:0.01019075, loss_ib:0.00255728
# epoch 29 loss_pde:0.01018710, loss_ib:0.00255678
# epoch 29 loss_pde:0.01018055, loss_ib:0.00255867
# epoch 29 loss_pde:0.01017606, loss_ib:0.00255693
# epoch 29 loss_pde:0.01016666, loss_ib:0.00255684
# epoch 29: loss 0.035849
# epoch 30 loss_pde:0.01016350, loss_ib:0.00255651
# epoch 30 loss_pde:0.01015127, loss_ib:0.00255727
# epoch 30 loss_pde:0.01014369, loss_ib:0.00255764
# epoch 30 loss_pde:0.01013095, loss_ib:0.00255845
# epoch 30 loss_pde:0.01011389, loss_ib:0.00255945
# epoch 30 loss_pde:0.01008812, loss_ib:0.00256077
# epoch 30 loss_pde:0.01004454, loss_ib:0.00256419
# epoch 30 loss_pde:0.01003199, loss_ib:0.00256437
# epoch 30 loss_pde:0.01002481, loss_ib:0.00256441
# epoch 30 loss_pde:0.01002031, loss_ib:0.00256431
# epoch 30 loss_pde:0.01001714, loss_ib:0.00256417
# epoch 30 loss_pde:0.01001304, loss_ib:0.00256409
# epoch 30 loss_pde:0.01000452, loss_ib:0.00256423
# epoch 30 loss_pde:0.00998586, loss_ib:0.00256501
# epoch 30 loss_pde:0.00996247, loss_ib:0.00256666
# epoch 30 loss_pde:0.00994432, loss_ib:0.00256728
# epoch 30 loss_pde:0.00992386, loss_ib:0.00256833
# epoch 30 loss_pde:0.00990448, loss_ib:0.00256946
# epoch 30 loss_pde:0.00988665, loss_ib:0.00257056
# epoch 30 loss_pde:0.00986989, loss_ib:0.00257151
# epoch 30: loss 0.035729
# epoch 31 loss_pde:0.00985161, loss_ib:0.00257242
# epoch 31 loss_pde:0.00983576, loss_ib:0.00257270
# epoch 31 loss_pde:0.00980806, loss_ib:0.00257391
# epoch 31 loss_pde:0.00980609, loss_ib:0.00257284
# epoch 31 loss_pde:0.00980935, loss_ib:0.00257139
# epoch 31 loss_pde:0.00981294, loss_ib:0.00256962
# epoch 31 loss_pde:0.00982753, loss_ib:0.00256699
# epoch 31 loss_pde:0.00983856, loss_ib:0.00256520
# epoch 31 loss_pde:0.00984542, loss_ib:0.00256373
# epoch 31 loss_pde:0.00985288, loss_ib:0.00256217
# epoch 31 loss_pde:0.00984636, loss_ib:0.00256187
# epoch 31 loss_pde:0.00985066, loss_ib:0.00256025
# epoch 31 loss_pde:0.00983898, loss_ib:0.00256068
# epoch 31 loss_pde:0.00982864, loss_ib:0.00256071
# epoch 31 loss_pde:0.00980878, loss_ib:0.00256189
# epoch 31 loss_pde:0.00979801, loss_ib:0.00256234
# epoch 31 loss_pde:0.00978906, loss_ib:0.00256251
# epoch 31 loss_pde:0.00977896, loss_ib:0.00256257
# epoch 31 loss_pde:0.00977457, loss_ib:0.00256188
# epoch 31 loss_pde:0.00977112, loss_ib:0.00256121
# epoch 31: loss 0.035576
# epoch 32 loss_pde:0.00977066, loss_ib:0.00256039
# epoch 32 loss_pde:0.00977093, loss_ib:0.00255950
# epoch 32 loss_pde:0.00976872, loss_ib:0.00255873
# epoch 32 loss_pde:0.00976585, loss_ib:0.00255788
# epoch 32 loss_pde:0.00974900, loss_ib:0.00255833
# epoch 32 loss_pde:0.00974462, loss_ib:0.00255784
# epoch 32 loss_pde:0.00973214, loss_ib:0.00255800
# epoch 32 loss_pde:0.00972004, loss_ib:0.00255791
# epoch 32 loss_pde:0.00970248, loss_ib:0.00255851
# epoch 32 loss_pde:0.00968770, loss_ib:0.00255902
# epoch 32 loss_pde:0.00967660, loss_ib:0.00255921
# epoch 32 loss_pde:0.00966630, loss_ib:0.00255924
# epoch 32 loss_pde:0.00965627, loss_ib:0.00255864
# epoch 32 loss_pde:0.00964851, loss_ib:0.00255766
# epoch 32 loss_pde:0.00964690, loss_ib:0.00255656
# epoch 32 loss_pde:0.00965300, loss_ib:0.00255493
# epoch 32 loss_pde:0.00965968, loss_ib:0.00255338
# epoch 32 loss_pde:0.00967003, loss_ib:0.00255141
# epoch 32 loss_pde:0.00967928, loss_ib:0.00254958
# epoch 32 loss_pde:0.00968968, loss_ib:0.00254769
# epoch 32: loss 0.035375
# epoch 33 loss_pde:0.00969810, loss_ib:0.00254591
# epoch 33 loss_pde:0.00970725, loss_ib:0.00254367
# epoch 33 loss_pde:0.00972606, loss_ib:0.00254010
# epoch 33 loss_pde:0.00973318, loss_ib:0.00253830
# epoch 33 loss_pde:0.00973848, loss_ib:0.00253646
# epoch 33 loss_pde:0.00974266, loss_ib:0.00253445
# epoch 33 loss_pde:0.00975295, loss_ib:0.00253164
# epoch 33 loss_pde:0.00975364, loss_ib:0.00253021
# epoch 33 loss_pde:0.00976248, loss_ib:0.00252809
# epoch 33 loss_pde:0.00977121, loss_ib:0.00252619
# epoch 33 loss_pde:0.00977228, loss_ib:0.00252490
# epoch 33 loss_pde:0.00977386, loss_ib:0.00252397
# epoch 33 loss_pde:0.00977019, loss_ib:0.00252337
# epoch 33 loss_pde:0.00976301, loss_ib:0.00252280
# epoch 33 loss_pde:0.00975165, loss_ib:0.00252256
# epoch 33 loss_pde:0.00974168, loss_ib:0.00252264
# epoch 33 loss_pde:0.00973310, loss_ib:0.00252266
# epoch 33 loss_pde:0.00972275, loss_ib:0.00252291
# epoch 33 loss_pde:0.00971470, loss_ib:0.00252284
# epoch 33 loss_pde:0.00970512, loss_ib:0.00252270
# epoch 33: loss 0.035157
# epoch 34 loss_pde:0.00969652, loss_ib:0.00252230
# epoch 34 loss_pde:0.00968840, loss_ib:0.00252175
# epoch 34 loss_pde:0.00968288, loss_ib:0.00252090
# epoch 34 loss_pde:0.00967571, loss_ib:0.00252011
# epoch 34 loss_pde:0.00967716, loss_ib:0.00251861
# epoch 34 loss_pde:0.00967404, loss_ib:0.00251808
# epoch 34 loss_pde:0.00967455, loss_ib:0.00251746
# epoch 34 loss_pde:0.00967924, loss_ib:0.00251632
# epoch 34 loss_pde:0.00967696, loss_ib:0.00251616
# epoch 34 loss_pde:0.00967354, loss_ib:0.00251583
# epoch 34 loss_pde:0.00966735, loss_ib:0.00251569
# epoch 34 loss_pde:0.00966382, loss_ib:0.00251510
# epoch 34 loss_pde:0.00965249, loss_ib:0.00251512
# epoch 34 loss_pde:0.00964940, loss_ib:0.00251470
# epoch 34 loss_pde:0.00964643, loss_ib:0.00251415
# epoch 34 loss_pde:0.00964052, loss_ib:0.00251370
# epoch 34 loss_pde:0.00963521, loss_ib:0.00251319
# epoch 34 loss_pde:0.00961799, loss_ib:0.00251385
# epoch 34 loss_pde:0.00961478, loss_ib:0.00251336
# epoch 34 loss_pde:0.00960766, loss_ib:0.00251302
# epoch 34: loss 0.034920
# epoch 35 loss_pde:0.00960531, loss_ib:0.00251217
# epoch 35 loss_pde:0.00960395, loss_ib:0.00251105
# epoch 35 loss_pde:0.00961010, loss_ib:0.00250935
# epoch 35 loss_pde:0.00960822, loss_ib:0.00250860
# epoch 35 loss_pde:0.00961389, loss_ib:0.00250710
# epoch 35 loss_pde:0.00961931, loss_ib:0.00250597
# epoch 35 loss_pde:0.00962511, loss_ib:0.00250462
# epoch 35 loss_pde:0.00963074, loss_ib:0.00250325
# epoch 35 loss_pde:0.00963706, loss_ib:0.00250180
# epoch 35 loss_pde:0.00964160, loss_ib:0.00250045
# epoch 35 loss_pde:0.00964804, loss_ib:0.00249895
# epoch 35 loss_pde:0.00965307, loss_ib:0.00249742
# epoch 35 loss_pde:0.00967604, loss_ib:0.00249414
# epoch 35 loss_pde:0.00967125, loss_ib:0.00249341
# epoch 35 loss_pde:0.00966531, loss_ib:0.00249287
# epoch 35 loss_pde:0.00966100, loss_ib:0.00249232
# epoch 35 loss_pde:0.00965681, loss_ib:0.00249175
# epoch 35 loss_pde:0.00965376, loss_ib:0.00249107
# epoch 35 loss_pde:0.00965385, loss_ib:0.00249032
# epoch 35 loss_pde:0.00965488, loss_ib:0.00248928
# epoch 35: loss 0.034727
# epoch 36 loss_pde:0.00965768, loss_ib:0.00248793
# epoch 36 loss_pde:0.00965879, loss_ib:0.00248670
# epoch 36 loss_pde:0.00966227, loss_ib:0.00248523
# epoch 36 loss_pde:0.00966145, loss_ib:0.00248431
# epoch 36 loss_pde:0.00966248, loss_ib:0.00248327
# epoch 36 loss_pde:0.00966027, loss_ib:0.00248237
# epoch 36 loss_pde:0.00965690, loss_ib:0.00248119
# epoch 36 loss_pde:0.00965724, loss_ib:0.00248053
# epoch 36 loss_pde:0.00965051, loss_ib:0.00247971
# epoch 36 loss_pde:0.00964704, loss_ib:0.00247912
# epoch 36 loss_pde:0.00964456, loss_ib:0.00247874
# epoch 36 loss_pde:0.00964361, loss_ib:0.00247833
# epoch 36 loss_pde:0.00964294, loss_ib:0.00247784
# epoch 36 loss_pde:0.00964287, loss_ib:0.00247704
# epoch 36 loss_pde:0.00963873, loss_ib:0.00247629
# epoch 36 loss_pde:0.00965354, loss_ib:0.00247355
# epoch 36 loss_pde:0.00964424, loss_ib:0.00247356
# epoch 36 loss_pde:0.00963613, loss_ib:0.00247339
# epoch 36 loss_pde:0.00962405, loss_ib:0.00247361
# epoch 36 loss_pde:0.00961630, loss_ib:0.00247344
# epoch 36: loss 0.034537
# epoch 37 loss_pde:0.00960441, loss_ib:0.00247361
# epoch 37 loss_pde:0.00959406, loss_ib:0.00247331
# epoch 37 loss_pde:0.00957897, loss_ib:0.00247318
# epoch 37 loss_pde:0.00956377, loss_ib:0.00247356
# epoch 37 loss_pde:0.00955954, loss_ib:0.00247329
# epoch 37 loss_pde:0.00955466, loss_ib:0.00247317
# epoch 37 loss_pde:0.00955276, loss_ib:0.00247296
# epoch 37 loss_pde:0.00955032, loss_ib:0.00247288
# epoch 37 loss_pde:0.00954820, loss_ib:0.00247271
# epoch 37 loss_pde:0.00954489, loss_ib:0.00247253
# epoch 37 loss_pde:0.00954059, loss_ib:0.00247219
# epoch 37 loss_pde:0.00953823, loss_ib:0.00247166
# epoch 37 loss_pde:0.00953399, loss_ib:0.00247135
# epoch 37 loss_pde:0.00953008, loss_ib:0.00247095
# epoch 37 loss_pde:0.00952681, loss_ib:0.00247053
# epoch 37 loss_pde:0.00952546, loss_ib:0.00247002
# epoch 37 loss_pde:0.00952380, loss_ib:0.00246954
# epoch 37 loss_pde:0.00952784, loss_ib:0.00246843
# epoch 37 loss_pde:0.00952883, loss_ib:0.00246754
# epoch 37 loss_pde:0.00953850, loss_ib:0.00246557
# epoch 37: loss 0.034341
# epoch 38 loss_pde:0.00954310, loss_ib:0.00246387
# epoch 38 loss_pde:0.00956233, loss_ib:0.00246052
# epoch 38 loss_pde:0.00956488, loss_ib:0.00245917
# epoch 38 loss_pde:0.00956194, loss_ib:0.00245848
# epoch 38 loss_pde:0.00955961, loss_ib:0.00245783
# epoch 38 loss_pde:0.00955375, loss_ib:0.00245781
# epoch 38 loss_pde:0.00954337, loss_ib:0.00245793
# epoch 38 loss_pde:0.00952605, loss_ib:0.00245821
# epoch 38 loss_pde:0.00950948, loss_ib:0.00245838
# epoch 38 loss_pde:0.00949691, loss_ib:0.00245867
# epoch 38 loss_pde:0.00949068, loss_ib:0.00245836
# epoch 38 loss_pde:0.00948136, loss_ib:0.00245849
# epoch 38 loss_pde:0.00948029, loss_ib:0.00245795
# epoch 38 loss_pde:0.00947825, loss_ib:0.00245754
# epoch 38 loss_pde:0.00947694, loss_ib:0.00245686
# epoch 38 loss_pde:0.00947780, loss_ib:0.00245577
# epoch 38 loss_pde:0.00947587, loss_ib:0.00245528
# epoch 38 loss_pde:0.00947393, loss_ib:0.00245462
# epoch 38 loss_pde:0.00947279, loss_ib:0.00245400
# epoch 38 loss_pde:0.00947303, loss_ib:0.00245333
# epoch 38: loss 0.034182
# epoch 39 loss_pde:0.00947361, loss_ib:0.00245261
# epoch 39 loss_pde:0.00947790, loss_ib:0.00245147
# epoch 39 loss_pde:0.00948075, loss_ib:0.00245049
# epoch 39 loss_pde:0.00948654, loss_ib:0.00244899
# epoch 39 loss_pde:0.00949218, loss_ib:0.00244737
# epoch 39 loss_pde:0.00949734, loss_ib:0.00244594
# epoch 39 loss_pde:0.00950091, loss_ib:0.00244482
# epoch 39 loss_pde:0.00950505, loss_ib:0.00244373
# epoch 39 loss_pde:0.00950760, loss_ib:0.00244281
# epoch 39 loss_pde:0.00951012, loss_ib:0.00244192
# epoch 39 loss_pde:0.00951326, loss_ib:0.00244090
# epoch 39 loss_pde:0.00951443, loss_ib:0.00243996
# epoch 39 loss_pde:0.00951576, loss_ib:0.00243917
# epoch 39 loss_pde:0.00951495, loss_ib:0.00243854
# epoch 39 loss_pde:0.00951482, loss_ib:0.00243787
# epoch 39 loss_pde:0.00951237, loss_ib:0.00243740
# epoch 39 loss_pde:0.00951269, loss_ib:0.00243651
# epoch 39 loss_pde:0.00950578, loss_ib:0.00243634
# epoch 39 loss_pde:0.00950396, loss_ib:0.00243588
# epoch 39 loss_pde:0.00950225, loss_ib:0.00243512
# epoch 39: loss 0.034000
# epoch 40 loss_pde:0.00949929, loss_ib:0.00243463
# epoch 40 loss_pde:0.00949849, loss_ib:0.00243413
# epoch 40 loss_pde:0.00949619, loss_ib:0.00243386
# epoch 40 loss_pde:0.00949571, loss_ib:0.00243329
# epoch 40 loss_pde:0.00948937, loss_ib:0.00243306
# epoch 40 loss_pde:0.00949377, loss_ib:0.00243173
# epoch 40 loss_pde:0.00949106, loss_ib:0.00243138
# epoch 40 loss_pde:0.00948858, loss_ib:0.00243089
# epoch 40 loss_pde:0.00948847, loss_ib:0.00243029
# epoch 40 loss_pde:0.00948946, loss_ib:0.00242970
# epoch 40 loss_pde:0.00949303, loss_ib:0.00242885
# epoch 40 loss_pde:0.00949741, loss_ib:0.00242775
# epoch 40 loss_pde:0.00950934, loss_ib:0.00242576
# epoch 40 loss_pde:0.00951973, loss_ib:0.00242420
# epoch 40 loss_pde:0.00952576, loss_ib:0.00242313
# epoch 40 loss_pde:0.00952887, loss_ib:0.00242223
# epoch 40 loss_pde:0.00952780, loss_ib:0.00242167
# epoch 40 loss_pde:0.00952322, loss_ib:0.00242135
# epoch 40 loss_pde:0.00951259, loss_ib:0.00242142
# epoch 40 loss_pde:0.00949636, loss_ib:0.00242202
# epoch 40: loss 0.033846
# epoch 41 loss_pde:0.00948524, loss_ib:0.00242246
# epoch 41 loss_pde:0.00947235, loss_ib:0.00242307
# epoch 41 loss_pde:0.00946074, loss_ib:0.00242354
# epoch 41 loss_pde:0.00945089, loss_ib:0.00242388
# epoch 41 loss_pde:0.00944423, loss_ib:0.00242390
# epoch 41 loss_pde:0.00943574, loss_ib:0.00242400
# epoch 41 loss_pde:0.00943107, loss_ib:0.00242374
# epoch 41 loss_pde:0.00942823, loss_ib:0.00242345
# epoch 41 loss_pde:0.00941832, loss_ib:0.00242371
# epoch 41 loss_pde:0.00941254, loss_ib:0.00242365
# epoch 41 loss_pde:0.00940704, loss_ib:0.00242346
# epoch 41 loss_pde:0.00938928, loss_ib:0.00242447
# epoch 41 loss_pde:0.00938349, loss_ib:0.00242434
# epoch 41 loss_pde:0.00937447, loss_ib:0.00242460
# epoch 41 loss_pde:0.00936362, loss_ib:0.00242484
# epoch 41 loss_pde:0.00934989, loss_ib:0.00242544
# epoch 41 loss_pde:0.00933960, loss_ib:0.00242573
# epoch 41 loss_pde:0.00933056, loss_ib:0.00242590
# epoch 41 loss_pde:0.00932467, loss_ib:0.00242562
# epoch 41 loss_pde:0.00932050, loss_ib:0.00242501
# epoch 41: loss 0.033710
# epoch 42 loss_pde:0.00932275, loss_ib:0.00242368
# epoch 42 loss_pde:0.00932767, loss_ib:0.00242219
# epoch 42 loss_pde:0.00932685, loss_ib:0.00242151
# epoch 42 loss_pde:0.00933238, loss_ib:0.00242019
# epoch 42 loss_pde:0.00933377, loss_ib:0.00241936
# epoch 42 loss_pde:0.00933501, loss_ib:0.00241850
# epoch 42 loss_pde:0.00933276, loss_ib:0.00241786
# epoch 42 loss_pde:0.00933872, loss_ib:0.00241742
# epoch 42 loss_pde:0.00933093, loss_ib:0.00241703
# epoch 42 loss_pde:0.00932211, loss_ib:0.00241715
# epoch 42 loss_pde:0.00931311, loss_ib:0.00241751
# epoch 42 loss_pde:0.00930411, loss_ib:0.00241801
# epoch 42 loss_pde:0.00929646, loss_ib:0.00241845
# epoch 42 loss_pde:0.00928941, loss_ib:0.00241884
# epoch 42 loss_pde:0.00928252, loss_ib:0.00241909
# epoch 42 loss_pde:0.00927292, loss_ib:0.00241937
# epoch 42 loss_pde:0.00926605, loss_ib:0.00241928
# epoch 42 loss_pde:0.00926516, loss_ib:0.00241868
# epoch 42 loss_pde:0.00926743, loss_ib:0.00241753
# epoch 42 loss_pde:0.00927287, loss_ib:0.00241606
# epoch 42: loss 0.033560
# epoch 43 loss_pde:0.00927957, loss_ib:0.00241456
# epoch 43 loss_pde:0.00928571, loss_ib:0.00241308
# epoch 43 loss_pde:0.00929797, loss_ib:0.00241089
# epoch 43 loss_pde:0.00929875, loss_ib:0.00240978
# epoch 43 loss_pde:0.00930278, loss_ib:0.00240873
# epoch 43 loss_pde:0.00930106, loss_ib:0.00240795
# epoch 43 loss_pde:0.00929662, loss_ib:0.00240756
# epoch 43 loss_pde:0.00929008, loss_ib:0.00240758
# epoch 43 loss_pde:0.00928396, loss_ib:0.00240765
# epoch 43 loss_pde:0.00927795, loss_ib:0.00240765
# epoch 43 loss_pde:0.00927180, loss_ib:0.00240758
# epoch 43 loss_pde:0.00927047, loss_ib:0.00240691
# epoch 43 loss_pde:0.00927108, loss_ib:0.00240571
# epoch 43 loss_pde:0.00927705, loss_ib:0.00240416
# epoch 43 loss_pde:0.00928322, loss_ib:0.00240272
# epoch 43 loss_pde:0.00929187, loss_ib:0.00240101
# epoch 43 loss_pde:0.00929480, loss_ib:0.00239977
# epoch 43 loss_pde:0.00931052, loss_ib:0.00239720
# epoch 43 loss_pde:0.00931471, loss_ib:0.00239581
# epoch 43 loss_pde:0.00932420, loss_ib:0.00239392
# epoch 43: loss 0.033425
# epoch 44 loss_pde:0.00933175, loss_ib:0.00239234
# epoch 44 loss_pde:0.00933611, loss_ib:0.00239102
# epoch 44 loss_pde:0.00934011, loss_ib:0.00238974
# epoch 44 loss_pde:0.00934441, loss_ib:0.00238837
# epoch 44 loss_pde:0.00935184, loss_ib:0.00238649
# epoch 44 loss_pde:0.00936707, loss_ib:0.00238398
# epoch 44 loss_pde:0.00937190, loss_ib:0.00238262
# epoch 44 loss_pde:0.00937517, loss_ib:0.00238166
# epoch 44 loss_pde:0.00937857, loss_ib:0.00238071
# epoch 44 loss_pde:0.00938073, loss_ib:0.00237987
# epoch 44 loss_pde:0.00938320, loss_ib:0.00237887
# epoch 44 loss_pde:0.00938936, loss_ib:0.00237772
# epoch 44 loss_pde:0.00938935, loss_ib:0.00237703
# epoch 44 loss_pde:0.00938910, loss_ib:0.00237643
# epoch 44 loss_pde:0.00938450, loss_ib:0.00237622
# epoch 44 loss_pde:0.00938094, loss_ib:0.00237602
# epoch 44 loss_pde:0.00937341, loss_ib:0.00237623
# epoch 44 loss_pde:0.00936784, loss_ib:0.00237610
# epoch 44 loss_pde:0.00935162, loss_ib:0.00237689
# epoch 44 loss_pde:0.00934615, loss_ib:0.00237693
# epoch 44: loss 0.033255
# epoch 45 loss_pde:0.00934099, loss_ib:0.00237674
# epoch 45 loss_pde:0.00933272, loss_ib:0.00237706
# epoch 45 loss_pde:0.00933140, loss_ib:0.00237680
# epoch 45 loss_pde:0.00933052, loss_ib:0.00237652
# epoch 45 loss_pde:0.00932877, loss_ib:0.00237631
# epoch 45 loss_pde:0.00932627, loss_ib:0.00237612
# epoch 45 loss_pde:0.00932186, loss_ib:0.00237600
# epoch 45 loss_pde:0.00931584, loss_ib:0.00237588
# epoch 45 loss_pde:0.00930961, loss_ib:0.00237580
# epoch 45 loss_pde:0.00930243, loss_ib:0.00237580
# epoch 45 loss_pde:0.00929690, loss_ib:0.00237558
# epoch 45 loss_pde:0.00929170, loss_ib:0.00237521
# epoch 45 loss_pde:0.00928797, loss_ib:0.00237466
# epoch 45 loss_pde:0.00928468, loss_ib:0.00237398
# epoch 45 loss_pde:0.00928161, loss_ib:0.00237309
# epoch 45 loss_pde:0.00927629, loss_ib:0.00237225
# epoch 45 loss_pde:0.00927700, loss_ib:0.00237081
# epoch 45 loss_pde:0.00927598, loss_ib:0.00237010
# epoch 45 loss_pde:0.00927674, loss_ib:0.00236902
# epoch 45 loss_pde:0.00927711, loss_ib:0.00236794
# epoch 45: loss 0.033108
# epoch 46 loss_pde:0.00927969, loss_ib:0.00236667
# epoch 46 loss_pde:0.00928161, loss_ib:0.00236564
# epoch 46 loss_pde:0.00928365, loss_ib:0.00236449
# epoch 46 loss_pde:0.00928431, loss_ib:0.00236353
# epoch 46 loss_pde:0.00928522, loss_ib:0.00236228
# epoch 46 loss_pde:0.00928555, loss_ib:0.00236091
# epoch 46 loss_pde:0.00928575, loss_ib:0.00235974
# epoch 46 loss_pde:0.00928777, loss_ib:0.00235866
# epoch 46 loss_pde:0.00928675, loss_ib:0.00235805
# epoch 46 loss_pde:0.00928355, loss_ib:0.00235736
# epoch 46 loss_pde:0.00928010, loss_ib:0.00235620
# epoch 46 loss_pde:0.00927534, loss_ib:0.00235535
# epoch 46 loss_pde:0.00928100, loss_ib:0.00235334
# epoch 46 loss_pde:0.00927198, loss_ib:0.00235291
# epoch 46 loss_pde:0.00927080, loss_ib:0.00235212
# epoch 46 loss_pde:0.00926492, loss_ib:0.00235199
# epoch 46 loss_pde:0.00926344, loss_ib:0.00235148
# epoch 46 loss_pde:0.00925799, loss_ib:0.00235126
# epoch 46 loss_pde:0.00926296, loss_ib:0.00234982
# epoch 46 loss_pde:0.00926168, loss_ib:0.00234907
# epoch 46: loss 0.032946
# epoch 47 loss_pde:0.00926798, loss_ib:0.00234739
# epoch 47 loss_pde:0.00928009, loss_ib:0.00234491
# epoch 47 loss_pde:0.00929821, loss_ib:0.00234187
# epoch 47 loss_pde:0.00930801, loss_ib:0.00234013
# epoch 47 loss_pde:0.00931732, loss_ib:0.00233822
# epoch 47 loss_pde:0.00932613, loss_ib:0.00233632
# epoch 47 loss_pde:0.00933249, loss_ib:0.00233459
# epoch 47 loss_pde:0.00933736, loss_ib:0.00233300
# epoch 47 loss_pde:0.00934200, loss_ib:0.00233152
# epoch 47 loss_pde:0.00933718, loss_ib:0.00233101
# epoch 47 loss_pde:0.00933659, loss_ib:0.00233024
# epoch 47 loss_pde:0.00932954, loss_ib:0.00233018
# epoch 47 loss_pde:0.00932420, loss_ib:0.00233002
# epoch 47 loss_pde:0.00931787, loss_ib:0.00233008
# epoch 47 loss_pde:0.00931328, loss_ib:0.00233007
# epoch 47 loss_pde:0.00930932, loss_ib:0.00232950
# epoch 47 loss_pde:0.00931001, loss_ib:0.00232796
# epoch 47 loss_pde:0.00931387, loss_ib:0.00232712
# epoch 47 loss_pde:0.00931739, loss_ib:0.00232548
# epoch 47 loss_pde:0.00932230, loss_ib:0.00232404
# epoch 47: loss 0.032742
# epoch 48 loss_pde:0.00932774, loss_ib:0.00232271
# epoch 48 loss_pde:0.00933217, loss_ib:0.00232152
# epoch 48 loss_pde:0.00933413, loss_ib:0.00232047
# epoch 48 loss_pde:0.00933167, loss_ib:0.00231961
# epoch 48 loss_pde:0.00931242, loss_ib:0.00232038
# epoch 48 loss_pde:0.00930298, loss_ib:0.00232018
# epoch 48 loss_pde:0.00929059, loss_ib:0.00232070
# epoch 48 loss_pde:0.00927103, loss_ib:0.00232177
# epoch 48 loss_pde:0.00924697, loss_ib:0.00232334
# epoch 48 loss_pde:0.00922415, loss_ib:0.00232485
# epoch 48 loss_pde:0.00919711, loss_ib:0.00232683
# epoch 48 loss_pde:0.00917775, loss_ib:0.00232817
# epoch 48 loss_pde:0.00916035, loss_ib:0.00232912
# epoch 48 loss_pde:0.00913407, loss_ib:0.00233068
# epoch 48 loss_pde:0.00912393, loss_ib:0.00233088
# epoch 48 loss_pde:0.00911736, loss_ib:0.00233065
# epoch 48 loss_pde:0.00911637, loss_ib:0.00233005
# epoch 48 loss_pde:0.00911812, loss_ib:0.00232920
# epoch 48 loss_pde:0.00912042, loss_ib:0.00232799
# epoch 48 loss_pde:0.00912369, loss_ib:0.00232642
# ...
# epoch 985 loss_pde:0.00429953, loss_ib:0.00050640
# epoch 985 loss_pde:0.00429899, loss_ib:0.00050642
# epoch 985 loss_pde:0.00429846, loss_ib:0.00050644
# epoch 985 loss_pde:0.00429765, loss_ib:0.00050647
# epoch 985 loss_pde:0.00429661, loss_ib:0.00050650
# epoch 985 loss_pde:0.00429582, loss_ib:0.00050652
# epoch 985 loss_pde:0.00429517, loss_ib:0.00050654
# epoch 985 loss_pde:0.00429460, loss_ib:0.00050654
# epoch 985 loss_pde:0.00429389, loss_ib:0.00050656
# epoch 985 loss_pde:0.00429389, loss_ib:0.00050653
# epoch 985: loss 0.009367
# epoch 986 loss_pde:0.00429361, loss_ib:0.00050653
# epoch 986 loss_pde:0.00429332, loss_ib:0.00050654
# epoch 986 loss_pde:0.00429301, loss_ib:0.00050654
# epoch 986 loss_pde:0.00429267, loss_ib:0.00050654
# epoch 986 loss_pde:0.00429223, loss_ib:0.00050656
# epoch 986 loss_pde:0.00429159, loss_ib:0.00050658
# epoch 986 loss_pde:0.00429011, loss_ib:0.00050666
# epoch 986 loss_pde:0.00428933, loss_ib:0.00050668
# epoch 986 loss_pde:0.00428858, loss_ib:0.00050670
# epoch 986 loss_pde:0.00428805, loss_ib:0.00050669
# epoch 986 loss_pde:0.00428763, loss_ib:0.00050668
# epoch 986 loss_pde:0.00428759, loss_ib:0.00050666
# epoch 986 loss_pde:0.00428756, loss_ib:0.00050664
# epoch 986 loss_pde:0.00428757, loss_ib:0.00050661
# epoch 986 loss_pde:0.00428761, loss_ib:0.00050658
# epoch 986 loss_pde:0.00428760, loss_ib:0.00050654
# epoch 986 loss_pde:0.00428755, loss_ib:0.00050651
# epoch 986 loss_pde:0.00428752, loss_ib:0.00050648
# epoch 986 loss_pde:0.00428741, loss_ib:0.00050647
# epoch 986 loss_pde:0.00428710, loss_ib:0.00050647
# epoch 986: loss 0.009359
# epoch 987 loss_pde:0.00428669, loss_ib:0.00050647
# epoch 987 loss_pde:0.00428636, loss_ib:0.00050646
# epoch 987 loss_pde:0.00428602, loss_ib:0.00050645
# epoch 987 loss_pde:0.00428587, loss_ib:0.00050642
# epoch 987 loss_pde:0.00428561, loss_ib:0.00050640
# epoch 987 loss_pde:0.00428554, loss_ib:0.00050635
# epoch 987 loss_pde:0.00428537, loss_ib:0.00050632
# epoch 987 loss_pde:0.00428509, loss_ib:0.00050630
# epoch 987 loss_pde:0.00428496, loss_ib:0.00050629
# epoch 987 loss_pde:0.00428458, loss_ib:0.00050628
# epoch 987 loss_pde:0.00428413, loss_ib:0.00050627
# epoch 987 loss_pde:0.00428358, loss_ib:0.00050629
# epoch 987 loss_pde:0.00428261, loss_ib:0.00050652
# epoch 987 loss_pde:0.00428249, loss_ib:0.00050639
# epoch 987 loss_pde:0.00428237, loss_ib:0.00050635
# epoch 987 loss_pde:0.00428223, loss_ib:0.00050634
# epoch 987 loss_pde:0.00428208, loss_ib:0.00050634
# epoch 987 loss_pde:0.00428188, loss_ib:0.00050634
# epoch 987 loss_pde:0.00428165, loss_ib:0.00050634
# epoch 987 loss_pde:0.00428143, loss_ib:0.00050633
# epoch 987: loss 0.009351
# epoch 988 loss_pde:0.00428123, loss_ib:0.00050632
# epoch 988 loss_pde:0.00428099, loss_ib:0.00050629
# epoch 988 loss_pde:0.00428160, loss_ib:0.00050622
# epoch 988 loss_pde:0.00428135, loss_ib:0.00050618
# epoch 988 loss_pde:0.00428120, loss_ib:0.00050615
# epoch 988 loss_pde:0.00428121, loss_ib:0.00050613
# epoch 988 loss_pde:0.00428121, loss_ib:0.00050611
# epoch 988 loss_pde:0.00428123, loss_ib:0.00050610
# epoch 988 loss_pde:0.00428124, loss_ib:0.00050608
# epoch 988 loss_pde:0.00428127, loss_ib:0.00050604
# epoch 988 loss_pde:0.00428115, loss_ib:0.00050601
# epoch 988 loss_pde:0.00428100, loss_ib:0.00050598
# epoch 988 loss_pde:0.00428055, loss_ib:0.00050596
# epoch 988 loss_pde:0.00428017, loss_ib:0.00050594
# epoch 988 loss_pde:0.00427977, loss_ib:0.00050594
# epoch 988 loss_pde:0.00427943, loss_ib:0.00050594
# epoch 988 loss_pde:0.00427902, loss_ib:0.00050595
# epoch 988 loss_pde:0.00427878, loss_ib:0.00050595
# epoch 988 loss_pde:0.00427842, loss_ib:0.00050595
# epoch 988 loss_pde:0.00427789, loss_ib:0.00050593
# epoch 988: loss 0.009344
# epoch 989 loss_pde:0.00427764, loss_ib:0.00050589
# epoch 989 loss_pde:0.00427744, loss_ib:0.00050586
# epoch 989 loss_pde:0.00427751, loss_ib:0.00050578
# epoch 989 loss_pde:0.00427741, loss_ib:0.00050573
# epoch 989 loss_pde:0.00427754, loss_ib:0.00050567
# epoch 989 loss_pde:0.00427743, loss_ib:0.00050563
# epoch 989 loss_pde:0.00427801, loss_ib:0.00050552
# epoch 989 loss_pde:0.00427778, loss_ib:0.00050551
# epoch 989 loss_pde:0.00427762, loss_ib:0.00050549
# epoch 989 loss_pde:0.00427722, loss_ib:0.00050548
# epoch 989 loss_pde:0.00427705, loss_ib:0.00050546
# epoch 989 loss_pde:0.00427685, loss_ib:0.00050543
# epoch 989 loss_pde:0.00427711, loss_ib:0.00050534
# epoch 989 loss_pde:0.00427728, loss_ib:0.00050529
# epoch 989 loss_pde:0.00427758, loss_ib:0.00050523
# epoch 989 loss_pde:0.00427764, loss_ib:0.00050518
# epoch 989 loss_pde:0.00427802, loss_ib:0.00050510
# epoch 989 loss_pde:0.00427839, loss_ib:0.00050503
# epoch 989 loss_pde:0.00427880, loss_ib:0.00050493
# epoch 989 loss_pde:0.00427913, loss_ib:0.00050484
# epoch 989: loss 0.009337
# epoch 990 loss_pde:0.00427955, loss_ib:0.00050474
# epoch 990 loss_pde:0.00427967, loss_ib:0.00050468
# epoch 990 loss_pde:0.00427964, loss_ib:0.00050465
# epoch 990 loss_pde:0.00427957, loss_ib:0.00050462
# epoch 990 loss_pde:0.00427945, loss_ib:0.00050460
# epoch 990 loss_pde:0.00427942, loss_ib:0.00050456
# epoch 990 loss_pde:0.00427933, loss_ib:0.00050453
# epoch 990 loss_pde:0.00427955, loss_ib:0.00050446
# epoch 990 loss_pde:0.00427961, loss_ib:0.00050443
# epoch 990 loss_pde:0.00427977, loss_ib:0.00050438
# epoch 990 loss_pde:0.00427999, loss_ib:0.00050430
# epoch 990 loss_pde:0.00428038, loss_ib:0.00050419
# epoch 990 loss_pde:0.00428062, loss_ib:0.00050411
# epoch 990 loss_pde:0.00428077, loss_ib:0.00050405
# epoch 990 loss_pde:0.00428079, loss_ib:0.00050402
# epoch 990 loss_pde:0.00428067, loss_ib:0.00050400
# epoch 990 loss_pde:0.00428059, loss_ib:0.00050398
# epoch 990 loss_pde:0.00428033, loss_ib:0.00050398
# epoch 990 loss_pde:0.00428006, loss_ib:0.00050397
# epoch 990 loss_pde:0.00427967, loss_ib:0.00050395
# epoch 990: loss 0.009327
# epoch 991 loss_pde:0.00427931, loss_ib:0.00050393
# epoch 991 loss_pde:0.00428182, loss_ib:0.00050400
# epoch 991 loss_pde:0.00428026, loss_ib:0.00050386
# epoch 991 loss_pde:0.00427962, loss_ib:0.00050384
# epoch 991 loss_pde:0.00427929, loss_ib:0.00050383
# epoch 991 loss_pde:0.00427910, loss_ib:0.00050383
# epoch 991 loss_pde:0.00427897, loss_ib:0.00050383
# epoch 991 loss_pde:0.00427891, loss_ib:0.00050382
# epoch 991 loss_pde:0.00427890, loss_ib:0.00050380
# epoch 991 loss_pde:0.00427896, loss_ib:0.00050376
# epoch 991 loss_pde:0.00427917, loss_ib:0.00050370
# epoch 991 loss_pde:0.00427980, loss_ib:0.00050359
# epoch 991 loss_pde:0.00428010, loss_ib:0.00050350
# epoch 991 loss_pde:0.00428019, loss_ib:0.00050346
# epoch 991 loss_pde:0.00428027, loss_ib:0.00050342
# epoch 991 loss_pde:0.00428027, loss_ib:0.00050340
# epoch 991 loss_pde:0.00428025, loss_ib:0.00050339
# epoch 991 loss_pde:0.00428017, loss_ib:0.00050337
# epoch 991 loss_pde:0.00428002, loss_ib:0.00050335
# epoch 991 loss_pde:0.00427999, loss_ib:0.00050335
# epoch 991: loss 0.009319
# epoch 992 loss_pde:0.00427982, loss_ib:0.00050331
# epoch 992 loss_pde:0.00427962, loss_ib:0.00050330
# epoch 992 loss_pde:0.00427942, loss_ib:0.00050330
# epoch 992 loss_pde:0.00427923, loss_ib:0.00050330
# epoch 992 loss_pde:0.00427907, loss_ib:0.00050331
# epoch 992 loss_pde:0.00427890, loss_ib:0.00050331
# epoch 992 loss_pde:0.00427869, loss_ib:0.00050332
# epoch 992 loss_pde:0.00427839, loss_ib:0.00050332
# epoch 992 loss_pde:0.00427803, loss_ib:0.00050332
# epoch 992 loss_pde:0.00427778, loss_ib:0.00050330
# epoch 992 loss_pde:0.00427767, loss_ib:0.00050329
# epoch 992 loss_pde:0.00427763, loss_ib:0.00050327
# epoch 992 loss_pde:0.00427764, loss_ib:0.00050326
# epoch 992 loss_pde:0.00427767, loss_ib:0.00050324
# epoch 992 loss_pde:0.00427772, loss_ib:0.00050322
# epoch 992 loss_pde:0.00427778, loss_ib:0.00050320
# epoch 992 loss_pde:0.00427786, loss_ib:0.00050318
# epoch 992 loss_pde:0.00427792, loss_ib:0.00050315
# epoch 992 loss_pde:0.00427859, loss_ib:0.00050306
# epoch 992 loss_pde:0.00427857, loss_ib:0.00050303
# epoch 992: loss 0.009313
# epoch 993 loss_pde:0.00427852, loss_ib:0.00050301
# epoch 993 loss_pde:0.00427851, loss_ib:0.00050298
# epoch 993 loss_pde:0.00427858, loss_ib:0.00050295
# epoch 993 loss_pde:0.00427871, loss_ib:0.00050291
# epoch 993 loss_pde:0.00427895, loss_ib:0.00050286
# epoch 993 loss_pde:0.00427947, loss_ib:0.00050275
# epoch 993 loss_pde:0.00427952, loss_ib:0.00050272
# epoch 993 loss_pde:0.00428033, loss_ib:0.00050259
# epoch 993 loss_pde:0.00428080, loss_ib:0.00050250
# epoch 993 loss_pde:0.00428125, loss_ib:0.00050244
# epoch 993 loss_pde:0.00428149, loss_ib:0.00050240
# epoch 993 loss_pde:0.00428170, loss_ib:0.00050236
# epoch 993 loss_pde:0.00428188, loss_ib:0.00050232
# epoch 993 loss_pde:0.00428205, loss_ib:0.00050228
# epoch 993 loss_pde:0.00428236, loss_ib:0.00050221
# epoch 993 loss_pde:0.00428243, loss_ib:0.00050219
# epoch 993 loss_pde:0.00428247, loss_ib:0.00050216
# epoch 993 loss_pde:0.00428248, loss_ib:0.00050213
# epoch 993 loss_pde:0.00428252, loss_ib:0.00050210
# epoch 993 loss_pde:0.00428259, loss_ib:0.00050207
# epoch 993: loss 0.009309
# epoch 994 loss_pde:0.00428273, loss_ib:0.00050203
# epoch 994 loss_pde:0.00428310, loss_ib:0.00050198
# epoch 994 loss_pde:0.00428323, loss_ib:0.00050194
# epoch 994 loss_pde:0.00428338, loss_ib:0.00050190
# epoch 994 loss_pde:0.00428354, loss_ib:0.00050186
# epoch 994 loss_pde:0.00428369, loss_ib:0.00050183
# epoch 994 loss_pde:0.00428384, loss_ib:0.00050180
# epoch 994 loss_pde:0.00428394, loss_ib:0.00050178
# epoch 994 loss_pde:0.00428405, loss_ib:0.00050176
# epoch 994 loss_pde:0.00428430, loss_ib:0.00050170
# epoch 994 loss_pde:0.00428417, loss_ib:0.00050168
# epoch 994 loss_pde:0.00428488, loss_ib:0.00050157
# epoch 994 loss_pde:0.00428489, loss_ib:0.00050155
# epoch 994 loss_pde:0.00428494, loss_ib:0.00050153
# epoch 994 loss_pde:0.00428496, loss_ib:0.00050150
# epoch 994 loss_pde:0.00428503, loss_ib:0.00050147
# epoch 994 loss_pde:0.00428510, loss_ib:0.00050144
# epoch 994 loss_pde:0.00428563, loss_ib:0.00050137
# epoch 994 loss_pde:0.00428568, loss_ib:0.00050134
# epoch 994 loss_pde:0.00428576, loss_ib:0.00050131
# epoch 994: loss 0.009303
# epoch 995 loss_pde:0.00428587, loss_ib:0.00050128
# epoch 995 loss_pde:0.00428601, loss_ib:0.00050124
# epoch 995 loss_pde:0.00428612, loss_ib:0.00050120
# epoch 995 loss_pde:0.00428623, loss_ib:0.00050116
# epoch 995 loss_pde:0.00428621, loss_ib:0.00050113
# epoch 995 loss_pde:0.00428637, loss_ib:0.00050107
# epoch 995 loss_pde:0.00428627, loss_ib:0.00050105
# epoch 995 loss_pde:0.00428593, loss_ib:0.00050104
# epoch 995 loss_pde:0.00428567, loss_ib:0.00050104
# epoch 995 loss_pde:0.00428543, loss_ib:0.00050104
# epoch 995 loss_pde:0.00428526, loss_ib:0.00050103
# epoch 995 loss_pde:0.00428529, loss_ib:0.00050100
# epoch 995 loss_pde:0.00428532, loss_ib:0.00050097
# epoch 995 loss_pde:0.00428551, loss_ib:0.00050091
# epoch 995 loss_pde:0.00428605, loss_ib:0.00050082
# epoch 995 loss_pde:0.00428628, loss_ib:0.00050076
# epoch 995 loss_pde:0.00428662, loss_ib:0.00050068
# epoch 995 loss_pde:0.00428704, loss_ib:0.00050060
# epoch 995 loss_pde:0.00428751, loss_ib:0.00050051
# epoch 995 loss_pde:0.00428795, loss_ib:0.00050043
# epoch 995: loss 0.009299
# epoch 996 loss_pde:0.00428858, loss_ib:0.00050034
# epoch 996 loss_pde:0.00428889, loss_ib:0.00050028
# epoch 996 loss_pde:0.00428910, loss_ib:0.00050023
# epoch 996 loss_pde:0.00428919, loss_ib:0.00050019
# epoch 996 loss_pde:0.00428915, loss_ib:0.00050016
# epoch 996 loss_pde:0.00428927, loss_ib:0.00050011
# epoch 996 loss_pde:0.00428924, loss_ib:0.00050007
# epoch 996 loss_pde:0.00428919, loss_ib:0.00050006
# epoch 996 loss_pde:0.00428920, loss_ib:0.00050002
# epoch 996 loss_pde:0.00428903, loss_ib:0.00050000
# epoch 996 loss_pde:0.00428911, loss_ib:0.00049997
# epoch 996 loss_pde:0.00428925, loss_ib:0.00049992
# epoch 996 loss_pde:0.00428942, loss_ib:0.00049986
# epoch 996 loss_pde:0.00428954, loss_ib:0.00049980
# epoch 996 loss_pde:0.00428971, loss_ib:0.00049974
# epoch 996 loss_pde:0.00428986, loss_ib:0.00049968
# epoch 996 loss_pde:0.00428990, loss_ib:0.00049963
# epoch 996 loss_pde:0.00428990, loss_ib:0.00049961
# epoch 996 loss_pde:0.00428987, loss_ib:0.00049957
# epoch 996 loss_pde:0.00428995, loss_ib:0.00049953
# epoch 996: loss 0.009292
# epoch 997 loss_pde:0.00429007, loss_ib:0.00049947
# epoch 997 loss_pde:0.00429058, loss_ib:0.00049938
# epoch 997 loss_pde:0.00429086, loss_ib:0.00049932
# epoch 997 loss_pde:0.00429107, loss_ib:0.00049928
# epoch 997 loss_pde:0.00429127, loss_ib:0.00049924
# epoch 997 loss_pde:0.00429146, loss_ib:0.00049920
# epoch 997 loss_pde:0.00429155, loss_ib:0.00049916
# epoch 997 loss_pde:0.00429159, loss_ib:0.00049912
# epoch 997 loss_pde:0.00429158, loss_ib:0.00049908
# epoch 997 loss_pde:0.00429141, loss_ib:0.00049906
# epoch 997 loss_pde:0.00429111, loss_ib:0.00049903
# epoch 997 loss_pde:0.00429012, loss_ib:0.00049908
# epoch 997 loss_pde:0.00428988, loss_ib:0.00049906
# epoch 997 loss_pde:0.00428967, loss_ib:0.00049905
# epoch 997 loss_pde:0.00428945, loss_ib:0.00049905
# epoch 997 loss_pde:0.00428923, loss_ib:0.00049906
# epoch 997 loss_pde:0.00428901, loss_ib:0.00049906
# epoch 997 loss_pde:0.00428873, loss_ib:0.00049905
# epoch 997 loss_pde:0.00428856, loss_ib:0.00049904
# epoch 997 loss_pde:0.00428844, loss_ib:0.00049902
# epoch 997: loss 0.009285
# epoch 998 loss_pde:0.00428838, loss_ib:0.00049900
# epoch 998 loss_pde:0.00428832, loss_ib:0.00049897
# epoch 998 loss_pde:0.00428831, loss_ib:0.00049893
# epoch 998 loss_pde:0.00428828, loss_ib:0.00049890
# epoch 998 loss_pde:0.00428823, loss_ib:0.00049886
# epoch 998 loss_pde:0.00428820, loss_ib:0.00049884
# epoch 998 loss_pde:0.00428809, loss_ib:0.00049880
# epoch 998 loss_pde:0.00428790, loss_ib:0.00049877
# epoch 998 loss_pde:0.00428762, loss_ib:0.00049875
# epoch 998 loss_pde:0.00428728, loss_ib:0.00049875
# epoch 998 loss_pde:0.00428697, loss_ib:0.00049875
# epoch 998 loss_pde:0.00428622, loss_ib:0.00049879
# epoch 998 loss_pde:0.00428609, loss_ib:0.00049877
# epoch 998 loss_pde:0.00428549, loss_ib:0.00049881
# epoch 998 loss_pde:0.00428474, loss_ib:0.00049885
# epoch 998 loss_pde:0.00428406, loss_ib:0.00049888
# epoch 998 loss_pde:0.00428342, loss_ib:0.00049892
# epoch 998 loss_pde:0.00428274, loss_ib:0.00049896
# epoch 998 loss_pde:0.00428253, loss_ib:0.00049897
# epoch 998 loss_pde:0.00428221, loss_ib:0.00049898
# epoch 998: loss 0.009278
# epoch 999 loss_pde:0.00428179, loss_ib:0.00049900
# epoch 999 loss_pde:0.00428131, loss_ib:0.00049902
# epoch 999 loss_pde:0.00428074, loss_ib:0.00049905
# epoch 999 loss_pde:0.00428009, loss_ib:0.00049909
# epoch 999 loss_pde:0.00427934, loss_ib:0.00049914
# epoch 999 loss_pde:0.00427880, loss_ib:0.00049917
# epoch 999 loss_pde:0.00427848, loss_ib:0.00049918
# epoch 999 loss_pde:0.00427823, loss_ib:0.00049919
# epoch 999 loss_pde:0.00427809, loss_ib:0.00049919
# epoch 999 loss_pde:0.00427804, loss_ib:0.00049918
# epoch 999 loss_pde:0.00427806, loss_ib:0.00049916
# epoch 999 loss_pde:0.00427807, loss_ib:0.00049913
# epoch 999 loss_pde:0.00427869, loss_ib:0.00049903
# epoch 999 loss_pde:0.00427874, loss_ib:0.00049899
# epoch 999 loss_pde:0.00427890, loss_ib:0.00049894
# epoch 999 loss_pde:0.00427899, loss_ib:0.00049891
# epoch 999 loss_pde:0.00427897, loss_ib:0.00049888
# epoch 999 loss_pde:0.00427882, loss_ib:0.00049887
# epoch 999 loss_pde:0.00427853, loss_ib:0.00049887
# epoch 999 loss_pde:0.00427771, loss_ib:0.00049892
# epoch 999: loss 0.009272
# epoch 1000 loss_pde:0.00427715, loss_ib:0.00049893
# epoch 1000 loss_pde:0.00427645, loss_ib:0.00049898
# epoch 1000 loss_pde:0.00427543, loss_ib:0.00049905
# epoch 1000 loss_pde:0.00427449, loss_ib:0.00049912
# epoch 1000 loss_pde:0.00427363, loss_ib:0.00049918
# epoch 1000 loss_pde:0.00427269, loss_ib:0.00049925
# epoch 1000 loss_pde:0.00427177, loss_ib:0.00049931
# epoch 1000 loss_pde:0.00427082, loss_ib:0.00049937
# epoch 1000 loss_pde:0.00427037, loss_ib:0.00049939
# epoch 1000 loss_pde:0.00427006, loss_ib:0.00049940
# epoch 1000 loss_pde:0.00426996, loss_ib:0.00049938
# epoch 1000 loss_pde:0.00426995, loss_ib:0.00049936
# epoch 1000 loss_pde:0.00427004, loss_ib:0.00049932
# epoch 1000 loss_pde:0.00427012, loss_ib:0.00049927
# epoch 1000 loss_pde:0.00427053, loss_ib:0.00049919
# epoch 1000 loss_pde:0.00427048, loss_ib:0.00049915
# epoch 1000 loss_pde:0.00427088, loss_ib:0.00049907
# epoch 1000 loss_pde:0.00427102, loss_ib:0.00049902
# epoch 1000 loss_pde:0.00427073, loss_ib:0.00049900
# epoch 1000 loss_pde:0.00427127, loss_ib:0.00049891
# epoch 1000: loss 0.009266
# Total training time: 10323.705754518509

# %%
device1 = torch.device("cpu")
#model.load_state_dict(torch.load(PATH))
#torch.save(model,'2DRiemanncase8.pt')
#model = torch.save('backcorner.pt')

# %%
#model = model.load_state_dict(torch.load( 'backcorner.pt'))
model = model.to(device)

# %%
model_path = 'naca0012_time02.pth'
model = torch.load(model_path, map_location=torch.device('cpu'))
model = model.to(device)

# %% [markdown]
# ## 后处理

# %%
# Evaluate on the whole computational domain
for i in range(50):
#u = to_numpy(model(x_test))
#x = to_numpy(x_test)
    x = np.linspace(0.0, 1.0, 401)                                   # Partitioned spatial axis
    y = np.linspace(0.0, 1.0, 400)                                   # Partitioned spatial axis
    t = np.linspace(0.20, 0.20, 1)                                        # Partitioned time axis
    t_grid, x_grid,y_grid = np.meshgrid(t,x,y)                                    # (t,x) in [0,0.2]x[a,b]
    T = t_grid.flatten()[:, None]                                        # Vectorized t_grid
    X = x_grid.flatten()[:, None]                                         # Vectorized x_grid
    Y = y_grid.flatten()[:, None]                                         # Vectorized x_grid
    x_test = np.hstack((T, X, Y))                                            # Vectorized whole domain
    x_test = torch.tensor(x_test, dtype=torch.float32).to(device1)
    u = to_numpy(model(x_test))
    #Xp,Yp = meshgrid(x,y)
    
    ue = np.zeros((401,400))
    for i in range(0,401):
        for j in range(0,400):
            ue[i,j] = u[j*400+i,3]
            
    plt.figure()
    plt.contourf(x_grid[:,0,:],y_grid[:,0,:],ue,50)
    #plt.pcolor(x_grid[:,0,:],y_grid[:,0,:],ue)
    #plt.colorbar(x_grid[:,0,:],y_grid[:,0,:],ue)
    #plt.scatter(x_int_train[:,1],)
    #plt.pcolor(x[:],u[:,1])
    #plt.pcolor(x[:],u[:,2])
    ax = plt.gca()
    ax.set_aspect(1)
    plt.savefig("test_rasterization.png", dpi=150)
    plt.show()
 
    #    uo = ue.flatten()[:,None]
    #    uxy= np.hstack((X, Y,uo))                                            # Vectorized whole domain

# %%
for k in range(50):
    Nd = 600
    T = 2.0/50*k
    t = np.linspace(T, T, 1)                                   # Partitioned spatial axis
    x = np.linspace(0.0,Lx,Nd)                                   # Partitioned spatial axis
    y = np.linspace(0.0,Ly,Nd)                                   # Partitioned spatial axis
    t_grid,x_grid,y_grid = np.meshgrid(t,x,y)                                    # (t,x) in [0,0.2]x[a,b]
    T = t_grid.flatten()[:, None]                                         # Vectorized x_grid
    X = x_grid.flatten()[:, None]                                         # Vectorized x_grid
    Y = y_grid.flatten()[:, None]                                         # Vectorized x_grid
    x_test = np.hstack((T,X,Y))                                            # Vectorized whole domain
    x_test = torch.tensor(x_test, dtype=torch.float32).to(device)
    u = to_numpy(model(x_test))
    #Xp,Yp = meshgrid(x,y)
    
    
    x_test = np.hstack((T,X,Y))                                            # Vectorized whole domain
    ue = np.zeros((Nd,Nd))
    for j in range(0,Nd):
        for i in range(0,Nd):
            ue[i,j] = u[i*Nd+j,0]
            x1 = x_test[i*Nd+j,1] 
            y1 = x_test[i*Nd+j,2] 
            if (((x1 - rx)>0) and ((x1-rx)<1)):
                yd1,yd2,dy1,dy2 = Naca0012data(x1-rx)
                if (((y1-ry)>yd2) and ((y1-ry)<yd1)):
                    ue[i,j] = 0.0
                
    uo1 = ue.flatten()[:,None]
    ue = np.zeros((Nd,Nd))
    for j in range(0,Nd):
        for i in range(0,Nd):
            ue[i,j] = u[i*Nd+j,1]
            x1 = x_test[i*Nd+j,1] 
            y1 = x_test[i*Nd+j,2] 
            if (((x1 - rx)>0) and ((x1-rx)<1)):
                yd1,yd2,dy1,dy2 = Naca0012data(x1-rx)
                if (((y1-ry)>yd2) and ((y1-ry)<yd1)):
                    ue[i,j] = 0.0
    uo2 = ue.flatten()[:,None]
    ue = np.zeros((Nd,Nd))
    for j in range(0,Nd):
        for i in range(0,Nd):
            ue[i,j] = u[i*Nd+j,2]
            x1 = x_test[i*Nd+j,1] 
            y1 = x_test[i*Nd+j,2] 
            if (((x1 - rx)>0) and ((x1-rx)<1)):
                yd1,yd2,dy1,dy2 = Naca0012data(x1-rx)
                if (((y1-ry)>yd2) and ((y1-ry)<yd1)):
                    ue[i,j] = 0.0
            
    uo3 = ue.flatten()[:,None]
    ue = np.zeros((Nd,Nd))
    for j in range(0,Nd):
        for i in range(0,Nd):
            ue[i,j] = u[i*Nd+j,3]
            x1 = x_test[i*Nd+j,1] 
            y1 = x_test[i*Nd+j,2] 
            if (((x1 - rx)>0) and ((x1-rx)<1)):
                yd1,yd2,dy1,dy2 = Naca0012data(x1-rx)
                if (((y1-ry)>yd2) and ((y1-ry)<yd1)):
                    ue[i,j] = 0.0
    uo4 = ue.flatten()[:,None]
    filename = "naca{}.dat".format(k) 
    uxy= np.hstack((X, Y,uo1,uo2,uo3,uo4)) 
    f = open(filename,'w')
    f.write(var2)
    np.savetxt(f, uxy)# Vectorized whole domain
    f.close()

# %%
Nd = 600
T = 2.0
t = np.linspace(T, T, 1)                                   # Partitioned spatial axis
x = np.linspace(0.0,Lx,Nd)                                   # Partitioned spatial axis
y = np.linspace(0.0,Ly,Nd)                                   # Partitioned spatial axis
t_grid,x_grid,y_grid = np.meshgrid(t,x,y)                                    # (t,x) in [0,0.2]x[a,b]
T = t_grid.flatten()[:, None]                                         # Vectorized x_grid
X = x_grid.flatten()[:, None]                                         # Vectorized x_grid
Y = y_grid.flatten()[:, None]                                         # Vectorized x_grid
x_test = np.hstack((T,X,Y))                                            # Vectorized whole domain
x_test = torch.tensor(x_test, dtype=torch.float32).to(device)
u = to_numpy(model(x_test))
#Xp,Yp = meshgrid(x,y)


x_test = np.hstack((T,X,Y))                                            # Vectorized whole domain
ue = np.zeros((Nd,Nd))
for j in range(0,Nd):
    for i in range(0,Nd):
        ue[i,j] = u[i*Nd+j,0]
        x1 = x_test[i*Nd+j,1] 
        y1 = x_test[i*Nd+j,2] 
        if ((x1 - rx)**2 +(y1-ry)**2< rd**2):
            ue[i,j] = 0.0
            
uo1 = ue.flatten()[:,None]
ue = np.zeros((Nd,Nd))
for j in range(0,Nd):
    for i in range(0,Nd):
        ue[i,j] = u[i*Nd+j,1]
        x1 = x_test[i*Nd+j,1] 
        y1 = x_test[i*Nd+j,2] 
        if ((x1 - rx)**2 +(y1-ry)**2< rd**2):
            ue[i,j] = 0.0
uo2 = ue.flatten()[:,None]
ue = np.zeros((Nd,Nd))
for j in range(0,Nd):
    for i in range(0,Nd):
        ue[i,j] = u[i*Nd+j,2]
        x1 = x_test[i*Nd+j,1] 
        y1 = x_test[i*Nd+j,2] 
        if ((x1 - rx)**2 +(y1-ry)**2< rd**2):
            ue[i,j] = 0.0
        
uo3 = ue.flatten()[:,None]
ue = np.zeros((Nd,Nd))
for j in range(0,Nd):
    for i in range(0,Nd):
        ue[i,j] = u[i*Nd+j,0]
        x1 = x_test[i*Nd+j,1] 
        y1 = x_test[i*Nd+j,2] 
        if (((x1 - rx)>0) and ((x1-rx)<1)):
            yd1,yd2,dy1,dy2 = Naca0012data(x1-rx)
            if (((y1-ry)>yd2) and ((y1-ry)<yd1)):
              #  print(x1-rx,yd1,dy1,yd2,dy2)
                ue[i,j] = 0.0
#uo4 = ue.flatten()[:,None]
#filename = "temp{}.dat".format(44) 
#uxy= np.hstack((X, Y,uo1,uo2,uo3,uo4)) 
#f = open(filename,'w')
#f.write(var2)
#np.savetxt(f, uxy)# Vectorized whole domain
#f.close()

# %%
var2 = """TITLE="Euler"
 VARIABLES="x","y","rou"，"u","v","p"
ZONE I=         600 J=         600 F=POINT
"""

# %%
model
# Out:
# DNN(
#   (net): Sequential(
#     (Linear_layer_1): Linear(in_features=3, out_features=90, bias=True)
#     (Tanh_layer_1): Tanh()
#     (Linear_layer_2): Linear(in_features=90, out_features=90, bias=True)
#     (Tanh_layer_2): Tanh()
#     (Linear_layer_3): Linear(in_features=90, out_features=90, bias=True)
#     (Tanh_layer_3): Tanh()
#     (Linear_layer_4): Linear(in_features=90, out_features=90, bias=True)
#     (Tanh_layer_4): Tanh()
#     (Linear_layer_5): Linear(in_features=90, out_features=90, bias=True)
#     (Tanh_layer_5): Tanh()
#     (Linear_layer_final): Linear(in_features=90, out_features=4, bias=True)
#   )
# )

# %%
filename = '1.dat'
with open(filename, 'r', encoding='utf-8') as fileobj:
    for line in fileobj:
        print(var2)
# Out:
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
# ...
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
plt.figure()
plt.contourf(x_grid[:,0,:],y_grid[:,0,:],ue,60)
#plt.pcolor(x_grid[:,0,:],y_grid[:,0,:],ue)
#plt.colorbar(x_grid[:,0,:],y_grid[:,0,:],ue)
#plt.scatter(x_int_train[:,1],)
#plt.pcolor(x[:],u[:,1])
#plt.pcolor(x[:],u[:,2])
ax = plt.gca()
ax.set_aspect(1)
plt.show()
plt.savefig("Riemann2.pdf", dpi=150)

# %%
            #fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
#surf = ax.plot_surface(x_grid[:,0,:], y_grid[:,0,:], ue, cmap=cm.coolwarm,
#                       linewidth=0, antialiased=False)
#
## Customize the z axis.
#ax.set_zlim(0, 1.01)
#ax.zaxis.set_major_locator(LinearLocator(10))
## A StrMethodFormatter is used automatically
#ax.zaxis.set_major_formatter('{x:.02f}')
#
## Add a color bar which maps values to colors.
#fig.colorbar(surf, shrink=0.5, aspect=5)
#plt.show()

# %%
xlimits = np.array([[0.,Tend],[0.0, 3], [0.0,3]])  #interal
sampling = LHS(xlimits=xlimits)
x_int_train = sampling(num_int)
A = []
for i in range(num_int):
    x = x_int_train[i,1]
    y = x_int_train[i,2]
    if (x< 0.5 and y< 1.5):
        A.append(i)
x_int_train = np.delete(x_int_train,A,axis=0)

# %%
plt.figure()
plt.scatter(x_int_train[1:1000,1],x_int_train[1:1000,2])
#plt.pcolor(x_grid[:,0,:],y_grid[:,0,:],ue)
#plt.colorbar(x_grid[:,0,:],y_grid[:,0,:],ue)
#plt.scatter(x_int_train[:,1],)
#plt.pcolor(x[:],u[:,1])
#plt.pcolor(x[:],u[:,2])
ax = plt.gca()
ax.set_aspect(1)
plt.show()

# %%
torch.save(model,'2DRiemanncase8.pt')

# %%
model

# %%
#device1 = torch.device("cpu")
#model.load_state_dict(torch.load(PATH))
#model = model.to(device1)
#torch.save(model,'2DRiemanncase8.pt')
model = torch.load('2DRiemanncase8.pt')

# %%
model
