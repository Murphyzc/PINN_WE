# %%
import torch
import torch.nn as nn
import numpy as np
import time
import scipy.io
import matplotlib.pyplot as plt
from numpy import arange, meshgrid
from smt.sampling_methods import LHS
# Seeds
torch.manual_seed(123)
np.random.seed(123)
def train(epoch):
    model.train()
    def closure():
        optimizer.zero_grad()                                                     
        loss_pde = model.loss_pde(x_int_train)                                   
        loss_ic = model.loss_ic(x_ic_train, rho_ic_train,u_ic_train,v_ic_train,p_ic_train)   
        loss_bdL = model.loss_bc(x_bcL_train, rho_bcL_train,u_bcL_train,v_bcL_train,p_bcL_train)   
        loss_bdR = model.loss_bc1(x_bcR_train,rho_bcR_train,u_bcR_train,v_bcR_train,p_bcR_train)   
        loss_bdI = model.bd_B(x_bcI_train, sin_bcI_train,cos_bcI_train)  

        loss_rh = model.loss_rh(xrh,xrhL,xrhD) # RH relation
        loss_ib = loss_ic  +  loss_bdI +loss_bdL
        loss = loss_pde + 10*loss_ib

        print(f'epoch {epoch} loss_pde:{loss_pde:.8f}, loss_ib:{loss_ib:.8f}')
        loss.backward()
        return loss

    # Optimize loss function
    loss = optimizer.step(closure)
    loss_value = loss.item() if not isinstance(loss, float) else loss
    # Print total loss
    print(f'epoch {epoch}: loss {loss_value:.6f}')
    
# Calculate gradients using torch.autograd.grad
def gradients(outputs, inputs):
    return torch.autograd.grad(outputs, inputs,grad_outputs=torch.ones_like(outputs), create_graph=True)

# Convert torch tensor into np.array
def to_numpy(input):
    if isinstance(input, torch.Tensor):
        return input.detach().cpu().numpy()
    elif isinstance(input, np.ndarray):
        return input
    else:
        raise TypeError('Unknown type of input, expected torch.Tensor or ' \
                        'np.ndarray, but got {}'.format(type(input)))
def IC(x):
    N =x.shape[0]
    rho_init = np.zeros((x.shape[0]))                                              # rho - initial condition
    u_init = np.zeros((x.shape[0]))                                                # u - initial condition
    v_init = np.zeros((x.shape[0]))                                                # u - initial condition
    p_init = np.zeros((x.shape[0]))                                                # p - initial condition
    
    gamma = 1.4
    rho1 = 2.112
    p1 =  3.011
    v1 = 0.0
    u1 = np.sqrt(1.4*p1/rho1)*0.728
    
    rho2 = 1.0
    p2 = 1.
    v2 = 0.0
    #u1 = ms*npsqrt(gamma)
    u2 = 0.0
    # rho, p - initial condition
    for i in range(N):
        if x[i,1] < 0.5:
            rho_init[i] = rho1
            u_init[i] =   u1
            v_init[i] =  v1
            p_init[i] =  p1
        else:
            rho_init[i] = rho2
            u_init[i] =   u2
            v_init[i] =  v2
            p_init[i] =  p2

    return rho_init, u_init, v_init,p_init

def BC_L(x):
    N =x.shape[0]
    rho_init = np.zeros((x.shape[0]))                                              # rho - initial condition
    u_init = np.zeros((x.shape[0]))                                                # u - initial condition
    v_init = np.zeros((x.shape[0]))                                                # u - initial condition
    p_init = np.zeros((x.shape[0]))                                                # p - initial condition
    
    gamma = 1.4
    #u1 = ms*npsqrt(gamma)
    # rho, p - initial condition
    rho1 = 2.112
    p1 =  3.011
    v1 = 0.0
    u1 = np.sqrt(1.4*p1/rho1)*0.728
    for i in range(N):
        rho_init[i] = rho1
        u_init[i] =  u1
        v_init[i] =  v1
        p_init[i] =  p1
    return rho_init, u_init, v_init,p_init
def BC_R(x):
    N =x.shape[0]
    rho_init = np.zeros((x.shape[0]))                                              # rho - initial condition
    u_init = np.zeros((x.shape[0]))                                                # u - initial condition
    v_init = np.zeros((x.shape[0]))                                                # u - initial condition
    p_init = np.zeros((x.shape[0]))                                                # p - initial condition
    
    gamma = 1.4
    ms = 2.0
    rho1 = 1.0
    p1 = 1.0
    v1 = 0.0
    u1 = 0
    # rho, p - initial condition
    for i in range(N):
        rho_init[i] = rho1
        u_init[i] = u1
        v_init[i] = v1
        p_init[i] = p1

    return rho_init, u_init, v_init,p_init
def BC_Cut(x):
    N =x.shape[0]
    rho_init = np.zeros((x.shape[0]))
    u_init = np.zeros((x.shape[0]))
    v_init = np.zeros((x.shape[0]))
    p_init = np.zeros((x.shape[0]))
    
    gamma = 1.4
    ms = 2.0
    rho1 = 1.0
    p1 = 1.0
    v1 = 0.0
    u1 = 0
    # rho, p - initial condition
    for i in range(N):
        rho_init[i] = 10.01
        u_init[i] =  0
        v_init[i] = 0
        p_init[i] = 10.01

    return rho_init, u_init, v_init,p_init
    
class DNN(nn.Module):

    def __init__(self):
        super(DNN, self).__init__()
        self.net = nn.Sequential()                                                  # Define neural network
        self.net.add_module('Linear_layer_1', nn.Linear(3, 90))                     # First linear layer
        self.net.add_module('Tanh_layer_1', nn.Tanh())                              # First activation Layer

        for num in range(2, 6):                                                     # Number of layers (2 through 7)
            self.net.add_module('Linear_layer_%d' % (num), nn.Linear(90, 90))       # Linear layer
            self.net.add_module('Tanh_layer_%d' % (num), nn.Tanh())                 # Activation Layer
        self.net.add_module('Linear_layer_final', nn.Linear(90, 4))                 # Output Layer

    # Forward Feed
    def forward(self, x):
        return self.net(x)

    def bd_B(self,x,sin,cos):
        yb = self.net(x)
        rhob,pb,ub,vb = yb[:, 0:1], yb[:, 1:2], yb[:, 2:3],yb[:,3:]
        drhob_g = gradients(rhob, x)[0]                                      # Gradient [u_t, u_x]
        rhob_x, rhob_y = drhob_g[:, 1:2], drhob_g[:, 2:3]                            # Partial derivatives u_t, u_x
        dub_g = gradients(ub, x)[0]                                      # Gradient [u_t, u_x]
        ub_x, ub_y = dub_g[:, 1:2], dub_g[:, 2:3]                            # Partial derivatives u_t, u_x
        dvb_g = gradients(vb, x)[0]                                      # Gradient [u_t, u_x]
        vb_x, vb_y = dvb_g[:, 1:2], dvb_g[:, 2:3]                            # Partial derivatives u_t, u_x
        dpb_g = gradients(pb, x)[0]                                      # Gradient [p_t, p_x]
        pb_x, pb_y = dpb_g[:, 1:2], dpb_g[:, 2:3]                            # Partial derivatives p_t, p_x
        
        deltau = ub_x + vb_y
        lam = 0.1*(abs(deltau) - deltau) + 1
        #lam = (deltau) - deltau) + 1
        
        fb = (((ub*cos + vb*sin)/lam)**2).mean() +\
            (((pb_x*cos + pb_y*sin)/lam)**2).mean() +\
            (((rhob_x*cos + rhob_y*sin)/lam)**2).mean()
        return fb
    def bd_OY(self,x):
        y = self.net(x)
        rho,p,u,v = y[:, 0:1], y[:, 1:2], y[:, 2:3],y[:,3:]
        
        drho_g = gradients(rho, x)[0]                                  # Gradient [rho_t, rho_x]
        rho_x,rho_y = drho_g[:, :1], drho_g[:, 1:2]                    # Partial derivatives rho_t, rho_x
        du_g = gradients(u, x)[0]                                      # Gradient [u_t, u_x]
        u_x, u_y = du_g[:, :1], du_g[:, 1:2]                            # Partial derivatives u_t, u_x
        dv_g = gradients(v, x)[0]                                      # Gradient [u_t, u_x]
        v_x, v_y = dv_g[:, :1], dv_g[:, 1:2]                            # Partial derivatives u_t, u_x
        dp_g = gradients(p, x)[0]                                      # Gradient [p_t, p_x]
        p_x, p_y = dp_g[:, :1], dp_g[:, 1:2]                            # Partial derivatives p_t, p_x
        
        deltau = u_x + v_y
        lam = 0.1*(abs(deltau) - deltau) + 1
        
        f = ((( u_y)/lam)**2).mean() +\
            ((( v_y)/lam)**2).mean() +\
            ((( p_y)/lam)**2).mean() +\
            ((( rho_y)/lam)**2).mean()
        return f
    
    def bd_OX(self,x):
        y = self.net(x)
        rho,p,u,v = y[:, 0:1], y[:, 1:2], y[:, 2:3],y[:,3:]
        
        drho_g = gradients(rho, x)[0]                                  # Gradient [rho_t, rho_x]
        rho_x,rho_y = drho_g[:, :1], drho_g[:, 1:2]                    # Partial derivatives rho_t, rho_x
        du_g = gradients(u, x)[0]                                      # Gradient [u_t, u_x]
        u_x, u_y = du_g[:, :1], du_g[:, 1:2]                            # Partial derivatives u_t, u_x
        dv_g = gradients(v, x)[0]                                      # Gradient [u_t, u_x]
        v_x, v_y = dv_g[:, :1], dv_g[:, 1:2]                            # Partial derivatives u_t, u_x
        dp_g = gradients(p, x)[0]                                      # Gradient [p_t, p_x]
        p_x, p_y = dp_g[:, :1], dp_g[:, 1:2]                            # Partial derivatives p_t, p_x
        
        deltau = u_x + v_y
        lam = 0.1*(abs(deltau) - deltau) + 1
        
        f = ((( u_x)/lam)**2).mean() +\
            ((( v_x)/lam)**2).mean() +\
            ((( p_x)/lam)**2).mean() +\
            ((( rho_x)/lam)**2).mean()
        return f
     
    # Loss function for PDE
    def loss_rh(self, x,xl,xd):
        y = self.net(x)
        yl = self.net(xl)
        yd = self.net(xd)
        gamma = 1.4                                                   
        epsilon = 1e-5
        rho,p,u,v = y[:, 0:1], y[:, 1:2], y[:, 2:3],y[:,3:]
        rhol,pl,ul,vl = yl[:, 0:1], yl[:, 1:2], yl[:, 2:3],yl[:,3:]
        rhod,pd,ud,vd = yd[:, 0:1], yd[:, 1:2], yd[:, 2:3],yd[:,3:]

        eta = torch.clamp(abs(p - pl) - 0.2, min=0) * torch.clamp(
            abs(u - ul)+abs(v-vl) - 0.2, min=0
        )
        loss_rh1 = (
            (rho * rhol * ((v-vl)**2+(u - ul) ** 2) - (pl - p) * (rhol - rho)) ** 2 * eta
        ).mean() + (
            ((rho * pl / 0.4 - rhol * p / 0.4) - 0.5 * (pl + p) * (rhol - rho)) ** 2
            * eta
        ).mean() 
        eta = torch.clamp(abs(p - pd) - 0.2, min=0) * torch.clamp(
            abs(u - ud)+abs(v-vd) - 0.2, min=0
        )
        loss_rh2 = (
            (rho * rhod * ((v-vd)**2+(u - ud) ** 2) - (pd - p) * (rhod - rho)) ** 2 * eta
        ).mean() + (
            ((rho * pd / 0.4 - rhod * p / 0.4) - 0.5 * (pd + p) * (rhod - rho)) ** 2
            * eta
        ).mean() 
        return loss_rh1 + loss_rh2


 #   def loss_pde(self, x):
 #       
 #       y = self.net(x)
 #       gamma = 1.4                                                   
 #       epsilon = 1e-5
 #       rho,p,u,v = y[:, 0:1], y[:, 1:2], y[:, 2:3],y[:,3:]
 #       
 #       rhoE = p/(gamma - 1) +0.5*rho*(u**2+v**2)
 #       
 #       f1 = rho*u
 #       f2 = rho*u*u+p
 #       f3 = rho*u*v
 #       f4 = (rhoE+p)*u
 #       
 #       g1 = rho*v
 #       g2 = rho*v*u
 #       g3 = rho*v*v + p
 #       g4 = (rhoE+p)*v
 #       
 #       drho_g = gradients(rho,x)[0]
 #       U1_t = drho_g[:, :1]
 #       dU2_g = gradients(f1,x)[0]
 #       U2_t = dU2_g[:, :1]
 #       dU3_g = gradients(g1,x)[0]
 #       U3_t = dU3_g[:, :1]
 #       dU4_g = gradients(rhoE,x)[0]
 #       U4_t = dU4_g[:, :1]
 #       
 #       df1_g = gradients(f1, x)[0]                                  
 #       f1_x = df1_g[:, 1:2]
 #       df2_g = gradients(f2, x)[0]                                  
 #       f2_x = df2_g[:, 1:2]
 #       df3_g = gradients(f3, x)[0]                                  
 #       f3_x = df3_g[:, 1:2]
 #       df4_g = gradients(f4, x)[0]                                  
 #       f4_x = df4_g[:, 1:2]
 #       
 #       dg1_g = gradients(g1, x)[0]                                  
 #       g1_y = dg1_g[:, 2:3]
 #       dg2_g = gradients(g2, x)[0]                                  
 #       g2_y = dg2_g[:, 2:3]
 #       dg3_g = gradients(g3, x)[0]                                  
 #       g3_y = dg3_g[:, 2:3]
 #       dg4_g = gradients(g4, x)[0]                                  
 #       g4_y = dg4_g[:, 2:3]
 #       
 #       
 #       du_g = gradients(u, x)[0]                                
 #       u_x = du_g[:, 1:2]         
 #       dv_g = gradients(v, x)[0]                    
 #       v_y = dv_g[:, 2:3]         
 #       
 #       d = np.random.rand()
 #       deltau = u_x + v_y
 #       nab = abs(deltau) - deltau
 #       
 #       
 #       d = 1.0
 #       lam = d*(0.1*nab) + 1
 #       
 #       f = (((U1_t + f1_x+g1_y )/lam)**2).mean() +\
 #           (((U2_t + f2_x+g2_y )/lam)**2).mean() +\
 #           (((U3_t + f3_x+g3_y )/lam)**2).mean() +\
 #           (((U4_t + f4_x+g4_y )/lam)**2).mean()

 #       return f
    def loss_pde(self, x):
        y = self.net(x)                                                # Neural network
        rho,p,u,v = y[:, 0:1], y[:, 1:2], y[:, 2:3],y[:,3:]
        gamma = 1.4                                                    # Heat Capacity Ratio
        drho_g = gradients(rho, x)[0]                                  # Gradient [rho_t, rho_x]
        rho_t, rho_x,rho_y = drho_g[:, :1], drho_g[:, 1:2],drho_g[:,2:]
        du_g = gradients(u, x)[0]                                      # Gradient [u_t, u_x]
        u_t, u_x, u_y = du_g[:, :1], du_g[:, 1:2], du_g[:,2:]                            # Partial derivatives u_t, u_x
        dv_g = gradients(v, x)[0]                                      # Gradient [u_t, u_x]
        v_t, v_x, v_y = dv_g[:, :1], dv_g[:, 1:2], dv_g[:,2:]                            # Partial derivatives u_t, u_x
        dp_g = gradients(p, x)[0]                                      # Gradient [p_t, p_x]
        p_t, p_x, p_y = dp_g[:, :1], dp_g[:, 1:2], dp_g[:,2:]                            # Partial derivatives p_t, p_x
        
        deltau = u_x + v_y
        lam = 0.1*(abs(deltau) - deltau) + 1

        f = (((rho_t+rho*deltau+u*rho_x + v*rho_y)/lam)**2).mean() +\
            (((rho*u_t+rho*u*u_x+rho*v*u_y+p_x)/lam)**2).mean() +\
            (((rho*v_t+rho*u*v_x+rho*v*v_y+p_y)/lam)**2).mean() +\
            (((p_t+u*p_x+v*p_y+1.4*p*deltau)/lam)**2).mean()
    
        return f


    # Loss function for initial condition
    def loss_ic(self, x_ic, rho_ic, u_ic, v_ic,p_ic):
        U_ic = self.net(x_ic)                                                      # Initial condition
        rho_ic_nn, p_ic_nn,u_ic_nn,v_ic_nn = U_ic[:, 0], U_ic[:, 1], U_ic[:, 2],U_ic[:,3]            # rho, u, p - initial condition

        # Loss function for the initial condition
        loss_ics = ((u_ic_nn - u_ic) ** 2).mean() + \
               ((rho_ic_nn- rho_ic) ** 2).mean()  + \
               ((p_ic_nn - p_ic) ** 2).mean() +\
               ((v_ic_nn - v_ic) ** 2).mean()

        return loss_ics

    def loss_bc(self, x_ic, rho_ic, u_ic, v_ic,p_ic):
        U_ic = self.net(x_ic)                                                      # Initial condition
        rho_ic_nn, p_ic_nn,u_ic_nn,v_ic_nn = U_ic[:, 0], U_ic[:, 1], U_ic[:, 2],U_ic[:,3]            # rho, u, p - initial condition

        # Loss function for the initial condition
        loss_ics = ((u_ic_nn - u_ic) ** 2).mean() + \
               ((rho_ic_nn- rho_ic) ** 2).mean()  + \
               ((p_ic_nn - p_ic) ** 2).mean() +\
               ((v_ic_nn - v_ic) ** 2).mean()

        return loss_ics
    def loss_bc1(self, x_ic, rho_ic, u_ic, v_ic,p_ic):
        U_ic = self.net(x_ic)                                                      # Initial condition
        rho_ic_nn, p_ic_nn,u_ic_nn,v_ic_nn = U_ic[:, 0], U_ic[:, 1], U_ic[:, 2],U_ic[:,3]            # rho, u, p - initial condition

        # Loss function for the initial condition
        loss_ics = ((rho_ic_nn- rho_ic) ** 2).mean()  + \
               ((p_ic_nn - p_ic) ** 2).mean() 

        return loss_ics

def BD_circle(t,xc,yc,r,n):
    x = np.zeros((n,3)) 
    sin = np.zeros((n,1)) 
    cos = np.zeros((n,1)) 

    for i in range(n):
        the = 2*np.random.rand()*np.pi
        xd = np.cos(the + np.pi/2)
        yd = np.sin(the + np.pi/2)
        x[i,0] = np.random.rand()*t
        x[i,1] = xc  + xd*r
        x[i,2] = yc  + yd*r
        cos[i,0] = xd 
        sin[i,0] = yd
    return x, sin,cos

def Pertur(x, dx):
    N =x.shape[0]
    xL = np.zeros((N,3))
    xR = np.zeros((N,3))
    xU = np.zeros((N,3))
    xD = np.zeros((N,3))
    
    for i in range(N):
        xL[i,0] = x[i,0]
        xR[i,0] = x[i,0]
        xU[i,0] = x[i,0]
        xD[i,0] = x[i,0]
        
        
        xL[i,1] = x[i,1] - dx
        xR[i,1] = x[i,1] + dx
        xU[i,1] = x[i,1]
        xD[i,1] = x[i,1]
        
        xL[i,2] = x[i,2] 
        xR[i,2] = x[i,2]
        xU[i,2] = x[i,2] + dx
        xD[i,2] = x[i,2] - dx
        
    return xL,xR,xU,xD
    
    
    
def BD_BackCorner(t,n):
    
    x = np.zeros((n,3)) 
    x2 = np.zeros((n,3)) 
    sin = np.zeros((n,1)) 
    sin2 = np.zeros((n,1)) 
    cos = np.zeros((n,1)) 
    cos2 = np.zeros((n,1)) 
    
    for i in range(n):
        x[i,0] = np.random.rand()*t
        x[i,1] = np.random.rand()*0.3 + 0.2
        x[i,2] = 1.5
        sin[i] = 1
        cos[i] = 0
    for i in range(n):
        x2[i,0] = np.random.rand()*t
        x2[i,1] = np.random.rand()*0.5
        x2[i,2] = 1.5
        sin2[i] = 1
        cos2[i] = 0
    x = np.vstack((x,x2))
    sin = np.vstack((sin,sin2))
    cos = np.vstack((cos,cos2))
    
    for i in range(n):
        x2[i,0] = np.random.rand()*t
        x2[i,1] = 0.5
        x2[i,2] = np.random.rand()*1.5
        sin2[i] = 0
        cos2[i] = 1
        
    x = np.vstack((x,x2))
    sin = np.vstack((sin,sin2))
    cos = np.vstack((cos,cos2))
    
    for i in range(n):
        x2[i,0] = np.random.rand()*t
        x2[i,1] = 0.5
        x2[i,2] = np.random.rand()*0.3 + 1.2
        sin2[i] = 0
        cos2[i] = 1
        
    x = np.vstack((x,x2))
    sin = np.vstack((sin,sin2))
    cos = np.vstack((cos,cos2))
        
    return x,sin,cos

def Pertur_2D(x,T,dx,dy):
  N=x.shape[0]
  xS   = np.zeros((N,3))
  xL   = np.zeros((N,3))
  xD   = np.zeros((N,3))
  
  for i in range(N):
      xS[i,1] = x[i,1]
      xS[i,2] = x[i,2]
      xS[i,0] = x[i,0] + T


      xL[i,1] = x[i,1] + dx
      xL[i,2] = x[i,2]
      xL[i,0] = x[i,0] + T

      xD[i,1] = x[i,1]
      xD[i,2] = x[i,2] + dy
      xD[i,0] = x[i,0] + T

  return xS,xL,xD


# Solve Euler equations using PINNs
# def main():
  # Initialization
#device = torch.device('cuda')                                          # Run on CPU
device = torch.device('cuda')                                          # Run on CPU
lr = 0.001                                                           # Learning rate
num_ib = 15000                                                # Random sampled points from IC0
num_int = 100000                                                # Random sampled points in interior
Tend = 0.4
Lx = 1.5
Ly = 2.0
rx = 1.0
ry = 1.0
rd = 0.25
dx = Lx/150
dy = Ly/150


xlimits = np.array([[0.,Tend],[0.0, Lx], [0,Ly]])  #interal
sampling = LHS(xlimits=xlimits)
x_int_train = sampling(num_int)

#xlimits = np.array([[0.,Tend],[0.5, 2], [0.5,2]])  #interal
#sampling = LHS(xlimits=xlimits)
#x_int1_train = sampling(num_int)
#x_int_train =  np.vstack((x_int_train,x_int1_train))

A = []
for i in range(num_int):
    x = x_int_train[i,1]
    y = x_int_train[i,2]
    if ((x - rx)**2 +(y-ry)**2< rd**2):
        A.append(i)
x_int_train = np.delete(x_int_train,A,axis=0)

#xlimits = np.array([[0.0, Tend], [1.0, 4.0], [0.2,1.0]])
#sampling = LHS(xlimits=xlimits)
#x_int_train_add = sampling(3*num_int)
#x_int_train = np.vstack((x_int_train,x_int_train_add))

#x_intL_train,x_intR_train,x_intU_train,x_intD_train = Pertur(x_int_train, 0.01)

xlimits = np.array([[0.,0.0],[0.0,Lx], [0.0,Ly]])  #interal
sampling = LHS(xlimits=xlimits)
x_ic_train = sampling(num_ib)
A = []
for i in range(num_ib):
    x = x_ic_train[i,1]
    y = x_ic_train[i,2]
    if ((x - rx)**2 +(y-ry)**2< rd**2):
        A.append(i)
x_ic_train = np.delete(x_ic_train,A,axis=0)


#xlimits = np.array([[0.0, 0.0], [1.0, 4.0], [0.2,1.0]])
#sampling = LHS(xlimits=xlimits)
#x_ic_train_add = sampling(3*num_int)
#x_ic_train = np.vstack((x_ic_train,x_ic_train_add))


xlimits = np.array([[0.0,Tend],[0.0, 0.0], [0.0,Ly]])
sampling = LHS(xlimits=xlimits)
x_bcL_train =  sampling(num_ib)

xlimits = np.array([[0.0,Tend], [Lx, Lx], [0.0,Ly]])
sampling = LHS(xlimits=xlimits)
x_bcR_train =  sampling(num_ib)


xlimits = np.array([[0.0,Tend],[0.0, Lx], [Ly,Ly]])
sampling = LHS(xlimits=xlimits)
x_bcU_train =  sampling(num_ib)

xlimits = np.array([[0.0,Tend], [0.0, Lx], [0.0,0.0]])
sampling = LHS(xlimits=xlimits)
x_bcD_train =  sampling(num_ib)                                           # Vectorized whole domain

#xlimits = np.array([[0.0,0.0],[0.0, Lx], [0.0,Ly]])
#sampling = LHS(xlimits=xlimits)
#x_ic_train =  sampling(num_ib)
#A = []
#for i in range(num_ib):
#    x = x_ic_train[i,1]
#    y = x_ic_train[i,2]
#    if ((x-rx)**2 + (y-ry)**2 ) < rd**2:
#        A.append(i)
#x_ic_train = np.delete(x_ic_train,A,axis=0)


x_bcI_train,sin_bcI_train,cos_bcI_train = BD_circle(Tend,rx,ry,rd,num_ib)
#x_bcI_train,sin_bcI_train,cos_bcI_train = BD_BackCorner(Tend,num_ib)

rho_bcL_train, u_bcL_train,v_bcL_train, p_bcL_train = BC_L(x_bcL_train)  
rho_bcR_train, u_bcR_train,v_bcR_train, p_bcR_train = BC_L(x_bcR_train)  
#rho_cut_train, u_cut_train,v_cut_train, p_cut_train = BC_Cut(x_cut_train)  
rho_ic_train, u_ic_train,v_ic_train, p_ic_train = IC(x_ic_train)  

xrh,xrhL,xrhD= Pertur_2D(x_ic_train,Tend,dx,dy)

x_int_train = torch.tensor(x_int_train, requires_grad=True, dtype=torch.float32).to(device)
xrh = torch.tensor(xrh, requires_grad=True, dtype=torch.float32).to(device)
xrhL = torch.tensor(xrhL, requires_grad=True, dtype=torch.float32).to(device)
xrhD = torch.tensor(xrhD, requires_grad=True, dtype=torch.float32).to(device)
#x_intL_train = torch.tensor(x_intL_train,dtype=torch.float32).to(device
#x_intR_train = torch.tensor(x_intR_train,dtype=torch.float32).to(device)
#x_intU_train = torch.tensor(x_intU_train,dtype=torch.float32).to(device)
#x_intD_train = torch.tensor(x_intD_train,dtype=torch.float32).to(device)

rho_bcL_train = torch.tensor(rho_bcL_train, dtype=torch.float32).to(device)
u_bcL_train = torch.tensor(u_bcL_train, dtype=torch.float32).to(device)
v_bcL_train = torch.tensor(v_bcL_train, dtype=torch.float32).to(device)
p_bcL_train = torch.tensor(p_bcL_train, dtype=torch.float32).to(device)

rho_bcR_train = torch.tensor(rho_bcR_train, dtype=torch.float32).to(device)
u_bcR_train = torch.tensor(u_bcR_train, dtype=torch.float32).to(device)
v_bcR_train = torch.tensor(v_bcR_train, dtype=torch.float32).to(device)
p_bcR_train = torch.tensor(p_bcR_train, dtype=torch.float32).to(device)

x_bcD_train = torch.tensor(x_bcD_train,requires_grad=True, dtype=torch.float32).to(device)
x_bcU_train = torch.tensor(x_bcU_train, requires_grad=True, dtype=torch.float32).to(device)
x_bcR_train = torch.tensor(x_bcR_train, requires_grad=True, dtype=torch.float32).to(device)
x_bcL_train = torch.tensor(x_bcL_train, dtype=torch.float32).to(device)
x_bcI_train = torch.tensor(x_bcI_train, requires_grad=True, dtype=torch.float32).to(device)
sin_bcI_train = torch.tensor(sin_bcI_train, dtype=torch.float32).to(device)
cos_bcI_train = torch.tensor(cos_bcI_train, dtype=torch.float32).to(device)

#rho_cut_train = torch.tensor(rho_cut_train, dtype=torch.float32).to(device)
#u_cut_train = torch.tensor(u_cut_train, dtype=torch.float32).to(device)
#v_cut_train = torch.tensor(v_cut_train, dtype=torch.float32).to(device)
#p_cut_train = torch.tensor(p_cut_train, dtype=torch.float32).to(device)
#x_cut_train = torch.tensor(x_cut_train, dtype=torch.float32).to(device)

rho_ic_train = torch.tensor(rho_ic_train, dtype=torch.float32).to(device)
u_ic_train = torch.tensor(u_ic_train, dtype=torch.float32).to(device)
v_ic_train = torch.tensor(v_ic_train, dtype=torch.float32).to(device)
p_ic_train = torch.tensor(p_ic_train, dtype=torch.float32).to(device)
x_ic_train = torch.tensor(x_ic_train, dtype=torch.float32).to(device)


#model = DNN().to(device)

#optimizer = torch.optim.LBFGS(model.parameters(),lr=lr,max_iter=500)
#rho_ic_train.clone().detach().requires_grad_(True)
#u_ic_train.clone().detach().requires_grad_(True)
# Initialize neural network

print('Start training...')
# Out:
# Start training...

# %%
model = DNN().to(device)

# %%
lr = 0.001
#optimizer = torch.optim.LBFGS(model.parameters(),lr=lr,max_iter=500)
optimizer = torch.optim.Adam(model.parameters(), lr=lr)
#scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer_Adam,gamma=0.995)
#optimizer = torch.optim.LBFGS(model.parameters(),lr=0.5,max_iter=20)
#optimizer_LBFGS = torch.optim.LBFGS(model.parameters(), lr=0.01, max_iter=50000)

# %%
epochs = 1000
tic = time.time()
for epoch in range(1, epochs+1):
    train(epoch)
toc = time.time()
print(f'Total training time: {toc - tic}')
# Out:
# epoch 1 loss_pde:0.61110437, loss_ib:0.23832101
# epoch 1: loss 2.994315
# epoch 2 loss_pde:0.60089457, loss_ib:0.23892362
# epoch 2: loss 2.990131
# epoch 3 loss_pde:0.59720767, loss_ib:0.23852515
# epoch 3: loss 2.982459
# epoch 4 loss_pde:0.61705184, loss_ib:0.23729293
# epoch 4: loss 2.989981
# epoch 5 loss_pde:0.59698755, loss_ib:0.23913299
# epoch 5: loss 2.988317
# epoch 6 loss_pde:0.60491246, loss_ib:0.23731808
# epoch 6: loss 2.978093
# epoch 7 loss_pde:0.60377556, loss_ib:0.23769817
# epoch 7: loss 2.980757
# epoch 8 loss_pde:0.59946370, loss_ib:0.23816149
# epoch 8: loss 2.981079
# epoch 9 loss_pde:0.60995501, loss_ib:0.23664831
# epoch 9: loss 2.976438
# epoch 10 loss_pde:0.59765178, loss_ib:0.23802125
# epoch 10: loss 2.977864
# epoch 11 loss_pde:0.60533577, loss_ib:0.23702885
# epoch 11: loss 2.975624
# epoch 12 loss_pde:0.60273767, loss_ib:0.23676051
# epoch 12: loss 2.970343
# epoch 13 loss_pde:0.59885269, loss_ib:0.23731562
# epoch 13: loss 2.972009
# epoch 14 loss_pde:0.60724771, loss_ib:0.23651934
# epoch 14: loss 2.972441
# epoch 15 loss_pde:0.59848493, loss_ib:0.23697793
# epoch 15: loss 2.968264
# epoch 16 loss_pde:0.60625750, loss_ib:0.23611359
# epoch 16: loss 2.967393
# epoch 17 loss_pde:0.60141039, loss_ib:0.23654078
# epoch 17: loss 2.966818
# epoch 18 loss_pde:0.59882438, loss_ib:0.23652107
# epoch 18: loss 2.964035
# epoch 19 loss_pde:0.60662436, loss_ib:0.23572145
# epoch 19: loss 2.963839
# epoch 20 loss_pde:0.59924680, loss_ib:0.23646002
# epoch 20: loss 2.963847
# epoch 21 loss_pde:0.60507256, loss_ib:0.23557827
# epoch 21: loss 2.960855
# epoch 22 loss_pde:0.59998810, loss_ib:0.23592468
# epoch 22: loss 2.959235
# epoch 23 loss_pde:0.59981924, loss_ib:0.23592767
# epoch 23: loss 2.959096
# epoch 24 loss_pde:0.60457587, loss_ib:0.23528798
# epoch 24: loss 2.957456
# epoch 25 loss_pde:0.59870279, loss_ib:0.23574500
# epoch 25: loss 2.956153
# epoch 26 loss_pde:0.60355526, loss_ib:0.23521292
# epoch 26: loss 2.955684
# epoch 27 loss_pde:0.59909523, loss_ib:0.23548357
# epoch 27: loss 2.953931
# epoch 28 loss_pde:0.60103977, loss_ib:0.23510523
# epoch 28: loss 2.952092
# epoch 29 loss_pde:0.60192311, loss_ib:0.23496267
# epoch 29: loss 2.951550
# epoch 30 loss_pde:0.59930700, loss_ib:0.23512769
# epoch 30: loss 2.950584
# epoch 31 loss_pde:0.60314500, loss_ib:0.23458965
# epoch 31: loss 2.949041
# epoch 32 loss_pde:0.59877861, loss_ib:0.23493211
# epoch 32: loss 2.948100
# epoch 33 loss_pde:0.60258973, loss_ib:0.23444152
# epoch 33: loss 2.947005
# epoch 34 loss_pde:0.59997052, loss_ib:0.23454103
# epoch 34: loss 2.945381
# epoch 35 loss_pde:0.59954536, loss_ib:0.23447281
# epoch 35: loss 2.944273
# epoch 36 loss_pde:0.60175145, loss_ib:0.23417300
# epoch 36: loss 2.943481
# epoch 37 loss_pde:0.59848481, loss_ib:0.23437294
# epoch 37: loss 2.942214
# epoch 38 loss_pde:0.60168707, loss_ib:0.23392724
# epoch 38: loss 2.940959
# epoch 39 loss_pde:0.59851944, loss_ib:0.23414409
# epoch 39: loss 2.939960
# epoch 40 loss_pde:0.60021186, loss_ib:0.23384991
# epoch 40: loss 2.938711
# epoch 41 loss_pde:0.59946567, loss_ib:0.23379013
# epoch 41: loss 2.937367
# epoch 42 loss_pde:0.59897274, loss_ib:0.23373772
# epoch 42: loss 2.936350
# epoch 43 loss_pde:0.60002518, loss_ib:0.23352991
# epoch 43: loss 2.935324
# epoch 44 loss_pde:0.59777206, loss_ib:0.23363164
# epoch 44: loss 2.934088
# epoch 45 loss_pde:0.60019118, loss_ib:0.23327544
# epoch 45: loss 2.932945
# epoch 46 loss_pde:0.59770417, loss_ib:0.23341726
# epoch 46: loss 2.931877
# epoch 47 loss_pde:0.59922808, loss_ib:0.23314194
# epoch 47: loss 2.930648
# epoch 48 loss_pde:0.59784669, loss_ib:0.23315725
# epoch 48: loss 2.929419
# epoch 49 loss_pde:0.59773523, loss_ib:0.23306060
# epoch 49: loss 2.928341
# epoch 50 loss_pde:0.59850895, loss_ib:0.23287229
# epoch 50: loss 2.927232
# epoch 51 loss_pde:0.59701163, loss_ib:0.23290351
# epoch 51: loss 2.926047
# epoch 52 loss_pde:0.59841800, loss_ib:0.23265076
# epoch 52: loss 2.924926
# epoch 53 loss_pde:0.59659445, loss_ib:0.23272349
# epoch 53: loss 2.923830
# epoch 54 loss_pde:0.59796798, loss_ib:0.23246768
# epoch 54: loss 2.922645
# epoch 55 loss_pde:0.59656984, loss_ib:0.23248881
# epoch 55: loss 2.921458
# epoch 56 loss_pde:0.59733033, loss_ib:0.23230012
# epoch 56: loss 2.920331
# epoch 57 loss_pde:0.59659058, loss_ib:0.23226003
# epoch 57: loss 2.919191
# epoch 58 loss_pde:0.59641081, loss_ib:0.23216034
# epoch 58: loss 2.918014
# epoch 59 loss_pde:0.59674007, loss_ib:0.23201364
# epoch 59: loss 2.916877
# epoch 60 loss_pde:0.59570831, loss_ib:0.23200518
# epoch 60: loss 2.915760
# epoch 61 loss_pde:0.59664023, loss_ib:0.23179698
# epoch 61: loss 2.914610
# epoch 62 loss_pde:0.59522772, loss_ib:0.23182197
# epoch 62: loss 2.913447
# epoch 63 loss_pde:0.59622341, loss_ib:0.23160867
# epoch 63: loss 2.912310
# epoch 64 loss_pde:0.59494203, loss_ib:0.23162244
# epoch 64: loss 2.911166
# epoch 65 loss_pde:0.59567869, loss_ib:0.23143195
# epoch 65: loss 2.909998
# epoch 66 loss_pde:0.59466916, loss_ib:0.23141673
# epoch 66: loss 2.908836
# epoch 67 loss_pde:0.59519023, loss_ib:0.23125020
# epoch 67: loss 2.907692
# epoch 68 loss_pde:0.59451795, loss_ib:0.23120190
# epoch 68: loss 2.906537
# epoch 69 loss_pde:0.59454554, loss_ib:0.23108269
# epoch 69: loss 2.905373
# epoch 70 loss_pde:0.59430134, loss_ib:0.23099172
# epoch 70: loss 2.904219
# epoch 71 loss_pde:0.59397441, loss_ib:0.23090972
# epoch 71: loss 2.903072
# epoch 72 loss_pde:0.59415627, loss_ib:0.23077579
# epoch 72: loss 2.901914
# epoch 73 loss_pde:0.59347218, loss_ib:0.23072806
# epoch 73: loss 2.900753
# epoch 74 loss_pde:0.59377176, loss_ib:0.23058277
# epoch 74: loss 2.899599
# epoch 75 loss_pde:0.59298313, loss_ib:0.23054631
# epoch 75: loss 2.898446
# epoch 76 loss_pde:0.59353113, loss_ib:0.23037544
# epoch 76: loss 2.897285
# epoch 77 loss_pde:0.59254718, loss_ib:0.23035762
# epoch 77: loss 2.896123
# epoch 78 loss_pde:0.59323180, loss_ib:0.23017347
# epoch 78: loss 2.894967
# epoch 79 loss_pde:0.59205437, loss_ib:0.23017544
# epoch 79: loss 2.893809
# epoch 80 loss_pde:0.59300536, loss_ib:0.22996406
# epoch 80: loss 2.892646
# epoch 81 loss_pde:0.59163481, loss_ib:0.22998495
# epoch 81: loss 2.891484
# epoch 82 loss_pde:0.59275103, loss_ib:0.22975764
# epoch 82: loss 2.890327
# epoch 83 loss_pde:0.59109467, loss_ib:0.22980767
# epoch 83: loss 2.889171
# epoch 84 loss_pde:0.59264439, loss_ib:0.22953713
# epoch 84: loss 2.888016
# epoch 85 loss_pde:0.59049314, loss_ib:0.22963732
# epoch 85: loss 2.886867
# epoch 86 loss_pde:0.59269261, loss_ib:0.22930372
# epoch 86: loss 2.885730
# epoch 87 loss_pde:0.58973676, loss_ib:0.22948721
# epoch 87: loss 2.884609
# epoch 88 loss_pde:0.59306979, loss_ib:0.22904441
# epoch 88: loss 2.883514
# epoch 89 loss_pde:0.58880967, loss_ib:0.22936559
# epoch 89: loss 2.882466
# epoch 90 loss_pde:0.59396505, loss_ib:0.22875313
# epoch 90: loss 2.881496
# epoch 91 loss_pde:0.58758545, loss_ib:0.22930767
# epoch 91: loss 2.880662
# epoch 92 loss_pde:0.59622318, loss_ib:0.22838420
# epoch 92: loss 2.880065
# epoch 93 loss_pde:0.58631092, loss_ib:0.22935662
# epoch 93: loss 2.879877
# epoch 94 loss_pde:0.60150760, loss_ib:0.22789386
# epoch 94: loss 2.880446
# epoch 95 loss_pde:0.58603072, loss_ib:0.22963111
# epoch 95: loss 2.882342
# epoch 96 loss_pde:0.61482418, loss_ib:0.22719383
# epoch 96: loss 2.886763
# epoch 97 loss_pde:0.59195101, loss_ib:0.23036771
# epoch 97: loss 2.895628
# epoch 98 loss_pde:0.65130246, loss_ib:0.22619115
# epoch 98: loss 2.913214
# epoch 99 loss_pde:0.62421709, loss_ib:0.23212633
# epoch 99: loss 2.945480
# epoch 100 loss_pde:0.75739473, loss_ib:0.22491649
# epoch 100: loss 3.006560
# epoch 101 loss_pde:0.74737167, loss_ib:0.23601766
# epoch 101: loss 3.107548
# epoch 102 loss_pde:1.03636551, loss_ib:0.22410345
# epoch 102: loss 3.277400
# epoch 103 loss_pde:1.04402149, loss_ib:0.24264152
# epoch 103: loss 3.470437
# epoch 104 loss_pde:1.40272784, loss_ib:0.22476068
# epoch 104: loss 3.650335
# epoch 105 loss_pde:1.10702682, loss_ib:0.24415852
# epoch 105: loss 3.548612
# epoch 106 loss_pde:0.98974979, loss_ib:0.22445647
# epoch 106: loss 3.234314
# epoch 107 loss_pde:0.59360772, loss_ib:0.23180915
# epoch 107: loss 2.911699
# epoch 108 loss_pde:0.58986813, loss_ib:0.23227981
# epoch 108: loss 2.912666
# epoch 109 loss_pde:0.89159006, loss_ib:0.22440483
# epoch 109: loss 3.135638
# epoch 110 loss_pde:0.81799102, loss_ib:0.23917232
# epoch 110: loss 3.209714
# epoch 111 loss_pde:0.79024673, loss_ib:0.22522801
# epoch 111: loss 3.042527
# epoch 112 loss_pde:0.56983501, loss_ib:0.22984780
# epoch 112: loss 2.868313
# epoch 113 loss_pde:0.60255951, loss_ib:0.23265219
# epoch 113: loss 2.929081
# epoch 114 loss_pde:0.82590318, loss_ib:0.22417411
# epoch 114: loss 3.067644
# epoch 115 loss_pde:0.67765409, loss_ib:0.23482932
# epoch 115: loss 3.025947
# epoch 116 loss_pde:0.62292320, loss_ib:0.22655828
# epoch 116: loss 2.888506
# epoch 117 loss_pde:0.60224885, loss_ib:0.22671276
# epoch 117: loss 2.869376
# epoch 118 loss_pde:0.63592398, loss_ib:0.23256400
# epoch 118: loss 2.961564
# epoch 119 loss_pde:0.73701704, loss_ib:0.22418173
# epoch 119: loss 2.978834
# epoch 120 loss_pde:0.58575338, loss_ib:0.23016050
# epoch 120: loss 2.887358
# epoch 121 loss_pde:0.57179105, loss_ib:0.22818518
# epoch 121: loss 2.853643
# epoch 122 loss_pde:0.66368926, loss_ib:0.22470666
# epoch 122: loss 2.910756
# epoch 123 loss_pde:0.61916906, loss_ib:0.23102385
# epoch 123: loss 2.929407
# epoch 124 loss_pde:0.62520033, loss_ib:0.22507483
# epoch 124: loss 2.875948
# epoch 125 loss_pde:0.57938957, loss_ib:0.22665569
# epoch 125: loss 2.845947
# epoch 126 loss_pde:0.58601987, loss_ib:0.22936313
# epoch 126: loss 2.879651
# epoch 127 loss_pde:0.65532094, loss_ib:0.22434877
# epoch 127: loss 2.898808
# epoch 128 loss_pde:0.57886195, loss_ib:0.22854237
# epoch 128: loss 2.864286
# epoch 129 loss_pde:0.57470268, loss_ib:0.22660035
# epoch 129: loss 2.840706
# epoch 130 loss_pde:0.61215568, loss_ib:0.22484402
# epoch 130: loss 2.860596
# epoch 131 loss_pde:0.58461469, loss_ib:0.22899957
# epoch 131: loss 2.874610
# epoch 132 loss_pde:0.60556793, loss_ib:0.22489370
# epoch 132: loss 2.854505
# epoch 133 loss_pde:0.57456166, loss_ib:0.22615109
# epoch 133: loss 2.836072
# epoch 134 loss_pde:0.57426715, loss_ib:0.22721410
# epoch 134: loss 2.846408
# epoch 135 loss_pde:0.61704803, loss_ib:0.22409742
# epoch 135: loss 2.858022
# epoch 136 loss_pde:0.57321656, loss_ib:0.22731473
# epoch 136: loss 2.846364
# epoch 137 loss_pde:0.57791638, loss_ib:0.22538707
# epoch 137: loss 2.831787
# epoch 138 loss_pde:0.58991992, loss_ib:0.22454327
# epoch 138: loss 2.835353
# epoch 139 loss_pde:0.57692301, loss_ib:0.22671466
# epoch 139: loss 2.844069
# epoch 140 loss_pde:0.59997690, loss_ib:0.22392730
# epoch 140: loss 2.839250
# epoch 141 loss_pde:0.57194525, loss_ib:0.22561547
# epoch 141: loss 2.828100
# epoch 142 loss_pde:0.57206440, loss_ib:0.22548592
# epoch 142: loss 2.826924
# epoch 143 loss_pde:0.59545988, loss_ib:0.22373138
# epoch 143: loss 2.832774
# epoch 144 loss_pde:0.57398695, loss_ib:0.22580919
# epoch 144: loss 2.832079
# epoch 145 loss_pde:0.58482468, loss_ib:0.22396927
# epoch 145: loss 2.824517
# epoch 146 loss_pde:0.57706726, loss_ib:0.22435866
# epoch 146: loss 2.820654
# epoch 147 loss_pde:0.57235962, loss_ib:0.22509412
# epoch 147: loss 2.823301
# epoch 148 loss_pde:0.59247702, loss_ib:0.22322282
# epoch 148: loss 2.824705
# epoch 149 loss_pde:0.57363033, loss_ib:0.22469516
# epoch 149: loss 2.820582
# epoch 150 loss_pde:0.57889932, loss_ib:0.22370647
# epoch 150: loss 2.815964
# epoch 151 loss_pde:0.58184862, loss_ib:0.22337756
# epoch 151: loss 2.815624
# epoch 152 loss_pde:0.57304233, loss_ib:0.22440892
# epoch 152: loss 2.817132
# epoch 153 loss_pde:0.58698732, loss_ib:0.22288279
# epoch 153: loss 2.815815
# epoch 154 loss_pde:0.57404774, loss_ib:0.22380383
# epoch 154: loss 2.812086
# epoch 155 loss_pde:0.57620722, loss_ib:0.22335488
# epoch 155: loss 2.809756
# epoch 156 loss_pde:0.58217627, loss_ib:0.22277544
# epoch 156: loss 2.809931
# epoch 157 loss_pde:0.57235360, loss_ib:0.22376244
# epoch 157: loss 2.809978
# epoch 158 loss_pde:0.58224559, loss_ib:0.22257397
# epoch 158: loss 2.807985
# epoch 159 loss_pde:0.57449162, loss_ib:0.22307426
# epoch 159: loss 2.805234
# epoch 160 loss_pde:0.57526577, loss_ib:0.22285642
# epoch 160: loss 2.803830
# epoch 161 loss_pde:0.58118874, loss_ib:0.22224568
# epoch 161: loss 2.803645
# epoch 162 loss_pde:0.57273334, loss_ib:0.22302340
# epoch 162: loss 2.802967
# epoch 163 loss_pde:0.58042043, loss_ib:0.22206572
# epoch 163: loss 2.801078
# epoch 164 loss_pde:0.57548994, loss_ib:0.22234887
# epoch 164: loss 2.798979
# epoch 165 loss_pde:0.57566363, loss_ib:0.22221076
# epoch 165: loss 2.797771
# epoch 166 loss_pde:0.58026624, loss_ib:0.22169289
# epoch 166: loss 2.797195
# epoch 167 loss_pde:0.57355529, loss_ib:0.22227086
# epoch 167: loss 2.796264
# epoch 168 loss_pde:0.57959300, loss_ib:0.22150336
# epoch 168: loss 2.794626
# epoch 169 loss_pde:0.57549679, loss_ib:0.22173783
# epoch 169: loss 2.792875
# epoch 170 loss_pde:0.57564747, loss_ib:0.22159755
# epoch 170: loss 2.791623
# epoch 171 loss_pde:0.57870340, loss_ib:0.22120655
# epoch 171: loss 2.790769
# epoch 172 loss_pde:0.57364279, loss_ib:0.22161216
# epoch 172: loss 2.789764
# epoch 173 loss_pde:0.57858330, loss_ib:0.22097702
# epoch 173: loss 2.788353
# epoch 174 loss_pde:0.57474142, loss_ib:0.22120537
# epoch 174: loss 2.786795
# epoch 175 loss_pde:0.57554990, loss_ib:0.22099113
# epoch 175: loss 2.785461
# epoch 176 loss_pde:0.57707572, loss_ib:0.22073245
# epoch 176: loss 2.784400
# epoch 177 loss_pde:0.57357717, loss_ib:0.22097751
# epoch 177: loss 2.783352
# epoch 178 loss_pde:0.57756442, loss_ib:0.22045378
# epoch 178: loss 2.782102
# epoch 179 loss_pde:0.57391202, loss_ib:0.22067791
# epoch 179: loss 2.780691
# epoch 180 loss_pde:0.57554895, loss_ib:0.22037694
# epoch 180: loss 2.779318
# epoch 181 loss_pde:0.57555461, loss_ib:0.22025441
# epoch 181: loss 2.778099
# epoch 182 loss_pde:0.57362038, loss_ib:0.22033522
# epoch 182: loss 2.776973
# epoch 183 loss_pde:0.57646829, loss_ib:0.21993320
# epoch 183: loss 2.775800
# epoch 184 loss_pde:0.57329237, loss_ib:0.22012258
# epoch 184: loss 2.774518
# epoch 185 loss_pde:0.57561839, loss_ib:0.21975580
# epoch 185: loss 2.773176
# epoch 186 loss_pde:0.57433844, loss_ib:0.21975294
# epoch 186: loss 2.771868
# epoch 187 loss_pde:0.57399887, loss_ib:0.21966350
# epoch 187: loss 2.770634
# epoch 188 loss_pde:0.57536232, loss_ib:0.21940795
# epoch 188: loss 2.769442
# epoch 189 loss_pde:0.57318217, loss_ib:0.21950468
# epoch 189: loss 2.768229
# epoch 190 loss_pde:0.57548833, loss_ib:0.21914749
# epoch 190: loss 2.766963
# epoch 191 loss_pde:0.57339603, loss_ib:0.21922641
# epoch 191: loss 2.765660
# epoch 192 loss_pde:0.57431674, loss_ib:0.21900441
# epoch 192: loss 2.764361
# epoch 193 loss_pde:0.57403857, loss_ib:0.21890561
# epoch 193: loss 2.763095
# epoch 194 loss_pde:0.57328457, loss_ib:0.21885729
# epoch 194: loss 2.761858
# epoch 195 loss_pde:0.57464480, loss_ib:0.21859787
# epoch 195: loss 2.760623
# epoch 196 loss_pde:0.57279444, loss_ib:0.21865748
# epoch 196: loss 2.759369
# epoch 197 loss_pde:0.57431221, loss_ib:0.21837756
# epoch 197: loss 2.758088
# epoch 198 loss_pde:0.57294250, loss_ib:0.21838497
# epoch 198: loss 2.756792
# epoch 199 loss_pde:0.57355797, loss_ib:0.21819440
# epoch 199: loss 2.755502
# epoch 200 loss_pde:0.57338339, loss_ib:0.21808435
# epoch 200: loss 2.754227
# epoch 201 loss_pde:0.57274306, loss_ib:0.21802211
# epoch 201: loss 2.752964
# epoch 202 loss_pde:0.57365519, loss_ib:0.21780470
# epoch 202: loss 2.751702
# epoch 203 loss_pde:0.57235891, loss_ib:0.21780713
# epoch 203: loss 2.750430
# epoch 204 loss_pde:0.57348555, loss_ib:0.21756592
# epoch 204: loss 2.749145
# epoch 205 loss_pde:0.57231128, loss_ib:0.21755381
# epoch 205: loss 2.747849
# epoch 206 loss_pde:0.57296824, loss_ib:0.21735834
# epoch 206: loss 2.746552
# epoch 207 loss_pde:0.57252532, loss_ib:0.21727319
# epoch 207: loss 2.745257
# epoch 208 loss_pde:0.57238704, loss_ib:0.21715814
# epoch 208: loss 2.743968
# epoch 209 loss_pde:0.57269925, loss_ib:0.21699828
# epoch 209: loss 2.742682
# epoch 210 loss_pde:0.57195747, loss_ib:0.21694364
# epoch 210: loss 2.741394
# epoch 211 loss_pde:0.57271230, loss_ib:0.21673885
# epoch 211: loss 2.740101
# epoch 212 loss_pde:0.57173896, loss_ib:0.21670623
# epoch 212: loss 2.738801
# epoch 213 loss_pde:0.57246357, loss_ib:0.21650328
# epoch 213: loss 2.737496
# epoch 214 loss_pde:0.57166928, loss_ib:0.21645184
# epoch 214: loss 2.736188
# epoch 215 loss_pde:0.57207948, loss_ib:0.21627976
# epoch 215: loss 2.734877
# epoch 216 loss_pde:0.57169795, loss_ib:0.21618681
# epoch 216: loss 2.733566
# epoch 217 loss_pde:0.57166952, loss_ib:0.21605851
# epoch 217: loss 2.732255
# epoch 218 loss_pde:0.57172865, loss_ib:0.21592143
# epoch 218: loss 2.730943
# epoch 219 loss_pde:0.57132500, loss_ib:0.21583042
# epoch 219: loss 2.729629
# epoch 220 loss_pde:0.57169473, loss_ib:0.21566190
# epoch 220: loss 2.728314
# epoch 221 loss_pde:0.57105118, loss_ib:0.21559438
# epoch 221: loss 2.726995
# epoch 222 loss_pde:0.57157117, loss_ib:0.21541016
# epoch 222: loss 2.725673
# epoch 223 loss_pde:0.57087237, loss_ib:0.21534750
# epoch 223: loss 2.724347
# epoch 224 loss_pde:0.57138151, loss_ib:0.21516374
# epoch 224: loss 2.723019
# epoch 225 loss_pde:0.57072520, loss_ib:0.21509616
# epoch 225: loss 2.721687
# epoch 226 loss_pde:0.57112706, loss_ib:0.21492255
# epoch 226: loss 2.720353
# epoch 227 loss_pde:0.57062328, loss_ib:0.21483925
# epoch 227: loss 2.719016
# epoch 228 loss_pde:0.57088149, loss_ib:0.21467951
# epoch 228: loss 2.717677
# epoch 229 loss_pde:0.57051098, loss_ib:0.21458243
# epoch 229: loss 2.716335
# epoch 230 loss_pde:0.57061946, loss_ib:0.21443722
# epoch 230: loss 2.714992
# epoch 231 loss_pde:0.57040989, loss_ib:0.21432357
# epoch 231: loss 2.713645
# epoch 232 loss_pde:0.57040709, loss_ib:0.21418901
# epoch 232: loss 2.712297
# epoch 233 loss_pde:0.57029253, loss_ib:0.21406536
# epoch 233: loss 2.710946
# epoch 234 loss_pde:0.57018209, loss_ib:0.21394102
# epoch 234: loss 2.709592
# epoch 235 loss_pde:0.57016504, loss_ib:0.21380712
# epoch 235: loss 2.708236
# epoch 236 loss_pde:0.56999373, loss_ib:0.21368836
# epoch 236: loss 2.706877
# epoch 237 loss_pde:0.57004493, loss_ib:0.21354710
# epoch 237: loss 2.705516
# epoch 238 loss_pde:0.56979442, loss_ib:0.21343574
# epoch 238: loss 2.704152
# epoch 239 loss_pde:0.56992203, loss_ib:0.21328631
# epoch 239: loss 2.702785
# epoch 240 loss_pde:0.56959468, loss_ib:0.21318215
# epoch 240: loss 2.701416
# epoch 241 loss_pde:0.56982183, loss_ib:0.21302226
# epoch 241: loss 2.700044
# epoch 242 loss_pde:0.56938207, loss_ib:0.21292880
# epoch 242: loss 2.698670
# epoch 243 loss_pde:0.56975591, loss_ib:0.21275380
# epoch 243: loss 2.697294
# epoch 244 loss_pde:0.56913400, loss_ib:0.21267822
# epoch 244: loss 2.695916
# epoch 245 loss_pde:0.56974262, loss_ib:0.21247950
# epoch 245: loss 2.694538
# epoch 246 loss_pde:0.56882358, loss_ib:0.21243352
# epoch 246: loss 2.693159
# epoch 247 loss_pde:0.56984472, loss_ib:0.21219379
# epoch 247: loss 2.691782
# epoch 248 loss_pde:0.56841099, loss_ib:0.21220018
# epoch 248: loss 2.690413
# epoch 249 loss_pde:0.57015365, loss_ib:0.21189034
# epoch 249: loss 2.689057
# epoch 250 loss_pde:0.56781596, loss_ib:0.21199127
# epoch 250: loss 2.687729
# epoch 251 loss_pde:0.57092732, loss_ib:0.21155247
# epoch 251: loss 2.686452
# epoch 252 loss_pde:0.56699169, loss_ib:0.21182834
# epoch 252: loss 2.685275
# epoch 253 loss_pde:0.57277054, loss_ib:0.21115211
# epoch 253: loss 2.684292
# epoch 254 loss_pde:0.56602627, loss_ib:0.21176547
# epoch 254: loss 2.683681
# epoch 255 loss_pde:0.57747078, loss_ib:0.21063411
# epoch 255: loss 2.683812
# epoch 256 loss_pde:0.56621140, loss_ib:0.21191813
# epoch 256: loss 2.685393
# epoch 257 loss_pde:0.59095383, loss_ib:0.20990187
# epoch 257: loss 2.689972
# epoch 258 loss_pde:0.57458675, loss_ib:0.21258345
# epoch 258: loss 2.700421
# epoch 259 loss_pde:0.63481814, loss_ib:0.20885308
# epoch 259: loss 2.723349
# epoch 260 loss_pde:0.62416351, loss_ib:0.21456638
# epoch 260: loss 2.769827
# epoch 261 loss_pde:0.78950590, loss_ib:0.20767102
# epoch 261: loss 2.866216
# epoch 262 loss_pde:0.83970249, loss_ib:0.21998280
# epoch 262: loss 3.039531
# epoch 263 loss_pde:1.27019572, loss_ib:0.20769009
# epoch 263: loss 3.347097
# epoch 264 loss_pde:1.37362671, loss_ib:0.23011263
# epoch 264: loss 3.674753
# epoch 265 loss_pde:1.80865741, loss_ib:0.20849235
# epoch 265: loss 3.893581
# epoch 266 loss_pde:1.21406054, loss_ib:0.22740069
# epoch 266: loss 3.488067
# epoch 267 loss_pde:0.81600583, loss_ib:0.20966154
# epoch 267: loss 2.912621
# epoch 268 loss_pde:0.57741517, loss_ib:0.21590395
# epoch 268: loss 2.736455
# epoch 269 loss_pde:0.79505420, loss_ib:0.22727938
# epoch 269: loss 3.067848
# epoch 270 loss_pde:1.13223529, loss_ib:0.20854272
# epoch 270: loss 3.217663
# epoch 271 loss_pde:0.70790815, loss_ib:0.21889494
# epoch 271: loss 2.896858
# epoch 272 loss_pde:0.55169463, loss_ib:0.21581897
# epoch 272: loss 2.709884
# epoch 273 loss_pde:0.74430633, loss_ib:0.21578257
# epoch 273: loss 2.902132
# epoch 274 loss_pde:0.73902434, loss_ib:0.22498116
# epoch 274: loss 2.988836
# epoch 275 loss_pde:0.68331170, loss_ib:0.20796958
# epoch 275: loss 2.763007
# epoch 276 loss_pde:0.56927240, loss_ib:0.21543679
# epoch 276: loss 2.723640
# epoch 277 loss_pde:0.63474578, loss_ib:0.22573385
# epoch 277: loss 2.892084
# epoch 278 loss_pde:0.69622457, loss_ib:0.21102977
# epoch 278: loss 2.806522
# epoch 279 loss_pde:0.55322194, loss_ib:0.21200243
# epoch 279: loss 2.673246
# epoch 280 loss_pde:0.57957709, loss_ib:0.21873015
# epoch 280: loss 2.766879
# epoch 281 loss_pde:0.65075701, loss_ib:0.21467070
# epoch 281: loss 2.797464
# epoch 282 loss_pde:0.55583894, loss_ib:0.21196741
# epoch 282: loss 2.675513
# epoch 283 loss_pde:0.55857712, loss_ib:0.21251342
# epoch 283: loss 2.683711
# epoch 284 loss_pde:0.62348199, loss_ib:0.21325025
# epoch 284: loss 2.755985
# epoch 285 loss_pde:0.55847645, loss_ib:0.21354946
# epoch 285: loss 2.693971
# epoch 286 loss_pde:0.55207562, loss_ib:0.20986512
# epoch 286: loss 2.650727
# epoch 287 loss_pde:0.60426378, loss_ib:0.21102491
# epoch 287: loss 2.714513
# epoch 288 loss_pde:0.56524754, loss_ib:0.21353763
# epoch 288: loss 2.700624
# epoch 289 loss_pde:0.55085903, loss_ib:0.20940204
# epoch 289: loss 2.644879
# epoch 290 loss_pde:0.59114277, loss_ib:0.20882826
# epoch 290: loss 2.679425
# epoch 291 loss_pde:0.56334001, loss_ib:0.21283546
# epoch 291: loss 2.691694
# epoch 292 loss_pde:0.55693126, loss_ib:0.20872730
# epoch 292: loss 2.644204
# epoch 293 loss_pde:0.57824838, loss_ib:0.20786069
# epoch 293: loss 2.656855
# epoch 294 loss_pde:0.56138802, loss_ib:0.21157798
# epoch 294: loss 2.677168
# epoch 295 loss_pde:0.56375057, loss_ib:0.20788598
# epoch 295: loss 2.642610
# epoch 296 loss_pde:0.56904685, loss_ib:0.20713542
# epoch 296: loss 2.640401
# epoch 297 loss_pde:0.55921340, loss_ib:0.21026209
# epoch 297: loss 2.661834
# epoch 298 loss_pde:0.57012993, loss_ib:0.20716241
# epoch 298: loss 2.641754
# epoch 299 loss_pde:0.55687571, loss_ib:0.20728129
# epoch 299: loss 2.629689
# epoch 300 loss_pde:0.55534393, loss_ib:0.20907862
# epoch 300: loss 2.646130
# epoch 301 loss_pde:0.57559919, loss_ib:0.20637967
# epoch 301: loss 2.639396
# epoch 302 loss_pde:0.55371904, loss_ib:0.20704952
# epoch 302: loss 2.624214
# epoch 303 loss_pde:0.55258983, loss_ib:0.20801720
# epoch 303: loss 2.632762
# epoch 304 loss_pde:0.57164848, loss_ib:0.20622177
# epoch 304: loss 2.633866
# epoch 305 loss_pde:0.55350345, loss_ib:0.20674863
# epoch 305: loss 2.620990
# epoch 306 loss_pde:0.55540258, loss_ib:0.20670424
# epoch 306: loss 2.622445
# epoch 307 loss_pde:0.56795353, loss_ib:0.20592739
# epoch 307: loss 2.627228
# epoch 308 loss_pde:0.55362540, loss_ib:0.20649309
# epoch 308: loss 2.618556
# epoch 309 loss_pde:0.55585772, loss_ib:0.20585553
# epoch 309: loss 2.614413
# epoch 310 loss_pde:0.56622082, loss_ib:0.20529990
# epoch 310: loss 2.619220
# epoch 311 loss_pde:0.55601704, loss_ib:0.20600061
# epoch 311: loss 2.616023
# epoch 312 loss_pde:0.55784369, loss_ib:0.20515883
# epoch 312: loss 2.609432
# epoch 313 loss_pde:0.56446671, loss_ib:0.20464365
# epoch 313: loss 2.610903
# epoch 314 loss_pde:0.55682522, loss_ib:0.20547664
# epoch 314: loss 2.611592
# epoch 315 loss_pde:0.56044233, loss_ib:0.20456062
# epoch 315: loss 2.606049
# epoch 316 loss_pde:0.56209338, loss_ib:0.20422052
# epoch 316: loss 2.604299
# epoch 317 loss_pde:0.55699325, loss_ib:0.20486584
# epoch 317: loss 2.605652
# epoch 318 loss_pde:0.56450433, loss_ib:0.20382541
# epoch 318: loss 2.602759
# epoch 319 loss_pde:0.55950272, loss_ib:0.20395826
# epoch 319: loss 2.599085
# epoch 320 loss_pde:0.55685043, loss_ib:0.20424788
# epoch 320: loss 2.599329
# epoch 321 loss_pde:0.56637293, loss_ib:0.20323594
# epoch 321: loss 2.598732
# epoch 322 loss_pde:0.55929339, loss_ib:0.20359804
# epoch 322: loss 2.595274
# epoch 323 loss_pde:0.55979317, loss_ib:0.20336580
# epoch 323: loss 2.593451
# epoch 324 loss_pde:0.56495106, loss_ib:0.20285091
# epoch 324: loss 2.593460
# epoch 325 loss_pde:0.55868161, loss_ib:0.20329420
# epoch 325: loss 2.591624
# epoch 326 loss_pde:0.56231749, loss_ib:0.20265742
# epoch 326: loss 2.588892
# epoch 327 loss_pde:0.56289166, loss_ib:0.20250282
# epoch 327: loss 2.587920
# epoch 328 loss_pde:0.55919665, loss_ib:0.20279470
# epoch 328: loss 2.587144
# epoch 329 loss_pde:0.56320935, loss_ib:0.20217171
# epoch 329: loss 2.584926
# epoch 330 loss_pde:0.56111133, loss_ib:0.20217942
# epoch 330: loss 2.582905
# epoch 331 loss_pde:0.56019855, loss_ib:0.20218743
# epoch 331: loss 2.582073
# epoch 332 loss_pde:0.56360918, loss_ib:0.20171751
# epoch 332: loss 2.580784
# epoch 333 loss_pde:0.56058955, loss_ib:0.20180781
# epoch 333: loss 2.578668
# epoch 334 loss_pde:0.56066930, loss_ib:0.20163441
# epoch 334: loss 2.577013
# epoch 335 loss_pde:0.56337827, loss_ib:0.20126130
# epoch 335: loss 2.575991
# epoch 336 loss_pde:0.56052423, loss_ib:0.20139758
# epoch 336: loss 2.574500
# epoch 337 loss_pde:0.56207561, loss_ib:0.20105051
# epoch 337: loss 2.572581
# epoch 338 loss_pde:0.56267309, loss_ib:0.20084170
# epoch 338: loss 2.571090
# epoch 339 loss_pde:0.56036496, loss_ib:0.20095202
# epoch 339: loss 2.569885
# epoch 340 loss_pde:0.56344318, loss_ib:0.20048642
# epoch 340: loss 2.568307
# epoch 341 loss_pde:0.56143516, loss_ib:0.20050876
# epoch 341: loss 2.566523
# epoch 342 loss_pde:0.56104946, loss_ib:0.20040126
# epoch 342: loss 2.565062
# epoch 343 loss_pde:0.56351799, loss_ib:0.20002377
# epoch 343: loss 2.563756
# epoch 344 loss_pde:0.56074810, loss_ib:0.20014392
# epoch 344: loss 2.562187
# epoch 345 loss_pde:0.56230408, loss_ib:0.19981824
# epoch 345: loss 2.560487
# epoch 346 loss_pde:0.56227022, loss_ib:0.19967203
# epoch 346: loss 2.558990
# epoch 347 loss_pde:0.56118834, loss_ib:0.19964139
# epoch 347: loss 2.557602
# epoch 348 loss_pde:0.56317502, loss_ib:0.19928792
# epoch 348: loss 2.556054
# epoch 349 loss_pde:0.56151855, loss_ib:0.19928902
# epoch 349: loss 2.554409
# epoch 350 loss_pde:0.56175536, loss_ib:0.19911310
# epoch 350: loss 2.552886
# epoch 351 loss_pde:0.56281811, loss_ib:0.19886288
# epoch 351: loss 2.551447
# epoch 352 loss_pde:0.56161547, loss_ib:0.19883016
# epoch 352: loss 2.549917
# epoch 353 loss_pde:0.56250620, loss_ib:0.19857922
# epoch 353: loss 2.548298
# epoch 354 loss_pde:0.56239647, loss_ib:0.19843422
# epoch 354: loss 2.546739
# epoch 355 loss_pde:0.56172925, loss_ib:0.19835253
# epoch 355: loss 2.545254
# epoch 356 loss_pde:0.56298870, loss_ib:0.19807467
# epoch 356: loss 2.543736
# epoch 357 loss_pde:0.56199718, loss_ib:0.19801496
# epoch 357: loss 2.542147
# epoch 358 loss_pde:0.56227726, loss_ib:0.19782898
# epoch 358: loss 2.540567
# epoch 359 loss_pde:0.56289893, loss_ib:0.19761433
# epoch 359: loss 2.539042
# epoch 360 loss_pde:0.56178606, loss_ib:0.19757320
# epoch 360: loss 2.537518
# epoch 361 loss_pde:0.56297249, loss_ib:0.19729729
# epoch 361: loss 2.535945
# epoch 362 loss_pde:0.56222796, loss_ib:0.19721265
# epoch 362: loss 2.534354
# epoch 363 loss_pde:0.56233203, loss_ib:0.19704606
# epoch 363: loss 2.532793
# epoch 364 loss_pde:0.56293970, loss_ib:0.19683121
# epoch 364: loss 2.531252
# epoch 365 loss_pde:0.56207323, loss_ib:0.19676167
# epoch 365: loss 2.529690
# epoch 366 loss_pde:0.56285751, loss_ib:0.19652441
# epoch 366: loss 2.528101
# epoch 367 loss_pde:0.56243646, loss_ib:0.19640790
# epoch 367: loss 2.526515
# epoch 368 loss_pde:0.56239504, loss_ib:0.19625531
# epoch 368: loss 2.524948
# epoch 369 loss_pde:0.56284642, loss_ib:0.19605356
# epoch 369: loss 2.523382
# epoch 370 loss_pde:0.56227440, loss_ib:0.19595236
# epoch 370: loss 2.521798
# epoch 371 loss_pde:0.56267172, loss_ib:0.19575281
# epoch 371: loss 2.520200
# epoch 372 loss_pde:0.56268889, loss_ib:0.19559172
# epoch 372: loss 2.518606
# epoch 373 loss_pde:0.56238884, loss_ib:0.19546330
# epoch 373: loss 2.517022
# epoch 374 loss_pde:0.56291932, loss_ib:0.19525148
# epoch 374: loss 2.515434
# epoch 375 loss_pde:0.56233025, loss_ib:0.19515038
# epoch 375: loss 2.513834
# epoch 376 loss_pde:0.56280535, loss_ib:0.19494203
# epoch 376: loss 2.512226
# epoch 377 loss_pde:0.56270587, loss_ib:0.19479135
# epoch 377: loss 2.510619
# epoch 378 loss_pde:0.56249881, loss_ib:0.19465181
# epoch 378: loss 2.509017
# epoch 379 loss_pde:0.56289274, loss_ib:0.19445190
# epoch 379: loss 2.507412
# epoch 380 loss_pde:0.56245363, loss_ib:0.19433439
# epoch 380: loss 2.505797
# epoch 381 loss_pde:0.56283826, loss_ib:0.19413385
# epoch 381: loss 2.504177
# epoch 382 loss_pde:0.56263793, loss_ib:0.19399174
# epoch 382: loss 2.502555
# epoch 383 loss_pde:0.56260598, loss_ib:0.19383286
# epoch 383: loss 2.500935
# epoch 384 loss_pde:0.56279147, loss_ib:0.19365205
# epoch 384: loss 2.499312
# epoch 385 loss_pde:0.56252819, loss_ib:0.19351555
# epoch 385: loss 2.497684
# epoch 386 loss_pde:0.56273651, loss_ib:0.19333132
# epoch 386: loss 2.496050
# epoch 387 loss_pde:0.56267995, loss_ib:0.19317324
# epoch 387: loss 2.494412
# epoch 388 loss_pde:0.56255686, loss_ib:0.19302171
# epoch 388: loss 2.492774
# epoch 389 loss_pde:0.56283092, loss_ib:0.19283032
# epoch 389: loss 2.491134
# epoch 390 loss_pde:0.56239426, loss_ib:0.19270977
# epoch 390: loss 2.489492
# epoch 391 loss_pde:0.56290019, loss_ib:0.19249451
# epoch 391: loss 2.487845
# epoch 392 loss_pde:0.56239015, loss_ib:0.19238056
# epoch 392: loss 2.486196
# epoch 393 loss_pde:0.56284982, loss_ib:0.19216958
# epoch 393: loss 2.484545
# epoch 394 loss_pde:0.56238455, loss_ib:0.19205120
# epoch 394: loss 2.482897
# epoch 395 loss_pde:0.56284732, loss_ib:0.19184057
# epoch 395: loss 2.481253
# epoch 396 loss_pde:0.56229109, loss_ib:0.19173272
# epoch 396: loss 2.479618
# epoch 397 loss_pde:0.56305867, loss_ib:0.19149449
# epoch 397: loss 2.478004
# epoch 398 loss_pde:0.56199145, loss_ib:0.19144362
# epoch 398: loss 2.476428
# epoch 399 loss_pde:0.56362110, loss_ib:0.19113101
# epoch 399: loss 2.474931
# epoch 400 loss_pde:0.56153709, loss_ib:0.19120525
# epoch 400: loss 2.473590
# epoch 401 loss_pde:0.56490719, loss_ib:0.19076468
# epoch 401: loss 2.472554
# epoch 402 loss_pde:0.56113803, loss_ib:0.19109876
# epoch 402: loss 2.472126
# epoch 403 loss_pde:0.56808883, loss_ib:0.19048287
# epoch 403: loss 2.472918
# epoch 404 loss_pde:0.56198049, loss_ib:0.19142234
# epoch 404: loss 2.476204
# epoch 405 loss_pde:0.57757038, loss_ib:0.19069828
# epoch 405: loss 2.484553
# epoch 406 loss_pde:0.57004821, loss_ib:0.19333619
# epoch 406: loss 2.503410
# epoch 407 loss_pde:0.61004925, loss_ib:0.19329682
# epoch 407: loss 2.543017
# epoch 408 loss_pde:0.61202407, loss_ib:0.20115924
# epoch 408: loss 2.623616
# epoch 409 loss_pde:0.72237152, loss_ib:0.20481339
# epoch 409: loss 2.770505
# epoch 410 loss_pde:0.76344395, loss_ib:0.22427009
# epoch 410: loss 3.006145
# epoch 411 loss_pde:0.97433239, loss_ib:0.22681947
# epoch 411: loss 3.242527
# epoch 412 loss_pde:0.92965752, loss_ib:0.23602068
# epoch 412: loss 3.289864
# epoch 413 loss_pde:0.92542112, loss_ib:0.20360662
# epoch 413: loss 2.961487
# epoch 414 loss_pde:0.63608253, loss_ib:0.19463737
# epoch 414: loss 2.582456
# epoch 415 loss_pde:0.59739375, loss_ib:0.19717543
# epoch 415: loss 2.569148
# epoch 416 loss_pde:0.65740275, loss_ib:0.20938241
# epoch 416: loss 2.751227
# epoch 417 loss_pde:0.66873109, loss_ib:0.20543304
# epoch 417: loss 2.723062
# epoch 418 loss_pde:0.72759688, loss_ib:0.18823983
# epoch 418: loss 2.609995
# epoch 419 loss_pde:0.61328954, loss_ib:0.20345089
# epoch 419: loss 2.647799
# epoch 420 loss_pde:0.59587979, loss_ib:0.20258535
# epoch 420: loss 2.621733
# epoch 421 loss_pde:0.59811187, loss_ib:0.19081236
# epoch 421: loss 2.506236
# epoch 422 loss_pde:0.59580213, loss_ib:0.19583665
# epoch 422: loss 2.554169
# epoch 423 loss_pde:0.66874647, loss_ib:0.19659483
# epoch 423: loss 2.634695
# epoch 424 loss_pde:0.57161421, loss_ib:0.19673581
# epoch 424: loss 2.538972
# epoch 425 loss_pde:0.54909134, loss_ib:0.18962000
# epoch 425: loss 2.445292
# epoch 426 loss_pde:0.61357558, loss_ib:0.19393341
# epoch 426: loss 2.552910
# epoch 427 loss_pde:0.58507252, loss_ib:0.19837533
# epoch 427: loss 2.568826
# epoch 428 loss_pde:0.60023367, loss_ib:0.18741961
# epoch 428: loss 2.474430
# epoch 429 loss_pde:0.56165463, loss_ib:0.19281338
# epoch 429: loss 2.489789
# epoch 430 loss_pde:0.55820239, loss_ib:0.19568895
# epoch 430: loss 2.515092
# epoch 431 loss_pde:0.59129882, loss_ib:0.18740848
# epoch 431: loss 2.465384
# epoch 432 loss_pde:0.55966961, loss_ib:0.19263902
# epoch 432: loss 2.486060
# epoch 433 loss_pde:0.57287681, loss_ib:0.19213918
# epoch 433: loss 2.494268
# epoch 434 loss_pde:0.54950500, loss_ib:0.18877698
# epoch 434: loss 2.437275
# epoch 435 loss_pde:0.54703933, loss_ib:0.19003005
# epoch 435: loss 2.447340
# epoch 436 loss_pde:0.58652395, loss_ib:0.18954799
# epoch 436: loss 2.482004
# epoch 437 loss_pde:0.55268860, loss_ib:0.18955562
# epoch 437: loss 2.448245
# epoch 438 loss_pde:0.55289871, loss_ib:0.18715978
# epoch 438: loss 2.424496
# epoch 439 loss_pde:0.55470234, loss_ib:0.18914291
# epoch 439: loss 2.446131
# epoch 440 loss_pde:0.54942399, loss_ib:0.18919955
# epoch 440: loss 2.441420
# epoch 441 loss_pde:0.57264960, loss_ib:0.18556853
# epoch 441: loss 2.428335
# epoch 442 loss_pde:0.54765707, loss_ib:0.18872455
# epoch 442: loss 2.434902
# epoch 443 loss_pde:0.55314565, loss_ib:0.18713067
# epoch 443: loss 2.424452
# epoch 444 loss_pde:0.55838859, loss_ib:0.18542388
# epoch 444: loss 2.412627
# epoch 445 loss_pde:0.54924458, loss_ib:0.18750452
# epoch 445: loss 2.424290
# epoch 446 loss_pde:0.56970364, loss_ib:0.18553223
# epoch 446: loss 2.425026
# epoch 447 loss_pde:0.54738450, loss_ib:0.18594937
# epoch 447: loss 2.406878
# epoch 448 loss_pde:0.54985261, loss_ib:0.18550733
# epoch 448: loss 2.404926
# epoch 449 loss_pde:0.56189150, loss_ib:0.18507744
# epoch 449: loss 2.412666
# epoch 450 loss_pde:0.54788083, loss_ib:0.18600653
# epoch 450: loss 2.407946
# epoch 451 loss_pde:0.56041533, loss_ib:0.18399209
# epoch 451: loss 2.400336
# epoch 452 loss_pde:0.55367738, loss_ib:0.18484142
# epoch 452: loss 2.402092
# epoch 453 loss_pde:0.55135059, loss_ib:0.18473607
# epoch 453: loss 2.398711
# epoch 454 loss_pde:0.55814552, loss_ib:0.18354614
# epoch 454: loss 2.393607
# epoch 455 loss_pde:0.55196798, loss_ib:0.18430209
# epoch 455: loss 2.394989
# epoch 456 loss_pde:0.56112647, loss_ib:0.18346334
# epoch 456: loss 2.395760
# epoch 457 loss_pde:0.55259275, loss_ib:0.18358429
# epoch 457: loss 2.388436
# epoch 458 loss_pde:0.55305791, loss_ib:0.18315899
# epoch 458: loss 2.384648
# epoch 459 loss_pde:0.55776387, loss_ib:0.18289798
# epoch 459: loss 2.386744
# epoch 460 loss_pde:0.55433381, loss_ib:0.18314786
# epoch 460: loss 2.385812
# epoch 461 loss_pde:0.56014770, loss_ib:0.18210392
# epoch 461: loss 2.381187
# epoch 462 loss_pde:0.55279523, loss_ib:0.18262592
# epoch 462: loss 2.379054
# epoch 463 loss_pde:0.55746728, loss_ib:0.18210128
# epoch 463: loss 2.378480
# epoch 464 loss_pde:0.55714995, loss_ib:0.18184711
# epoch 464: loss 2.375621
# epoch 465 loss_pde:0.55351114, loss_ib:0.18198170
# epoch 465: loss 2.373328
# epoch 466 loss_pde:0.56052059, loss_ib:0.18124431
# epoch 466: loss 2.372964
# epoch 467 loss_pde:0.55359542, loss_ib:0.18178688
# epoch 467: loss 2.371464
# epoch 468 loss_pde:0.55739933, loss_ib:0.18104805
# epoch 468: loss 2.367880
# epoch 469 loss_pde:0.55613881, loss_ib:0.18094543
# epoch 469: loss 2.365593
# epoch 470 loss_pde:0.55435026, loss_ib:0.18108451
# epoch 470: loss 2.365195
# epoch 471 loss_pde:0.55985069, loss_ib:0.18039268
# epoch 471: loss 2.363778
# epoch 472 loss_pde:0.55370533, loss_ib:0.18074936
# epoch 472: loss 2.361199
# epoch 473 loss_pde:0.55728519, loss_ib:0.18018626
# epoch 473: loss 2.359148
# epoch 474 loss_pde:0.55586690, loss_ib:0.18019482
# epoch 474: loss 2.357815
# epoch 475 loss_pde:0.55537677, loss_ib:0.18005385
# epoch 475: loss 2.355915
# epoch 476 loss_pde:0.55717880, loss_ib:0.17965519
# epoch 476: loss 2.353731
# epoch 477 loss_pde:0.55431449, loss_ib:0.17979784
# epoch 477: loss 2.352293
# epoch 478 loss_pde:0.55739444, loss_ib:0.17935959
# epoch 478: loss 2.350990
# epoch 479 loss_pde:0.55495524, loss_ib:0.17940922
# epoch 479: loss 2.349047
# epoch 480 loss_pde:0.55621296, loss_ib:0.17905015
# epoch 480: loss 2.346714
# epoch 481 loss_pde:0.55519927, loss_ib:0.17898043
# epoch 481: loss 2.345004
# epoch 482 loss_pde:0.55541682, loss_ib:0.17881769
# epoch 482: loss 2.343594
# epoch 483 loss_pde:0.55678952, loss_ib:0.17851375
# epoch 483: loss 2.341927
# epoch 484 loss_pde:0.55464548, loss_ib:0.17853378
# epoch 484: loss 2.339983
# epoch 485 loss_pde:0.55697161, loss_ib:0.17812553
# epoch 485: loss 2.338227
# epoch 486 loss_pde:0.55450201, loss_ib:0.17821269
# epoch 486: loss 2.336629
# epoch 487 loss_pde:0.55641484, loss_ib:0.17784028
# epoch 487: loss 2.334818
# epoch 488 loss_pde:0.55530012, loss_ib:0.17775944
# epoch 488: loss 2.332894
# epoch 489 loss_pde:0.55495012, loss_ib:0.17761706
# epoch 489: loss 2.331121
# epoch 490 loss_pde:0.55648106, loss_ib:0.17730831
# epoch 490: loss 2.329564
# epoch 491 loss_pde:0.55447632, loss_ib:0.17734437
# epoch 491: loss 2.327920
# epoch 492 loss_pde:0.55656719, loss_ib:0.17695303
# epoch 492: loss 2.326097
# epoch 493 loss_pde:0.55466509, loss_ib:0.17695971
# epoch 493: loss 2.324262
# epoch 494 loss_pde:0.55591512, loss_ib:0.17666179
# epoch 494: loss 2.322533
# epoch 495 loss_pde:0.55528224, loss_ib:0.17655584
# epoch 495: loss 2.320841
# epoch 496 loss_pde:0.55517322, loss_ib:0.17638975
# epoch 496: loss 2.319071
# epoch 497 loss_pde:0.55572528, loss_ib:0.17615505
# epoch 497: loss 2.317276
# epoch 498 loss_pde:0.55491060, loss_ib:0.17606404
# epoch 498: loss 2.315551
# epoch 499 loss_pde:0.55577767, loss_ib:0.17581016
# epoch 499: loss 2.313879
# epoch 500 loss_pde:0.55480981, loss_ib:0.17573659
# epoch 500: loss 2.312176
# epoch 501 loss_pde:0.55591375, loss_ib:0.17544831
# epoch 501: loss 2.310397
# epoch 502 loss_pde:0.55481011, loss_ib:0.17538017
# epoch 502: loss 2.308612
# epoch 503 loss_pde:0.55569649, loss_ib:0.17511702
# epoch 503: loss 2.306867
# epoch 504 loss_pde:0.55485648, loss_ib:0.17502879
# epoch 504: loss 2.305144
# epoch 505 loss_pde:0.55544114, loss_ib:0.17479634
# epoch 505: loss 2.303405
# epoch 506 loss_pde:0.55507898, loss_ib:0.17465572
# epoch 506: loss 2.301636
# epoch 507 loss_pde:0.55488795, loss_ib:0.17449948
# epoch 507: loss 2.299883
# epoch 508 loss_pde:0.55535734, loss_ib:0.17427967
# epoch 508: loss 2.298154
# epoch 509 loss_pde:0.55466300, loss_ib:0.17417762
# epoch 509: loss 2.296439
# epoch 510 loss_pde:0.55550057, loss_ib:0.17392057
# epoch 510: loss 2.294706
# epoch 511 loss_pde:0.55446357, loss_ib:0.17384900
# epoch 511: loss 2.292953
# epoch 512 loss_pde:0.55538511, loss_ib:0.17358166
# epoch 512: loss 2.291202
# epoch 513 loss_pde:0.55448133, loss_ib:0.17349792
# epoch 513: loss 2.289460
# epoch 514 loss_pde:0.55519462, loss_ib:0.17325328
# epoch 514: loss 2.287727
# epoch 515 loss_pde:0.55443025, loss_ib:0.17315561
# epoch 515: loss 2.285986
# epoch 516 loss_pde:0.55506957, loss_ib:0.17291652
# epoch 516: loss 2.284235
# epoch 517 loss_pde:0.55436701, loss_ib:0.17281133
# epoch 517: loss 2.282480
# epoch 518 loss_pde:0.55493617, loss_ib:0.17257962
# epoch 518: loss 2.280732
# epoch 519 loss_pde:0.55422699, loss_ib:0.17247652
# epoch 519: loss 2.278992
# epoch 520 loss_pde:0.55480057, loss_ib:0.17224520
# epoch 520: loss 2.277253
# epoch 521 loss_pde:0.55407721, loss_ib:0.17214307
# epoch 521: loss 2.275508
# epoch 522 loss_pde:0.55463207, loss_ib:0.17191274
# epoch 522: loss 2.273759
# epoch 523 loss_pde:0.55402201, loss_ib:0.17179899
# epoch 523: loss 2.272012
# epoch 524 loss_pde:0.55446017, loss_ib:0.17158087
# epoch 524: loss 2.270269
# epoch 525 loss_pde:0.55381674, loss_ib:0.17147131
# epoch 525: loss 2.268530
# epoch 526 loss_pde:0.55434102, loss_ib:0.17124507
# epoch 526: loss 2.266792
# epoch 527 loss_pde:0.55365241, loss_ib:0.17114000
# epoch 527: loss 2.265052
# epoch 528 loss_pde:0.55428672, loss_ib:0.17090270
# epoch 528: loss 2.263314
# epoch 529 loss_pde:0.55331963, loss_ib:0.17082593
# epoch 529: loss 2.261579
# epoch 530 loss_pde:0.55440068, loss_ib:0.17054521
# epoch 530: loss 2.259853
# epoch 531 loss_pde:0.55296087, loss_ib:0.17051782
# epoch 531: loss 2.258139
# epoch 532 loss_pde:0.55463207, loss_ib:0.17018124
# epoch 532: loss 2.256444
# epoch 533 loss_pde:0.55245477, loss_ib:0.17023255
# epoch 533: loss 2.254780
# epoch 534 loss_pde:0.55524027, loss_ib:0.16979304
# epoch 534: loss 2.253170
# epoch 535 loss_pde:0.55181432, loss_ib:0.16998434
# epoch 535: loss 2.251658
# epoch 536 loss_pde:0.55663997, loss_ib:0.16936857
# epoch 536: loss 2.250326
# epoch 537 loss_pde:0.55117118, loss_ib:0.16981444
# epoch 537: loss 2.249316
# epoch 538 loss_pde:0.56012869, loss_ib:0.16888036
# epoch 538: loss 2.248932
# epoch 539 loss_pde:0.55144978, loss_ib:0.16982256
# epoch 539: loss 2.249675
# epoch 540 loss_pde:0.56969094, loss_ib:0.16830406
# epoch 540: loss 2.252732
# epoch 541 loss_pde:0.55724561, loss_ib:0.17026769
# epoch 541: loss 2.259923
# epoch 542 loss_pde:0.59878933, loss_ib:0.16773474
# epoch 542: loss 2.276137
# epoch 543 loss_pde:0.58840477, loss_ib:0.17190316
# epoch 543: loss 2.307436
# epoch 544 loss_pde:0.69567406, loss_ib:0.16784750
# epoch 544: loss 2.374149
# epoch 545 loss_pde:0.71927065, loss_ib:0.17684981
# epoch 545: loss 2.487769
# epoch 546 loss_pde:1.00509214, loss_ib:0.17130437
# epoch 546: loss 2.718136
# epoch 547 loss_pde:1.10527837, loss_ib:0.18795860
# epoch 547: loss 2.984864
# epoch 548 loss_pde:1.58832693, loss_ib:0.17893964
# epoch 548: loss 3.377723
# epoch 549 loss_pde:1.35480547, loss_ib:0.19264337
# epoch 549: loss 3.281239
# epoch 550 loss_pde:1.20528316, loss_ib:0.17126696
# epoch 550: loss 2.917953
# epoch 551 loss_pde:0.60865390, loss_ib:0.17381451
# epoch 551: loss 2.346799
# epoch 552 loss_pde:0.56166840, loss_ib:0.17185624
# epoch 552: loss 2.280231
# epoch 553 loss_pde:0.93588394, loss_ib:0.16940632
# epoch 553: loss 2.629947
# epoch 554 loss_pde:0.90098798, loss_ib:0.18362585
# epoch 554: loss 2.737247
# epoch 555 loss_pde:0.79268217, loss_ib:0.16897690
# epoch 555: loss 2.482451
# epoch 556 loss_pde:0.53643799, loss_ib:0.16912691
# epoch 556: loss 2.227707
# epoch 557 loss_pde:0.62393039, loss_ib:0.17572552
# epoch 557: loss 2.381186
# epoch 558 loss_pde:0.87826437, loss_ib:0.17040761
# epoch 558: loss 2.582340
# epoch 559 loss_pde:0.66277051, loss_ib:0.17441592
# epoch 559: loss 2.406930
# epoch 560 loss_pde:0.54811502, loss_ib:0.16758940
# epoch 560: loss 2.224009
# epoch 561 loss_pde:0.65784740, loss_ib:0.16633894
# epoch 561: loss 2.321237
# epoch 562 loss_pde:0.67888665, loss_ib:0.17470606
# epoch 562: loss 2.425947
# epoch 563 loss_pde:0.64455962, loss_ib:0.16731311
# epoch 563: loss 2.317691
# epoch 564 loss_pde:0.53691715, loss_ib:0.16780132
# epoch 564: loss 2.214930
# epoch 565 loss_pde:0.58493590, loss_ib:0.17134282
# epoch 565: loss 2.298364
# epoch 566 loss_pde:0.68564498, loss_ib:0.16664068
# epoch 566: loss 2.352052
# epoch 567 loss_pde:0.55144727, loss_ib:0.16966140
# epoch 567: loss 2.248061
# epoch 568 loss_pde:0.53398353, loss_ib:0.16800642
# epoch 568: loss 2.214048
# epoch 569 loss_pde:0.62229216, loss_ib:0.16633834
# epoch 569: loss 2.285676
# epoch 570 loss_pde:0.57403070, loss_ib:0.17043719
# epoch 570: loss 2.278403
# epoch 571 loss_pde:0.55217475, loss_ib:0.16593990
# epoch 571: loss 2.211574
# epoch 572 loss_pde:0.55811036, loss_ib:0.16573891
# epoch 572: loss 2.215499
# epoch 573 loss_pde:0.56272805, loss_ib:0.16949268
# epoch 573: loss 2.257655
# epoch 574 loss_pde:0.58012831, loss_ib:0.16557096
# epoch 574: loss 2.235838
# epoch 575 loss_pde:0.53043866, loss_ib:0.16654082
# epoch 575: loss 2.195847
# epoch 576 loss_pde:0.53846729, loss_ib:0.16755418
# epoch 576: loss 2.214009
# epoch 577 loss_pde:0.58691466, loss_ib:0.16467541
# epoch 577: loss 2.233669
# epoch 578 loss_pde:0.53549135, loss_ib:0.16707526
# epoch 578: loss 2.206244
# epoch 579 loss_pde:0.53054285, loss_ib:0.16583894
# epoch 579: loss 2.188932
# epoch 580 loss_pde:0.56134003, loss_ib:0.16455293
# epoch 580: loss 2.206869
# epoch 581 loss_pde:0.54187942, loss_ib:0.16685873
# epoch 581: loss 2.210467
# epoch 582 loss_pde:0.54677844, loss_ib:0.16425548
# epoch 582: loss 2.189333
# epoch 583 loss_pde:0.53967845, loss_ib:0.16440894
# epoch 583: loss 2.183768
# epoch 584 loss_pde:0.53694576, loss_ib:0.16598666
# epoch 584: loss 2.196812
# epoch 585 loss_pde:0.55802763, loss_ib:0.16361859
# epoch 585: loss 2.194213
# epoch 586 loss_pde:0.53361559, loss_ib:0.16449459
# epoch 586: loss 2.178561
# epoch 587 loss_pde:0.53450543, loss_ib:0.16432545
# epoch 587: loss 2.177760
# epoch 588 loss_pde:0.55524051, loss_ib:0.16305132
# epoch 588: loss 2.185754
# epoch 589 loss_pde:0.53569102, loss_ib:0.16455474
# epoch 589: loss 2.181238
# epoch 590 loss_pde:0.53838032, loss_ib:0.16322385
# epoch 590: loss 2.170619
# epoch 591 loss_pde:0.54164255, loss_ib:0.16290943
# epoch 591: loss 2.170737
# epoch 592 loss_pde:0.53657109, loss_ib:0.16389456
# epoch 592: loss 2.175517
# epoch 593 loss_pde:0.54813421, loss_ib:0.16233176
# epoch 593: loss 2.171452
# epoch 594 loss_pde:0.53602648, loss_ib:0.16278578
# epoch 594: loss 2.163884
# epoch 595 loss_pde:0.53537446, loss_ib:0.16280875
# epoch 595: loss 2.163462
# epoch 596 loss_pde:0.54726195, loss_ib:0.16189294
# epoch 596: loss 2.166191
# epoch 597 loss_pde:0.53654742, loss_ib:0.16267240
# epoch 597: loss 2.163271
# epoch 598 loss_pde:0.54072243, loss_ib:0.16169119
# epoch 598: loss 2.157634
# epoch 599 loss_pde:0.54145753, loss_ib:0.16149022
# epoch 599: loss 2.156360
# epoch 600 loss_pde:0.53656709, loss_ib:0.16210888
# epoch 600: loss 2.157656
# epoch 601 loss_pde:0.54506332, loss_ib:0.16107525
# epoch 601: loss 2.155816
# epoch 602 loss_pde:0.53761894, loss_ib:0.16139187
# epoch 602: loss 2.151538
# epoch 603 loss_pde:0.53832775, loss_ib:0.16112512
# epoch 603: loss 2.149579
# epoch 604 loss_pde:0.54456705, loss_ib:0.16052848
# epoch 604: loss 2.149852
# epoch 605 loss_pde:0.53742814, loss_ib:0.16112596
# epoch 605: loss 2.148688
# epoch 606 loss_pde:0.54201561, loss_ib:0.16035026
# epoch 606: loss 2.145518
# epoch 607 loss_pde:0.54010314, loss_ib:0.16030277
# epoch 607: loss 2.143131
# epoch 608 loss_pde:0.53821546, loss_ib:0.16043377
# epoch 608: loss 2.142553
# epoch 609 loss_pde:0.54415929, loss_ib:0.15976200
# epoch 609: loss 2.141779
# epoch 610 loss_pde:0.53815305, loss_ib:0.16013560
# epoch 610: loss 2.139509
# epoch 611 loss_pde:0.54009116, loss_ib:0.15969235
# epoch 611: loss 2.137015
# epoch 612 loss_pde:0.54076004, loss_ib:0.15949316
# epoch 612: loss 2.135692
# epoch 613 loss_pde:0.53804284, loss_ib:0.15968663
# epoch 613: loss 2.134909
# epoch 614 loss_pde:0.54288387, loss_ib:0.15905127
# epoch 614: loss 2.133397
# epoch 615 loss_pde:0.53848857, loss_ib:0.15926884
# epoch 615: loss 2.131177
# epoch 616 loss_pde:0.53928417, loss_ib:0.15900345
# epoch 616: loss 2.129319
# epoch 617 loss_pde:0.54107076, loss_ib:0.15870968
# epoch 617: loss 2.128167
# epoch 618 loss_pde:0.53812045, loss_ib:0.15889044
# epoch 618: loss 2.127025
# epoch 619 loss_pde:0.54161829, loss_ib:0.15837206
# epoch 619: loss 2.125339
# epoch 620 loss_pde:0.53873730, loss_ib:0.15846601
# epoch 620: loss 2.123397
# epoch 621 loss_pde:0.53906524, loss_ib:0.15827303
# epoch 621: loss 2.121796
# epoch 622 loss_pde:0.54083925, loss_ib:0.15797080
# epoch 622: loss 2.120547
# epoch 623 loss_pde:0.53840762, loss_ib:0.15808135
# epoch 623: loss 2.119221
# epoch 624 loss_pde:0.54107451, loss_ib:0.15765104
# epoch 624: loss 2.117585
# epoch 625 loss_pde:0.53914976, loss_ib:0.15766929
# epoch 625: loss 2.115843
# epoch 626 loss_pde:0.53935891, loss_ib:0.15749426
# epoch 626: loss 2.114301
# epoch 627 loss_pde:0.54044282, loss_ib:0.15725136
# epoch 627: loss 2.112957
# epoch 628 loss_pde:0.53873485, loss_ib:0.15728390
# epoch 628: loss 2.111574
# epoch 629 loss_pde:0.54087955, loss_ib:0.15691377
# epoch 629: loss 2.110017
# epoch 630 loss_pde:0.53917634, loss_ib:0.15692095
# epoch 630: loss 2.108386
# epoch 631 loss_pde:0.53956628, loss_ib:0.15672810
# epoch 631: loss 2.106847
# epoch 632 loss_pde:0.54010963, loss_ib:0.15653276
# epoch 632: loss 2.105437
# epoch 633 loss_pde:0.53887743, loss_ib:0.15651658
# epoch 633: loss 2.104043
# epoch 634 loss_pde:0.54051203, loss_ib:0.15620518
# epoch 634: loss 2.102564
# epoch 635 loss_pde:0.53910184, loss_ib:0.15619072
# epoch 635: loss 2.101009
# epoch 636 loss_pde:0.53967792, loss_ib:0.15597905
# epoch 636: loss 2.099468
# epoch 637 loss_pde:0.53959644, loss_ib:0.15584056
# epoch 637: loss 2.098002
# epoch 638 loss_pde:0.53893900, loss_ib:0.15576480
# epoch 638: loss 2.096587
# epoch 639 loss_pde:0.54001105, loss_ib:0.15551487
# epoch 639: loss 2.095160
# epoch 640 loss_pde:0.53884339, loss_ib:0.15548398
# epoch 640: loss 2.093683
# epoch 641 loss_pde:0.53964639, loss_ib:0.15525287
# epoch 641: loss 2.092175
# epoch 642 loss_pde:0.53907430, loss_ib:0.15516065
# epoch 642: loss 2.090681
# epoch 643 loss_pde:0.53903949, loss_ib:0.15501839
# ...
# epoch 788: loss 1.917050
# epoch 789 loss_pde:0.53106922, loss_ib:0.13919069
# epoch 789: loss 1.922976
# epoch 790 loss_pde:0.52315885, loss_ib:0.14060947
# epoch 790: loss 1.929254
# epoch 791 loss_pde:0.53375196, loss_ib:0.13966493
# epoch 791: loss 1.930401
# epoch 792 loss_pde:0.52065510, loss_ib:0.14026409
# epoch 792: loss 1.923296
# epoch 793 loss_pde:0.52381259, loss_ib:0.13908370
# epoch 793: loss 1.914649
# epoch 794 loss_pde:0.51969337, loss_ib:0.13897596
# epoch 794: loss 1.909453
# epoch 795 loss_pde:0.52003622, loss_ib:0.13900249
# epoch 795: loss 1.910061
# epoch 796 loss_pde:0.52520007, loss_ib:0.13882771
# epoch 796: loss 1.913477
# epoch 797 loss_pde:0.52043855, loss_ib:0.13948172
# epoch 797: loss 1.915256
# epoch 798 loss_pde:0.52997136, loss_ib:0.13844135
# epoch 798: loss 1.914385
# epoch 799 loss_pde:0.51946497, loss_ib:0.13910295
# epoch 799: loss 1.910494
# epoch 800 loss_pde:0.52451360, loss_ib:0.13813774
# epoch 800: loss 1.905891
# epoch 801 loss_pde:0.51874024, loss_ib:0.13836889
# epoch 801: loss 1.902429
# epoch 802 loss_pde:0.51893294, loss_ib:0.13822362
# epoch 802: loss 1.901169
# epoch 803 loss_pde:0.52299565, loss_ib:0.13784821
# epoch 803: loss 1.901478
# epoch 804 loss_pde:0.51854074, loss_ib:0.13836803
# epoch 804: loss 1.902221
# epoch 805 loss_pde:0.52476138, loss_ib:0.13778658
# epoch 805: loss 1.902627
# epoch 806 loss_pde:0.51885360, loss_ib:0.13829227
# epoch 806: loss 1.901776
# epoch 807 loss_pde:0.52401865, loss_ib:0.13759169
# epoch 807: loss 1.899936
# epoch 808 loss_pde:0.51914525, loss_ib:0.13780524
# epoch 808: loss 1.897198
# epoch 809 loss_pde:0.52256036, loss_ib:0.13721433
# epoch 809: loss 1.894704
# epoch 810 loss_pde:0.51931310, loss_ib:0.13734527
# epoch 810: loss 1.892766
# epoch 811 loss_pde:0.52031249, loss_ib:0.13711089
# epoch 811: loss 1.891421
# epoch 812 loss_pde:0.52102357, loss_ib:0.13695736
# epoch 812: loss 1.890597
# epoch 813 loss_pde:0.51926434, loss_ib:0.13708831
# epoch 813: loss 1.890147
# epoch 814 loss_pde:0.52320462, loss_ib:0.13666169
# epoch 814: loss 1.889822
# epoch 815 loss_pde:0.51923198, loss_ib:0.13701482
# epoch 815: loss 1.889380
# epoch 816 loss_pde:0.52330554, loss_ib:0.13655414
# epoch 816: loss 1.888847
# epoch 817 loss_pde:0.51949453, loss_ib:0.13685863
# epoch 817: loss 1.888081
# epoch 818 loss_pde:0.52320021, loss_ib:0.13640364
# epoch 818: loss 1.887237
# epoch 819 loss_pde:0.51956129, loss_ib:0.13665383
# epoch 819: loss 1.886100
# epoch 820 loss_pde:0.52356404, loss_ib:0.13614543
# epoch 820: loss 1.885018
# epoch 821 loss_pde:0.51924580, loss_ib:0.13646179
# epoch 821: loss 1.883864
# epoch 822 loss_pde:0.52396452, loss_ib:0.13588774
# epoch 822: loss 1.882842
# epoch 823 loss_pde:0.51942277, loss_ib:0.13623585
# epoch 823: loss 1.881781
# epoch 824 loss_pde:0.52378339, loss_ib:0.13571237
# epoch 824: loss 1.880907
# epoch 825 loss_pde:0.51949787, loss_ib:0.13605990
# epoch 825: loss 1.880097
# epoch 826 loss_pde:0.52352095, loss_ib:0.13561222
# epoch 826: loss 1.879643
# epoch 827 loss_pde:0.51942092, loss_ib:0.13599104
# epoch 827: loss 1.879331
# epoch 828 loss_pde:0.52502108, loss_ib:0.13546790
# epoch 828: loss 1.879700
# epoch 829 loss_pde:0.51997077, loss_ib:0.13605410
# epoch 829: loss 1.880512
# epoch 830 loss_pde:0.52841401, loss_ib:0.13544796
# epoch 830: loss 1.882894
# epoch 831 loss_pde:0.52156472, loss_ib:0.13648036
# epoch 831: loss 1.886368
# epoch 832 loss_pde:0.53462571, loss_ib:0.13593845
# epoch 832: loss 1.894010
# epoch 833 loss_pde:0.52666390, loss_ib:0.13771904
# epoch 833: loss 1.903854
# epoch 834 loss_pde:0.54960001, loss_ib:0.13754246
# epoch 834: loss 1.925025
# epoch 835 loss_pde:0.54162216, loss_ib:0.14055648
# epoch 835: loss 1.947187
# epoch 836 loss_pde:0.58419389, loss_ib:0.14114775
# epoch 836: loss 1.995671
# epoch 837 loss_pde:0.57602984, loss_ib:0.14506097
# epoch 837: loss 2.026639
# epoch 838 loss_pde:0.64260483, loss_ib:0.14518018
# epoch 838: loss 2.094407
# epoch 839 loss_pde:0.61802524, loss_ib:0.14711767
# epoch 839: loss 2.089202
# epoch 840 loss_pde:0.66993153, loss_ib:0.14246818
# epoch 840: loss 2.094614
# epoch 841 loss_pde:0.59805298, loss_ib:0.14193666
# epoch 841: loss 2.017420
# epoch 842 loss_pde:0.58789665, loss_ib:0.13554253
# epoch 842: loss 1.943322
# epoch 843 loss_pde:0.52567691, loss_ib:0.13540941
# epoch 843: loss 1.879771
# epoch 844 loss_pde:0.51889205, loss_ib:0.13423949
# epoch 844: loss 1.861287
# epoch 845 loss_pde:0.54622799, loss_ib:0.13384070
# epoch 845: loss 1.884635
# epoch 846 loss_pde:0.54909289, loss_ib:0.13729957
# epoch 846: loss 1.922089
# epoch 847 loss_pde:0.58849996, loss_ib:0.13624980
# epoch 847: loss 1.950998
# epoch 848 loss_pde:0.55206490, loss_ib:0.13896266
# epoch 848: loss 1.941691
# epoch 849 loss_pde:0.55584192, loss_ib:0.13606691
# epoch 849: loss 1.916511
# epoch 850 loss_pde:0.52283943, loss_ib:0.13545164
# epoch 850: loss 1.877356
# epoch 851 loss_pde:0.51997751, loss_ib:0.13353053
# epoch 851: loss 1.855283
# epoch 852 loss_pde:0.52143097, loss_ib:0.13356276
# epoch 852: loss 1.857059
# epoch 853 loss_pde:0.52108276, loss_ib:0.13529308
# epoch 853: loss 1.874014
# epoch 854 loss_pde:0.54484248, loss_ib:0.13474877
# epoch 854: loss 1.892330
# epoch 855 loss_pde:0.53139913, loss_ib:0.13632849
# epoch 855: loss 1.894684
# epoch 856 loss_pde:0.54689592, loss_ib:0.13388363
# epoch 856: loss 1.885732
# epoch 857 loss_pde:0.52155954, loss_ib:0.13451523
# epoch 857: loss 1.866712
# epoch 858 loss_pde:0.52186203, loss_ib:0.13294826
# epoch 858: loss 1.851345
# epoch 859 loss_pde:0.51682448, loss_ib:0.13289855
# epoch 859: loss 1.845810
# epoch 860 loss_pde:0.51578104, loss_ib:0.13342713
# epoch 860: loss 1.850052
# epoch 861 loss_pde:0.52959675, loss_ib:0.13289717
# epoch 861: loss 1.858568
# epoch 862 loss_pde:0.52053177, loss_ib:0.13440342
# epoch 862: loss 1.864566
# epoch 863 loss_pde:0.53194427, loss_ib:0.13344541
# epoch 863: loss 1.866398
# epoch 864 loss_pde:0.51894671, loss_ib:0.13419335
# epoch 864: loss 1.860880
# epoch 865 loss_pde:0.52496845, loss_ib:0.13281921
# epoch 865: loss 1.853160
# epoch 866 loss_pde:0.51598436, loss_ib:0.13284940
# epoch 866: loss 1.844478
# epoch 867 loss_pde:0.51809955, loss_ib:0.13208728
# epoch 867: loss 1.838972
# epoch 868 loss_pde:0.51534909, loss_ib:0.13219643
# epoch 868: loss 1.837313
# epoch 869 loss_pde:0.51462746, loss_ib:0.13239856
# epoch 869: loss 1.838613
# epoch 870 loss_pde:0.52054465, loss_ib:0.13208839
# epoch 870: loss 1.841429
# epoch 871 loss_pde:0.51582479, loss_ib:0.13281426
# epoch 871: loss 1.843967
# epoch 872 loss_pde:0.52592403, loss_ib:0.13197446
# epoch 872: loss 1.845669
# epoch 873 loss_pde:0.51659954, loss_ib:0.13285346
# epoch 873: loss 1.845134
# epoch 874 loss_pde:0.52418703, loss_ib:0.13194792
# epoch 874: loss 1.843666
# epoch 875 loss_pde:0.51536739, loss_ib:0.13252561
# epoch 875: loss 1.840623
# epoch 876 loss_pde:0.52046973, loss_ib:0.13171817
# epoch 876: loss 1.837651
# epoch 877 loss_pde:0.51471019, loss_ib:0.13194546
# epoch 877: loss 1.834165
# epoch 878 loss_pde:0.51849329, loss_ib:0.13127233
# epoch 878: loss 1.831217
# epoch 879 loss_pde:0.51443881, loss_ib:0.13142096
# epoch 879: loss 1.828648
# epoch 880 loss_pde:0.51723099, loss_ib:0.13094084
# epoch 880: loss 1.826639
# epoch 881 loss_pde:0.51479411, loss_ib:0.13102339
# epoch 881: loss 1.825028
# epoch 882 loss_pde:0.51597840, loss_ib:0.13077842
# epoch 882: loss 1.823763
# epoch 883 loss_pde:0.51590109, loss_ib:0.13068910
# epoch 883: loss 1.822792
# epoch 884 loss_pde:0.51507401, loss_ib:0.13069595
# epoch 884: loss 1.822034
# epoch 885 loss_pde:0.51689410, loss_ib:0.13045229
# epoch 885: loss 1.821417
# epoch 886 loss_pde:0.51487303, loss_ib:0.13060585
# epoch 886: loss 1.820931
# epoch 887 loss_pde:0.51747215, loss_ib:0.13031857
# epoch 887: loss 1.820658
# epoch 888 loss_pde:0.51503032, loss_ib:0.13056172
# epoch 888: loss 1.820647
# epoch 889 loss_pde:0.51858294, loss_ib:0.13025829
# epoch 889: loss 1.821166
# epoch 890 loss_pde:0.51540190, loss_ib:0.13068600
# epoch 890: loss 1.822262
# epoch 891 loss_pde:0.52183306, loss_ib:0.13030380
# epoch 891: loss 1.824871
# epoch 892 loss_pde:0.51732904, loss_ib:0.13117112
# epoch 892: loss 1.829040
# epoch 893 loss_pde:0.52951366, loss_ib:0.13082150
# epoch 893: loss 1.837729
# epoch 894 loss_pde:0.52384669, loss_ib:0.13265242
# epoch 894: loss 1.850371
# epoch 895 loss_pde:0.54725194, loss_ib:0.13295989
# epoch 895: loss 1.876851
# epoch 896 loss_pde:0.54303539, loss_ib:0.13665219
# epoch 896: loss 1.909557
# epoch 897 loss_pde:0.59087819, loss_ib:0.13893038
# epoch 897: loss 1.980182
# epoch 898 loss_pde:0.59291685, loss_ib:0.14434291
# epoch 898: loss 2.036346
# epoch 899 loss_pde:0.68017685, loss_ib:0.14732666
# epoch 899: loss 2.153443
# epoch 900 loss_pde:0.66917026, loss_ib:0.14883643
# epoch 900: loss 2.157535
# epoch 901 loss_pde:0.74130201, loss_ib:0.14285101
# epoch 901: loss 2.169812
# epoch 902 loss_pde:0.64665467, loss_ib:0.13975435
# epoch 902: loss 2.044198
# epoch 903 loss_pde:0.60988390, loss_ib:0.13052520
# epoch 903: loss 1.915136
# epoch 904 loss_pde:0.52182508, loss_ib:0.12992939
# epoch 904: loss 1.821119
# epoch 905 loss_pde:0.51951402, loss_ib:0.12992874
# epoch 905: loss 1.818801
# epoch 906 loss_pde:0.58619690, loss_ib:0.13005178
# epoch 906: loss 1.886715
# epoch 907 loss_pde:0.59469438, loss_ib:0.13501722
# epoch 907: loss 1.944867
# epoch 908 loss_pde:0.62592888, loss_ib:0.13250703
# epoch 908: loss 1.950999
# epoch 909 loss_pde:0.55092871, loss_ib:0.13359901
# epoch 909: loss 1.886919
# epoch 910 loss_pde:0.52857316, loss_ib:0.12977619
# epoch 910: loss 1.826335
# epoch 911 loss_pde:0.51804835, loss_ib:0.12864995
# epoch 911: loss 1.804548
# epoch 912 loss_pde:0.52295256, loss_ib:0.13062574
# epoch 912: loss 1.829210
# epoch 913 loss_pde:0.55460829, loss_ib:0.13131946
# epoch 913: loss 1.867803
# epoch 914 loss_pde:0.53649294, loss_ib:0.13368654
# epoch 914: loss 1.873358
# epoch 915 loss_pde:0.54508138, loss_ib:0.13062815
# epoch 915: loss 1.851363
# epoch 916 loss_pde:0.51582360, loss_ib:0.12971541
# epoch 916: loss 1.812978
# epoch 917 loss_pde:0.51509362, loss_ib:0.12828901
# epoch 917: loss 1.797984
# epoch 918 loss_pde:0.51829249, loss_ib:0.12916213
# epoch 918: loss 1.809914
# epoch 919 loss_pde:0.52060437, loss_ib:0.13074030
# epoch 919: loss 1.828007
# epoch 920 loss_pde:0.54226798, loss_ib:0.12936622
# epoch 920: loss 1.835930
# epoch 921 loss_pde:0.52345693, loss_ib:0.13000433
# epoch 921: loss 1.823500
# epoch 922 loss_pde:0.52847672, loss_ib:0.12768592
# epoch 922: loss 1.805336
# epoch 923 loss_pde:0.50969917, loss_ib:0.12833595
# epoch 923: loss 1.793059
# epoch 924 loss_pde:0.51103854, loss_ib:0.12828732
# epoch 924: loss 1.793912
# epoch 925 loss_pde:0.52418768, loss_ib:0.12788771
# epoch 925: loss 1.803065
# epoch 926 loss_pde:0.51858705, loss_ib:0.12910609
# epoch 926: loss 1.809648
# epoch 927 loss_pde:0.53135353, loss_ib:0.12772001
# epoch 927: loss 1.808554
# epoch 928 loss_pde:0.51357174, loss_ib:0.12861346
# epoch 928: loss 1.799706
# epoch 929 loss_pde:0.51499003, loss_ib:0.12757063
# epoch 929: loss 1.790696
# epoch 930 loss_pde:0.51050651, loss_ib:0.12749092
# epoch 930: loss 1.785416
# epoch 931 loss_pde:0.50965399, loss_ib:0.12758562
# epoch 931: loss 1.785510
# epoch 932 loss_pde:0.51653159, loss_ib:0.12727001
# epoch 932: loss 1.789232
# epoch 933 loss_pde:0.51133108, loss_ib:0.12814584
# epoch 933: loss 1.792789
# epoch 934 loss_pde:0.51886064, loss_ib:0.12750737
# epoch 934: loss 1.793934
# epoch 935 loss_pde:0.51089430, loss_ib:0.12794963
# epoch 935: loss 1.790390
# epoch 936 loss_pde:0.51622534, loss_ib:0.12690298
# epoch 936: loss 1.785255
# epoch 937 loss_pde:0.50986975, loss_ib:0.12703893
# epoch 937: loss 1.780259
# epoch 938 loss_pde:0.51201862, loss_ib:0.12653764
# epoch 938: loss 1.777395
# epoch 939 loss_pde:0.51127833, loss_ib:0.12654929
# epoch 939: loss 1.776771
# epoch 940 loss_pde:0.51012248, loss_ib:0.12675564
# epoch 940: loss 1.777679
# epoch 941 loss_pde:0.51625061, loss_ib:0.12628332
# epoch 941: loss 1.779084
# epoch 942 loss_pde:0.51147133, loss_ib:0.12682864
# epoch 942: loss 1.779758
# epoch 943 loss_pde:0.51838261, loss_ib:0.12610993
# epoch 943: loss 1.779482
# epoch 944 loss_pde:0.51169419, loss_ib:0.12662752
# epoch 944: loss 1.777969
# epoch 945 loss_pde:0.51504976, loss_ib:0.12610751
# epoch 945: loss 1.776125
# epoch 946 loss_pde:0.51123625, loss_ib:0.12627232
# epoch 946: loss 1.773959
# epoch 947 loss_pde:0.51240528, loss_ib:0.12595083
# epoch 947: loss 1.771914
# epoch 948 loss_pde:0.51148355, loss_ib:0.12584409
# epoch 948: loss 1.769925
# epoch 949 loss_pde:0.51175767, loss_ib:0.12564623
# epoch 949: loss 1.768220
# epoch 950 loss_pde:0.51132399, loss_ib:0.12555747
# epoch 950: loss 1.766899
# epoch 951 loss_pde:0.51153189, loss_ib:0.12544200
# epoch 951: loss 1.765952
# epoch 952 loss_pde:0.51142275, loss_ib:0.12538576
# epoch 952: loss 1.765280
# epoch 953 loss_pde:0.51135522, loss_ib:0.12534510
# epoch 953: loss 1.764806
# epoch 954 loss_pde:0.51238883, loss_ib:0.12520894
# epoch 954: loss 1.764478
# epoch 955 loss_pde:0.51117682, loss_ib:0.12530589
# epoch 955: loss 1.764236
# epoch 956 loss_pde:0.51368541, loss_ib:0.12504146
# epoch 956: loss 1.764100
# epoch 957 loss_pde:0.51133364, loss_ib:0.12527420
# epoch 957: loss 1.764076
# epoch 958 loss_pde:0.51481104, loss_ib:0.12496255
# epoch 958: loss 1.764436
# epoch 959 loss_pde:0.51173532, loss_ib:0.12534487
# epoch 959: loss 1.765184
# epoch 960 loss_pde:0.51651144, loss_ib:0.12504879
# epoch 960: loss 1.766999
# epoch 961 loss_pde:0.51276571, loss_ib:0.12568271
# epoch 961: loss 1.769593
# epoch 962 loss_pde:0.52078855, loss_ib:0.12541366
# epoch 962: loss 1.774925
# epoch 963 loss_pde:0.51632929, loss_ib:0.12656748
# epoch 963: loss 1.782004
# epoch 964 loss_pde:0.53055841, loss_ib:0.12658954
# epoch 964: loss 1.796454
# epoch 965 loss_pde:0.52595508, loss_ib:0.12881108
# epoch 965: loss 1.814066
# epoch 966 loss_pde:0.55188966, loss_ib:0.12984847
# epoch 966: loss 1.850374
# epoch 967 loss_pde:0.54922521, loss_ib:0.13360873
# epoch 967: loss 1.885312
# epoch 968 loss_pde:0.59548241, loss_ib:0.13615276
# epoch 968: loss 1.957010
# epoch 969 loss_pde:0.59227890, loss_ib:0.13975827
# epoch 969: loss 1.989862
# epoch 970 loss_pde:0.65376818, loss_ib:0.13996467
# epoch 970: loss 2.053415
# epoch 971 loss_pde:0.62387127, loss_ib:0.13887367
# epoch 971: loss 2.012608
# epoch 972 loss_pde:0.64758539, loss_ib:0.13151978
# epoch 972: loss 1.962783
# epoch 973 loss_pde:0.57030064, loss_ib:0.12893407
# epoch 973: loss 1.859641
# epoch 974 loss_pde:0.54556215, loss_ib:0.12344838
# epoch 974: loss 1.780046
# epoch 975 loss_pde:0.51238513, loss_ib:0.12381335
# epoch 975: loss 1.750519
# epoch 976 loss_pde:0.52227038, loss_ib:0.12541798
# epoch 976: loss 1.776450
# epoch 977 loss_pde:0.57184386, loss_ib:0.12555268
# epoch 977: loss 1.827371
# epoch 978 loss_pde:0.56659758, loss_ib:0.12873930
# epoch 978: loss 1.853991
# epoch 979 loss_pde:0.58467257, loss_ib:0.12601589
# epoch 979: loss 1.844831
# epoch 980 loss_pde:0.53382140, loss_ib:0.12657966
# epoch 980: loss 1.799618
# epoch 981 loss_pde:0.52334702, loss_ib:0.12385694
# epoch 981: loss 1.761916
# epoch 982 loss_pde:0.51207167, loss_ib:0.12362616
# epoch 982: loss 1.748333
# epoch 983 loss_pde:0.51340729, loss_ib:0.12464395
# epoch 983: loss 1.759847
# epoch 984 loss_pde:0.53231883, loss_ib:0.12482706
# epoch 984: loss 1.780589
# epoch 985 loss_pde:0.52315617, loss_ib:0.12676384
# epoch 985: loss 1.790794
# epoch 986 loss_pde:0.53604949, loss_ib:0.12519644
# epoch 986: loss 1.788014
# epoch 987 loss_pde:0.51711011, loss_ib:0.12503579
# epoch 987: loss 1.767468
# epoch 988 loss_pde:0.52040523, loss_ib:0.12291814
# epoch 988: loss 1.749587
# epoch 989 loss_pde:0.50836831, loss_ib:0.12338400
# epoch 989: loss 1.742208
# epoch 990 loss_pde:0.51012129, loss_ib:0.12361214
# epoch 990: loss 1.746243
# epoch 991 loss_pde:0.51500511, loss_ib:0.12399243
# epoch 991: loss 1.754929
# epoch 992 loss_pde:0.51370490, loss_ib:0.12459755
# epoch 992: loss 1.759680
# epoch 993 loss_pde:0.52865922, loss_ib:0.12312007
# epoch 993: loss 1.759860
# epoch 994 loss_pde:0.51500762, loss_ib:0.12380838
# epoch 994: loss 1.753091
# epoch 995 loss_pde:0.52278781, loss_ib:0.12217876
# epoch 995: loss 1.744576
# epoch 996 loss_pde:0.50754988, loss_ib:0.12294663
# epoch 996: loss 1.737016
# epoch 997 loss_pde:0.50917292, loss_ib:0.12243865
# epoch 997: loss 1.733559
# epoch 998 loss_pde:0.51104331, loss_ib:0.12236071
# epoch 998: loss 1.734650
# epoch 999 loss_pde:0.50845224, loss_ib:0.12296646
# epoch 999: loss 1.738117
# epoch 1000 loss_pde:0.51948851, loss_ib:0.12218413
# epoch 1000: loss 1.741330
# Total training time: 371.2320730686188

# %%
lr = 0.0001
#optimizer = torch.optim.LBFGS(model.parameters(),lr=lr,max_iter=500)
optimizer = torch.optim.Adam(model.parameters(), lr=lr)
#scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer_Adam,gamma=0.995)
#optimizer = torch.optim.LBFGS(model.parameters(),lr=0.1,max_iter=10)
#optimizer_LBFGS = torch.optim.LBFGS(model.parameters(), lr=0.01, max_iter=50000)

# %%
epochs = 2
tic = time.time()
for epoch in range(1, epochs+1):
    train(epoch)
toc = time.time()
print(f'Total training time: {toc - tic}')
# Out:
# epoch 1 loss_pde:0.51012772, loss_ib:0.12317850
# epoch 1: loss 1.741913
# epoch 2 loss_pde:0.77215737, loss_ib:0.12959009
# epoch 2: loss 2.068058
# Total training time: 0.7930564880371094

# %%
lr = 0.0001
#optimizer = torch.optim.LBFGS(model.parameters(),lr=lr,max_iter=500)
#optimizer = torch.optim.Adam(model.parameters(), lr=lr)
#scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer_Adam,gamma=0.995)
optimizer = torch.optim.LBFGS(model.parameters(),lr=1,max_iter=20)
#optimizer_LBFGS = torch.optim.LBFGS(model.parameters(), lr=0.01, max_iter=50000)

# %%
epochs = 300
tic = time.time()
for epoch in range(1, epochs+1):
    train(epoch)
toc = time.time()
print(f'Total training time: {toc - tic}')
# Out:
# epoch 1 loss_pde:0.10344033, loss_ib:4.05444670
# epoch 1 loss_pde:0.20986223, loss_ib:4.13174295
# epoch 1 loss_pde:0.16846269, loss_ib:3.85252786
# epoch 1 loss_pde:0.19556396, loss_ib:3.82005334
# epoch 1 loss_pde:0.27339798, loss_ib:3.77893472
# epoch 1 loss_pde:0.38793039, loss_ib:3.72017121
# epoch 1 loss_pde:0.57371682, loss_ib:3.63972163
# epoch 1 loss_pde:0.69852483, loss_ib:3.58274317
# epoch 1 loss_pde:0.86379302, loss_ib:3.50459957
# epoch 1 loss_pde:1.17102456, loss_ib:3.38947463
# epoch 1 loss_pde:1.57016134, loss_ib:3.25986099
# epoch 1 loss_pde:1.81947947, loss_ib:3.17122483
# epoch 1 loss_pde:1.90057600, loss_ib:3.13329720
# epoch 1 loss_pde:1.85445106, loss_ib:3.09430909
# epoch 1 loss_pde:2.23778129, loss_ib:3.01654911
# epoch 1 loss_pde:1.97777498, loss_ib:2.98765135
# epoch 1 loss_pde:1.92066133, loss_ib:2.95562220
# epoch 1 loss_pde:1.96877086, loss_ib:2.91152453
# epoch 1 loss_pde:2.05527806, loss_ib:2.85840344
# epoch 1 loss_pde:2.15815830, loss_ib:2.79153728
# epoch 1: loss 40.647907
# epoch 2 loss_pde:2.19533801, loss_ib:2.74096513
# epoch 2 loss_pde:2.19088030, loss_ib:2.70635438
# epoch 2 loss_pde:2.19833612, loss_ib:2.67867994
# epoch 2 loss_pde:2.26007462, loss_ib:2.61413908
# epoch 2 loss_pde:2.37956142, loss_ib:2.54865074
# epoch 2 loss_pde:2.51107597, loss_ib:2.49111891
# epoch 2 loss_pde:2.65845728, loss_ib:2.44132662
# epoch 2 loss_pde:2.72717118, loss_ib:2.41429830
# epoch 2 loss_pde:2.83521318, loss_ib:2.36757565
# epoch 2 loss_pde:3.18801475, loss_ib:2.25337458
# epoch 2 loss_pde:3.61481500, loss_ib:2.15574694
# epoch 2 loss_pde:3.81852722, loss_ib:2.10748196
# epoch 2 loss_pde:3.95663786, loss_ib:2.05364060
# epoch 2 loss_pde:4.00414896, loss_ib:2.01517153
# epoch 2 loss_pde:4.00871086, loss_ib:1.97921538
# epoch 2 loss_pde:4.05914783, loss_ib:1.90534794
# epoch 2 loss_pde:4.08849001, loss_ib:1.85532951
# epoch 2 loss_pde:4.23998260, loss_ib:1.79432607
# epoch 2 loss_pde:4.28102016, loss_ib:1.75622725
# epoch 2 loss_pde:4.41313314, loss_ib:1.69172180
# epoch 2: loss 29.604988
# epoch 3 loss_pde:4.43036079, loss_ib:1.63827980
# epoch 3 loss_pde:4.47990847, loss_ib:1.58815682
# epoch 3 loss_pde:4.38904619, loss_ib:1.53978384
# epoch 3 loss_pde:4.42171001, loss_ib:1.50404680
# epoch 3 loss_pde:4.26360941, loss_ib:1.49524522
# epoch 3 loss_pde:4.08211899, loss_ib:1.48451078
# epoch 3 loss_pde:3.98521638, loss_ib:1.47565961
# epoch 3 loss_pde:3.91321921, loss_ib:1.45889032
# epoch 3 loss_pde:3.86126733, loss_ib:1.44039297
# epoch 3 loss_pde:3.85162163, loss_ib:1.42301250
# epoch 3 loss_pde:3.85415459, loss_ib:1.40041852
# epoch 3 loss_pde:3.86806774, loss_ib:1.38160241
# epoch 3 loss_pde:3.85492992, loss_ib:1.37143385
# epoch 3 loss_pde:3.82598662, loss_ib:1.36466908
# epoch 3 loss_pde:3.77203941, loss_ib:1.35803783
# epoch 3 loss_pde:3.67824841, loss_ib:1.35018396
# epoch 3 loss_pde:3.61430979, loss_ib:1.34226120
# epoch 3 loss_pde:3.58039594, loss_ib:1.32948828
# epoch 3 loss_pde:3.57702994, loss_ib:1.31016457
# epoch 3 loss_pde:3.59054875, loss_ib:1.28265882
# epoch 3: loss 20.813158
# epoch 4 loss_pde:3.61590409, loss_ib:1.26225841
# epoch 4 loss_pde:3.62654471, loss_ib:1.24915290
# epoch 4 loss_pde:3.64273119, loss_ib:1.23458385
# epoch 4 loss_pde:3.64030671, loss_ib:1.21486688
# epoch 4 loss_pde:3.59211493, loss_ib:1.18527842
# epoch 4 loss_pde:3.49870920, loss_ib:1.16713524
# epoch 4 loss_pde:3.47404861, loss_ib:1.14926612
# epoch 4 loss_pde:3.39847565, loss_ib:1.14558327
# epoch 4 loss_pde:3.40551758, loss_ib:1.12992001
# epoch 4 loss_pde:3.33963966, loss_ib:1.11473417
# epoch 4 loss_pde:3.34684992, loss_ib:1.09832692
# epoch 4 loss_pde:3.36387396, loss_ib:1.08126450
# epoch 4 loss_pde:3.37356997, loss_ib:1.07349324
# epoch 4 loss_pde:3.39207435, loss_ib:1.05735242
# epoch 4 loss_pde:3.40174460, loss_ib:1.04326868
# epoch 4 loss_pde:3.42073154, loss_ib:1.03396034
# epoch 4 loss_pde:3.42747927, loss_ib:1.02743196
# epoch 4 loss_pde:3.44834280, loss_ib:1.01757669
# epoch 4 loss_pde:3.46129179, loss_ib:0.99521095
# epoch 4 loss_pde:3.53747582, loss_ib:0.96765965
# epoch 4: loss 16.238489
# epoch 5 loss_pde:3.54344082, loss_ib:0.94746053
# epoch 5 loss_pde:3.54491401, loss_ib:0.92726916
# epoch 5 loss_pde:3.42032361, loss_ib:0.93008995
# epoch 5 loss_pde:3.32262564, loss_ib:0.93236625
# epoch 5 loss_pde:3.19891262, loss_ib:0.93681794
# epoch 5 loss_pde:3.17210340, loss_ib:0.93154556
# epoch 5 loss_pde:3.20699739, loss_ib:0.90910757
# epoch 5 loss_pde:3.31238151, loss_ib:0.88469547
# epoch 5 loss_pde:3.42140532, loss_ib:0.86180580
# epoch 5 loss_pde:3.46151733, loss_ib:0.84499121
# epoch 5 loss_pde:3.42866039, loss_ib:0.83170623
# epoch 5 loss_pde:3.30265784, loss_ib:0.83108842
# epoch 5 loss_pde:3.19273281, loss_ib:0.83180243
# epoch 5 loss_pde:3.07474279, loss_ib:0.83070624
# epoch 5 loss_pde:3.05505514, loss_ib:0.81973982
# epoch 5 loss_pde:3.10587955, loss_ib:0.79942077
# epoch 5 loss_pde:3.21030998, loss_ib:0.77968878
# epoch 5 loss_pde:3.26643014, loss_ib:0.76886690
# epoch 5 loss_pde:3.33216143, loss_ib:0.75868213
# epoch 5 loss_pde:3.33879471, loss_ib:0.74794644
# epoch 5: loss 13.018046
# epoch 6 loss_pde:3.37828827, loss_ib:0.72741020
# epoch 6 loss_pde:3.28633356, loss_ib:0.72534412
# epoch 6 loss_pde:3.21761918, loss_ib:0.71749240
# epoch 6 loss_pde:3.07221603, loss_ib:0.72086680
# epoch 6 loss_pde:3.06421781, loss_ib:0.71468359
# epoch 6 loss_pde:2.99433661, loss_ib:0.79917800
# epoch 6 loss_pde:3.01867819, loss_ib:0.70483363
# epoch 6 loss_pde:3.08486772, loss_ib:0.70868200
# epoch 6 loss_pde:3.03353786, loss_ib:0.69522703
# epoch 6 loss_pde:3.01290560, loss_ib:0.69563210
# epoch 6 loss_pde:2.98617387, loss_ib:0.69398880
# epoch 6 loss_pde:2.98487520, loss_ib:0.68816823
# epoch 6 loss_pde:3.02308965, loss_ib:0.67489064
# epoch 6 loss_pde:3.06120491, loss_ib:0.66643715
# epoch 6 loss_pde:3.06092262, loss_ib:0.66038996
# epoch 6 loss_pde:3.06292915, loss_ib:0.65176475
# epoch 6 loss_pde:3.01634407, loss_ib:0.64986157
# epoch 6 loss_pde:2.99209023, loss_ib:0.64919055
# epoch 6 loss_pde:2.96543074, loss_ib:0.64609224
# epoch 6 loss_pde:2.97843361, loss_ib:0.63943136
# epoch 6: loss 10.652390
# epoch 7 loss_pde:2.93077421, loss_ib:0.64971441
# epoch 7 loss_pde:3.01295567, loss_ib:0.62279826
# epoch 7 loss_pde:3.01131296, loss_ib:0.61906761
# epoch 7 loss_pde:3.00873137, loss_ib:0.61151546
# epoch 7 loss_pde:2.98520684, loss_ib:0.60794908
# epoch 7 loss_pde:2.92377830, loss_ib:0.60210198
# epoch 7 loss_pde:2.84564519, loss_ib:0.59527320
# epoch 7 loss_pde:2.80365467, loss_ib:0.58728915
# epoch 7 loss_pde:2.79188132, loss_ib:0.57952392
# epoch 7 loss_pde:2.83554697, loss_ib:0.56294405
# epoch 7 loss_pde:2.79526401, loss_ib:0.55739510
# epoch 7 loss_pde:2.78029060, loss_ib:0.55062681
# epoch 7 loss_pde:2.71417689, loss_ib:0.55204618
# epoch 7 loss_pde:2.71714187, loss_ib:0.54645234
# epoch 7 loss_pde:2.70294952, loss_ib:0.54207253
# epoch 7 loss_pde:2.69118166, loss_ib:0.53772652
# epoch 7 loss_pde:2.63777018, loss_ib:0.53675413
# epoch 7 loss_pde:2.63373756, loss_ib:0.53236169
# epoch 7 loss_pde:2.58612490, loss_ib:0.53198242
# epoch 7 loss_pde:2.51703978, loss_ib:0.52964240
# epoch 7: loss 9.427918
# epoch 8 loss_pde:2.47929764, loss_ib:0.52564812
# epoch 8 loss_pde:2.45661092, loss_ib:0.51754153
# epoch 8 loss_pde:2.47720933, loss_ib:0.50536239
# epoch 8 loss_pde:2.39651632, loss_ib:0.54033715
# epoch 8 loss_pde:2.47035861, loss_ib:0.49535039
# epoch 8 loss_pde:2.46124697, loss_ib:0.49325642
# epoch 8 loss_pde:2.45575023, loss_ib:0.48819789
# epoch 8 loss_pde:2.41686845, loss_ib:0.48534009
# epoch 8 loss_pde:2.38354754, loss_ib:0.48215896
# epoch 8 loss_pde:2.26267099, loss_ib:0.48663858
# epoch 8 loss_pde:2.28673983, loss_ib:0.47732112
# epoch 8 loss_pde:2.26850939, loss_ib:0.47542733
# epoch 8 loss_pde:2.24328995, loss_ib:0.47139665
# epoch 8 loss_pde:2.21385908, loss_ib:0.47024339
# epoch 8 loss_pde:2.21158695, loss_ib:0.46717930
# epoch 8 loss_pde:2.18227124, loss_ib:0.46442404
# epoch 8 loss_pde:2.16640949, loss_ib:0.46131349
# epoch 8 loss_pde:2.09934378, loss_ib:0.45948330
# epoch 8 loss_pde:2.13227892, loss_ib:0.46841803
# epoch 8 loss_pde:2.06758690, loss_ib:0.45501664
# epoch 8: loss 7.735779
# epoch 9 loss_pde:2.04959154, loss_ib:0.45478913
# epoch 9 loss_pde:2.01512241, loss_ib:0.45444095
# epoch 9 loss_pde:1.99877012, loss_ib:0.45358658
# epoch 9 loss_pde:1.98119748, loss_ib:0.45148519
# epoch 9 loss_pde:2.02955818, loss_ib:0.47037372
# epoch 9 loss_pde:1.97168326, loss_ib:0.44763744
# epoch 9 loss_pde:1.96723700, loss_ib:0.44634423
# epoch 9 loss_pde:1.96249533, loss_ib:0.44271249
# epoch 9 loss_pde:1.95948911, loss_ib:0.44156352
# epoch 9 loss_pde:1.95191133, loss_ib:0.43845034
# epoch 9 loss_pde:1.93253517, loss_ib:0.43422619
# epoch 9 loss_pde:1.92845321, loss_ib:0.42924234
# epoch 9 loss_pde:1.91578305, loss_ib:0.42734209
# epoch 9 loss_pde:1.89628315, loss_ib:0.42596284
# epoch 9 loss_pde:1.84880960, loss_ib:0.43409672
# epoch 9 loss_pde:1.86123157, loss_ib:0.42478102
# epoch 9 loss_pde:1.85142076, loss_ib:0.42342076
# epoch 9 loss_pde:1.82454991, loss_ib:0.42131078
# epoch 9 loss_pde:1.79239988, loss_ib:0.42184716
# epoch 9 loss_pde:1.76830554, loss_ib:0.42034262
# epoch 9: loss 6.597483
# epoch 10 loss_pde:1.73577881, loss_ib:0.41938543
# epoch 10 loss_pde:1.72898078, loss_ib:0.41570961
# epoch 10 loss_pde:1.69817996, loss_ib:0.41301045
# epoch 10 loss_pde:1.69634151, loss_ib:0.40945989
# epoch 10 loss_pde:1.69753242, loss_ib:0.40615100
# epoch 10 loss_pde:1.69915247, loss_ib:0.40450940
# epoch 10 loss_pde:1.69521809, loss_ib:0.40334105
# epoch 10 loss_pde:1.68811822, loss_ib:0.40160677
# epoch 10 loss_pde:1.67670190, loss_ib:0.39795077
# epoch 10 loss_pde:1.66383278, loss_ib:0.39566141
# epoch 10 loss_pde:1.67543888, loss_ib:0.39000949
# epoch 10 loss_pde:1.67329907, loss_ib:0.38564700
# epoch 10 loss_pde:1.65747690, loss_ib:0.38283482
# epoch 10 loss_pde:1.65154278, loss_ib:0.38038030
# epoch 10 loss_pde:1.64528823, loss_ib:0.37932998
# epoch 10 loss_pde:1.63250613, loss_ib:0.37709960
# epoch 10 loss_pde:1.62494946, loss_ib:0.37442335
# epoch 10 loss_pde:1.61405587, loss_ib:0.37092122
# epoch 10 loss_pde:1.62440705, loss_ib:0.36665714
# epoch 10 loss_pde:1.61565542, loss_ib:0.36434457
# epoch 10: loss 5.929633
# epoch 11 loss_pde:1.60193253, loss_ib:0.36340955
# epoch 11 loss_pde:1.59066820, loss_ib:0.36090189
# epoch 11 loss_pde:1.57685781, loss_ib:0.35971728
# epoch 11 loss_pde:1.56991506, loss_ib:0.35589403
# epoch 11 loss_pde:1.55485177, loss_ib:0.35410476
# epoch 11 loss_pde:1.55327702, loss_ib:0.35127351
# epoch 11 loss_pde:1.53534508, loss_ib:0.35080633
# epoch 11 loss_pde:1.51503456, loss_ib:0.35041124
# epoch 11 loss_pde:1.50614691, loss_ib:0.34950384
# epoch 11 loss_pde:1.49093294, loss_ib:0.34824786
# epoch 11 loss_pde:1.55635667, loss_ib:0.36109728
# epoch 11 loss_pde:1.48609424, loss_ib:0.34373325
# epoch 11 loss_pde:1.47885859, loss_ib:0.34277350
# epoch 11 loss_pde:1.46906793, loss_ib:0.34062532
# epoch 11 loss_pde:1.45790982, loss_ib:0.33962128
# epoch 11 loss_pde:1.50236773, loss_ib:0.33757639
# epoch 11 loss_pde:1.43718529, loss_ib:0.33553413
# epoch 11 loss_pde:1.41762495, loss_ib:0.33555603
# epoch 11 loss_pde:1.39790893, loss_ib:0.33529457
# epoch 11 loss_pde:1.39152396, loss_ib:0.33304039
# epoch 11: loss 5.236028
# epoch 12 loss_pde:1.37750483, loss_ib:0.33234125
# epoch 12 loss_pde:1.36648297, loss_ib:0.33211878
# epoch 12 loss_pde:1.35414505, loss_ib:0.33098939
# epoch 12 loss_pde:1.33742595, loss_ib:0.33017775
# epoch 12 loss_pde:1.31918514, loss_ib:0.32903144
# epoch 12 loss_pde:1.30156434, loss_ib:0.32824463
# epoch 12 loss_pde:1.29778826, loss_ib:0.32651889
# epoch 12 loss_pde:1.29929662, loss_ib:0.32370371
# epoch 12 loss_pde:1.29194331, loss_ib:0.32029569
# epoch 12 loss_pde:1.31293535, loss_ib:0.31420067
# epoch 12 loss_pde:1.28516245, loss_ib:0.31143579
# epoch 12 loss_pde:1.26625657, loss_ib:0.30858651
# epoch 12 loss_pde:1.24832690, loss_ib:0.30670241
# epoch 12 loss_pde:1.24340701, loss_ib:0.30518344
# epoch 12 loss_pde:1.24415278, loss_ib:0.30305976
# epoch 12 loss_pde:1.23468041, loss_ib:0.30005506
# epoch 12 loss_pde:1.22134578, loss_ib:0.29798421
# epoch 12 loss_pde:1.21306324, loss_ib:0.29556867
# epoch 12 loss_pde:1.20648050, loss_ib:0.29320893
# epoch 12 loss_pde:1.21183765, loss_ib:0.29012209
# epoch 12: loss 4.700917
# epoch 13 loss_pde:1.20232153, loss_ib:0.28940058
# epoch 13 loss_pde:1.20206404, loss_ib:0.28813320
# epoch 13 loss_pde:1.20030344, loss_ib:0.28685948
# epoch 13 loss_pde:1.18790925, loss_ib:0.28382251
# epoch 13 loss_pde:1.17631173, loss_ib:0.28095409
# epoch 13 loss_pde:1.15635586, loss_ib:0.27928254
# epoch 13 loss_pde:1.26313162, loss_ib:0.28159332
# epoch 13 loss_pde:1.13511741, loss_ib:0.27657029
# epoch 13 loss_pde:1.12441015, loss_ib:0.27638048
# epoch 13 loss_pde:1.10449195, loss_ib:0.27595904
# epoch 13 loss_pde:1.09700966, loss_ib:0.27440181
# epoch 13 loss_pde:1.09278250, loss_ib:0.27178535
# epoch 13 loss_pde:1.10175931, loss_ib:0.26775989
# epoch 13 loss_pde:1.10881495, loss_ib:0.26427895
# epoch 13 loss_pde:1.10828400, loss_ib:0.26252171
# epoch 13 loss_pde:1.12038946, loss_ib:0.25957292
# epoch 13 loss_pde:1.10069847, loss_ib:0.26327443
# epoch 13 loss_pde:1.09067941, loss_ib:0.26000506
# epoch 13 loss_pde:1.09338284, loss_ib:0.25875202
# epoch 13 loss_pde:1.09415126, loss_ib:0.25680545
# epoch 13: loss 4.096327
# epoch 14 loss_pde:1.09014547, loss_ib:0.25458646
# epoch 14 loss_pde:1.10596061, loss_ib:0.25273320
# epoch 14 loss_pde:1.10841274, loss_ib:0.24796072
# epoch 14 loss_pde:1.06685269, loss_ib:0.24740621
# epoch 14 loss_pde:1.05714154, loss_ib:0.24676171
# epoch 14 loss_pde:1.04547548, loss_ib:0.24572141
# epoch 14 loss_pde:1.05101180, loss_ib:0.24448712
# epoch 14 loss_pde:1.04853666, loss_ib:0.24189441
# epoch 14 loss_pde:1.03170586, loss_ib:0.24133478
# epoch 14 loss_pde:1.02729547, loss_ib:0.24013485
# epoch 14 loss_pde:1.02428794, loss_ib:0.23862119
# epoch 14 loss_pde:1.01916254, loss_ib:0.23728335
# epoch 14 loss_pde:1.00276899, loss_ib:0.23558454
# epoch 14 loss_pde:1.04293501, loss_ib:0.23986638
# epoch 14 loss_pde:0.98189086, loss_ib:0.23327802
# epoch 14 loss_pde:0.96753991, loss_ib:0.23317771
# epoch 14 loss_pde:0.95970500, loss_ib:0.23260310
# epoch 14 loss_pde:0.94330204, loss_ib:0.23160629
# epoch 14 loss_pde:0.94466150, loss_ib:0.23178038
# epoch 14 loss_pde:0.93358445, loss_ib:0.22954543
# epoch 14: loss 3.636010
# epoch 15 loss_pde:0.92746544, loss_ib:0.22889949
# epoch 15 loss_pde:0.91891479, loss_ib:0.22734129
# epoch 15 loss_pde:0.91396248, loss_ib:0.22623804
# epoch 15 loss_pde:0.90895259, loss_ib:0.22488067
# epoch 15 loss_pde:0.90188360, loss_ib:0.22309975
# epoch 15 loss_pde:0.92004663, loss_ib:0.22621085
# epoch 15 loss_pde:0.89024305, loss_ib:0.22134535
# epoch 15 loss_pde:0.89156872, loss_ib:0.22046222
# epoch 15 loss_pde:0.87286234, loss_ib:0.22108598
# epoch 15 loss_pde:0.87294197, loss_ib:0.21902277
# epoch 15 loss_pde:0.86763191, loss_ib:0.21729343
# epoch 15 loss_pde:0.85233438, loss_ib:0.21588652
# epoch 15 loss_pde:0.83887333, loss_ib:0.21551701
# epoch 15 loss_pde:0.83499491, loss_ib:0.21495238
# epoch 15 loss_pde:0.82330108, loss_ib:0.21449390
# epoch 15 loss_pde:0.81902927, loss_ib:0.21347679
# epoch 15 loss_pde:0.82814741, loss_ib:0.21308121
# epoch 15 loss_pde:0.81718481, loss_ib:0.21149336
# epoch 15 loss_pde:0.80781746, loss_ib:0.21161900
# epoch 15 loss_pde:0.80770165, loss_ib:0.21102391
# epoch 15: loss 3.216460
# epoch 16 loss_pde:0.80603802, loss_ib:0.20922321
# epoch 16 loss_pde:0.80020475, loss_ib:0.20845622
# epoch 16 loss_pde:0.91056150, loss_ib:0.21787858
# epoch 16 loss_pde:0.78807282, loss_ib:0.20718183
# epoch 16 loss_pde:0.78873920, loss_ib:0.20779249
# epoch 16 loss_pde:0.78044450, loss_ib:0.20693618
# epoch 16 loss_pde:0.77958739, loss_ib:0.20647660
# epoch 16 loss_pde:0.77398741, loss_ib:0.20593381
# epoch 16 loss_pde:0.76668215, loss_ib:0.20513879
# epoch 16 loss_pde:0.75098455, loss_ib:0.20567116
# epoch 16 loss_pde:0.75816393, loss_ib:0.20387021
# epoch 16 loss_pde:0.74719691, loss_ib:0.20299295
# epoch 16 loss_pde:0.74258626, loss_ib:0.20247214
# epoch 16 loss_pde:0.73739004, loss_ib:0.20181990
# epoch 16 loss_pde:0.74329877, loss_ib:0.20261943
# epoch 16 loss_pde:0.73502922, loss_ib:0.20011276
# epoch 16 loss_pde:0.73057806, loss_ib:0.19967988
# epoch 16 loss_pde:0.72242230, loss_ib:0.19880775
# epoch 16 loss_pde:0.71921551, loss_ib:0.19783691
# epoch 16 loss_pde:0.71202856, loss_ib:0.19728813
# epoch 16: loss 2.898270
# epoch 17 loss_pde:0.71725672, loss_ib:0.19573356
# epoch 17 loss_pde:0.71725845, loss_ib:0.19449675
# epoch 17 loss_pde:0.71135294, loss_ib:0.19390310
# epoch 17 loss_pde:0.70421922, loss_ib:0.19338730
# epoch 17 loss_pde:0.70073873, loss_ib:0.19265448
# epoch 17 loss_pde:0.70418739, loss_ib:0.19130851
# epoch 17 loss_pde:0.69292843, loss_ib:0.19131374
# epoch 17 loss_pde:0.68859226, loss_ib:0.19086835
# epoch 17 loss_pde:0.68467921, loss_ib:0.19049722
# epoch 17 loss_pde:0.68074125, loss_ib:0.19007960
# epoch 17 loss_pde:0.67857116, loss_ib:0.18923149
# epoch 17 loss_pde:0.67647004, loss_ib:0.18793318
# epoch 17 loss_pde:0.67282808, loss_ib:0.18549152
# epoch 17 loss_pde:0.67769384, loss_ib:0.18340544
# epoch 17 loss_pde:0.67238569, loss_ib:0.18155727
# epoch 17 loss_pde:0.66586185, loss_ib:0.18092793
# epoch 17 loss_pde:0.67203438, loss_ib:0.17916973
# epoch 17 loss_pde:0.67225432, loss_ib:0.17834447
# epoch 17 loss_pde:0.67882049, loss_ib:0.17650963
# epoch 17 loss_pde:0.68036842, loss_ib:0.17494197
# epoch 17: loss 2.674592
# epoch 18 loss_pde:0.68426585, loss_ib:0.17317113
# epoch 18 loss_pde:0.68907988, loss_ib:0.17205343
# epoch 18 loss_pde:0.69131970, loss_ib:0.17065893
# epoch 18 loss_pde:0.68814623, loss_ib:0.16976234
# epoch 18 loss_pde:0.68227232, loss_ib:0.16860378
# epoch 18 loss_pde:0.68877876, loss_ib:0.16659828
# epoch 18 loss_pde:0.69311088, loss_ib:0.16481544
# epoch 18 loss_pde:0.70280844, loss_ib:0.16275129
# epoch 18 loss_pde:0.70687413, loss_ib:0.16112602
# epoch 18 loss_pde:0.71249235, loss_ib:0.15952839
# epoch 18 loss_pde:0.70802557, loss_ib:0.15882604
# epoch 18 loss_pde:0.70499760, loss_ib:0.15750667
# epoch 18 loss_pde:0.70339298, loss_ib:0.15634668
# epoch 18 loss_pde:0.70827878, loss_ib:0.15585269
# epoch 18 loss_pde:0.69928777, loss_ib:0.15490642
# epoch 18 loss_pde:0.69793683, loss_ib:0.15452334
# epoch 18 loss_pde:0.69447631, loss_ib:0.15403351
# epoch 18 loss_pde:0.69490784, loss_ib:0.15273802
# epoch 18 loss_pde:0.69690239, loss_ib:0.15110627
# epoch 18 loss_pde:0.69766939, loss_ib:0.15025547
# epoch 18: loss 2.415977
# epoch 19 loss_pde:0.69540751, loss_ib:0.14832497
# epoch 19 loss_pde:0.69275308, loss_ib:0.14742978
# epoch 19 loss_pde:0.69619179, loss_ib:0.14595164
# epoch 19 loss_pde:0.69802427, loss_ib:0.14424062
# epoch 19 loss_pde:0.71109301, loss_ib:0.14142647
# epoch 19 loss_pde:0.70800632, loss_ib:0.14072269
# epoch 19 loss_pde:0.70763999, loss_ib:0.13993196
# epoch 19 loss_pde:0.70456868, loss_ib:0.13877058
# epoch 19 loss_pde:0.71109533, loss_ib:0.13678025
# epoch 19 loss_pde:0.70844424, loss_ib:0.13594146
# epoch 19 loss_pde:0.70330095, loss_ib:0.13542479
# epoch 19 loss_pde:0.70169878, loss_ib:0.13452241
# epoch 19 loss_pde:0.70398837, loss_ib:0.13293114
# epoch 19 loss_pde:0.70391428, loss_ib:0.13206752
# epoch 19 loss_pde:0.70179015, loss_ib:0.13142018
# epoch 19 loss_pde:0.69998336, loss_ib:0.13054663
# epoch 19 loss_pde:0.69791770, loss_ib:0.12966381
# epoch 19 loss_pde:0.69927335, loss_ib:0.12878400
# epoch 19 loss_pde:0.70105451, loss_ib:0.12758315
# epoch 19 loss_pde:0.70061117, loss_ib:0.12694150
# epoch 19: loss 2.178657
# epoch 20 loss_pde:0.70118999, loss_ib:0.12608646
# epoch 20 loss_pde:0.69203752, loss_ib:0.12598996
# epoch 20 loss_pde:0.68931437, loss_ib:0.12529357
# epoch 20 loss_pde:0.67615330, loss_ib:0.12576891
# epoch 20 loss_pde:0.66894019, loss_ib:0.12560266
# epoch 20 loss_pde:0.66446346, loss_ib:0.12521842
# epoch 20 loss_pde:0.66168082, loss_ib:0.12412550
# epoch 20 loss_pde:0.66143072, loss_ib:0.12321611
# epoch 20 loss_pde:0.66326070, loss_ib:0.12192687
# epoch 20 loss_pde:0.65886456, loss_ib:0.12133718
# epoch 20 loss_pde:0.65686083, loss_ib:0.12056226
# epoch 20 loss_pde:0.65363514, loss_ib:0.11980898
# epoch 20 loss_pde:0.65431964, loss_ib:0.11891635
# epoch 20 loss_pde:0.64889765, loss_ib:0.11835407
# epoch 20 loss_pde:0.64464891, loss_ib:0.11802462
# epoch 20 loss_pde:0.64181811, loss_ib:0.11742694
# epoch 20 loss_pde:0.63926750, loss_ib:0.11700805
# epoch 20 loss_pde:0.63891906, loss_ib:0.11605208
# epoch 20 loss_pde:0.63973194, loss_ib:0.11510837
# epoch 20 loss_pde:0.64338380, loss_ib:0.11398161
# epoch 20: loss 1.962055
# epoch 21 loss_pde:0.64565212, loss_ib:0.11287969
# epoch 21 loss_pde:0.64457339, loss_ib:0.11218425
# epoch 21 loss_pde:0.64233977, loss_ib:0.11162466
# epoch 21 loss_pde:0.64343756, loss_ib:0.11073340
# epoch 21 loss_pde:0.63940471, loss_ib:0.11017688
# epoch 21 loss_pde:0.63783669, loss_ib:0.10925055
# epoch 21 loss_pde:0.63494653, loss_ib:0.10882194
# epoch 21 loss_pde:0.63143802, loss_ib:0.10863189
# epoch 21 loss_pde:0.62684286, loss_ib:0.10824772
# epoch 21 loss_pde:0.62275338, loss_ib:0.10800196
# epoch 21 loss_pde:0.62214756, loss_ib:0.10701573
# epoch 21 loss_pde:0.62046313, loss_ib:0.10639329
# epoch 21 loss_pde:0.61906606, loss_ib:0.10592662
# epoch 21 loss_pde:0.62588239, loss_ib:0.10471636
# epoch 21 loss_pde:0.62204850, loss_ib:0.10435159
# epoch 21 loss_pde:0.61975068, loss_ib:0.10392826
# epoch 21 loss_pde:0.62042022, loss_ib:0.10315253
# epoch 21 loss_pde:0.62030655, loss_ib:0.10262216
# epoch 21 loss_pde:0.62348199, loss_ib:0.10126163
# epoch 21 loss_pde:0.62175542, loss_ib:0.10041542
# epoch 21: loss 1.774449
# epoch 22 loss_pde:0.61976129, loss_ib:0.09946750
# epoch 22 loss_pde:0.61762196, loss_ib:0.09874605
# epoch 22 loss_pde:0.61734265, loss_ib:0.09808213
# epoch 22 loss_pde:0.61785936, loss_ib:0.09744325
# epoch 22 loss_pde:0.61628348, loss_ib:0.09699149
# epoch 22 loss_pde:0.60996372, loss_ib:0.09698267
# epoch 22 loss_pde:0.60712868, loss_ib:0.09662481
# epoch 22 loss_pde:0.60323209, loss_ib:0.09623087
# epoch 22 loss_pde:0.60842282, loss_ib:0.09512962
# epoch 22 loss_pde:0.60549426, loss_ib:0.09458859
# epoch 22 loss_pde:0.60693341, loss_ib:0.09374482
# epoch 22 loss_pde:0.60999238, loss_ib:0.09284879
# epoch 22 loss_pde:0.61526960, loss_ib:0.09176461
# epoch 22 loss_pde:0.61645961, loss_ib:0.09102856
# epoch 22 loss_pde:0.61701238, loss_ib:0.09031145
# epoch 22 loss_pde:0.61669797, loss_ib:0.08964756
# epoch 22 loss_pde:0.61442155, loss_ib:0.08901334
# epoch 22 loss_pde:0.61517119, loss_ib:0.08858546
# epoch 22 loss_pde:0.61072111, loss_ib:0.08826703
# epoch 22 loss_pde:0.60891688, loss_ib:0.08804892
# epoch 22: loss 1.614436
# epoch 23 loss_pde:0.60893911, loss_ib:0.08765373
# epoch 23 loss_pde:0.60720140, loss_ib:0.08732682
# epoch 23 loss_pde:0.60610741, loss_ib:0.08675776
# epoch 23 loss_pde:0.60324192, loss_ib:0.08620019
# epoch 23 loss_pde:0.60021275, loss_ib:0.08615636
# epoch 23 loss_pde:0.59897536, loss_ib:0.08584474
# epoch 23 loss_pde:0.59707516, loss_ib:0.08563165
# epoch 23 loss_pde:0.59404308, loss_ib:0.08539913
# epoch 23 loss_pde:0.59399092, loss_ib:0.08479732
# epoch 23 loss_pde:0.58700997, loss_ib:0.08487392
# epoch 23 loss_pde:0.58517325, loss_ib:0.08458598
# epoch 23 loss_pde:0.58070880, loss_ib:0.08432793
# epoch 23 loss_pde:0.57611775, loss_ib:0.08423387
# epoch 23 loss_pde:0.56875163, loss_ib:0.08414957
# epoch 23 loss_pde:0.56701630, loss_ib:0.08383781
# epoch 23 loss_pde:0.56599081, loss_ib:0.08353821
# epoch 23 loss_pde:0.56689405, loss_ib:0.08314970
# epoch 23 loss_pde:0.56790102, loss_ib:0.08267679
# epoch 23 loss_pde:0.57089186, loss_ib:0.08180690
# epoch 23 loss_pde:0.57062018, loss_ib:0.08122762
# epoch 23: loss 1.485476
# epoch 24 loss_pde:0.57274759, loss_ib:0.08043848
# epoch 24 loss_pde:0.56930584, loss_ib:0.08029315
# epoch 24 loss_pde:0.56504107, loss_ib:0.08024557
# epoch 24 loss_pde:0.56111681, loss_ib:0.08011995
# epoch 24 loss_pde:0.55936784, loss_ib:0.07984553
# epoch 24 loss_pde:0.56017137, loss_ib:0.07916891
# epoch 24 loss_pde:0.56213951, loss_ib:0.07842240
# epoch 24 loss_pde:0.56361055, loss_ib:0.07790422
# epoch 24 loss_pde:0.56655717, loss_ib:0.07721157
# epoch 24 loss_pde:0.56662774, loss_ib:0.07676521
# epoch 24 loss_pde:0.56715763, loss_ib:0.07623617
# epoch 24 loss_pde:0.56862152, loss_ib:0.07564230
# epoch 24 loss_pde:0.56566584, loss_ib:0.07549139
# epoch 24 loss_pde:0.56323707, loss_ib:0.07537925
# epoch 24 loss_pde:0.56229317, loss_ib:0.07509741
# epoch 24 loss_pde:0.56251770, loss_ib:0.07474024
# epoch 24 loss_pde:0.56315511, loss_ib:0.07431870
# epoch 24 loss_pde:0.56231409, loss_ib:0.07388657
# epoch 24 loss_pde:0.56334466, loss_ib:0.07330465
# epoch 24 loss_pde:0.56336582, loss_ib:0.07284828
# epoch 24: loss 1.377132
# epoch 25 loss_pde:0.56196350, loss_ib:0.07252609
# epoch 25 loss_pde:0.56307793, loss_ib:0.07200087
# epoch 25 loss_pde:0.56316507, loss_ib:0.07154530
# epoch 25 loss_pde:0.56305051, loss_ib:0.07108628
# epoch 25 loss_pde:0.56575179, loss_ib:0.07043627
# epoch 25 loss_pde:0.56237644, loss_ib:0.07042351
# epoch 25 loss_pde:0.56210423, loss_ib:0.07000772
# epoch 25 loss_pde:0.56039739, loss_ib:0.06974479
# epoch 25 loss_pde:0.56184214, loss_ib:0.06922757
# epoch 25 loss_pde:0.56235868, loss_ib:0.06884955
# epoch 25 loss_pde:0.56288362, loss_ib:0.06842023
# epoch 25 loss_pde:0.56169903, loss_ib:0.06805925
# epoch 25 loss_pde:0.56447333, loss_ib:0.06729632
# epoch 25 loss_pde:0.56227046, loss_ib:0.06712668
# epoch 25 loss_pde:0.56302989, loss_ib:0.06654483
# epoch 25 loss_pde:0.56323808, loss_ib:0.06618750
# epoch 25 loss_pde:0.56526285, loss_ib:0.06565870
# epoch 25 loss_pde:0.56816441, loss_ib:0.06493955
# epoch 25 loss_pde:0.57079351, loss_ib:0.06424446
# epoch 25 loss_pde:0.57012874, loss_ib:0.06392643
# epoch 25: loss 1.287224
# epoch 26 loss_pde:0.56810480, loss_ib:0.06368701
# epoch 26 loss_pde:0.56705773, loss_ib:0.06346221
# epoch 26 loss_pde:0.56674415, loss_ib:0.06315091
# epoch 26 loss_pde:0.56694657, loss_ib:0.06274374
# epoch 26 loss_pde:0.56794548, loss_ib:0.06232595
# epoch 26 loss_pde:0.56942385, loss_ib:0.06192386
# epoch 26 loss_pde:0.56906587, loss_ib:0.06142209
# epoch 26 loss_pde:0.56683958, loss_ib:0.06136132
# epoch 26 loss_pde:0.56496042, loss_ib:0.06106664
# epoch 26 loss_pde:0.56232238, loss_ib:0.06091017
# epoch 26 loss_pde:0.56191337, loss_ib:0.06056730
# epoch 26 loss_pde:0.56291991, loss_ib:0.06014403
# epoch 26 loss_pde:0.56121564, loss_ib:0.06001695
# epoch 26 loss_pde:0.56091315, loss_ib:0.05962602
# epoch 26 loss_pde:0.55680937, loss_ib:0.05963548
# epoch 26 loss_pde:0.55492169, loss_ib:0.05953884
# epoch 26 loss_pde:0.55495077, loss_ib:0.05932488
# epoch 26 loss_pde:0.55435944, loss_ib:0.05907252
# epoch 26 loss_pde:0.55448300, loss_ib:0.05877733
# epoch 26 loss_pde:0.55587959, loss_ib:0.05831283
# epoch 26: loss 1.204975
# epoch 27 loss_pde:0.55530494, loss_ib:0.05793925
# epoch 27 loss_pde:0.55518776, loss_ib:0.05749915
# epoch 27 loss_pde:0.55278331, loss_ib:0.05744207
# epoch 27 loss_pde:0.55174226, loss_ib:0.05720421
# epoch 27 loss_pde:0.54877156, loss_ib:0.05710549
# epoch 27 loss_pde:0.54626650, loss_ib:0.05698930
# epoch 27 loss_pde:0.54322940, loss_ib:0.05691480
# epoch 27 loss_pde:0.54081243, loss_ib:0.05670659
# epoch 27 loss_pde:0.53836328, loss_ib:0.05655482
# epoch 27 loss_pde:0.53537190, loss_ib:0.05655785
# epoch 27 loss_pde:0.53742689, loss_ib:0.05608196
# epoch 27 loss_pde:0.53768146, loss_ib:0.05575743
# epoch 27 loss_pde:0.53704077, loss_ib:0.05550188
# epoch 27 loss_pde:0.53880274, loss_ib:0.05499720
# epoch 27 loss_pde:0.53876024, loss_ib:0.05469816
# epoch 27 loss_pde:0.53981107, loss_ib:0.05425172
# epoch 27 loss_pde:0.53940600, loss_ib:0.05392000
# epoch 27 loss_pde:0.53837883, loss_ib:0.05371626
# epoch 27 loss_pde:0.53664982, loss_ib:0.05363697
# epoch 27 loss_pde:0.53525543, loss_ib:0.05346044
# epoch 27: loss 1.134697
# epoch 28 loss_pde:0.53367114, loss_ib:0.05327000
# epoch 28 loss_pde:0.53259200, loss_ib:0.05304119
# epoch 28 loss_pde:0.53268218, loss_ib:0.05271512
# epoch 28 loss_pde:0.53163183, loss_ib:0.05251452
# epoch 28 loss_pde:0.53098464, loss_ib:0.05230814
# epoch 28 loss_pde:0.53093201, loss_ib:0.05202632
# epoch 28 loss_pde:0.53175211, loss_ib:0.05146777
# epoch 28 loss_pde:0.53428459, loss_ib:0.05077670
# epoch 28 loss_pde:0.53404635, loss_ib:0.05049003
# epoch 28 loss_pde:0.53201801, loss_ib:0.05043874
# epoch 28 loss_pde:0.53171837, loss_ib:0.05028069
# epoch 28 loss_pde:0.52822757, loss_ib:0.05035718
# epoch 28 loss_pde:0.52646935, loss_ib:0.05022805
# epoch 28 loss_pde:0.52297002, loss_ib:0.05025198
# epoch 28 loss_pde:0.52192020, loss_ib:0.05006975
# epoch 28 loss_pde:0.51997507, loss_ib:0.04994498
# epoch 28 loss_pde:0.51908517, loss_ib:0.04980777
# epoch 28 loss_pde:0.51798868, loss_ib:0.04967039
# epoch 28 loss_pde:0.51808697, loss_ib:0.04938789
# epoch 28 loss_pde:0.52048182, loss_ib:0.04891359
# epoch 28: loss 1.066371
# epoch 29 loss_pde:0.52081287, loss_ib:0.04862860
# epoch 29 loss_pde:0.52096045, loss_ib:0.04838737
# epoch 29 loss_pde:0.52091950, loss_ib:0.04806982
# epoch 29 loss_pde:0.51959682, loss_ib:0.04781516
# epoch 29 loss_pde:0.52117121, loss_ib:0.04741283
# epoch 29 loss_pde:0.51836437, loss_ib:0.04740805
# epoch 29 loss_pde:0.51658493, loss_ib:0.04744570
# epoch 29 loss_pde:0.51581144, loss_ib:0.04735519
# epoch 29 loss_pde:0.51385838, loss_ib:0.04723508
# epoch 29 loss_pde:0.51127386, loss_ib:0.04701463
# epoch 29 loss_pde:0.50738943, loss_ib:0.04699046
# epoch 29 loss_pde:0.50630015, loss_ib:0.04687678
# epoch 29 loss_pde:0.50557911, loss_ib:0.04676615
# epoch 29 loss_pde:0.50492281, loss_ib:0.04663061
# epoch 29 loss_pde:0.50477129, loss_ib:0.04639561
# epoch 29 loss_pde:0.50528187, loss_ib:0.04604400
# epoch 29 loss_pde:0.50623584, loss_ib:0.04570784
# epoch 29 loss_pde:0.50649887, loss_ib:0.04544881
# epoch 29 loss_pde:0.50678003, loss_ib:0.04515481
# epoch 29 loss_pde:0.50444746, loss_ib:0.04517525
# epoch 29: loss 1.007099
# epoch 30 loss_pde:0.50294578, loss_ib:0.04502641
# epoch 30 loss_pde:0.50109899, loss_ib:0.04494439
# epoch 30 loss_pde:0.49943936, loss_ib:0.04492025
# epoch 30 loss_pde:0.49885488, loss_ib:0.04470423
# epoch 30 loss_pde:0.49962255, loss_ib:0.04445070
# epoch 30 loss_pde:0.49913967, loss_ib:0.04429872
# epoch 30 loss_pde:0.49921241, loss_ib:0.04418454
# epoch 30 loss_pde:0.49868244, loss_ib:0.04403871
# epoch 30 loss_pde:0.49765867, loss_ib:0.04392187
# epoch 30 loss_pde:0.49536341, loss_ib:0.04390340
# epoch 30 loss_pde:0.49346453, loss_ib:0.04391781
# epoch 30 loss_pde:0.49219769, loss_ib:0.04386290
# epoch 30 loss_pde:0.49220702, loss_ib:0.04365274
# epoch 30 loss_pde:0.49492481, loss_ib:0.04306525
# epoch 30 loss_pde:0.49628451, loss_ib:0.04269212
# epoch 30 loss_pde:0.49752569, loss_ib:0.04238530
# epoch 30 loss_pde:0.49800149, loss_ib:0.04215686
# epoch 30 loss_pde:0.49745271, loss_ib:0.04201414
# epoch 30 loss_pde:0.49617895, loss_ib:0.04191714
# epoch 30 loss_pde:0.49500537, loss_ib:0.04176074
# epoch 30: loss 0.953210
# epoch 31 loss_pde:0.49353373, loss_ib:0.04165578
# epoch 31 loss_pde:0.49230814, loss_ib:0.04159336
# epoch 31 loss_pde:0.49212626, loss_ib:0.04147355
# epoch 31 loss_pde:0.49142489, loss_ib:0.04137562
# epoch 31 loss_pde:0.49066705, loss_ib:0.04117490
# epoch 31 loss_pde:0.48941818, loss_ib:0.04108698
# epoch 31 loss_pde:0.48853651, loss_ib:0.04098948
# epoch 31 loss_pde:0.48796627, loss_ib:0.04091009
# epoch 31 loss_pde:0.48773760, loss_ib:0.04074494
# epoch 31 loss_pde:0.48949718, loss_ib:0.04033731
# epoch 31 loss_pde:0.49021012, loss_ib:0.04007275
# epoch 31 loss_pde:0.49112299, loss_ib:0.03977501
# epoch 31 loss_pde:0.49330404, loss_ib:0.03928592
# epoch 31 loss_pde:0.49298206, loss_ib:0.03908698
# epoch 31 loss_pde:0.49165660, loss_ib:0.03903985
# epoch 31 loss_pde:0.49106598, loss_ib:0.03888837
# epoch 31 loss_pde:0.49115217, loss_ib:0.03867808
# epoch 31 loss_pde:0.49203426, loss_ib:0.03837344
# epoch 31 loss_pde:0.49380869, loss_ib:0.03794516
# epoch 31 loss_pde:0.49493733, loss_ib:0.03764649
# epoch 31: loss 0.910092
# epoch 32 loss_pde:0.49599087, loss_ib:0.03740531
# epoch 32 loss_pde:0.49346381, loss_ib:0.03750904
# epoch 32 loss_pde:0.49315432, loss_ib:0.03741459
# epoch 32 loss_pde:0.49198228, loss_ib:0.03734707
# epoch 32 loss_pde:0.49192169, loss_ib:0.03711573
# epoch 32 loss_pde:0.49039295, loss_ib:0.03705214
# epoch 32 loss_pde:0.48976505, loss_ib:0.03693111
# epoch 32 loss_pde:0.48865700, loss_ib:0.03680754
# epoch 32 loss_pde:0.48674536, loss_ib:0.03676465
# epoch 32 loss_pde:0.48418605, loss_ib:0.03677443
# epoch 32 loss_pde:0.48240224, loss_ib:0.03672882
# epoch 32 loss_pde:0.47973505, loss_ib:0.03683208
# epoch 32 loss_pde:0.47913820, loss_ib:0.03675218
# epoch 32 loss_pde:0.47891143, loss_ib:0.03660753
# epoch 32 loss_pde:0.47868967, loss_ib:0.03644385
# epoch 32 loss_pde:0.47845861, loss_ib:0.03627566
# epoch 32 loss_pde:0.47816882, loss_ib:0.03615175
# epoch 32 loss_pde:0.47785440, loss_ib:0.03605018
# epoch 32 loss_pde:0.47708362, loss_ib:0.03598151
# epoch 32 loss_pde:0.47643507, loss_ib:0.03585336
# epoch 32: loss 0.870044
# epoch 33 loss_pde:0.47582486, loss_ib:0.03573539
# epoch 33 loss_pde:0.47581881, loss_ib:0.03559244
# epoch 33 loss_pde:0.47535035, loss_ib:0.03544918
# epoch 33 loss_pde:0.47463119, loss_ib:0.03530236
# epoch 33 loss_pde:0.47389090, loss_ib:0.03512457
# epoch 33 loss_pde:0.47353429, loss_ib:0.03497843
# epoch 33 loss_pde:0.47198552, loss_ib:0.03498642
# epoch 33 loss_pde:0.47143996, loss_ib:0.03490950
# epoch 33 loss_pde:0.47045860, loss_ib:0.03483945
# epoch 33 loss_pde:0.47044557, loss_ib:0.03459907
# epoch 33 loss_pde:0.46940815, loss_ib:0.03448292
# epoch 33 loss_pde:0.47007003, loss_ib:0.03421019
# epoch 33 loss_pde:0.46943361, loss_ib:0.03409670
# epoch 33 loss_pde:0.47104484, loss_ib:0.03379855
# epoch 33 loss_pde:0.47028992, loss_ib:0.03375736
# epoch 33 loss_pde:0.47063318, loss_ib:0.03356883
# epoch 33 loss_pde:0.47021717, loss_ib:0.03343744
# epoch 33 loss_pde:0.47093982, loss_ib:0.03314659
# epoch 33 loss_pde:0.47134459, loss_ib:0.03290968
# epoch 33 loss_pde:0.47154313, loss_ib:0.03270236
# epoch 33: loss 0.833179
# epoch 34 loss_pde:0.47202832, loss_ib:0.03248002
# epoch 34 loss_pde:0.47057077, loss_ib:0.03244201
# epoch 34 loss_pde:0.46874985, loss_ib:0.03241693
# epoch 34 loss_pde:0.46713078, loss_ib:0.03243054
# epoch 34 loss_pde:0.46575111, loss_ib:0.03240403
# epoch 34 loss_pde:0.46449512, loss_ib:0.03231497
# epoch 34 loss_pde:0.46397439, loss_ib:0.03216200
# epoch 34 loss_pde:0.46352848, loss_ib:0.03204500
# epoch 34 loss_pde:0.46379983, loss_ib:0.03186065
# epoch 34 loss_pde:0.46287918, loss_ib:0.03178663
# epoch 34 loss_pde:0.46275562, loss_ib:0.03163571
# epoch 34 loss_pde:0.46253335, loss_ib:0.03148407
# epoch 34 loss_pde:0.46159661, loss_ib:0.03140646
# epoch 34 loss_pde:0.46187440, loss_ib:0.03121425
# epoch 34 loss_pde:0.46145597, loss_ib:0.03111579
# epoch 34 loss_pde:0.46050671, loss_ib:0.03108206
# epoch 34 loss_pde:0.45974302, loss_ib:0.03103174
# epoch 34 loss_pde:0.45808506, loss_ib:0.03105829
# epoch 34 loss_pde:0.45658153, loss_ib:0.03105915
# epoch 34 loss_pde:0.45610878, loss_ib:0.03096847
# epoch 34: loss 0.796829
# epoch 35 loss_pde:0.45593178, loss_ib:0.03085298
# epoch 35 loss_pde:0.45593438, loss_ib:0.03070555
# epoch 35 loss_pde:0.45665678, loss_ib:0.03044130
# epoch 35 loss_pde:0.45592618, loss_ib:0.03031155
# epoch 35 loss_pde:0.45505041, loss_ib:0.03026706
# epoch 35 loss_pde:0.45431948, loss_ib:0.03025157
# epoch 35 loss_pde:0.45315301, loss_ib:0.03025905
# epoch 35 loss_pde:0.45282039, loss_ib:0.03014139
# epoch 35 loss_pde:0.45141873, loss_ib:0.03018873
# epoch 35 loss_pde:0.45183298, loss_ib:0.03004871
# epoch 35 loss_pde:0.45227996, loss_ib:0.02985158
# epoch 35 loss_pde:0.45245212, loss_ib:0.02965850
# epoch 35 loss_pde:0.45204213, loss_ib:0.02950838
# epoch 35 loss_pde:0.45116907, loss_ib:0.02943695
# epoch 35 loss_pde:0.45020831, loss_ib:0.02938673
# epoch 35 loss_pde:0.44927412, loss_ib:0.02934255
# epoch 35 loss_pde:0.44868487, loss_ib:0.02923403
# epoch 35 loss_pde:0.44839537, loss_ib:0.02912385
# epoch 35 loss_pde:0.44827899, loss_ib:0.02903193
# epoch 35 loss_pde:0.44768107, loss_ib:0.02897952
# epoch 35: loss 0.764462
# epoch 36 loss_pde:0.44597539, loss_ib:0.02897917
# epoch 36 loss_pde:0.44375822, loss_ib:0.02900589
# epoch 36 loss_pde:0.44179711, loss_ib:0.02905402
# epoch 36 loss_pde:0.44087011, loss_ib:0.02902977
# epoch 36 loss_pde:0.44021913, loss_ib:0.02896522
# epoch 36 loss_pde:0.43914381, loss_ib:0.02887606
# epoch 36 loss_pde:0.43819472, loss_ib:0.02881435
# epoch 36 loss_pde:0.43728286, loss_ib:0.02876938
# epoch 36 loss_pde:0.43698165, loss_ib:0.02869286
# epoch 36 loss_pde:0.43573785, loss_ib:0.02872261
# epoch 36 loss_pde:0.43485892, loss_ib:0.02867174
# epoch 36 loss_pde:0.43303514, loss_ib:0.02869451
# epoch 36 loss_pde:0.43195522, loss_ib:0.02863304
# epoch 36 loss_pde:0.43282419, loss_ib:0.02841533
# epoch 36 loss_pde:0.43229896, loss_ib:0.02836716
# epoch 36 loss_pde:0.43227437, loss_ib:0.02829812
# epoch 36 loss_pde:0.43208253, loss_ib:0.02821846
# epoch 36 loss_pde:0.43203557, loss_ib:0.02804410
# epoch 36 loss_pde:0.43163407, loss_ib:0.02793811
# epoch 36 loss_pde:0.43103212, loss_ib:0.02788376
# epoch 36: loss 0.735767
# epoch 37 loss_pde:0.43061757, loss_ib:0.02782417
# epoch 37 loss_pde:0.42988887, loss_ib:0.02777790
# epoch 37 loss_pde:0.42949390, loss_ib:0.02762058
# epoch 37 loss_pde:0.42838776, loss_ib:0.02760082
# epoch 37 loss_pde:0.42789280, loss_ib:0.02752799
# epoch 37 loss_pde:0.42746466, loss_ib:0.02744246
# epoch 37 loss_pde:0.42683330, loss_ib:0.02741811
# epoch 37 loss_pde:0.42582735, loss_ib:0.02737221
# epoch 37 loss_pde:0.42539638, loss_ib:0.02724817
# epoch 37 loss_pde:0.42523956, loss_ib:0.02708899
# epoch 37 loss_pde:0.42603746, loss_ib:0.02690623
# epoch 37 loss_pde:0.42618302, loss_ib:0.02677338
# epoch 37 loss_pde:0.42646992, loss_ib:0.02659898
# epoch 37 loss_pde:0.42628488, loss_ib:0.02643605
# epoch 37 loss_pde:0.42456150, loss_ib:0.02645570
# epoch 37 loss_pde:0.42411047, loss_ib:0.02639667
# epoch 37 loss_pde:0.42363012, loss_ib:0.02634850
# epoch 37 loss_pde:0.42370367, loss_ib:0.02626922
# epoch 37 loss_pde:0.42401883, loss_ib:0.02615259
# epoch 37 loss_pde:0.42426920, loss_ib:0.02599320
# epoch 37: loss 0.708859
# epoch 38 loss_pde:0.42457336, loss_ib:0.02585548
# epoch 38 loss_pde:0.42349860, loss_ib:0.02585216
# epoch 38 loss_pde:0.42253712, loss_ib:0.02586178
# epoch 38 loss_pde:0.42121470, loss_ib:0.02585572
# epoch 38 loss_pde:0.42185867, loss_ib:0.02570090
# epoch 38 loss_pde:0.42144862, loss_ib:0.02561251
# epoch 38 loss_pde:0.42096484, loss_ib:0.02557711
# epoch 38 loss_pde:0.42173505, loss_ib:0.02540785
# epoch 38 loss_pde:0.42118871, loss_ib:0.02533301
# epoch 38 loss_pde:0.42211142, loss_ib:0.02513034
# epoch 38 loss_pde:0.42124140, loss_ib:0.02510354
# epoch 38 loss_pde:0.42053211, loss_ib:0.02511353
# epoch 38 loss_pde:0.42001086, loss_ib:0.02505907
# epoch 38 loss_pde:0.41916266, loss_ib:0.02498247
# epoch 38 loss_pde:0.41870981, loss_ib:0.02488456
# epoch 38 loss_pde:0.41842973, loss_ib:0.02478723
# epoch 38 loss_pde:0.41678375, loss_ib:0.02479932
# epoch 38 loss_pde:0.41686463, loss_ib:0.02465990
# epoch 38 loss_pde:0.41484794, loss_ib:0.02472910
# epoch 38 loss_pde:0.41315761, loss_ib:0.02478155
# epoch 38: loss 0.683128
# epoch 39 loss_pde:0.41257587, loss_ib:0.02470513
# epoch 39 loss_pde:0.41183966, loss_ib:0.02460990
# epoch 39 loss_pde:0.41161510, loss_ib:0.02450741
# epoch 39 loss_pde:0.41223639, loss_ib:0.02433629
# epoch 39 loss_pde:0.41181669, loss_ib:0.02428550
# epoch 39 loss_pde:0.41078982, loss_ib:0.02429070
# epoch 39 loss_pde:0.40899974, loss_ib:0.02431948
# epoch 39 loss_pde:0.40734476, loss_ib:0.02437245
# epoch 39 loss_pde:0.40696752, loss_ib:0.02431926
# epoch 39 loss_pde:0.40690684, loss_ib:0.02423784
# epoch 39 loss_pde:0.40667000, loss_ib:0.02416473
# epoch 39 loss_pde:0.40696496, loss_ib:0.02404736
# epoch 39 loss_pde:0.40537789, loss_ib:0.02409591
# epoch 39 loss_pde:0.40496692, loss_ib:0.02402733
# epoch 39 loss_pde:0.40368715, loss_ib:0.02403864
# epoch 39 loss_pde:0.40324596, loss_ib:0.02398438
# epoch 39 loss_pde:0.40275872, loss_ib:0.02393610
# epoch 39 loss_pde:0.40284485, loss_ib:0.02383191
# epoch 39 loss_pde:0.40290320, loss_ib:0.02370155
# epoch 39 loss_pde:0.40193087, loss_ib:0.02360162
# epoch 39: loss 0.659627
# epoch 40 loss_pde:0.40244877, loss_ib:0.02342181
# epoch 40 loss_pde:0.40133330, loss_ib:0.02344441
# epoch 40 loss_pde:0.39946395, loss_ib:0.02350910
# epoch 40 loss_pde:0.39835811, loss_ib:0.02349653
# epoch 40 loss_pde:0.39701450, loss_ib:0.02346580
# epoch 40 loss_pde:0.39681929, loss_ib:0.02334167
# epoch 40 loss_pde:0.39682943, loss_ib:0.02323166
# epoch 40 loss_pde:0.39693981, loss_ib:0.02313769
# epoch 40 loss_pde:0.39642191, loss_ib:0.02308685
# epoch 40 loss_pde:0.39658299, loss_ib:0.02295321
# epoch 40 loss_pde:0.39551669, loss_ib:0.02293412
# epoch 40 loss_pde:0.39511570, loss_ib:0.02286755
# epoch 40 loss_pde:0.39495912, loss_ib:0.02279683
# epoch 40 loss_pde:0.39462316, loss_ib:0.02275953
# epoch 40 loss_pde:0.39462304, loss_ib:0.02269264
# epoch 40 loss_pde:0.39411470, loss_ib:0.02268865
# epoch 40 loss_pde:0.39287323, loss_ib:0.02272545
# epoch 40 loss_pde:0.39132416, loss_ib:0.02276721
# epoch 40 loss_pde:0.38865811, loss_ib:0.02291650
# epoch 40 loss_pde:0.38758582, loss_ib:0.02293322
# epoch 40: loss 0.636667
# epoch 41 loss_pde:0.38664010, loss_ib:0.02293503
# epoch 41 loss_pde:0.38617331, loss_ib:0.02287598
# epoch 41 loss_pde:0.38550010, loss_ib:0.02277620
# epoch 41 loss_pde:0.38540590, loss_ib:0.02266756
# epoch 41 loss_pde:0.38466674, loss_ib:0.02264365
# epoch 41 loss_pde:0.38343602, loss_ib:0.02263585
# epoch 41 loss_pde:0.38246107, loss_ib:0.02263247
# epoch 41 loss_pde:0.38151786, loss_ib:0.02263917
# epoch 41 loss_pde:0.38126817, loss_ib:0.02257465
# epoch 41 loss_pde:0.38039118, loss_ib:0.02258452
# epoch 41 loss_pde:0.38086325, loss_ib:0.02245189
# epoch 41 loss_pde:0.38134602, loss_ib:0.02233813
# epoch 41 loss_pde:0.38120213, loss_ib:0.02229916
# epoch 41 loss_pde:0.38093871, loss_ib:0.02223737
# epoch 41 loss_pde:0.37944192, loss_ib:0.02228560
# epoch 41 loss_pde:0.38084424, loss_ib:0.02218161
# epoch 41 loss_pde:0.37913346, loss_ib:0.02216024
# epoch 41 loss_pde:0.37890908, loss_ib:0.02213846
# epoch 41 loss_pde:0.37900573, loss_ib:0.02206785
# epoch 41 loss_pde:0.37917191, loss_ib:0.02196139
# epoch 41: loss 0.615990
# epoch 42 loss_pde:0.37948164, loss_ib:0.02179319
# epoch 42 loss_pde:0.37918717, loss_ib:0.02171135
# epoch 42 loss_pde:0.37839475, loss_ib:0.02170099
# epoch 42 loss_pde:0.37727299, loss_ib:0.02173044
# epoch 42 loss_pde:0.37644964, loss_ib:0.02174312
# epoch 42 loss_pde:0.37508702, loss_ib:0.02176309
# epoch 42 loss_pde:0.37452844, loss_ib:0.02170111
# epoch 42 loss_pde:0.37382376, loss_ib:0.02164988
# epoch 42 loss_pde:0.37389073, loss_ib:0.02155871
# epoch 42 loss_pde:0.37377131, loss_ib:0.02146092
# epoch 42 loss_pde:0.37364066, loss_ib:0.02136145
# epoch 42 loss_pde:0.37252641, loss_ib:0.02137563
# epoch 42 loss_pde:0.37202772, loss_ib:0.02133788
# epoch 42 loss_pde:0.37123764, loss_ib:0.02134913
# epoch 42 loss_pde:0.37073806, loss_ib:0.02134492
# epoch 42 loss_pde:0.37013549, loss_ib:0.02132110
# epoch 42 loss_pde:0.36956078, loss_ib:0.02129021
# epoch 42 loss_pde:0.36851442, loss_ib:0.02126642
# epoch 42 loss_pde:0.36783767, loss_ib:0.02121986
# epoch 42 loss_pde:0.36744815, loss_ib:0.02119000
# epoch 42: loss 0.597414
# epoch 43 loss_pde:0.36676383, loss_ib:0.02118906
# epoch 43 loss_pde:0.36628860, loss_ib:0.02116342
# epoch 43 loss_pde:0.36596960, loss_ib:0.02111540
# epoch 43 loss_pde:0.36531910, loss_ib:0.02107744
# epoch 43 loss_pde:0.36526990, loss_ib:0.02100181
# epoch 43 loss_pde:0.36475927, loss_ib:0.02096780
# epoch 43 loss_pde:0.36400393, loss_ib:0.02096867
# epoch 43 loss_pde:0.36320680, loss_ib:0.02096131
# epoch 43 loss_pde:0.36310592, loss_ib:0.02086594
# epoch 43 loss_pde:0.36248347, loss_ib:0.02082924
# epoch 43 loss_pde:0.36249411, loss_ib:0.02073088
# epoch 43 loss_pde:0.36239943, loss_ib:0.02066002
# epoch 43 loss_pde:0.36204582, loss_ib:0.02056994
# epoch 43 loss_pde:0.36224303, loss_ib:0.02045967
# epoch 43 loss_pde:0.36140758, loss_ib:0.02048476
# epoch 43 loss_pde:0.36013341, loss_ib:0.02054163
# epoch 43 loss_pde:0.35969168, loss_ib:0.02052819
# epoch 43 loss_pde:0.35936078, loss_ib:0.02048031
# epoch 43 loss_pde:0.35930356, loss_ib:0.02035988
# epoch 43 loss_pde:0.35892341, loss_ib:0.02029297
# epoch 43: loss 0.578654
# epoch 44 loss_pde:0.35931492, loss_ib:0.02014362
# epoch 44 loss_pde:0.35836869, loss_ib:0.02015101
# epoch 44 loss_pde:0.35796955, loss_ib:0.02010375
# epoch 44 loss_pde:0.35745043, loss_ib:0.02007467
# epoch 44 loss_pde:0.35591763, loss_ib:0.02012222
# epoch 44 loss_pde:0.35538399, loss_ib:0.02006165
# epoch 44 loss_pde:0.35487789, loss_ib:0.02000643
# epoch 44 loss_pde:0.35482043, loss_ib:0.01995599
# epoch 44 loss_pde:0.35472828, loss_ib:0.01991353
# epoch 44 loss_pde:0.35397917, loss_ib:0.01988992
# epoch 44 loss_pde:0.35229206, loss_ib:0.01995779
# epoch 44 loss_pde:0.35146993, loss_ib:0.01995780
# epoch 44 loss_pde:0.35106567, loss_ib:0.01994043
# epoch 44 loss_pde:0.35058361, loss_ib:0.01989245
# epoch 44 loss_pde:0.35047403, loss_ib:0.01981988
# epoch 44 loss_pde:0.35079229, loss_ib:0.01969051
# epoch 44 loss_pde:0.35057712, loss_ib:0.01962373
# epoch 44 loss_pde:0.35001847, loss_ib:0.01957636
# epoch 44 loss_pde:0.34945133, loss_ib:0.01954842
# epoch 44 loss_pde:0.34797481, loss_ib:0.01960026
# epoch 44: loss 0.560751
# epoch 45 loss_pde:0.34649959, loss_ib:0.01963901
# epoch 45 loss_pde:0.34529972, loss_ib:0.01968349
# epoch 45 loss_pde:0.34436786, loss_ib:0.01969399
# epoch 45 loss_pde:0.34341323, loss_ib:0.01966494
# epoch 45 loss_pde:0.34274575, loss_ib:0.01961778
# epoch 45 loss_pde:0.34224951, loss_ib:0.01957115
# epoch 45 loss_pde:0.34172034, loss_ib:0.01954412
# epoch 45 loss_pde:0.34192443, loss_ib:0.01945778
# epoch 45 loss_pde:0.34139317, loss_ib:0.01944831
# epoch 45 loss_pde:0.34056723, loss_ib:0.01943706
# epoch 45 loss_pde:0.33987227, loss_ib:0.01940108
# epoch 45 loss_pde:0.33952320, loss_ib:0.01932604
# epoch 45 loss_pde:0.33924556, loss_ib:0.01928553
# epoch 45 loss_pde:0.33916891, loss_ib:0.01923604
# epoch 45 loss_pde:0.33882305, loss_ib:0.01916101
# epoch 45 loss_pde:0.33843333, loss_ib:0.01920344
# epoch 45 loss_pde:0.33809054, loss_ib:0.01910495
# epoch 45 loss_pde:0.33790463, loss_ib:0.01908842
# epoch 45 loss_pde:0.33760327, loss_ib:0.01905797
# epoch 45 loss_pde:0.33717602, loss_ib:0.01903015
# epoch 45: loss 0.542890
# epoch 46 loss_pde:0.33711061, loss_ib:0.01892858
# epoch 46 loss_pde:0.33586028, loss_ib:0.01896358
# epoch 46 loss_pde:0.33578205, loss_ib:0.01887206
# epoch 46 loss_pde:0.33555865, loss_ib:0.01881009
# epoch 46 loss_pde:0.33539203, loss_ib:0.01875883
# epoch 46 loss_pde:0.33486757, loss_ib:0.01871778
# epoch 46 loss_pde:0.33471459, loss_ib:0.01865442
# epoch 46 loss_pde:0.33460969, loss_ib:0.01860426
# epoch 46 loss_pde:0.33469158, loss_ib:0.01852584
# epoch 46 loss_pde:0.33448592, loss_ib:0.01849707
# epoch 46 loss_pde:0.33429477, loss_ib:0.01846988
# epoch 46 loss_pde:0.33379236, loss_ib:0.01844658
# epoch 46 loss_pde:0.33353457, loss_ib:0.01840410
# epoch 46 loss_pde:0.33222717, loss_ib:0.01841964
# epoch 46 loss_pde:0.33248603, loss_ib:0.01831140
# epoch 46 loss_pde:0.33244202, loss_ib:0.01825969
# epoch 46 loss_pde:0.33216751, loss_ib:0.01817555
# epoch 46 loss_pde:0.33177909, loss_ib:0.01809972
# epoch 46 loss_pde:0.33162940, loss_ib:0.01809824
# epoch 46 loss_pde:0.33116040, loss_ib:0.01805615
# epoch 46: loss 0.526396
# epoch 47 loss_pde:0.33078155, loss_ib:0.01805868
# epoch 47 loss_pde:0.33025783, loss_ib:0.01805905
# epoch 47 loss_pde:0.32974094, loss_ib:0.01805398
# epoch 47 loss_pde:0.32930532, loss_ib:0.01801478
# epoch 47 loss_pde:0.32893074, loss_ib:0.01796838
# epoch 47 loss_pde:0.32856077, loss_ib:0.01793216
# epoch 47 loss_pde:0.32845229, loss_ib:0.01787231
# epoch 47 loss_pde:0.32817426, loss_ib:0.01783232
# epoch 47 loss_pde:0.32738453, loss_ib:0.01781701
# epoch 47 loss_pde:0.32678959, loss_ib:0.01779040
# epoch 47 loss_pde:0.32597235, loss_ib:0.01780423
# epoch 47 loss_pde:0.32518378, loss_ib:0.01781333
# epoch 47 loss_pde:0.32414645, loss_ib:0.01783554
# epoch 47 loss_pde:0.32307744, loss_ib:0.01784659
# epoch 47 loss_pde:0.32208306, loss_ib:0.01785627
# epoch 47 loss_pde:0.32176936, loss_ib:0.01783281
# epoch 47 loss_pde:0.32149306, loss_ib:0.01780246
# epoch 47 loss_pde:0.32146582, loss_ib:0.01775634
# epoch 47 loss_pde:0.32073787, loss_ib:0.01776377
# epoch 47 loss_pde:0.32036573, loss_ib:0.01775033
# epoch 47: loss 0.511368
# epoch 48 loss_pde:0.31992039, loss_ib:0.01773567
# epoch 48 loss_pde:0.31948495, loss_ib:0.01770377
# epoch 48 loss_pde:0.31903428, loss_ib:0.01766223
# epoch 48 loss_pde:0.31864327, loss_ib:0.01765151
# epoch 48 loss_pde:0.31852928, loss_ib:0.01761282
# epoch 48 loss_pde:0.31816274, loss_ib:0.01759202
# epoch 48 loss_pde:0.31785345, loss_ib:0.01757196
# epoch 48 loss_pde:0.31747824, loss_ib:0.01753484
# epoch 48 loss_pde:0.31713021, loss_ib:0.01753798
# epoch 48 loss_pde:0.31700885, loss_ib:0.01749039
# epoch 48 loss_pde:0.31695804, loss_ib:0.01744761
# epoch 48 loss_pde:0.31671700, loss_ib:0.01742380
# epoch 48 loss_pde:0.31624416, loss_ib:0.01738865
# epoch 48 loss_pde:0.31701314, loss_ib:0.01727449
# epoch 48 loss_pde:0.31574339, loss_ib:0.01729875
# epoch 48 loss_pde:0.31562102, loss_ib:0.01727561
# epoch 48 loss_pde:0.31537300, loss_ib:0.01726079
# epoch 48 loss_pde:0.31501722, loss_ib:0.01723835
# epoch 48 loss_pde:0.31451726, loss_ib:0.01723899
# epoch 48 loss_pde:0.31435415, loss_ib:0.01719562
# ...
# epoch 105 loss_pde:0.14664432, loss_ib:0.00769822
# epoch 105 loss_pde:0.14666761, loss_ib:0.00768982
# epoch 105 loss_pde:0.14664973, loss_ib:0.00767883
# epoch 105 loss_pde:0.14652576, loss_ib:0.00768047
# epoch 105 loss_pde:0.14648734, loss_ib:0.00766970
# epoch 105 loss_pde:0.14642742, loss_ib:0.00766775
# epoch 105 loss_pde:0.14636055, loss_ib:0.00766516
# epoch 105 loss_pde:0.14625990, loss_ib:0.00765942
# epoch 105 loss_pde:0.14636371, loss_ib:0.00770149
# epoch 105 loss_pde:0.14613996, loss_ib:0.00765381
# epoch 105 loss_pde:0.14611849, loss_ib:0.00765278
# epoch 105 loss_pde:0.14603943, loss_ib:0.00764395
# epoch 105 loss_pde:0.14594370, loss_ib:0.00763577
# epoch 105 loss_pde:0.14591266, loss_ib:0.00762766
# epoch 105 loss_pde:0.14577611, loss_ib:0.00762078
# epoch 105 loss_pde:0.14570519, loss_ib:0.00761797
# epoch 105 loss_pde:0.14567675, loss_ib:0.00761175
# epoch 105 loss_pde:0.14549735, loss_ib:0.00761257
# epoch 105 loss_pde:0.14541405, loss_ib:0.00760604
# epoch 105: loss 0.223815
# epoch 106 loss_pde:0.14528239, loss_ib:0.00760714
# epoch 106 loss_pde:0.14513043, loss_ib:0.00761093
# epoch 106 loss_pde:0.14500363, loss_ib:0.00761761
# epoch 106 loss_pde:0.14475250, loss_ib:0.00761822
# epoch 106 loss_pde:0.14477262, loss_ib:0.00760450
# epoch 106 loss_pde:0.14482981, loss_ib:0.00758393
# epoch 106 loss_pde:0.14484920, loss_ib:0.00757069
# epoch 106 loss_pde:0.14466998, loss_ib:0.00757897
# epoch 106 loss_pde:0.14477783, loss_ib:0.00753996
# epoch 106 loss_pde:0.14471917, loss_ib:0.00753784
# epoch 106 loss_pde:0.14460032, loss_ib:0.00753746
# epoch 106 loss_pde:0.14452507, loss_ib:0.00753280
# epoch 106 loss_pde:0.14437774, loss_ib:0.00752826
# epoch 106 loss_pde:0.14435285, loss_ib:0.00751327
# epoch 106 loss_pde:0.14428683, loss_ib:0.00751026
# epoch 106 loss_pde:0.14421855, loss_ib:0.00749980
# epoch 106 loss_pde:0.14408864, loss_ib:0.00750899
# epoch 106 loss_pde:0.14402033, loss_ib:0.00749268
# epoch 106 loss_pde:0.14402276, loss_ib:0.00748144
# epoch 106 loss_pde:0.14394243, loss_ib:0.00747648
# epoch 106: loss 0.221354
# epoch 107 loss_pde:0.14391249, loss_ib:0.00746670
# epoch 107 loss_pde:0.14381796, loss_ib:0.00746415
# epoch 107 loss_pde:0.14369470, loss_ib:0.00746273
# epoch 107 loss_pde:0.14354795, loss_ib:0.00745800
# epoch 107 loss_pde:0.14331165, loss_ib:0.00747794
# epoch 107 loss_pde:0.14330024, loss_ib:0.00745423
# epoch 107 loss_pde:0.14330059, loss_ib:0.00744350
# epoch 107 loss_pde:0.14321706, loss_ib:0.00743545
# epoch 107 loss_pde:0.14312446, loss_ib:0.00742363
# epoch 107 loss_pde:0.14279257, loss_ib:0.00743247
# epoch 107 loss_pde:0.14269711, loss_ib:0.00742805
# epoch 107 loss_pde:0.14263028, loss_ib:0.00742372
# epoch 107 loss_pde:0.14258926, loss_ib:0.00741880
# epoch 107 loss_pde:0.14260882, loss_ib:0.00741228
# epoch 107 loss_pde:0.14256555, loss_ib:0.00740556
# epoch 107 loss_pde:0.14253673, loss_ib:0.00740141
# epoch 107 loss_pde:0.14251946, loss_ib:0.00739686
# epoch 107 loss_pde:0.14248748, loss_ib:0.00739388
# epoch 107 loss_pde:0.14245236, loss_ib:0.00738151
# epoch 107 loss_pde:0.14240810, loss_ib:0.00737604
# epoch 107: loss 0.218579
# epoch 108 loss_pde:0.14226212, loss_ib:0.00737091
# epoch 108 loss_pde:0.14228134, loss_ib:0.00737693
# epoch 108 loss_pde:0.14211532, loss_ib:0.00736562
# epoch 108 loss_pde:0.14202613, loss_ib:0.00736557
# epoch 108 loss_pde:0.14180690, loss_ib:0.00736992
# epoch 108 loss_pde:0.14163198, loss_ib:0.00737123
# epoch 108 loss_pde:0.14127727, loss_ib:0.00737803
# epoch 108 loss_pde:0.14100632, loss_ib:0.00741127
# epoch 108 loss_pde:0.14099173, loss_ib:0.00737072
# epoch 108 loss_pde:0.14101903, loss_ib:0.00735885
# epoch 108 loss_pde:0.14094785, loss_ib:0.00735367
# epoch 108 loss_pde:0.14105868, loss_ib:0.00733544
# epoch 108 loss_pde:0.14094777, loss_ib:0.00733777
# epoch 108 loss_pde:0.14081627, loss_ib:0.00733875
# epoch 108 loss_pde:0.14079319, loss_ib:0.00733292
# epoch 108 loss_pde:0.14081137, loss_ib:0.00731662
# epoch 108 loss_pde:0.14068283, loss_ib:0.00733207
# epoch 108 loss_pde:0.14076646, loss_ib:0.00729504
# epoch 108 loss_pde:0.14073718, loss_ib:0.00728984
# epoch 108 loss_pde:0.14063677, loss_ib:0.00728748
# epoch 108: loss 0.215971
# epoch 109 loss_pde:0.14051059, loss_ib:0.00728801
# epoch 109 loss_pde:0.14022151, loss_ib:0.00729595
# epoch 109 loss_pde:0.13999780, loss_ib:0.00730866
# epoch 109 loss_pde:0.13994193, loss_ib:0.00729710
# epoch 109 loss_pde:0.13989685, loss_ib:0.00729231
# epoch 109 loss_pde:0.13968238, loss_ib:0.00730326
# epoch 109 loss_pde:0.13944635, loss_ib:0.00730298
# epoch 109 loss_pde:0.13935214, loss_ib:0.00730058
# epoch 109 loss_pde:0.13912517, loss_ib:0.00731122
# epoch 109 loss_pde:0.13902277, loss_ib:0.00731123
# epoch 109 loss_pde:0.13886394, loss_ib:0.00731264
# epoch 109 loss_pde:0.13870981, loss_ib:0.00731507
# epoch 109 loss_pde:0.13848162, loss_ib:0.00732195
# epoch 109 loss_pde:0.13826482, loss_ib:0.00732959
# epoch 109 loss_pde:0.13816546, loss_ib:0.00732605
# epoch 109 loss_pde:0.13801675, loss_ib:0.00732424
# epoch 109 loss_pde:0.13802411, loss_ib:0.00731023
# epoch 109 loss_pde:0.13791864, loss_ib:0.00730940
# epoch 109 loss_pde:0.13784313, loss_ib:0.00731514
# epoch 109 loss_pde:0.13775057, loss_ib:0.00731095
# epoch 109: loss 0.213391
# epoch 110 loss_pde:0.13765538, loss_ib:0.00731369
# epoch 110 loss_pde:0.13750115, loss_ib:0.00732077
# epoch 110 loss_pde:0.13733898, loss_ib:0.00732883
# epoch 110 loss_pde:0.13717471, loss_ib:0.00738862
# epoch 110 loss_pde:0.13708270, loss_ib:0.00734131
# epoch 110 loss_pde:0.13705546, loss_ib:0.00734013
# epoch 110 loss_pde:0.13694978, loss_ib:0.00734118
# epoch 110 loss_pde:0.13688925, loss_ib:0.00734200
# epoch 110 loss_pde:0.13661455, loss_ib:0.00734938
# epoch 110 loss_pde:0.13674335, loss_ib:0.00737484
# epoch 110 loss_pde:0.13643822, loss_ib:0.00734637
# epoch 110 loss_pde:0.13639504, loss_ib:0.00734350
# epoch 110 loss_pde:0.13637289, loss_ib:0.00733592
# epoch 110 loss_pde:0.13618514, loss_ib:0.00733797
# epoch 110 loss_pde:0.13616830, loss_ib:0.00733344
# epoch 110 loss_pde:0.13612927, loss_ib:0.00732875
# epoch 110 loss_pde:0.13604997, loss_ib:0.00732646
# epoch 110 loss_pde:0.13591564, loss_ib:0.00732441
# epoch 110 loss_pde:0.13550955, loss_ib:0.00735735
# epoch 110 loss_pde:0.13554221, loss_ib:0.00733737
# epoch 110: loss 0.210792
# epoch 111 loss_pde:0.13547839, loss_ib:0.00733290
# epoch 111 loss_pde:0.13531926, loss_ib:0.00733712
# epoch 111 loss_pde:0.13518664, loss_ib:0.00734397
# epoch 111 loss_pde:0.13493691, loss_ib:0.00734916
# epoch 111 loss_pde:0.13482614, loss_ib:0.00735112
# epoch 111 loss_pde:0.13467379, loss_ib:0.00735379
# epoch 111 loss_pde:0.13459401, loss_ib:0.00734866
# epoch 111 loss_pde:0.13455908, loss_ib:0.00733089
# epoch 111 loss_pde:0.13635147, loss_ib:0.00755821
# epoch 111 loss_pde:0.13445400, loss_ib:0.00732775
# epoch 111 loss_pde:0.13469326, loss_ib:0.00730664
# epoch 111 loss_pde:0.13456233, loss_ib:0.00730884
# epoch 111 loss_pde:0.13455762, loss_ib:0.00730647
# epoch 111 loss_pde:0.13459367, loss_ib:0.00729314
# epoch 111 loss_pde:0.13460705, loss_ib:0.00728251
# epoch 111 loss_pde:0.13448811, loss_ib:0.00727363
# epoch 111 loss_pde:0.13436402, loss_ib:0.00727504
# epoch 111 loss_pde:0.13424268, loss_ib:0.00726868
# epoch 111 loss_pde:0.13413128, loss_ib:0.00727004
# epoch 111 loss_pde:0.13399979, loss_ib:0.00727132
# epoch 111: loss 0.208807
# epoch 112 loss_pde:0.13380636, loss_ib:0.00727071
# epoch 112 loss_pde:0.13361801, loss_ib:0.00727159
# epoch 112 loss_pde:0.13346364, loss_ib:0.00727032
# epoch 112 loss_pde:0.13344464, loss_ib:0.00726364
# epoch 112 loss_pde:0.13341692, loss_ib:0.00725398
# epoch 112 loss_pde:0.13335735, loss_ib:0.00724639
# epoch 112 loss_pde:0.13318411, loss_ib:0.00723291
# epoch 112 loss_pde:0.13310413, loss_ib:0.00723767
# epoch 112 loss_pde:0.13296092, loss_ib:0.00722600
# epoch 112 loss_pde:0.13292074, loss_ib:0.00722315
# epoch 112 loss_pde:0.13284659, loss_ib:0.00721890
# epoch 112 loss_pde:0.13273244, loss_ib:0.00721275
# epoch 112 loss_pde:0.13278648, loss_ib:0.00722726
# epoch 112 loss_pde:0.13255754, loss_ib:0.00720485
# epoch 112 loss_pde:0.13252430, loss_ib:0.00720159
# epoch 112 loss_pde:0.13241561, loss_ib:0.00720305
# epoch 112 loss_pde:0.13237721, loss_ib:0.00720167
# epoch 112 loss_pde:0.13234197, loss_ib:0.00719871
# epoch 112 loss_pde:0.13227320, loss_ib:0.00719625
# epoch 112 loss_pde:0.13222578, loss_ib:0.00719283
# epoch 112: loss 0.206513
# epoch 113 loss_pde:0.13217866, loss_ib:0.00718909
# epoch 113 loss_pde:0.13212480, loss_ib:0.00718127
# epoch 113 loss_pde:0.13211513, loss_ib:0.00717498
# epoch 113 loss_pde:0.13209368, loss_ib:0.00716660
# epoch 113 loss_pde:0.13205723, loss_ib:0.00716369
# epoch 113 loss_pde:0.13195358, loss_ib:0.00716325
# epoch 113 loss_pde:0.13174602, loss_ib:0.00716955
# epoch 113 loss_pde:0.13157304, loss_ib:0.00717565
# epoch 113 loss_pde:0.13146849, loss_ib:0.00717549
# epoch 113 loss_pde:0.13130465, loss_ib:0.00717110
# epoch 113 loss_pde:0.13125750, loss_ib:0.00716287
# epoch 113 loss_pde:0.13123742, loss_ib:0.00715009
# epoch 113 loss_pde:0.13122578, loss_ib:0.00713110
# epoch 113 loss_pde:0.13114662, loss_ib:0.00713252
# epoch 113 loss_pde:0.13113907, loss_ib:0.00712336
# epoch 113 loss_pde:0.13106313, loss_ib:0.00712522
# epoch 113 loss_pde:0.13089165, loss_ib:0.00713342
# epoch 113 loss_pde:0.13054912, loss_ib:0.00714729
# epoch 113 loss_pde:0.13014828, loss_ib:0.00716177
# epoch 113 loss_pde:0.13022353, loss_ib:0.00720137
# epoch 113: loss 0.204070
# epoch 114 loss_pde:0.12990916, loss_ib:0.00716242
# epoch 114 loss_pde:0.12995507, loss_ib:0.00715106
# epoch 114 loss_pde:0.12997477, loss_ib:0.00713482
# epoch 114 loss_pde:0.13040097, loss_ib:0.00711223
# epoch 114 loss_pde:0.13004129, loss_ib:0.00711054
# epoch 114 loss_pde:0.12994735, loss_ib:0.00711288
# epoch 114 loss_pde:0.12981388, loss_ib:0.00710792
# epoch 114 loss_pde:0.12971382, loss_ib:0.00710253
# epoch 114 loss_pde:0.12972769, loss_ib:0.00707914
# epoch 114 loss_pde:0.12965883, loss_ib:0.00707371
# epoch 114 loss_pde:0.12958056, loss_ib:0.00707209
# epoch 114 loss_pde:0.12953754, loss_ib:0.00707053
# epoch 114 loss_pde:0.12946442, loss_ib:0.00706890
# epoch 114 loss_pde:0.12921670, loss_ib:0.00707576
# epoch 114 loss_pde:0.12954326, loss_ib:0.00706233
# epoch 114 loss_pde:0.12910202, loss_ib:0.00705957
# epoch 114 loss_pde:0.12902908, loss_ib:0.00705900
# epoch 114 loss_pde:0.12891816, loss_ib:0.00705399
# epoch 114 loss_pde:0.12889753, loss_ib:0.00704855
# epoch 114 loss_pde:0.12889500, loss_ib:0.00703525
# epoch 114: loss 0.201533
# epoch 115 loss_pde:0.12891763, loss_ib:0.00702094
# epoch 115 loss_pde:0.12898314, loss_ib:0.00700375
# epoch 115 loss_pde:0.12917109, loss_ib:0.00702764
# epoch 115 loss_pde:0.12897539, loss_ib:0.00699390
# epoch 115 loss_pde:0.12895259, loss_ib:0.00699210
# epoch 115 loss_pde:0.12889388, loss_ib:0.00698573
# epoch 115 loss_pde:0.12885897, loss_ib:0.00698418
# epoch 115 loss_pde:0.12885959, loss_ib:0.00697776
# epoch 115 loss_pde:0.12881313, loss_ib:0.00697427
# epoch 115 loss_pde:0.12879212, loss_ib:0.00697170
# epoch 115 loss_pde:0.12875818, loss_ib:0.00697050
# epoch 115 loss_pde:0.12861027, loss_ib:0.00697214
# epoch 115 loss_pde:0.12841789, loss_ib:0.00698626
# epoch 115 loss_pde:0.12817438, loss_ib:0.00698741
# epoch 115 loss_pde:0.12811604, loss_ib:0.00698501
# epoch 115 loss_pde:0.12803204, loss_ib:0.00698523
# epoch 115 loss_pde:0.12798202, loss_ib:0.00698461
# epoch 115 loss_pde:0.12794214, loss_ib:0.00697848
# epoch 115 loss_pde:0.12788497, loss_ib:0.00696750
# epoch 115 loss_pde:0.12784442, loss_ib:0.00695498
# epoch 115: loss 0.199127
# epoch 116 loss_pde:0.12775959, loss_ib:0.00694402
# epoch 116 loss_pde:0.12765317, loss_ib:0.00693907
# epoch 116 loss_pde:0.12764029, loss_ib:0.00692677
# epoch 116 loss_pde:0.12753664, loss_ib:0.00692533
# epoch 116 loss_pde:0.12747817, loss_ib:0.00692045
# epoch 116 loss_pde:0.12745404, loss_ib:0.00691045
# epoch 116 loss_pde:0.12752622, loss_ib:0.00690464
# epoch 116 loss_pde:0.12746739, loss_ib:0.00689013
# epoch 116 loss_pde:0.12745535, loss_ib:0.00688761
# epoch 116 loss_pde:0.12740254, loss_ib:0.00688365
# epoch 116 loss_pde:0.12727603, loss_ib:0.00688400
# epoch 116 loss_pde:0.12719816, loss_ib:0.00688838
# epoch 116 loss_pde:0.12695798, loss_ib:0.00689475
# epoch 116 loss_pde:0.12690754, loss_ib:0.00689514
# epoch 116 loss_pde:0.12684029, loss_ib:0.00689390
# epoch 116 loss_pde:0.12684231, loss_ib:0.00688419
# epoch 116 loss_pde:0.12679991, loss_ib:0.00687988
# epoch 116 loss_pde:0.12678716, loss_ib:0.00687141
# epoch 116 loss_pde:0.12674716, loss_ib:0.00686524
# epoch 116 loss_pde:0.12663934, loss_ib:0.00686509
# epoch 116: loss 0.197200
# epoch 117 loss_pde:0.12657276, loss_ib:0.00685989
# epoch 117 loss_pde:0.12649956, loss_ib:0.00685921
# epoch 117 loss_pde:0.12640056, loss_ib:0.00685753
# epoch 117 loss_pde:0.12630394, loss_ib:0.00685536
# epoch 117 loss_pde:0.12621431, loss_ib:0.00685147
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 4
#       2 tic = time.time()
#       3 for epoch in range(1, epochs+1):
# ----> 4     train(epoch)
#       5 toc = time.time()
#       6 print(f'Total training time: {toc - tic}')
#
# Cell In[6], line 31, in train(epoch)
#      28     return loss
#      30 # Optimize loss function
# ---> 31 loss = optimizer.step(closure)
#      32 loss_value = loss.item() if not isinstance(loss, float) else loss
#      33 # Print total loss
#
# File ~/anaconda3/envs/ML/lib/python3.11/site-packages/torch/optim/optimizer.py:280, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     276         else:
#     277             raise RuntimeError(f"{func} must return None or a tuple of (new_args, new_kwargs),"
#     278                                f"but got {result}.")
# --> 280 out = func(*args, **kwargs)
#     281 self._optimizer_step_code()
#     283 # call optimizer step post hooks
#
# File ~/anaconda3/envs/ML/lib/python3.11/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File ~/anaconda3/envs/ML/lib/python3.11/site-packages/torch/optim/lbfgs.py:438, in LBFGS.step(self, closure)
#     433 if n_iter != max_iter:
#     434     # re-evaluate function only if not in last iteration
#     435     # the reason we do this: in a stochastic setting,
#     436     # no use to re-evaluate that function here
#     437     with torch.enable_grad():
# --> 438         loss = float(closure())
#     439     flat_grad = self._gather_flat_grad()
#     440     opt_cond = flat_grad.abs().max() <= tolerance_grad
#
# File ~/anaconda3/envs/ML/lib/python3.11/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# Cell In[6], line 27, in train.<locals>.closure()
#      24 loss = loss_pde + 10*loss_ib
#      26 print(f'epoch {epoch} loss_pde:{loss_pde:.8f}, loss_ib:{loss_ib:.8f}')
# ---> 27 loss.backward()
#      28 return loss
#
# File ~/anaconda3/envs/ML/lib/python3.11/site-packages/torch/_tensor.py:487, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     477 if has_torch_function_unary(self):
#     478     return handle_torch_function(
#     479         Tensor.backward,
#     480         (self,),
#    (...)
#     485         inputs=inputs,
#     486     )
# --> 487 torch.autograd.backward(
#     488     self, gradient, retain_graph, create_graph, inputs=inputs
#     489 )
#
# File ~/anaconda3/envs/ML/lib/python3.11/site-packages/torch/autograd/__init__.py:200, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     195     retain_graph = create_graph
#     197 # The reason we repeat same the comment below is that
#     198 # some Python versions print out the first line of a multi-line function
#     199 # calls in the traceback and some print out the last line
# --> 200 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     201     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     202     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:

# %%
epochs = 300
tic = time.time()
for epoch in range(1, epochs+1):
    train(epoch)
toc = time.time()
print(f'Total training time: {toc - tic}')
# Out:
# epoch 1 loss_pde:0.10344033, loss_ib:4.05444670
# epoch 1 loss_pde:0.20986223, loss_ib:4.13174295
# epoch 1 loss_pde:0.16846269, loss_ib:3.85252786
# epoch 1 loss_pde:0.19556396, loss_ib:3.82005334
# epoch 1 loss_pde:0.27339798, loss_ib:3.77893472
# epoch 1 loss_pde:0.38793039, loss_ib:3.72017121
# epoch 1 loss_pde:0.57371682, loss_ib:3.63972163
# epoch 1 loss_pde:0.69852483, loss_ib:3.58274317
# epoch 1 loss_pde:0.86379302, loss_ib:3.50459957
# epoch 1 loss_pde:1.17102456, loss_ib:3.38947463
# epoch 1 loss_pde:1.57016134, loss_ib:3.25986099
# epoch 1 loss_pde:1.81947947, loss_ib:3.17122483
# epoch 1 loss_pde:1.90057600, loss_ib:3.13329720
# epoch 1 loss_pde:1.85445106, loss_ib:3.09430909
# epoch 1 loss_pde:2.23778129, loss_ib:3.01654911
# epoch 1 loss_pde:1.97777498, loss_ib:2.98765135
# epoch 1 loss_pde:1.92066133, loss_ib:2.95562220
# epoch 1 loss_pde:1.96877086, loss_ib:2.91152453
# epoch 1 loss_pde:2.05527806, loss_ib:2.85840344
# epoch 1 loss_pde:2.15815830, loss_ib:2.79153728
# epoch 1: loss 40.647907
# epoch 2 loss_pde:2.19533801, loss_ib:2.74096513
# epoch 2 loss_pde:2.19088030, loss_ib:2.70635438
# epoch 2 loss_pde:2.19833612, loss_ib:2.67867994
# epoch 2 loss_pde:2.26007462, loss_ib:2.61413908
# epoch 2 loss_pde:2.37956142, loss_ib:2.54865074
# epoch 2 loss_pde:2.51107597, loss_ib:2.49111891
# epoch 2 loss_pde:2.65845728, loss_ib:2.44132662
# epoch 2 loss_pde:2.72717118, loss_ib:2.41429830
# epoch 2 loss_pde:2.83521318, loss_ib:2.36757565
# epoch 2 loss_pde:3.18801475, loss_ib:2.25337458
# epoch 2 loss_pde:3.61481500, loss_ib:2.15574694
# epoch 2 loss_pde:3.81852722, loss_ib:2.10748196
# epoch 2 loss_pde:3.95663786, loss_ib:2.05364060
# epoch 2 loss_pde:4.00414896, loss_ib:2.01517153
# epoch 2 loss_pde:4.00871086, loss_ib:1.97921538
# epoch 2 loss_pde:4.05914783, loss_ib:1.90534794
# epoch 2 loss_pde:4.08849001, loss_ib:1.85532951
# epoch 2 loss_pde:4.23998260, loss_ib:1.79432607
# epoch 2 loss_pde:4.28102016, loss_ib:1.75622725
# epoch 2 loss_pde:4.41313314, loss_ib:1.69172180
# epoch 2: loss 29.604988
# epoch 3 loss_pde:4.43036079, loss_ib:1.63827980
# epoch 3 loss_pde:4.47990847, loss_ib:1.58815682
# epoch 3 loss_pde:4.38904619, loss_ib:1.53978384
# epoch 3 loss_pde:4.42171001, loss_ib:1.50404680
# epoch 3 loss_pde:4.26360941, loss_ib:1.49524522
# epoch 3 loss_pde:4.08211899, loss_ib:1.48451078
# epoch 3 loss_pde:3.98521638, loss_ib:1.47565961
# epoch 3 loss_pde:3.91321921, loss_ib:1.45889032
# epoch 3 loss_pde:3.86126733, loss_ib:1.44039297
# epoch 3 loss_pde:3.85162163, loss_ib:1.42301250
# epoch 3 loss_pde:3.85415459, loss_ib:1.40041852
# epoch 3 loss_pde:3.86806774, loss_ib:1.38160241
# epoch 3 loss_pde:3.85492992, loss_ib:1.37143385
# epoch 3 loss_pde:3.82598662, loss_ib:1.36466908
# epoch 3 loss_pde:3.77203941, loss_ib:1.35803783
# epoch 3 loss_pde:3.67824841, loss_ib:1.35018396
# epoch 3 loss_pde:3.61430979, loss_ib:1.34226120
# epoch 3 loss_pde:3.58039594, loss_ib:1.32948828
# epoch 3 loss_pde:3.57702994, loss_ib:1.31016457
# epoch 3 loss_pde:3.59054875, loss_ib:1.28265882
# epoch 3: loss 20.813158
# epoch 4 loss_pde:3.61590409, loss_ib:1.26225841
# epoch 4 loss_pde:3.62654471, loss_ib:1.24915290
# epoch 4 loss_pde:3.64273119, loss_ib:1.23458385
# epoch 4 loss_pde:3.64030671, loss_ib:1.21486688
# epoch 4 loss_pde:3.59211493, loss_ib:1.18527842
# epoch 4 loss_pde:3.49870920, loss_ib:1.16713524
# epoch 4 loss_pde:3.47404861, loss_ib:1.14926612
# epoch 4 loss_pde:3.39847565, loss_ib:1.14558327
# epoch 4 loss_pde:3.40551758, loss_ib:1.12992001
# epoch 4 loss_pde:3.33963966, loss_ib:1.11473417
# epoch 4 loss_pde:3.34684992, loss_ib:1.09832692
# epoch 4 loss_pde:3.36387396, loss_ib:1.08126450
# epoch 4 loss_pde:3.37356997, loss_ib:1.07349324
# epoch 4 loss_pde:3.39207435, loss_ib:1.05735242
# epoch 4 loss_pde:3.40174460, loss_ib:1.04326868
# epoch 4 loss_pde:3.42073154, loss_ib:1.03396034
# epoch 4 loss_pde:3.42747927, loss_ib:1.02743196
# epoch 4 loss_pde:3.44834280, loss_ib:1.01757669
# epoch 4 loss_pde:3.46129179, loss_ib:0.99521095
# epoch 4 loss_pde:3.53747582, loss_ib:0.96765965
# epoch 4: loss 16.238489
# epoch 5 loss_pde:3.54344082, loss_ib:0.94746053
# epoch 5 loss_pde:3.54491401, loss_ib:0.92726916
# epoch 5 loss_pde:3.42032361, loss_ib:0.93008995
# epoch 5 loss_pde:3.32262564, loss_ib:0.93236625
# epoch 5 loss_pde:3.19891262, loss_ib:0.93681794
# epoch 5 loss_pde:3.17210340, loss_ib:0.93154556
# epoch 5 loss_pde:3.20699739, loss_ib:0.90910757
# epoch 5 loss_pde:3.31238151, loss_ib:0.88469547
# epoch 5 loss_pde:3.42140532, loss_ib:0.86180580
# epoch 5 loss_pde:3.46151733, loss_ib:0.84499121
# epoch 5 loss_pde:3.42866039, loss_ib:0.83170623
# epoch 5 loss_pde:3.30265784, loss_ib:0.83108842
# epoch 5 loss_pde:3.19273281, loss_ib:0.83180243
# epoch 5 loss_pde:3.07474279, loss_ib:0.83070624
# epoch 5 loss_pde:3.05505514, loss_ib:0.81973982
# epoch 5 loss_pde:3.10587955, loss_ib:0.79942077
# epoch 5 loss_pde:3.21030998, loss_ib:0.77968878
# epoch 5 loss_pde:3.26643014, loss_ib:0.76886690
# epoch 5 loss_pde:3.33216143, loss_ib:0.75868213
# epoch 5 loss_pde:3.33879471, loss_ib:0.74794644
# epoch 5: loss 13.018046
# epoch 6 loss_pde:3.37828827, loss_ib:0.72741020
# epoch 6 loss_pde:3.28633356, loss_ib:0.72534412
# epoch 6 loss_pde:3.21761918, loss_ib:0.71749240
# epoch 6 loss_pde:3.07221603, loss_ib:0.72086680
# epoch 6 loss_pde:3.06421781, loss_ib:0.71468359
# epoch 6 loss_pde:2.99433661, loss_ib:0.79917800
# epoch 6 loss_pde:3.01867819, loss_ib:0.70483363
# epoch 6 loss_pde:3.08486772, loss_ib:0.70868200
# epoch 6 loss_pde:3.03353786, loss_ib:0.69522703
# epoch 6 loss_pde:3.01290560, loss_ib:0.69563210
# epoch 6 loss_pde:2.98617387, loss_ib:0.69398880
# epoch 6 loss_pde:2.98487520, loss_ib:0.68816823
# epoch 6 loss_pde:3.02308965, loss_ib:0.67489064
# epoch 6 loss_pde:3.06120491, loss_ib:0.66643715
# epoch 6 loss_pde:3.06092262, loss_ib:0.66038996
# epoch 6 loss_pde:3.06292915, loss_ib:0.65176475
# epoch 6 loss_pde:3.01634407, loss_ib:0.64986157
# epoch 6 loss_pde:2.99209023, loss_ib:0.64919055
# epoch 6 loss_pde:2.96543074, loss_ib:0.64609224
# epoch 6 loss_pde:2.97843361, loss_ib:0.63943136
# epoch 6: loss 10.652390
# epoch 7 loss_pde:2.93077421, loss_ib:0.64971441
# epoch 7 loss_pde:3.01295567, loss_ib:0.62279826
# epoch 7 loss_pde:3.01131296, loss_ib:0.61906761
# epoch 7 loss_pde:3.00873137, loss_ib:0.61151546
# epoch 7 loss_pde:2.98520684, loss_ib:0.60794908
# epoch 7 loss_pde:2.92377830, loss_ib:0.60210198
# epoch 7 loss_pde:2.84564519, loss_ib:0.59527320
# epoch 7 loss_pde:2.80365467, loss_ib:0.58728915
# epoch 7 loss_pde:2.79188132, loss_ib:0.57952392
# epoch 7 loss_pde:2.83554697, loss_ib:0.56294405
# epoch 7 loss_pde:2.79526401, loss_ib:0.55739510
# epoch 7 loss_pde:2.78029060, loss_ib:0.55062681
# epoch 7 loss_pde:2.71417689, loss_ib:0.55204618
# epoch 7 loss_pde:2.71714187, loss_ib:0.54645234
# epoch 7 loss_pde:2.70294952, loss_ib:0.54207253
# epoch 7 loss_pde:2.69118166, loss_ib:0.53772652
# epoch 7 loss_pde:2.63777018, loss_ib:0.53675413
# epoch 7 loss_pde:2.63373756, loss_ib:0.53236169
# epoch 7 loss_pde:2.58612490, loss_ib:0.53198242
# epoch 7 loss_pde:2.51703978, loss_ib:0.52964240
# epoch 7: loss 9.427918
# epoch 8 loss_pde:2.47929764, loss_ib:0.52564812
# epoch 8 loss_pde:2.45661092, loss_ib:0.51754153
# epoch 8 loss_pde:2.47720933, loss_ib:0.50536239
# epoch 8 loss_pde:2.39651632, loss_ib:0.54033715
# epoch 8 loss_pde:2.47035861, loss_ib:0.49535039
# epoch 8 loss_pde:2.46124697, loss_ib:0.49325642
# epoch 8 loss_pde:2.45575023, loss_ib:0.48819789
# epoch 8 loss_pde:2.41686845, loss_ib:0.48534009
# epoch 8 loss_pde:2.38354754, loss_ib:0.48215896
# epoch 8 loss_pde:2.26267099, loss_ib:0.48663858
# epoch 8 loss_pde:2.28673983, loss_ib:0.47732112
# epoch 8 loss_pde:2.26850939, loss_ib:0.47542733
# epoch 8 loss_pde:2.24328995, loss_ib:0.47139665
# epoch 8 loss_pde:2.21385908, loss_ib:0.47024339
# epoch 8 loss_pde:2.21158695, loss_ib:0.46717930
# epoch 8 loss_pde:2.18227124, loss_ib:0.46442404
# epoch 8 loss_pde:2.16640949, loss_ib:0.46131349
# epoch 8 loss_pde:2.09934378, loss_ib:0.45948330
# epoch 8 loss_pde:2.13227892, loss_ib:0.46841803
# epoch 8 loss_pde:2.06758690, loss_ib:0.45501664
# epoch 8: loss 7.735779
# epoch 9 loss_pde:2.04959154, loss_ib:0.45478913
# epoch 9 loss_pde:2.01512241, loss_ib:0.45444095
# epoch 9 loss_pde:1.99877012, loss_ib:0.45358658
# epoch 9 loss_pde:1.98119748, loss_ib:0.45148519
# epoch 9 loss_pde:2.02955818, loss_ib:0.47037372
# epoch 9 loss_pde:1.97168326, loss_ib:0.44763744
# epoch 9 loss_pde:1.96723700, loss_ib:0.44634423
# epoch 9 loss_pde:1.96249533, loss_ib:0.44271249
# epoch 9 loss_pde:1.95948911, loss_ib:0.44156352
# epoch 9 loss_pde:1.95191133, loss_ib:0.43845034
# epoch 9 loss_pde:1.93253517, loss_ib:0.43422619
# epoch 9 loss_pde:1.92845321, loss_ib:0.42924234
# epoch 9 loss_pde:1.91578305, loss_ib:0.42734209
# epoch 9 loss_pde:1.89628315, loss_ib:0.42596284
# epoch 9 loss_pde:1.84880960, loss_ib:0.43409672
# epoch 9 loss_pde:1.86123157, loss_ib:0.42478102
# epoch 9 loss_pde:1.85142076, loss_ib:0.42342076
# epoch 9 loss_pde:1.82454991, loss_ib:0.42131078
# epoch 9 loss_pde:1.79239988, loss_ib:0.42184716
# epoch 9 loss_pde:1.76830554, loss_ib:0.42034262
# epoch 9: loss 6.597483
# epoch 10 loss_pde:1.73577881, loss_ib:0.41938543
# epoch 10 loss_pde:1.72898078, loss_ib:0.41570961
# epoch 10 loss_pde:1.69817996, loss_ib:0.41301045
# epoch 10 loss_pde:1.69634151, loss_ib:0.40945989
# epoch 10 loss_pde:1.69753242, loss_ib:0.40615100
# epoch 10 loss_pde:1.69915247, loss_ib:0.40450940
# epoch 10 loss_pde:1.69521809, loss_ib:0.40334105
# epoch 10 loss_pde:1.68811822, loss_ib:0.40160677
# epoch 10 loss_pde:1.67670190, loss_ib:0.39795077
# epoch 10 loss_pde:1.66383278, loss_ib:0.39566141
# epoch 10 loss_pde:1.67543888, loss_ib:0.39000949
# epoch 10 loss_pde:1.67329907, loss_ib:0.38564700
# epoch 10 loss_pde:1.65747690, loss_ib:0.38283482
# epoch 10 loss_pde:1.65154278, loss_ib:0.38038030
# epoch 10 loss_pde:1.64528823, loss_ib:0.37932998
# epoch 10 loss_pde:1.63250613, loss_ib:0.37709960
# epoch 10 loss_pde:1.62494946, loss_ib:0.37442335
# epoch 10 loss_pde:1.61405587, loss_ib:0.37092122
# epoch 10 loss_pde:1.62440705, loss_ib:0.36665714
# epoch 10 loss_pde:1.61565542, loss_ib:0.36434457
# epoch 10: loss 5.929633
# epoch 11 loss_pde:1.60193253, loss_ib:0.36340955
# epoch 11 loss_pde:1.59066820, loss_ib:0.36090189
# epoch 11 loss_pde:1.57685781, loss_ib:0.35971728
# epoch 11 loss_pde:1.56991506, loss_ib:0.35589403
# epoch 11 loss_pde:1.55485177, loss_ib:0.35410476
# epoch 11 loss_pde:1.55327702, loss_ib:0.35127351
# epoch 11 loss_pde:1.53534508, loss_ib:0.35080633
# epoch 11 loss_pde:1.51503456, loss_ib:0.35041124
# epoch 11 loss_pde:1.50614691, loss_ib:0.34950384
# epoch 11 loss_pde:1.49093294, loss_ib:0.34824786
# epoch 11 loss_pde:1.55635667, loss_ib:0.36109728
# epoch 11 loss_pde:1.48609424, loss_ib:0.34373325
# epoch 11 loss_pde:1.47885859, loss_ib:0.34277350
# epoch 11 loss_pde:1.46906793, loss_ib:0.34062532
# epoch 11 loss_pde:1.45790982, loss_ib:0.33962128
# epoch 11 loss_pde:1.50236773, loss_ib:0.33757639
# epoch 11 loss_pde:1.43718529, loss_ib:0.33553413
# epoch 11 loss_pde:1.41762495, loss_ib:0.33555603
# epoch 11 loss_pde:1.39790893, loss_ib:0.33529457
# epoch 11 loss_pde:1.39152396, loss_ib:0.33304039
# epoch 11: loss 5.236028
# epoch 12 loss_pde:1.37750483, loss_ib:0.33234125
# epoch 12 loss_pde:1.36648297, loss_ib:0.33211878
# epoch 12 loss_pde:1.35414505, loss_ib:0.33098939
# epoch 12 loss_pde:1.33742595, loss_ib:0.33017775
# epoch 12 loss_pde:1.31918514, loss_ib:0.32903144
# epoch 12 loss_pde:1.30156434, loss_ib:0.32824463
# epoch 12 loss_pde:1.29778826, loss_ib:0.32651889
# epoch 12 loss_pde:1.29929662, loss_ib:0.32370371
# epoch 12 loss_pde:1.29194331, loss_ib:0.32029569
# epoch 12 loss_pde:1.31293535, loss_ib:0.31420067
# epoch 12 loss_pde:1.28516245, loss_ib:0.31143579
# epoch 12 loss_pde:1.26625657, loss_ib:0.30858651
# epoch 12 loss_pde:1.24832690, loss_ib:0.30670241
# epoch 12 loss_pde:1.24340701, loss_ib:0.30518344
# epoch 12 loss_pde:1.24415278, loss_ib:0.30305976
# epoch 12 loss_pde:1.23468041, loss_ib:0.30005506
# epoch 12 loss_pde:1.22134578, loss_ib:0.29798421
# epoch 12 loss_pde:1.21306324, loss_ib:0.29556867
# epoch 12 loss_pde:1.20648050, loss_ib:0.29320893
# epoch 12 loss_pde:1.21183765, loss_ib:0.29012209
# epoch 12: loss 4.700917
# epoch 13 loss_pde:1.20232153, loss_ib:0.28940058
# epoch 13 loss_pde:1.20206404, loss_ib:0.28813320
# epoch 13 loss_pde:1.20030344, loss_ib:0.28685948
# epoch 13 loss_pde:1.18790925, loss_ib:0.28382251
# epoch 13 loss_pde:1.17631173, loss_ib:0.28095409
# epoch 13 loss_pde:1.15635586, loss_ib:0.27928254
# epoch 13 loss_pde:1.26313162, loss_ib:0.28159332
# epoch 13 loss_pde:1.13511741, loss_ib:0.27657029
# epoch 13 loss_pde:1.12441015, loss_ib:0.27638048
# epoch 13 loss_pde:1.10449195, loss_ib:0.27595904
# epoch 13 loss_pde:1.09700966, loss_ib:0.27440181
# epoch 13 loss_pde:1.09278250, loss_ib:0.27178535
# epoch 13 loss_pde:1.10175931, loss_ib:0.26775989
# epoch 13 loss_pde:1.10881495, loss_ib:0.26427895
# epoch 13 loss_pde:1.10828400, loss_ib:0.26252171
# epoch 13 loss_pde:1.12038946, loss_ib:0.25957292
# epoch 13 loss_pde:1.10069847, loss_ib:0.26327443
# epoch 13 loss_pde:1.09067941, loss_ib:0.26000506
# epoch 13 loss_pde:1.09338284, loss_ib:0.25875202
# epoch 13 loss_pde:1.09415126, loss_ib:0.25680545
# epoch 13: loss 4.096327
# epoch 14 loss_pde:1.09014547, loss_ib:0.25458646
# epoch 14 loss_pde:1.10596061, loss_ib:0.25273320
# epoch 14 loss_pde:1.10841274, loss_ib:0.24796072
# epoch 14 loss_pde:1.06685269, loss_ib:0.24740621
# epoch 14 loss_pde:1.05714154, loss_ib:0.24676171
# epoch 14 loss_pde:1.04547548, loss_ib:0.24572141
# epoch 14 loss_pde:1.05101180, loss_ib:0.24448712
# epoch 14 loss_pde:1.04853666, loss_ib:0.24189441
# epoch 14 loss_pde:1.03170586, loss_ib:0.24133478
# epoch 14 loss_pde:1.02729547, loss_ib:0.24013485
# epoch 14 loss_pde:1.02428794, loss_ib:0.23862119
# epoch 14 loss_pde:1.01916254, loss_ib:0.23728335
# epoch 14 loss_pde:1.00276899, loss_ib:0.23558454
# epoch 14 loss_pde:1.04293501, loss_ib:0.23986638
# epoch 14 loss_pde:0.98189086, loss_ib:0.23327802
# epoch 14 loss_pde:0.96753991, loss_ib:0.23317771
# epoch 14 loss_pde:0.95970500, loss_ib:0.23260310
# epoch 14 loss_pde:0.94330204, loss_ib:0.23160629
# epoch 14 loss_pde:0.94466150, loss_ib:0.23178038
# epoch 14 loss_pde:0.93358445, loss_ib:0.22954543
# epoch 14: loss 3.636010
# epoch 15 loss_pde:0.92746544, loss_ib:0.22889949
# epoch 15 loss_pde:0.91891479, loss_ib:0.22734129
# epoch 15 loss_pde:0.91396248, loss_ib:0.22623804
# epoch 15 loss_pde:0.90895259, loss_ib:0.22488067
# epoch 15 loss_pde:0.90188360, loss_ib:0.22309975
# epoch 15 loss_pde:0.92004663, loss_ib:0.22621085
# epoch 15 loss_pde:0.89024305, loss_ib:0.22134535
# epoch 15 loss_pde:0.89156872, loss_ib:0.22046222
# epoch 15 loss_pde:0.87286234, loss_ib:0.22108598
# epoch 15 loss_pde:0.87294197, loss_ib:0.21902277
# epoch 15 loss_pde:0.86763191, loss_ib:0.21729343
# epoch 15 loss_pde:0.85233438, loss_ib:0.21588652
# epoch 15 loss_pde:0.83887333, loss_ib:0.21551701
# epoch 15 loss_pde:0.83499491, loss_ib:0.21495238
# epoch 15 loss_pde:0.82330108, loss_ib:0.21449390
# epoch 15 loss_pde:0.81902927, loss_ib:0.21347679
# epoch 15 loss_pde:0.82814741, loss_ib:0.21308121
# epoch 15 loss_pde:0.81718481, loss_ib:0.21149336
# epoch 15 loss_pde:0.80781746, loss_ib:0.21161900
# epoch 15 loss_pde:0.80770165, loss_ib:0.21102391
# epoch 15: loss 3.216460
# epoch 16 loss_pde:0.80603802, loss_ib:0.20922321
# epoch 16 loss_pde:0.80020475, loss_ib:0.20845622
# epoch 16 loss_pde:0.91056150, loss_ib:0.21787858
# epoch 16 loss_pde:0.78807282, loss_ib:0.20718183
# epoch 16 loss_pde:0.78873920, loss_ib:0.20779249
# epoch 16 loss_pde:0.78044450, loss_ib:0.20693618
# epoch 16 loss_pde:0.77958739, loss_ib:0.20647660
# epoch 16 loss_pde:0.77398741, loss_ib:0.20593381
# epoch 16 loss_pde:0.76668215, loss_ib:0.20513879
# epoch 16 loss_pde:0.75098455, loss_ib:0.20567116
# epoch 16 loss_pde:0.75816393, loss_ib:0.20387021
# epoch 16 loss_pde:0.74719691, loss_ib:0.20299295
# epoch 16 loss_pde:0.74258626, loss_ib:0.20247214
# epoch 16 loss_pde:0.73739004, loss_ib:0.20181990
# epoch 16 loss_pde:0.74329877, loss_ib:0.20261943
# epoch 16 loss_pde:0.73502922, loss_ib:0.20011276
# epoch 16 loss_pde:0.73057806, loss_ib:0.19967988
# epoch 16 loss_pde:0.72242230, loss_ib:0.19880775
# epoch 16 loss_pde:0.71921551, loss_ib:0.19783691
# epoch 16 loss_pde:0.71202856, loss_ib:0.19728813
# epoch 16: loss 2.898270
# epoch 17 loss_pde:0.71725672, loss_ib:0.19573356
# epoch 17 loss_pde:0.71725845, loss_ib:0.19449675
# epoch 17 loss_pde:0.71135294, loss_ib:0.19390310
# epoch 17 loss_pde:0.70421922, loss_ib:0.19338730
# epoch 17 loss_pde:0.70073873, loss_ib:0.19265448
# epoch 17 loss_pde:0.70418739, loss_ib:0.19130851
# epoch 17 loss_pde:0.69292843, loss_ib:0.19131374
# epoch 17 loss_pde:0.68859226, loss_ib:0.19086835
# epoch 17 loss_pde:0.68467921, loss_ib:0.19049722
# epoch 17 loss_pde:0.68074125, loss_ib:0.19007960
# epoch 17 loss_pde:0.67857116, loss_ib:0.18923149
# epoch 17 loss_pde:0.67647004, loss_ib:0.18793318
# epoch 17 loss_pde:0.67282808, loss_ib:0.18549152
# epoch 17 loss_pde:0.67769384, loss_ib:0.18340544
# epoch 17 loss_pde:0.67238569, loss_ib:0.18155727
# epoch 17 loss_pde:0.66586185, loss_ib:0.18092793
# epoch 17 loss_pde:0.67203438, loss_ib:0.17916973
# epoch 17 loss_pde:0.67225432, loss_ib:0.17834447
# epoch 17 loss_pde:0.67882049, loss_ib:0.17650963
# epoch 17 loss_pde:0.68036842, loss_ib:0.17494197
# epoch 17: loss 2.674592
# epoch 18 loss_pde:0.68426585, loss_ib:0.17317113
# epoch 18 loss_pde:0.68907988, loss_ib:0.17205343
# epoch 18 loss_pde:0.69131970, loss_ib:0.17065893
# epoch 18 loss_pde:0.68814623, loss_ib:0.16976234
# epoch 18 loss_pde:0.68227232, loss_ib:0.16860378
# epoch 18 loss_pde:0.68877876, loss_ib:0.16659828
# epoch 18 loss_pde:0.69311088, loss_ib:0.16481544
# epoch 18 loss_pde:0.70280844, loss_ib:0.16275129
# epoch 18 loss_pde:0.70687413, loss_ib:0.16112602
# epoch 18 loss_pde:0.71249235, loss_ib:0.15952839
# epoch 18 loss_pde:0.70802557, loss_ib:0.15882604
# epoch 18 loss_pde:0.70499760, loss_ib:0.15750667
# epoch 18 loss_pde:0.70339298, loss_ib:0.15634668
# epoch 18 loss_pde:0.70827878, loss_ib:0.15585269
# epoch 18 loss_pde:0.69928777, loss_ib:0.15490642
# epoch 18 loss_pde:0.69793683, loss_ib:0.15452334
# epoch 18 loss_pde:0.69447631, loss_ib:0.15403351
# epoch 18 loss_pde:0.69490784, loss_ib:0.15273802
# epoch 18 loss_pde:0.69690239, loss_ib:0.15110627
# epoch 18 loss_pde:0.69766939, loss_ib:0.15025547
# epoch 18: loss 2.415977
# epoch 19 loss_pde:0.69540751, loss_ib:0.14832497
# epoch 19 loss_pde:0.69275308, loss_ib:0.14742978
# epoch 19 loss_pde:0.69619179, loss_ib:0.14595164
# epoch 19 loss_pde:0.69802427, loss_ib:0.14424062
# epoch 19 loss_pde:0.71109301, loss_ib:0.14142647
# epoch 19 loss_pde:0.70800632, loss_ib:0.14072269
# epoch 19 loss_pde:0.70763999, loss_ib:0.13993196
# epoch 19 loss_pde:0.70456868, loss_ib:0.13877058
# epoch 19 loss_pde:0.71109533, loss_ib:0.13678025
# epoch 19 loss_pde:0.70844424, loss_ib:0.13594146
# epoch 19 loss_pde:0.70330095, loss_ib:0.13542479
# epoch 19 loss_pde:0.70169878, loss_ib:0.13452241
# epoch 19 loss_pde:0.70398837, loss_ib:0.13293114
# epoch 19 loss_pde:0.70391428, loss_ib:0.13206752
# epoch 19 loss_pde:0.70179015, loss_ib:0.13142018
# epoch 19 loss_pde:0.69998336, loss_ib:0.13054663
# epoch 19 loss_pde:0.69791770, loss_ib:0.12966381
# epoch 19 loss_pde:0.69927335, loss_ib:0.12878400
# epoch 19 loss_pde:0.70105451, loss_ib:0.12758315
# epoch 19 loss_pde:0.70061117, loss_ib:0.12694150
# epoch 19: loss 2.178657
# epoch 20 loss_pde:0.70118999, loss_ib:0.12608646
# epoch 20 loss_pde:0.69203752, loss_ib:0.12598996
# epoch 20 loss_pde:0.68931437, loss_ib:0.12529357
# epoch 20 loss_pde:0.67615330, loss_ib:0.12576891
# epoch 20 loss_pde:0.66894019, loss_ib:0.12560266
# epoch 20 loss_pde:0.66446346, loss_ib:0.12521842
# epoch 20 loss_pde:0.66168082, loss_ib:0.12412550
# epoch 20 loss_pde:0.66143072, loss_ib:0.12321611
# epoch 20 loss_pde:0.66326070, loss_ib:0.12192687
# epoch 20 loss_pde:0.65886456, loss_ib:0.12133718
# epoch 20 loss_pde:0.65686083, loss_ib:0.12056226
# epoch 20 loss_pde:0.65363514, loss_ib:0.11980898
# epoch 20 loss_pde:0.65431964, loss_ib:0.11891635
# epoch 20 loss_pde:0.64889765, loss_ib:0.11835407
# epoch 20 loss_pde:0.64464891, loss_ib:0.11802462
# epoch 20 loss_pde:0.64181811, loss_ib:0.11742694
# epoch 20 loss_pde:0.63926750, loss_ib:0.11700805
# epoch 20 loss_pde:0.63891906, loss_ib:0.11605208
# epoch 20 loss_pde:0.63973194, loss_ib:0.11510837
# epoch 20 loss_pde:0.64338380, loss_ib:0.11398161
# epoch 20: loss 1.962055
# epoch 21 loss_pde:0.64565212, loss_ib:0.11287969
# epoch 21 loss_pde:0.64457339, loss_ib:0.11218425
# epoch 21 loss_pde:0.64233977, loss_ib:0.11162466
# epoch 21 loss_pde:0.64343756, loss_ib:0.11073340
# epoch 21 loss_pde:0.63940471, loss_ib:0.11017688
# epoch 21 loss_pde:0.63783669, loss_ib:0.10925055
# epoch 21 loss_pde:0.63494653, loss_ib:0.10882194
# epoch 21 loss_pde:0.63143802, loss_ib:0.10863189
# epoch 21 loss_pde:0.62684286, loss_ib:0.10824772
# epoch 21 loss_pde:0.62275338, loss_ib:0.10800196
# epoch 21 loss_pde:0.62214756, loss_ib:0.10701573
# epoch 21 loss_pde:0.62046313, loss_ib:0.10639329
# epoch 21 loss_pde:0.61906606, loss_ib:0.10592662
# epoch 21 loss_pde:0.62588239, loss_ib:0.10471636
# epoch 21 loss_pde:0.62204850, loss_ib:0.10435159
# epoch 21 loss_pde:0.61975068, loss_ib:0.10392826
# epoch 21 loss_pde:0.62042022, loss_ib:0.10315253
# epoch 21 loss_pde:0.62030655, loss_ib:0.10262216
# epoch 21 loss_pde:0.62348199, loss_ib:0.10126163
# epoch 21 loss_pde:0.62175542, loss_ib:0.10041542
# epoch 21: loss 1.774449
# epoch 22 loss_pde:0.61976129, loss_ib:0.09946750
# epoch 22 loss_pde:0.61762196, loss_ib:0.09874605
# epoch 22 loss_pde:0.61734265, loss_ib:0.09808213
# epoch 22 loss_pde:0.61785936, loss_ib:0.09744325
# epoch 22 loss_pde:0.61628348, loss_ib:0.09699149
# epoch 22 loss_pde:0.60996372, loss_ib:0.09698267
# epoch 22 loss_pde:0.60712868, loss_ib:0.09662481
# epoch 22 loss_pde:0.60323209, loss_ib:0.09623087
# epoch 22 loss_pde:0.60842282, loss_ib:0.09512962
# epoch 22 loss_pde:0.60549426, loss_ib:0.09458859
# epoch 22 loss_pde:0.60693341, loss_ib:0.09374482
# epoch 22 loss_pde:0.60999238, loss_ib:0.09284879
# epoch 22 loss_pde:0.61526960, loss_ib:0.09176461
# epoch 22 loss_pde:0.61645961, loss_ib:0.09102856
# epoch 22 loss_pde:0.61701238, loss_ib:0.09031145
# epoch 22 loss_pde:0.61669797, loss_ib:0.08964756
# epoch 22 loss_pde:0.61442155, loss_ib:0.08901334
# epoch 22 loss_pde:0.61517119, loss_ib:0.08858546
# epoch 22 loss_pde:0.61072111, loss_ib:0.08826703
# epoch 22 loss_pde:0.60891688, loss_ib:0.08804892
# epoch 22: loss 1.614436
# epoch 23 loss_pde:0.60893911, loss_ib:0.08765373
# epoch 23 loss_pde:0.60720140, loss_ib:0.08732682
# epoch 23 loss_pde:0.60610741, loss_ib:0.08675776
# epoch 23 loss_pde:0.60324192, loss_ib:0.08620019
# epoch 23 loss_pde:0.60021275, loss_ib:0.08615636
# epoch 23 loss_pde:0.59897536, loss_ib:0.08584474
# epoch 23 loss_pde:0.59707516, loss_ib:0.08563165
# epoch 23 loss_pde:0.59404308, loss_ib:0.08539913
# epoch 23 loss_pde:0.59399092, loss_ib:0.08479732
# epoch 23 loss_pde:0.58700997, loss_ib:0.08487392
# epoch 23 loss_pde:0.58517325, loss_ib:0.08458598
# epoch 23 loss_pde:0.58070880, loss_ib:0.08432793
# epoch 23 loss_pde:0.57611775, loss_ib:0.08423387
# epoch 23 loss_pde:0.56875163, loss_ib:0.08414957
# epoch 23 loss_pde:0.56701630, loss_ib:0.08383781
# epoch 23 loss_pde:0.56599081, loss_ib:0.08353821
# epoch 23 loss_pde:0.56689405, loss_ib:0.08314970
# epoch 23 loss_pde:0.56790102, loss_ib:0.08267679
# epoch 23 loss_pde:0.57089186, loss_ib:0.08180690
# epoch 23 loss_pde:0.57062018, loss_ib:0.08122762
# epoch 23: loss 1.485476
# epoch 24 loss_pde:0.57274759, loss_ib:0.08043848
# epoch 24 loss_pde:0.56930584, loss_ib:0.08029315
# epoch 24 loss_pde:0.56504107, loss_ib:0.08024557
# epoch 24 loss_pde:0.56111681, loss_ib:0.08011995
# epoch 24 loss_pde:0.55936784, loss_ib:0.07984553
# epoch 24 loss_pde:0.56017137, loss_ib:0.07916891
# epoch 24 loss_pde:0.56213951, loss_ib:0.07842240
# epoch 24 loss_pde:0.56361055, loss_ib:0.07790422
# epoch 24 loss_pde:0.56655717, loss_ib:0.07721157
# epoch 24 loss_pde:0.56662774, loss_ib:0.07676521
# epoch 24 loss_pde:0.56715763, loss_ib:0.07623617
# epoch 24 loss_pde:0.56862152, loss_ib:0.07564230
# epoch 24 loss_pde:0.56566584, loss_ib:0.07549139
# epoch 24 loss_pde:0.56323707, loss_ib:0.07537925
# epoch 24 loss_pde:0.56229317, loss_ib:0.07509741
# epoch 24 loss_pde:0.56251770, loss_ib:0.07474024
# epoch 24 loss_pde:0.56315511, loss_ib:0.07431870
# epoch 24 loss_pde:0.56231409, loss_ib:0.07388657
# epoch 24 loss_pde:0.56334466, loss_ib:0.07330465
# epoch 24 loss_pde:0.56336582, loss_ib:0.07284828
# epoch 24: loss 1.377132
# epoch 25 loss_pde:0.56196350, loss_ib:0.07252609
# epoch 25 loss_pde:0.56307793, loss_ib:0.07200087
# epoch 25 loss_pde:0.56316507, loss_ib:0.07154530
# epoch 25 loss_pde:0.56305051, loss_ib:0.07108628
# epoch 25 loss_pde:0.56575179, loss_ib:0.07043627
# epoch 25 loss_pde:0.56237644, loss_ib:0.07042351
# epoch 25 loss_pde:0.56210423, loss_ib:0.07000772
# epoch 25 loss_pde:0.56039739, loss_ib:0.06974479
# epoch 25 loss_pde:0.56184214, loss_ib:0.06922757
# epoch 25 loss_pde:0.56235868, loss_ib:0.06884955
# epoch 25 loss_pde:0.56288362, loss_ib:0.06842023
# epoch 25 loss_pde:0.56169903, loss_ib:0.06805925
# epoch 25 loss_pde:0.56447333, loss_ib:0.06729632
# epoch 25 loss_pde:0.56227046, loss_ib:0.06712668
# epoch 25 loss_pde:0.56302989, loss_ib:0.06654483
# epoch 25 loss_pde:0.56323808, loss_ib:0.06618750
# epoch 25 loss_pde:0.56526285, loss_ib:0.06565870
# epoch 25 loss_pde:0.56816441, loss_ib:0.06493955
# epoch 25 loss_pde:0.57079351, loss_ib:0.06424446
# epoch 25 loss_pde:0.57012874, loss_ib:0.06392643
# epoch 25: loss 1.287224
# epoch 26 loss_pde:0.56810480, loss_ib:0.06368701
# epoch 26 loss_pde:0.56705773, loss_ib:0.06346221
# epoch 26 loss_pde:0.56674415, loss_ib:0.06315091
# epoch 26 loss_pde:0.56694657, loss_ib:0.06274374
# epoch 26 loss_pde:0.56794548, loss_ib:0.06232595
# epoch 26 loss_pde:0.56942385, loss_ib:0.06192386
# epoch 26 loss_pde:0.56906587, loss_ib:0.06142209
# epoch 26 loss_pde:0.56683958, loss_ib:0.06136132
# epoch 26 loss_pde:0.56496042, loss_ib:0.06106664
# epoch 26 loss_pde:0.56232238, loss_ib:0.06091017
# epoch 26 loss_pde:0.56191337, loss_ib:0.06056730
# epoch 26 loss_pde:0.56291991, loss_ib:0.06014403
# epoch 26 loss_pde:0.56121564, loss_ib:0.06001695
# epoch 26 loss_pde:0.56091315, loss_ib:0.05962602
# epoch 26 loss_pde:0.55680937, loss_ib:0.05963548
# epoch 26 loss_pde:0.55492169, loss_ib:0.05953884
# epoch 26 loss_pde:0.55495077, loss_ib:0.05932488
# epoch 26 loss_pde:0.55435944, loss_ib:0.05907252
# epoch 26 loss_pde:0.55448300, loss_ib:0.05877733
# epoch 26 loss_pde:0.55587959, loss_ib:0.05831283
# epoch 26: loss 1.204975
# epoch 27 loss_pde:0.55530494, loss_ib:0.05793925
# epoch 27 loss_pde:0.55518776, loss_ib:0.05749915
# epoch 27 loss_pde:0.55278331, loss_ib:0.05744207
# epoch 27 loss_pde:0.55174226, loss_ib:0.05720421
# epoch 27 loss_pde:0.54877156, loss_ib:0.05710549
# epoch 27 loss_pde:0.54626650, loss_ib:0.05698930
# epoch 27 loss_pde:0.54322940, loss_ib:0.05691480
# epoch 27 loss_pde:0.54081243, loss_ib:0.05670659
# epoch 27 loss_pde:0.53836328, loss_ib:0.05655482
# epoch 27 loss_pde:0.53537190, loss_ib:0.05655785
# epoch 27 loss_pde:0.53742689, loss_ib:0.05608196
# epoch 27 loss_pde:0.53768146, loss_ib:0.05575743
# epoch 27 loss_pde:0.53704077, loss_ib:0.05550188
# epoch 27 loss_pde:0.53880274, loss_ib:0.05499720
# epoch 27 loss_pde:0.53876024, loss_ib:0.05469816
# epoch 27 loss_pde:0.53981107, loss_ib:0.05425172
# epoch 27 loss_pde:0.53940600, loss_ib:0.05392000
# epoch 27 loss_pde:0.53837883, loss_ib:0.05371626
# epoch 27 loss_pde:0.53664982, loss_ib:0.05363697
# epoch 27 loss_pde:0.53525543, loss_ib:0.05346044
# epoch 27: loss 1.134697
# epoch 28 loss_pde:0.53367114, loss_ib:0.05327000
# epoch 28 loss_pde:0.53259200, loss_ib:0.05304119
# epoch 28 loss_pde:0.53268218, loss_ib:0.05271512
# epoch 28 loss_pde:0.53163183, loss_ib:0.05251452
# epoch 28 loss_pde:0.53098464, loss_ib:0.05230814
# epoch 28 loss_pde:0.53093201, loss_ib:0.05202632
# epoch 28 loss_pde:0.53175211, loss_ib:0.05146777
# epoch 28 loss_pde:0.53428459, loss_ib:0.05077670
# epoch 28 loss_pde:0.53404635, loss_ib:0.05049003
# epoch 28 loss_pde:0.53201801, loss_ib:0.05043874
# epoch 28 loss_pde:0.53171837, loss_ib:0.05028069
# epoch 28 loss_pde:0.52822757, loss_ib:0.05035718
# epoch 28 loss_pde:0.52646935, loss_ib:0.05022805
# epoch 28 loss_pde:0.52297002, loss_ib:0.05025198
# epoch 28 loss_pde:0.52192020, loss_ib:0.05006975
# epoch 28 loss_pde:0.51997507, loss_ib:0.04994498
# epoch 28 loss_pde:0.51908517, loss_ib:0.04980777
# epoch 28 loss_pde:0.51798868, loss_ib:0.04967039
# epoch 28 loss_pde:0.51808697, loss_ib:0.04938789
# epoch 28 loss_pde:0.52048182, loss_ib:0.04891359
# epoch 28: loss 1.066371
# epoch 29 loss_pde:0.52081287, loss_ib:0.04862860
# epoch 29 loss_pde:0.52096045, loss_ib:0.04838737
# epoch 29 loss_pde:0.52091950, loss_ib:0.04806982
# epoch 29 loss_pde:0.51959682, loss_ib:0.04781516
# epoch 29 loss_pde:0.52117121, loss_ib:0.04741283
# epoch 29 loss_pde:0.51836437, loss_ib:0.04740805
# epoch 29 loss_pde:0.51658493, loss_ib:0.04744570
# epoch 29 loss_pde:0.51581144, loss_ib:0.04735519
# epoch 29 loss_pde:0.51385838, loss_ib:0.04723508
# epoch 29 loss_pde:0.51127386, loss_ib:0.04701463
# epoch 29 loss_pde:0.50738943, loss_ib:0.04699046
# epoch 29 loss_pde:0.50630015, loss_ib:0.04687678
# epoch 29 loss_pde:0.50557911, loss_ib:0.04676615
# epoch 29 loss_pde:0.50492281, loss_ib:0.04663061
# epoch 29 loss_pde:0.50477129, loss_ib:0.04639561
# epoch 29 loss_pde:0.50528187, loss_ib:0.04604400
# epoch 29 loss_pde:0.50623584, loss_ib:0.04570784
# epoch 29 loss_pde:0.50649887, loss_ib:0.04544881
# epoch 29 loss_pde:0.50678003, loss_ib:0.04515481
# epoch 29 loss_pde:0.50444746, loss_ib:0.04517525
# epoch 29: loss 1.007099
# epoch 30 loss_pde:0.50294578, loss_ib:0.04502641
# epoch 30 loss_pde:0.50109899, loss_ib:0.04494439
# epoch 30 loss_pde:0.49943936, loss_ib:0.04492025
# epoch 30 loss_pde:0.49885488, loss_ib:0.04470423
# epoch 30 loss_pde:0.49962255, loss_ib:0.04445070
# epoch 30 loss_pde:0.49913967, loss_ib:0.04429872
# epoch 30 loss_pde:0.49921241, loss_ib:0.04418454
# epoch 30 loss_pde:0.49868244, loss_ib:0.04403871
# epoch 30 loss_pde:0.49765867, loss_ib:0.04392187
# epoch 30 loss_pde:0.49536341, loss_ib:0.04390340
# epoch 30 loss_pde:0.49346453, loss_ib:0.04391781
# epoch 30 loss_pde:0.49219769, loss_ib:0.04386290
# epoch 30 loss_pde:0.49220702, loss_ib:0.04365274
# epoch 30 loss_pde:0.49492481, loss_ib:0.04306525
# epoch 30 loss_pde:0.49628451, loss_ib:0.04269212
# epoch 30 loss_pde:0.49752569, loss_ib:0.04238530
# epoch 30 loss_pde:0.49800149, loss_ib:0.04215686
# epoch 30 loss_pde:0.49745271, loss_ib:0.04201414
# epoch 30 loss_pde:0.49617895, loss_ib:0.04191714
# epoch 30 loss_pde:0.49500537, loss_ib:0.04176074
# epoch 30: loss 0.953210
# epoch 31 loss_pde:0.49353373, loss_ib:0.04165578
# epoch 31 loss_pde:0.49230814, loss_ib:0.04159336
# epoch 31 loss_pde:0.49212626, loss_ib:0.04147355
# epoch 31 loss_pde:0.49142489, loss_ib:0.04137562
# epoch 31 loss_pde:0.49066705, loss_ib:0.04117490
# epoch 31 loss_pde:0.48941818, loss_ib:0.04108698
# epoch 31 loss_pde:0.48853651, loss_ib:0.04098948
# epoch 31 loss_pde:0.48796627, loss_ib:0.04091009
# epoch 31 loss_pde:0.48773760, loss_ib:0.04074494
# epoch 31 loss_pde:0.48949718, loss_ib:0.04033731
# epoch 31 loss_pde:0.49021012, loss_ib:0.04007275
# epoch 31 loss_pde:0.49112299, loss_ib:0.03977501
# epoch 31 loss_pde:0.49330404, loss_ib:0.03928592
# epoch 31 loss_pde:0.49298206, loss_ib:0.03908698
# epoch 31 loss_pde:0.49165660, loss_ib:0.03903985
# epoch 31 loss_pde:0.49106598, loss_ib:0.03888837
# epoch 31 loss_pde:0.49115217, loss_ib:0.03867808
# epoch 31 loss_pde:0.49203426, loss_ib:0.03837344
# epoch 31 loss_pde:0.49380869, loss_ib:0.03794516
# epoch 31 loss_pde:0.49493733, loss_ib:0.03764649
# epoch 31: loss 0.910092
# epoch 32 loss_pde:0.49599087, loss_ib:0.03740531
# epoch 32 loss_pde:0.49346381, loss_ib:0.03750904
# epoch 32 loss_pde:0.49315432, loss_ib:0.03741459
# epoch 32 loss_pde:0.49198228, loss_ib:0.03734707
# epoch 32 loss_pde:0.49192169, loss_ib:0.03711573
# epoch 32 loss_pde:0.49039295, loss_ib:0.03705214
# epoch 32 loss_pde:0.48976505, loss_ib:0.03693111
# epoch 32 loss_pde:0.48865700, loss_ib:0.03680754
# epoch 32 loss_pde:0.48674536, loss_ib:0.03676465
# epoch 32 loss_pde:0.48418605, loss_ib:0.03677443
# epoch 32 loss_pde:0.48240224, loss_ib:0.03672882
# epoch 32 loss_pde:0.47973505, loss_ib:0.03683208
# epoch 32 loss_pde:0.47913820, loss_ib:0.03675218
# epoch 32 loss_pde:0.47891143, loss_ib:0.03660753
# epoch 32 loss_pde:0.47868967, loss_ib:0.03644385
# epoch 32 loss_pde:0.47845861, loss_ib:0.03627566
# epoch 32 loss_pde:0.47816882, loss_ib:0.03615175
# epoch 32 loss_pde:0.47785440, loss_ib:0.03605018
# epoch 32 loss_pde:0.47708362, loss_ib:0.03598151
# epoch 32 loss_pde:0.47643507, loss_ib:0.03585336
# epoch 32: loss 0.870044
# epoch 33 loss_pde:0.47582486, loss_ib:0.03573539
# epoch 33 loss_pde:0.47581881, loss_ib:0.03559244
# epoch 33 loss_pde:0.47535035, loss_ib:0.03544918
# epoch 33 loss_pde:0.47463119, loss_ib:0.03530236
# epoch 33 loss_pde:0.47389090, loss_ib:0.03512457
# epoch 33 loss_pde:0.47353429, loss_ib:0.03497843
# epoch 33 loss_pde:0.47198552, loss_ib:0.03498642
# epoch 33 loss_pde:0.47143996, loss_ib:0.03490950
# epoch 33 loss_pde:0.47045860, loss_ib:0.03483945
# epoch 33 loss_pde:0.47044557, loss_ib:0.03459907
# epoch 33 loss_pde:0.46940815, loss_ib:0.03448292
# epoch 33 loss_pde:0.47007003, loss_ib:0.03421019
# epoch 33 loss_pde:0.46943361, loss_ib:0.03409670
# epoch 33 loss_pde:0.47104484, loss_ib:0.03379855
# epoch 33 loss_pde:0.47028992, loss_ib:0.03375736
# epoch 33 loss_pde:0.47063318, loss_ib:0.03356883
# epoch 33 loss_pde:0.47021717, loss_ib:0.03343744
# epoch 33 loss_pde:0.47093982, loss_ib:0.03314659
# epoch 33 loss_pde:0.47134459, loss_ib:0.03290968
# epoch 33 loss_pde:0.47154313, loss_ib:0.03270236
# epoch 33: loss 0.833179
# epoch 34 loss_pde:0.47202832, loss_ib:0.03248002
# epoch 34 loss_pde:0.47057077, loss_ib:0.03244201
# epoch 34 loss_pde:0.46874985, loss_ib:0.03241693
# epoch 34 loss_pde:0.46713078, loss_ib:0.03243054
# epoch 34 loss_pde:0.46575111, loss_ib:0.03240403
# epoch 34 loss_pde:0.46449512, loss_ib:0.03231497
# epoch 34 loss_pde:0.46397439, loss_ib:0.03216200
# epoch 34 loss_pde:0.46352848, loss_ib:0.03204500
# epoch 34 loss_pde:0.46379983, loss_ib:0.03186065
# epoch 34 loss_pde:0.46287918, loss_ib:0.03178663
# epoch 34 loss_pde:0.46275562, loss_ib:0.03163571
# epoch 34 loss_pde:0.46253335, loss_ib:0.03148407
# epoch 34 loss_pde:0.46159661, loss_ib:0.03140646
# epoch 34 loss_pde:0.46187440, loss_ib:0.03121425
# epoch 34 loss_pde:0.46145597, loss_ib:0.03111579
# epoch 34 loss_pde:0.46050671, loss_ib:0.03108206
# epoch 34 loss_pde:0.45974302, loss_ib:0.03103174
# epoch 34 loss_pde:0.45808506, loss_ib:0.03105829
# epoch 34 loss_pde:0.45658153, loss_ib:0.03105915
# epoch 34 loss_pde:0.45610878, loss_ib:0.03096847
# epoch 34: loss 0.796829
# epoch 35 loss_pde:0.45593178, loss_ib:0.03085298
# epoch 35 loss_pde:0.45593438, loss_ib:0.03070555
# epoch 35 loss_pde:0.45665678, loss_ib:0.03044130
# epoch 35 loss_pde:0.45592618, loss_ib:0.03031155
# epoch 35 loss_pde:0.45505041, loss_ib:0.03026706
# epoch 35 loss_pde:0.45431948, loss_ib:0.03025157
# epoch 35 loss_pde:0.45315301, loss_ib:0.03025905
# epoch 35 loss_pde:0.45282039, loss_ib:0.03014139
# epoch 35 loss_pde:0.45141873, loss_ib:0.03018873
# epoch 35 loss_pde:0.45183298, loss_ib:0.03004871
# epoch 35 loss_pde:0.45227996, loss_ib:0.02985158
# epoch 35 loss_pde:0.45245212, loss_ib:0.02965850
# epoch 35 loss_pde:0.45204213, loss_ib:0.02950838
# epoch 35 loss_pde:0.45116907, loss_ib:0.02943695
# epoch 35 loss_pde:0.45020831, loss_ib:0.02938673
# epoch 35 loss_pde:0.44927412, loss_ib:0.02934255
# epoch 35 loss_pde:0.44868487, loss_ib:0.02923403
# epoch 35 loss_pde:0.44839537, loss_ib:0.02912385
# epoch 35 loss_pde:0.44827899, loss_ib:0.02903193
# epoch 35 loss_pde:0.44768107, loss_ib:0.02897952
# epoch 35: loss 0.764462
# epoch 36 loss_pde:0.44597539, loss_ib:0.02897917
# epoch 36 loss_pde:0.44375822, loss_ib:0.02900589
# epoch 36 loss_pde:0.44179711, loss_ib:0.02905402
# epoch 36 loss_pde:0.44087011, loss_ib:0.02902977
# epoch 36 loss_pde:0.44021913, loss_ib:0.02896522
# epoch 36 loss_pde:0.43914381, loss_ib:0.02887606
# epoch 36 loss_pde:0.43819472, loss_ib:0.02881435
# epoch 36 loss_pde:0.43728286, loss_ib:0.02876938
# epoch 36 loss_pde:0.43698165, loss_ib:0.02869286
# epoch 36 loss_pde:0.43573785, loss_ib:0.02872261
# epoch 36 loss_pde:0.43485892, loss_ib:0.02867174
# epoch 36 loss_pde:0.43303514, loss_ib:0.02869451
# epoch 36 loss_pde:0.43195522, loss_ib:0.02863304
# epoch 36 loss_pde:0.43282419, loss_ib:0.02841533
# epoch 36 loss_pde:0.43229896, loss_ib:0.02836716
# epoch 36 loss_pde:0.43227437, loss_ib:0.02829812
# epoch 36 loss_pde:0.43208253, loss_ib:0.02821846
# epoch 36 loss_pde:0.43203557, loss_ib:0.02804410
# epoch 36 loss_pde:0.43163407, loss_ib:0.02793811
# epoch 36 loss_pde:0.43103212, loss_ib:0.02788376
# epoch 36: loss 0.735767
# epoch 37 loss_pde:0.43061757, loss_ib:0.02782417
# epoch 37 loss_pde:0.42988887, loss_ib:0.02777790
# epoch 37 loss_pde:0.42949390, loss_ib:0.02762058
# epoch 37 loss_pde:0.42838776, loss_ib:0.02760082
# epoch 37 loss_pde:0.42789280, loss_ib:0.02752799
# epoch 37 loss_pde:0.42746466, loss_ib:0.02744246
# epoch 37 loss_pde:0.42683330, loss_ib:0.02741811
# epoch 37 loss_pde:0.42582735, loss_ib:0.02737221
# epoch 37 loss_pde:0.42539638, loss_ib:0.02724817
# epoch 37 loss_pde:0.42523956, loss_ib:0.02708899
# epoch 37 loss_pde:0.42603746, loss_ib:0.02690623
# epoch 37 loss_pde:0.42618302, loss_ib:0.02677338
# epoch 37 loss_pde:0.42646992, loss_ib:0.02659898
# epoch 37 loss_pde:0.42628488, loss_ib:0.02643605
# epoch 37 loss_pde:0.42456150, loss_ib:0.02645570
# epoch 37 loss_pde:0.42411047, loss_ib:0.02639667
# epoch 37 loss_pde:0.42363012, loss_ib:0.02634850
# epoch 37 loss_pde:0.42370367, loss_ib:0.02626922
# epoch 37 loss_pde:0.42401883, loss_ib:0.02615259
# epoch 37 loss_pde:0.42426920, loss_ib:0.02599320
# epoch 37: loss 0.708859
# epoch 38 loss_pde:0.42457336, loss_ib:0.02585548
# epoch 38 loss_pde:0.42349860, loss_ib:0.02585216
# epoch 38 loss_pde:0.42253712, loss_ib:0.02586178
# epoch 38 loss_pde:0.42121470, loss_ib:0.02585572
# epoch 38 loss_pde:0.42185867, loss_ib:0.02570090
# epoch 38 loss_pde:0.42144862, loss_ib:0.02561251
# epoch 38 loss_pde:0.42096484, loss_ib:0.02557711
# epoch 38 loss_pde:0.42173505, loss_ib:0.02540785
# epoch 38 loss_pde:0.42118871, loss_ib:0.02533301
# epoch 38 loss_pde:0.42211142, loss_ib:0.02513034
# epoch 38 loss_pde:0.42124140, loss_ib:0.02510354
# epoch 38 loss_pde:0.42053211, loss_ib:0.02511353
# epoch 38 loss_pde:0.42001086, loss_ib:0.02505907
# epoch 38 loss_pde:0.41916266, loss_ib:0.02498247
# epoch 38 loss_pde:0.41870981, loss_ib:0.02488456
# epoch 38 loss_pde:0.41842973, loss_ib:0.02478723
# epoch 38 loss_pde:0.41678375, loss_ib:0.02479932
# epoch 38 loss_pde:0.41686463, loss_ib:0.02465990
# epoch 38 loss_pde:0.41484794, loss_ib:0.02472910
# epoch 38 loss_pde:0.41315761, loss_ib:0.02478155
# epoch 38: loss 0.683128
# epoch 39 loss_pde:0.41257587, loss_ib:0.02470513
# epoch 39 loss_pde:0.41183966, loss_ib:0.02460990
# epoch 39 loss_pde:0.41161510, loss_ib:0.02450741
# epoch 39 loss_pde:0.41223639, loss_ib:0.02433629
# epoch 39 loss_pde:0.41181669, loss_ib:0.02428550
# epoch 39 loss_pde:0.41078982, loss_ib:0.02429070
# epoch 39 loss_pde:0.40899974, loss_ib:0.02431948
# epoch 39 loss_pde:0.40734476, loss_ib:0.02437245
# epoch 39 loss_pde:0.40696752, loss_ib:0.02431926
# epoch 39 loss_pde:0.40690684, loss_ib:0.02423784
# epoch 39 loss_pde:0.40667000, loss_ib:0.02416473
# epoch 39 loss_pde:0.40696496, loss_ib:0.02404736
# epoch 39 loss_pde:0.40537789, loss_ib:0.02409591
# epoch 39 loss_pde:0.40496692, loss_ib:0.02402733
# epoch 39 loss_pde:0.40368715, loss_ib:0.02403864
# epoch 39 loss_pde:0.40324596, loss_ib:0.02398438
# epoch 39 loss_pde:0.40275872, loss_ib:0.02393610
# epoch 39 loss_pde:0.40284485, loss_ib:0.02383191
# epoch 39 loss_pde:0.40290320, loss_ib:0.02370155
# epoch 39 loss_pde:0.40193087, loss_ib:0.02360162
# epoch 39: loss 0.659627
# epoch 40 loss_pde:0.40244877, loss_ib:0.02342181
# epoch 40 loss_pde:0.40133330, loss_ib:0.02344441
# epoch 40 loss_pde:0.39946395, loss_ib:0.02350910
# epoch 40 loss_pde:0.39835811, loss_ib:0.02349653
# epoch 40 loss_pde:0.39701450, loss_ib:0.02346580
# epoch 40 loss_pde:0.39681929, loss_ib:0.02334167
# epoch 40 loss_pde:0.39682943, loss_ib:0.02323166
# epoch 40 loss_pde:0.39693981, loss_ib:0.02313769
# epoch 40 loss_pde:0.39642191, loss_ib:0.02308685
# epoch 40 loss_pde:0.39658299, loss_ib:0.02295321
# epoch 40 loss_pde:0.39551669, loss_ib:0.02293412
# epoch 40 loss_pde:0.39511570, loss_ib:0.02286755
# epoch 40 loss_pde:0.39495912, loss_ib:0.02279683
# epoch 40 loss_pde:0.39462316, loss_ib:0.02275953
# epoch 40 loss_pde:0.39462304, loss_ib:0.02269264
# epoch 40 loss_pde:0.39411470, loss_ib:0.02268865
# epoch 40 loss_pde:0.39287323, loss_ib:0.02272545
# epoch 40 loss_pde:0.39132416, loss_ib:0.02276721
# epoch 40 loss_pde:0.38865811, loss_ib:0.02291650
# epoch 40 loss_pde:0.38758582, loss_ib:0.02293322
# epoch 40: loss 0.636667
# epoch 41 loss_pde:0.38664010, loss_ib:0.02293503
# epoch 41 loss_pde:0.38617331, loss_ib:0.02287598
# epoch 41 loss_pde:0.38550010, loss_ib:0.02277620
# epoch 41 loss_pde:0.38540590, loss_ib:0.02266756
# epoch 41 loss_pde:0.38466674, loss_ib:0.02264365
# epoch 41 loss_pde:0.38343602, loss_ib:0.02263585
# epoch 41 loss_pde:0.38246107, loss_ib:0.02263247
# epoch 41 loss_pde:0.38151786, loss_ib:0.02263917
# epoch 41 loss_pde:0.38126817, loss_ib:0.02257465
# epoch 41 loss_pde:0.38039118, loss_ib:0.02258452
# epoch 41 loss_pde:0.38086325, loss_ib:0.02245189
# epoch 41 loss_pde:0.38134602, loss_ib:0.02233813
# epoch 41 loss_pde:0.38120213, loss_ib:0.02229916
# epoch 41 loss_pde:0.38093871, loss_ib:0.02223737
# epoch 41 loss_pde:0.37944192, loss_ib:0.02228560
# epoch 41 loss_pde:0.38084424, loss_ib:0.02218161
# epoch 41 loss_pde:0.37913346, loss_ib:0.02216024
# epoch 41 loss_pde:0.37890908, loss_ib:0.02213846
# epoch 41 loss_pde:0.37900573, loss_ib:0.02206785
# epoch 41 loss_pde:0.37917191, loss_ib:0.02196139
# epoch 41: loss 0.615990
# epoch 42 loss_pde:0.37948164, loss_ib:0.02179319
# epoch 42 loss_pde:0.37918717, loss_ib:0.02171135
# epoch 42 loss_pde:0.37839475, loss_ib:0.02170099
# epoch 42 loss_pde:0.37727299, loss_ib:0.02173044
# epoch 42 loss_pde:0.37644964, loss_ib:0.02174312
# epoch 42 loss_pde:0.37508702, loss_ib:0.02176309
# epoch 42 loss_pde:0.37452844, loss_ib:0.02170111
# epoch 42 loss_pde:0.37382376, loss_ib:0.02164988
# epoch 42 loss_pde:0.37389073, loss_ib:0.02155871
# epoch 42 loss_pde:0.37377131, loss_ib:0.02146092
# epoch 42 loss_pde:0.37364066, loss_ib:0.02136145
# epoch 42 loss_pde:0.37252641, loss_ib:0.02137563
# epoch 42 loss_pde:0.37202772, loss_ib:0.02133788
# epoch 42 loss_pde:0.37123764, loss_ib:0.02134913
# epoch 42 loss_pde:0.37073806, loss_ib:0.02134492
# epoch 42 loss_pde:0.37013549, loss_ib:0.02132110
# epoch 42 loss_pde:0.36956078, loss_ib:0.02129021
# epoch 42 loss_pde:0.36851442, loss_ib:0.02126642
# epoch 42 loss_pde:0.36783767, loss_ib:0.02121986
# epoch 42 loss_pde:0.36744815, loss_ib:0.02119000
# epoch 42: loss 0.597414
# epoch 43 loss_pde:0.36676383, loss_ib:0.02118906
# epoch 43 loss_pde:0.36628860, loss_ib:0.02116342
# epoch 43 loss_pde:0.36596960, loss_ib:0.02111540
# epoch 43 loss_pde:0.36531910, loss_ib:0.02107744
# epoch 43 loss_pde:0.36526990, loss_ib:0.02100181
# epoch 43 loss_pde:0.36475927, loss_ib:0.02096780
# epoch 43 loss_pde:0.36400393, loss_ib:0.02096867
# epoch 43 loss_pde:0.36320680, loss_ib:0.02096131
# epoch 43 loss_pde:0.36310592, loss_ib:0.02086594
# epoch 43 loss_pde:0.36248347, loss_ib:0.02082924
# epoch 43 loss_pde:0.36249411, loss_ib:0.02073088
# epoch 43 loss_pde:0.36239943, loss_ib:0.02066002
# epoch 43 loss_pde:0.36204582, loss_ib:0.02056994
# epoch 43 loss_pde:0.36224303, loss_ib:0.02045967
# epoch 43 loss_pde:0.36140758, loss_ib:0.02048476
# epoch 43 loss_pde:0.36013341, loss_ib:0.02054163
# epoch 43 loss_pde:0.35969168, loss_ib:0.02052819
# epoch 43 loss_pde:0.35936078, loss_ib:0.02048031
# epoch 43 loss_pde:0.35930356, loss_ib:0.02035988
# epoch 43 loss_pde:0.35892341, loss_ib:0.02029297
# epoch 43: loss 0.578654
# epoch 44 loss_pde:0.35931492, loss_ib:0.02014362
# epoch 44 loss_pde:0.35836869, loss_ib:0.02015101
# epoch 44 loss_pde:0.35796955, loss_ib:0.02010375
# epoch 44 loss_pde:0.35745043, loss_ib:0.02007467
# epoch 44 loss_pde:0.35591763, loss_ib:0.02012222
# epoch 44 loss_pde:0.35538399, loss_ib:0.02006165
# epoch 44 loss_pde:0.35487789, loss_ib:0.02000643
# epoch 44 loss_pde:0.35482043, loss_ib:0.01995599
# epoch 44 loss_pde:0.35472828, loss_ib:0.01991353
# epoch 44 loss_pde:0.35397917, loss_ib:0.01988992
# epoch 44 loss_pde:0.35229206, loss_ib:0.01995779
# epoch 44 loss_pde:0.35146993, loss_ib:0.01995780
# epoch 44 loss_pde:0.35106567, loss_ib:0.01994043
# epoch 44 loss_pde:0.35058361, loss_ib:0.01989245
# epoch 44 loss_pde:0.35047403, loss_ib:0.01981988
# epoch 44 loss_pde:0.35079229, loss_ib:0.01969051
# epoch 44 loss_pde:0.35057712, loss_ib:0.01962373
# epoch 44 loss_pde:0.35001847, loss_ib:0.01957636
# epoch 44 loss_pde:0.34945133, loss_ib:0.01954842
# epoch 44 loss_pde:0.34797481, loss_ib:0.01960026
# epoch 44: loss 0.560751
# epoch 45 loss_pde:0.34649959, loss_ib:0.01963901
# epoch 45 loss_pde:0.34529972, loss_ib:0.01968349
# epoch 45 loss_pde:0.34436786, loss_ib:0.01969399
# epoch 45 loss_pde:0.34341323, loss_ib:0.01966494
# epoch 45 loss_pde:0.34274575, loss_ib:0.01961778
# epoch 45 loss_pde:0.34224951, loss_ib:0.01957115
# epoch 45 loss_pde:0.34172034, loss_ib:0.01954412
# epoch 45 loss_pde:0.34192443, loss_ib:0.01945778
# epoch 45 loss_pde:0.34139317, loss_ib:0.01944831
# epoch 45 loss_pde:0.34056723, loss_ib:0.01943706
# epoch 45 loss_pde:0.33987227, loss_ib:0.01940108
# epoch 45 loss_pde:0.33952320, loss_ib:0.01932604
# epoch 45 loss_pde:0.33924556, loss_ib:0.01928553
# epoch 45 loss_pde:0.33916891, loss_ib:0.01923604
# epoch 45 loss_pde:0.33882305, loss_ib:0.01916101
# epoch 45 loss_pde:0.33843333, loss_ib:0.01920344
# epoch 45 loss_pde:0.33809054, loss_ib:0.01910495
# epoch 45 loss_pde:0.33790463, loss_ib:0.01908842
# epoch 45 loss_pde:0.33760327, loss_ib:0.01905797
# epoch 45 loss_pde:0.33717602, loss_ib:0.01903015
# epoch 45: loss 0.542890
# epoch 46 loss_pde:0.33711061, loss_ib:0.01892858
# epoch 46 loss_pde:0.33586028, loss_ib:0.01896358
# epoch 46 loss_pde:0.33578205, loss_ib:0.01887206
# epoch 46 loss_pde:0.33555865, loss_ib:0.01881009
# epoch 46 loss_pde:0.33539203, loss_ib:0.01875883
# epoch 46 loss_pde:0.33486757, loss_ib:0.01871778
# epoch 46 loss_pde:0.33471459, loss_ib:0.01865442
# epoch 46 loss_pde:0.33460969, loss_ib:0.01860426
# epoch 46 loss_pde:0.33469158, loss_ib:0.01852584
# epoch 46 loss_pde:0.33448592, loss_ib:0.01849707
# epoch 46 loss_pde:0.33429477, loss_ib:0.01846988
# epoch 46 loss_pde:0.33379236, loss_ib:0.01844658
# epoch 46 loss_pde:0.33353457, loss_ib:0.01840410
# epoch 46 loss_pde:0.33222717, loss_ib:0.01841964
# epoch 46 loss_pde:0.33248603, loss_ib:0.01831140
# epoch 46 loss_pde:0.33244202, loss_ib:0.01825969
# epoch 46 loss_pde:0.33216751, loss_ib:0.01817555
# epoch 46 loss_pde:0.33177909, loss_ib:0.01809972
# epoch 46 loss_pde:0.33162940, loss_ib:0.01809824
# epoch 46 loss_pde:0.33116040, loss_ib:0.01805615
# epoch 46: loss 0.526396
# epoch 47 loss_pde:0.33078155, loss_ib:0.01805868
# epoch 47 loss_pde:0.33025783, loss_ib:0.01805905
# epoch 47 loss_pde:0.32974094, loss_ib:0.01805398
# epoch 47 loss_pde:0.32930532, loss_ib:0.01801478
# epoch 47 loss_pde:0.32893074, loss_ib:0.01796838
# epoch 47 loss_pde:0.32856077, loss_ib:0.01793216
# epoch 47 loss_pde:0.32845229, loss_ib:0.01787231
# epoch 47 loss_pde:0.32817426, loss_ib:0.01783232
# epoch 47 loss_pde:0.32738453, loss_ib:0.01781701
# epoch 47 loss_pde:0.32678959, loss_ib:0.01779040
# epoch 47 loss_pde:0.32597235, loss_ib:0.01780423
# epoch 47 loss_pde:0.32518378, loss_ib:0.01781333
# epoch 47 loss_pde:0.32414645, loss_ib:0.01783554
# epoch 47 loss_pde:0.32307744, loss_ib:0.01784659
# epoch 47 loss_pde:0.32208306, loss_ib:0.01785627
# epoch 47 loss_pde:0.32176936, loss_ib:0.01783281
# epoch 47 loss_pde:0.32149306, loss_ib:0.01780246
# epoch 47 loss_pde:0.32146582, loss_ib:0.01775634
# epoch 47 loss_pde:0.32073787, loss_ib:0.01776377
# epoch 47 loss_pde:0.32036573, loss_ib:0.01775033
# epoch 47: loss 0.511368
# epoch 48 loss_pde:0.31992039, loss_ib:0.01773567
# epoch 48 loss_pde:0.31948495, loss_ib:0.01770377
# epoch 48 loss_pde:0.31903428, loss_ib:0.01766223
# epoch 48 loss_pde:0.31864327, loss_ib:0.01765151
# epoch 48 loss_pde:0.31852928, loss_ib:0.01761282
# epoch 48 loss_pde:0.31816274, loss_ib:0.01759202
# epoch 48 loss_pde:0.31785345, loss_ib:0.01757196
# epoch 48 loss_pde:0.31747824, loss_ib:0.01753484
# epoch 48 loss_pde:0.31713021, loss_ib:0.01753798
# epoch 48 loss_pde:0.31700885, loss_ib:0.01749039
# epoch 48 loss_pde:0.31695804, loss_ib:0.01744761
# epoch 48 loss_pde:0.31671700, loss_ib:0.01742380
# epoch 48 loss_pde:0.31624416, loss_ib:0.01738865
# epoch 48 loss_pde:0.31701314, loss_ib:0.01727449
# epoch 48 loss_pde:0.31574339, loss_ib:0.01729875
# epoch 48 loss_pde:0.31562102, loss_ib:0.01727561
# epoch 48 loss_pde:0.31537300, loss_ib:0.01726079
# epoch 48 loss_pde:0.31501722, loss_ib:0.01723835
# epoch 48 loss_pde:0.31451726, loss_ib:0.01723899
# epoch 48 loss_pde:0.31435415, loss_ib:0.01719562
# ...
# epoch 105 loss_pde:0.14664973, loss_ib:0.00767883
# epoch 105 loss_pde:0.14652576, loss_ib:0.00768047
# epoch 105 loss_pde:0.14648734, loss_ib:0.00766970
# epoch 105 loss_pde:0.14642742, loss_ib:0.00766775
# epoch 105 loss_pde:0.14636055, loss_ib:0.00766516
# epoch 105 loss_pde:0.14625990, loss_ib:0.00765942
# epoch 105 loss_pde:0.14636371, loss_ib:0.00770149
# epoch 105 loss_pde:0.14613996, loss_ib:0.00765381
# epoch 105 loss_pde:0.14611849, loss_ib:0.00765278
# epoch 105 loss_pde:0.14603943, loss_ib:0.00764395
# epoch 105 loss_pde:0.14594370, loss_ib:0.00763577
# epoch 105 loss_pde:0.14591266, loss_ib:0.00762766
# epoch 105 loss_pde:0.14577611, loss_ib:0.00762078
# epoch 105 loss_pde:0.14570519, loss_ib:0.00761797
# epoch 105 loss_pde:0.14567675, loss_ib:0.00761175
# epoch 105 loss_pde:0.14549735, loss_ib:0.00761257
# epoch 105 loss_pde:0.14541405, loss_ib:0.00760604
# epoch 105: loss 0.223815
# epoch 106 loss_pde:0.14528239, loss_ib:0.00760714
# epoch 106 loss_pde:0.14513043, loss_ib:0.00761093
# epoch 106 loss_pde:0.14500363, loss_ib:0.00761761
# epoch 106 loss_pde:0.14475250, loss_ib:0.00761822
# epoch 106 loss_pde:0.14477262, loss_ib:0.00760450
# epoch 106 loss_pde:0.14482981, loss_ib:0.00758393
# epoch 106 loss_pde:0.14484920, loss_ib:0.00757069
# epoch 106 loss_pde:0.14466998, loss_ib:0.00757897
# epoch 106 loss_pde:0.14477783, loss_ib:0.00753996
# epoch 106 loss_pde:0.14471917, loss_ib:0.00753784
# epoch 106 loss_pde:0.14460032, loss_ib:0.00753746
# epoch 106 loss_pde:0.14452507, loss_ib:0.00753280
# epoch 106 loss_pde:0.14437774, loss_ib:0.00752826
# epoch 106 loss_pde:0.14435285, loss_ib:0.00751327
# epoch 106 loss_pde:0.14428683, loss_ib:0.00751026
# epoch 106 loss_pde:0.14421855, loss_ib:0.00749980
# epoch 106 loss_pde:0.14408864, loss_ib:0.00750899
# epoch 106 loss_pde:0.14402033, loss_ib:0.00749268
# epoch 106 loss_pde:0.14402276, loss_ib:0.00748144
# epoch 106 loss_pde:0.14394243, loss_ib:0.00747648
# epoch 106: loss 0.221354
# epoch 107 loss_pde:0.14391249, loss_ib:0.00746670
# epoch 107 loss_pde:0.14381796, loss_ib:0.00746415
# epoch 107 loss_pde:0.14369470, loss_ib:0.00746273
# epoch 107 loss_pde:0.14354795, loss_ib:0.00745800
# epoch 107 loss_pde:0.14331165, loss_ib:0.00747794
# epoch 107 loss_pde:0.14330024, loss_ib:0.00745423
# epoch 107 loss_pde:0.14330059, loss_ib:0.00744350
# epoch 107 loss_pde:0.14321706, loss_ib:0.00743545
# epoch 107 loss_pde:0.14312446, loss_ib:0.00742363
# epoch 107 loss_pde:0.14279257, loss_ib:0.00743247
# epoch 107 loss_pde:0.14269711, loss_ib:0.00742805
# epoch 107 loss_pde:0.14263028, loss_ib:0.00742372
# epoch 107 loss_pde:0.14258926, loss_ib:0.00741880
# epoch 107 loss_pde:0.14260882, loss_ib:0.00741228
# epoch 107 loss_pde:0.14256555, loss_ib:0.00740556
# epoch 107 loss_pde:0.14253673, loss_ib:0.00740141
# epoch 107 loss_pde:0.14251946, loss_ib:0.00739686
# epoch 107 loss_pde:0.14248748, loss_ib:0.00739388
# epoch 107 loss_pde:0.14245236, loss_ib:0.00738151
# epoch 107 loss_pde:0.14240810, loss_ib:0.00737604
# epoch 107: loss 0.218579
# epoch 108 loss_pde:0.14226212, loss_ib:0.00737091
# epoch 108 loss_pde:0.14228134, loss_ib:0.00737693
# epoch 108 loss_pde:0.14211532, loss_ib:0.00736562
# epoch 108 loss_pde:0.14202613, loss_ib:0.00736557
# epoch 108 loss_pde:0.14180690, loss_ib:0.00736992
# epoch 108 loss_pde:0.14163198, loss_ib:0.00737123
# epoch 108 loss_pde:0.14127727, loss_ib:0.00737803
# epoch 108 loss_pde:0.14100632, loss_ib:0.00741127
# epoch 108 loss_pde:0.14099173, loss_ib:0.00737072
# epoch 108 loss_pde:0.14101903, loss_ib:0.00735885
# epoch 108 loss_pde:0.14094785, loss_ib:0.00735367
# epoch 108 loss_pde:0.14105868, loss_ib:0.00733544
# epoch 108 loss_pde:0.14094777, loss_ib:0.00733777
# epoch 108 loss_pde:0.14081627, loss_ib:0.00733875
# epoch 108 loss_pde:0.14079319, loss_ib:0.00733292
# epoch 108 loss_pde:0.14081137, loss_ib:0.00731662
# epoch 108 loss_pde:0.14068283, loss_ib:0.00733207
# epoch 108 loss_pde:0.14076646, loss_ib:0.00729504
# epoch 108 loss_pde:0.14073718, loss_ib:0.00728984
# epoch 108 loss_pde:0.14063677, loss_ib:0.00728748
# epoch 108: loss 0.215971
# epoch 109 loss_pde:0.14051059, loss_ib:0.00728801
# epoch 109 loss_pde:0.14022151, loss_ib:0.00729595
# epoch 109 loss_pde:0.13999780, loss_ib:0.00730866
# epoch 109 loss_pde:0.13994193, loss_ib:0.00729710
# epoch 109 loss_pde:0.13989685, loss_ib:0.00729231
# epoch 109 loss_pde:0.13968238, loss_ib:0.00730326
# epoch 109 loss_pde:0.13944635, loss_ib:0.00730298
# epoch 109 loss_pde:0.13935214, loss_ib:0.00730058
# epoch 109 loss_pde:0.13912517, loss_ib:0.00731122
# epoch 109 loss_pde:0.13902277, loss_ib:0.00731123
# epoch 109 loss_pde:0.13886394, loss_ib:0.00731264
# epoch 109 loss_pde:0.13870981, loss_ib:0.00731507
# epoch 109 loss_pde:0.13848162, loss_ib:0.00732195
# epoch 109 loss_pde:0.13826482, loss_ib:0.00732959
# epoch 109 loss_pde:0.13816546, loss_ib:0.00732605
# epoch 109 loss_pde:0.13801675, loss_ib:0.00732424
# epoch 109 loss_pde:0.13802411, loss_ib:0.00731023
# epoch 109 loss_pde:0.13791864, loss_ib:0.00730940
# epoch 109 loss_pde:0.13784313, loss_ib:0.00731514
# epoch 109 loss_pde:0.13775057, loss_ib:0.00731095
# epoch 109: loss 0.213391
# epoch 110 loss_pde:0.13765538, loss_ib:0.00731369
# epoch 110 loss_pde:0.13750115, loss_ib:0.00732077
# epoch 110 loss_pde:0.13733898, loss_ib:0.00732883
# epoch 110 loss_pde:0.13717471, loss_ib:0.00738862
# epoch 110 loss_pde:0.13708270, loss_ib:0.00734131
# epoch 110 loss_pde:0.13705546, loss_ib:0.00734013
# epoch 110 loss_pde:0.13694978, loss_ib:0.00734118
# epoch 110 loss_pde:0.13688925, loss_ib:0.00734200
# epoch 110 loss_pde:0.13661455, loss_ib:0.00734938
# epoch 110 loss_pde:0.13674335, loss_ib:0.00737484
# epoch 110 loss_pde:0.13643822, loss_ib:0.00734637
# epoch 110 loss_pde:0.13639504, loss_ib:0.00734350
# epoch 110 loss_pde:0.13637289, loss_ib:0.00733592
# epoch 110 loss_pde:0.13618514, loss_ib:0.00733797
# epoch 110 loss_pde:0.13616830, loss_ib:0.00733344
# epoch 110 loss_pde:0.13612927, loss_ib:0.00732875
# epoch 110 loss_pde:0.13604997, loss_ib:0.00732646
# epoch 110 loss_pde:0.13591564, loss_ib:0.00732441
# epoch 110 loss_pde:0.13550955, loss_ib:0.00735735
# epoch 110 loss_pde:0.13554221, loss_ib:0.00733737
# epoch 110: loss 0.210792
# epoch 111 loss_pde:0.13547839, loss_ib:0.00733290
# epoch 111 loss_pde:0.13531926, loss_ib:0.00733712
# epoch 111 loss_pde:0.13518664, loss_ib:0.00734397
# epoch 111 loss_pde:0.13493691, loss_ib:0.00734916
# epoch 111 loss_pde:0.13482614, loss_ib:0.00735112
# epoch 111 loss_pde:0.13467379, loss_ib:0.00735379
# epoch 111 loss_pde:0.13459401, loss_ib:0.00734866
# epoch 111 loss_pde:0.13455908, loss_ib:0.00733089
# epoch 111 loss_pde:0.13635147, loss_ib:0.00755821
# epoch 111 loss_pde:0.13445400, loss_ib:0.00732775
# epoch 111 loss_pde:0.13469326, loss_ib:0.00730664
# epoch 111 loss_pde:0.13456233, loss_ib:0.00730884
# epoch 111 loss_pde:0.13455762, loss_ib:0.00730647
# epoch 111 loss_pde:0.13459367, loss_ib:0.00729314
# epoch 111 loss_pde:0.13460705, loss_ib:0.00728251
# epoch 111 loss_pde:0.13448811, loss_ib:0.00727363
# epoch 111 loss_pde:0.13436402, loss_ib:0.00727504
# epoch 111 loss_pde:0.13424268, loss_ib:0.00726868
# epoch 111 loss_pde:0.13413128, loss_ib:0.00727004
# epoch 111 loss_pde:0.13399979, loss_ib:0.00727132
# epoch 111: loss 0.208807
# epoch 112 loss_pde:0.13380636, loss_ib:0.00727071
# epoch 112 loss_pde:0.13361801, loss_ib:0.00727159
# epoch 112 loss_pde:0.13346364, loss_ib:0.00727032
# epoch 112 loss_pde:0.13344464, loss_ib:0.00726364
# epoch 112 loss_pde:0.13341692, loss_ib:0.00725398
# epoch 112 loss_pde:0.13335735, loss_ib:0.00724639
# epoch 112 loss_pde:0.13318411, loss_ib:0.00723291
# epoch 112 loss_pde:0.13310413, loss_ib:0.00723767
# epoch 112 loss_pde:0.13296092, loss_ib:0.00722600
# epoch 112 loss_pde:0.13292074, loss_ib:0.00722315
# epoch 112 loss_pde:0.13284659, loss_ib:0.00721890
# epoch 112 loss_pde:0.13273244, loss_ib:0.00721275
# epoch 112 loss_pde:0.13278648, loss_ib:0.00722726
# epoch 112 loss_pde:0.13255754, loss_ib:0.00720485
# epoch 112 loss_pde:0.13252430, loss_ib:0.00720159
# epoch 112 loss_pde:0.13241561, loss_ib:0.00720305
# epoch 112 loss_pde:0.13237721, loss_ib:0.00720167
# epoch 112 loss_pde:0.13234197, loss_ib:0.00719871
# epoch 112 loss_pde:0.13227320, loss_ib:0.00719625
# epoch 112 loss_pde:0.13222578, loss_ib:0.00719283
# epoch 112: loss 0.206513
# epoch 113 loss_pde:0.13217866, loss_ib:0.00718909
# epoch 113 loss_pde:0.13212480, loss_ib:0.00718127
# epoch 113 loss_pde:0.13211513, loss_ib:0.00717498
# epoch 113 loss_pde:0.13209368, loss_ib:0.00716660
# epoch 113 loss_pde:0.13205723, loss_ib:0.00716369
# epoch 113 loss_pde:0.13195358, loss_ib:0.00716325
# epoch 113 loss_pde:0.13174602, loss_ib:0.00716955
# epoch 113 loss_pde:0.13157304, loss_ib:0.00717565
# epoch 113 loss_pde:0.13146849, loss_ib:0.00717549
# epoch 113 loss_pde:0.13130465, loss_ib:0.00717110
# epoch 113 loss_pde:0.13125750, loss_ib:0.00716287
# epoch 113 loss_pde:0.13123742, loss_ib:0.00715009
# epoch 113 loss_pde:0.13122578, loss_ib:0.00713110
# epoch 113 loss_pde:0.13114662, loss_ib:0.00713252
# epoch 113 loss_pde:0.13113907, loss_ib:0.00712336
# epoch 113 loss_pde:0.13106313, loss_ib:0.00712522
# epoch 113 loss_pde:0.13089165, loss_ib:0.00713342
# epoch 113 loss_pde:0.13054912, loss_ib:0.00714729
# epoch 113 loss_pde:0.13014828, loss_ib:0.00716177
# epoch 113 loss_pde:0.13022353, loss_ib:0.00720137
# epoch 113: loss 0.204070
# epoch 114 loss_pde:0.12990916, loss_ib:0.00716242
# epoch 114 loss_pde:0.12995507, loss_ib:0.00715106
# epoch 114 loss_pde:0.12997477, loss_ib:0.00713482
# epoch 114 loss_pde:0.13040097, loss_ib:0.00711223
# epoch 114 loss_pde:0.13004129, loss_ib:0.00711054
# epoch 114 loss_pde:0.12994735, loss_ib:0.00711288
# epoch 114 loss_pde:0.12981388, loss_ib:0.00710792
# epoch 114 loss_pde:0.12971382, loss_ib:0.00710253
# epoch 114 loss_pde:0.12972769, loss_ib:0.00707914
# epoch 114 loss_pde:0.12965883, loss_ib:0.00707371
# epoch 114 loss_pde:0.12958056, loss_ib:0.00707209
# epoch 114 loss_pde:0.12953754, loss_ib:0.00707053
# epoch 114 loss_pde:0.12946442, loss_ib:0.00706890
# epoch 114 loss_pde:0.12921670, loss_ib:0.00707576
# epoch 114 loss_pde:0.12954326, loss_ib:0.00706233
# epoch 114 loss_pde:0.12910202, loss_ib:0.00705957
# epoch 114 loss_pde:0.12902908, loss_ib:0.00705900
# epoch 114 loss_pde:0.12891816, loss_ib:0.00705399
# epoch 114 loss_pde:0.12889753, loss_ib:0.00704855
# epoch 114 loss_pde:0.12889500, loss_ib:0.00703525
# epoch 114: loss 0.201533
# epoch 115 loss_pde:0.12891763, loss_ib:0.00702094
# epoch 115 loss_pde:0.12898314, loss_ib:0.00700375
# epoch 115 loss_pde:0.12917109, loss_ib:0.00702764
# epoch 115 loss_pde:0.12897539, loss_ib:0.00699390
# epoch 115 loss_pde:0.12895259, loss_ib:0.00699210
# epoch 115 loss_pde:0.12889388, loss_ib:0.00698573
# epoch 115 loss_pde:0.12885897, loss_ib:0.00698418
# epoch 115 loss_pde:0.12885959, loss_ib:0.00697776
# epoch 115 loss_pde:0.12881313, loss_ib:0.00697427
# epoch 115 loss_pde:0.12879212, loss_ib:0.00697170
# epoch 115 loss_pde:0.12875818, loss_ib:0.00697050
# epoch 115 loss_pde:0.12861027, loss_ib:0.00697214
# epoch 115 loss_pde:0.12841789, loss_ib:0.00698626
# epoch 115 loss_pde:0.12817438, loss_ib:0.00698741
# epoch 115 loss_pde:0.12811604, loss_ib:0.00698501
# epoch 115 loss_pde:0.12803204, loss_ib:0.00698523
# epoch 115 loss_pde:0.12798202, loss_ib:0.00698461
# epoch 115 loss_pde:0.12794214, loss_ib:0.00697848
# epoch 115 loss_pde:0.12788497, loss_ib:0.00696750
# epoch 115 loss_pde:0.12784442, loss_ib:0.00695498
# epoch 115: loss 0.199127
# epoch 116 loss_pde:0.12775959, loss_ib:0.00694402
# epoch 116 loss_pde:0.12765317, loss_ib:0.00693907
# epoch 116 loss_pde:0.12764029, loss_ib:0.00692677
# epoch 116 loss_pde:0.12753664, loss_ib:0.00692533
# epoch 116 loss_pde:0.12747817, loss_ib:0.00692045
# epoch 116 loss_pde:0.12745404, loss_ib:0.00691045
# epoch 116 loss_pde:0.12752622, loss_ib:0.00690464
# epoch 116 loss_pde:0.12746739, loss_ib:0.00689013
# epoch 116 loss_pde:0.12745535, loss_ib:0.00688761
# epoch 116 loss_pde:0.12740254, loss_ib:0.00688365
# epoch 116 loss_pde:0.12727603, loss_ib:0.00688400
# epoch 116 loss_pde:0.12719816, loss_ib:0.00688838
# epoch 116 loss_pde:0.12695798, loss_ib:0.00689475
# epoch 116 loss_pde:0.12690754, loss_ib:0.00689514
# epoch 116 loss_pde:0.12684029, loss_ib:0.00689390
# epoch 116 loss_pde:0.12684231, loss_ib:0.00688419
# epoch 116 loss_pde:0.12679991, loss_ib:0.00687988
# epoch 116 loss_pde:0.12678716, loss_ib:0.00687141
# epoch 116 loss_pde:0.12674716, loss_ib:0.00686524
# epoch 116 loss_pde:0.12663934, loss_ib:0.00686509
# epoch 116: loss 0.197200
# epoch 117 loss_pde:0.12657276, loss_ib:0.00685989
# epoch 117 loss_pde:0.12649956, loss_ib:0.00685921
# epoch 117 loss_pde:0.12640056, loss_ib:0.00685753
# epoch 117 loss_pde:0.12630394, loss_ib:0.00685536
# epoch 117 loss_pde:0.12621431, loss_ib:0.00685147
# ---------------------------------------------------------------------------
#
# KeyboardInterrupt                         Traceback (most recent call last)
#
# Cell In[21], line 4
#
#       2 tic = time.time()
#
#       3 for epoch in range(1, epochs+1):
#
# ----> 4     train(epoch)
#
#       5 toc = time.time()
#
#       6 print(f'Total training time: {toc - tic}')
#
#
#
# Cell In[6], line 31, in train(epoch)
#
#      28     return loss
#
#      30 # Optimize loss function
#
# ---> 31 loss = optimizer.step(closure)
#
#      32 loss_value = loss.item() if not isinstance(loss, float) else loss
#
#      33 # Print total loss
#
#
#
# File ~/anaconda3/envs/ML/lib/python3.11/site-packages/torch/optim/optimizer.py:280, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#
#     276         else:
#
#     277             raise RuntimeError(f"{func} must return None or a tuple of (new_args, new_kwargs),"
#
#     278                                f"but got {result}.")
#
# --> 280 out = func(*args, **kwargs)
#
#     281 self._optimizer_step_code()
#
#     283 # call optimizer step post hooks
#
#
#
# File ~/anaconda3/envs/ML/lib/python3.11/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#
#     112 @functools.wraps(func)
#
#     113 def decorate_context(*args, **kwargs):
#
#     114     with ctx_factory():
#
# --> 115         return func(*args, **kwargs)
#
#
#
# File ~/anaconda3/envs/ML/lib/python3.11/site-packages/torch/optim/lbfgs.py:438, in LBFGS.step(self, closure)
#
#     433 if n_iter != max_iter:
#
#     434     # re-evaluate function only if not in last iteration
#
#     435     # the reason we do this: in a stochastic setting,
#
#     436     # no use to re-evaluate that function here
#
#     437     with torch.enable_grad():
#
# --> 438         loss = float(closure())
#
#     439     flat_grad = self._gather_flat_grad()
#
#     440     opt_cond = flat_grad.abs().max() <= tolerance_grad
#
#
#
# File ~/anaconda3/envs/ML/lib/python3.11/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#
#     112 @functools.wraps(func)
#
#     113 def decorate_context(*args, **kwargs):
#
#     114     with ctx_factory():
#
# --> 115         return func(*args, **kwargs)
#
#
#
# Cell In[6], line 27, in train.<locals>.closure()
#
#      24 loss = loss_pde + 10*loss_ib
#
#      26 print(f'epoch {epoch} loss_pde:{loss_pde:.8f}, loss_ib:{loss_ib:.8f}')
#
# ---> 27 loss.backward()
#
#      28 return loss
#
#
#
# File ~/anaconda3/envs/ML/lib/python3.11/site-packages/torch/_tensor.py:487, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#
#     477 if has_torch_function_unary(self):
#
#     478     return handle_torch_function(
#
#     479         Tensor.backward,
#
#     480         (self,),
#
#    (...)
#
#     485         inputs=inputs,
#
#     486     )
#
# --> 487 torch.autograd.backward(
#
#     488     self, gradient, retain_graph, create_graph, inputs=inputs
#
#     489 )
#
#
#
# File ~/anaconda3/envs/ML/lib/python3.11/site-packages/torch/autograd/__init__.py:200, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#
#     195     retain_graph = create_graph
#
#     197 # The reason we repeat same the comment below is that
#
#     198 # some Python versions print out the first line of a multi-line function
#
#     199 # calls in the traceback and some print out the last line
#
# --> 200 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#
#     201     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#
#     202     allow_unreachable=True, accumulate_grad=True)
#
#
#
# KeyboardInterrupt:

# %%
model_path = 'backcorner_new_3.pth'
torch.save(model.to('cpu'), model_path)

# %%
device1 = torch.device("cpu")
#model.load_state_dict(torch.load(PATH))
#torch.save(model,'2DRiemanncase8.pt')
#model = torch.save('backcorner.pt')

# %%
#model = model.load_state_dict(torch.load( 'backcorner.pt'))
model = model.to(device)

# %%
model_path = 'Withoushock2D_new1.pth'
model = torch.load(model_path, map_location=torch.device('cpu'))
model = model.to(device)

# %%
# Evaluate on the whole computational domain
for i in range(50):
#u = to_numpy(model(x_test))
#x = to_numpy(x_test)
    x = np.linspace(0.0, 1.0, 401)                                   # Partitioned spatial axis
    y = np.linspace(0.0, 1.0, 400)                                   # Partitioned spatial axis
    t = np.linspace(0.20, 0.20, 1)                                        # Partitioned time axis
    t_grid, x_grid,y_grid = np.meshgrid(t,x,y)                                    # (t,x) in [0,0.2]x[a,b]
    T = t_grid.flatten()[:, None]                                        # Vectorized t_grid
    X = x_grid.flatten()[:, None]                                         # Vectorized x_grid
    Y = y_grid.flatten()[:, None]                                         # Vectorized x_grid
    x_test = np.hstack((T, X, Y))                                            # Vectorized whole domain
    x_test = torch.tensor(x_test, dtype=torch.float32).to(device1)
    u = to_numpy(model(x_test))
    #Xp,Yp = meshgrid(x,y)
    
    ue = np.zeros((401,400))
    for i in range(0,401):
        for j in range(0,400):
            ue[i,j] = u[j*400+i,3]
            
    plt.figure()
    plt.contourf(x_grid[:,0,:],y_grid[:,0,:],ue,50)
    #plt.pcolor(x_grid[:,0,:],y_grid[:,0,:],ue)
    #plt.colorbar(x_grid[:,0,:],y_grid[:,0,:],ue)
    #plt.scatter(x_int_train[:,1],)
    #plt.pcolor(x[:],u[:,1])
    #plt.pcolor(x[:],u[:,2])
    ax = plt.gca()
    ax.set_aspect(1)
    plt.savefig("test_rasterization.png", dpi=150)
    plt.show()
 
    #    uo = ue.flatten()[:,None]
    #    uxy= np.hstack((X, Y,uo))                                            # Vectorized whole domain
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[19], line 14
#      12 x_test = np.hstack((T, X, Y))                                            # Vectorized whole domain
#      13 x_test = torch.tensor(x_test, dtype=torch.float32).to(device1)
# ---> 14 u = to_numpy(model(x_test))
#      15 #Xp,Yp = meshgrid(x,y)
#      17 ue = np.zeros((401,400))
#
# File ~/anaconda3/envs/ML/lib/python3.11/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# Cell In[6], line 160, in DNN.forward(self, x)
#     159 def forward(self, x):
# --> 160     return self.net(x)
#
# File ~/anaconda3/envs/ML/lib/python3.11/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/anaconda3/envs/ML/lib/python3.11/site-packages/torch/nn/modules/container.py:217, in Sequential.forward(self, input)
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File ~/anaconda3/envs/ML/lib/python3.11/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/anaconda3/envs/ML/lib/python3.11/site-packages/torch/nn/modules/linear.py:114, in Linear.forward(self, input)
#     113 def forward(self, input: Tensor) -> Tensor:
# --> 114     return F.linear(input, self.weight, self.bias)
#
# RuntimeError: Expected all tensors to be on the same device, but found at least two devices, cuda:0 and cpu! (when checking argument for argument mat1 in method wrapper_CUDA_addmm)

# %%
for k in range(10):
    Nd = 400
    T = 0.4/50*k
    t = np.linspace(T, T, 1)                                   # Partitioned spatial axis
    x = np.linspace(0.0,Lx,Nd)                                   # Partitioned spatial axis
    y = np.linspace(0.0,Ly,Nd)                                   # Partitioned spatial axis
    t_grid,x_grid,y_grid = np.meshgrid(t,x,y)                                    # (t,x) in [0,0.2]x[a,b]
    T = t_grid.flatten()[:, None]                                         # Vectorized x_grid
    X = x_grid.flatten()[:, None]                                         # Vectorized x_grid
    Y = y_grid.flatten()[:, None]                                         # Vectorized x_grid
    x_test = np.hstack((T,X,Y))                                            # Vectorized whole domain
    x_test = torch.tensor(x_test, dtype=torch.float32).to(device)
    u = to_numpy(model(x_test))
    #Xp,Yp = meshgrid(x,y)
    
    
    x_test = np.hstack((T,X,Y))                                            # Vectorized whole domain
    ue = np.zeros((Nd,Nd))
    for j in range(0,Nd):
        for i in range(0,Nd):
            ue[i,j] = u[i*Nd+j,0]
            x1 = x_test[i*Nd+j,1] 
            y1 = x_test[i*Nd+j,2] 
            if ((x1 - 1.0)**2 +(y1-1.0)**2< 0.25**2):
                ue[i,j] = 0.0
                
    uo1 = ue.flatten()[:,None]
    ue = np.zeros((Nd,Nd))
    for j in range(0,Nd):
        for i in range(0,Nd):
            ue[i,j] = u[i*Nd+j,1]
            x1 = x_test[i*Nd+j,1] 
            y1 = x_test[i*Nd+j,2] 
            if ((x1 - 1.0)**2 +(y1-1.0)**2< 0.25**2):
                ue[i,j] = 0.0
    uo2 = ue.flatten()[:,None]
    ue = np.zeros((Nd,Nd))
    for j in range(0,Nd):
        for i in range(0,Nd):
            ue[i,j] = u[i*Nd+j,2]
            x1 = x_test[i*Nd+j,1] 
            y1 = x_test[i*Nd+j,2] 
            if ((x1 - 1.0)**2 +(y1-1.0)**2< 0.25**2):
                ue[i,j] = 0.0
            
    uo3 = ue.flatten()[:,None]
    ue = np.zeros((Nd,Nd))
    for j in range(0,Nd):
        for i in range(0,Nd):
            ue[i,j] = u[i*Nd+j,0]
            x1 = x_test[i*Nd+j,1] 
            y1 = x_test[i*Nd+j,2] 
            if ((x1 - 1.0)**2 +(y1-1.0)**2< 0.25**2):
                ue[i,j] = 0.0
    uo4 = ue.flatten()[:,None]
    filename = "shock0{}.dat".format(k) 
    uxy= np.hstack((X, Y,uo1,uo2,uo3,uo4)) 
    f = open(filename,'w')
    f.write(var2)
    np.savetxt(f, uxy)# Vectorized whole domain
    f.close()
for k in range(10,50):
    Nd = 400
    T = 0.4/50*k
    t = np.linspace(T, T, 1)                                   # Partitioned spatial axis
    x = np.linspace(0.0,Lx,Nd)                                   # Partitioned spatial axis
    y = np.linspace(0.0,Ly,Nd)                                   # Partitioned spatial axis
    t_grid,x_grid,y_grid = np.meshgrid(t,x,y)                                    # (t,x) in [0,0.2]x[a,b]
    T = t_grid.flatten()[:, None]                                         # Vectorized x_grid
    X = x_grid.flatten()[:, None]                                         # Vectorized x_grid
    Y = y_grid.flatten()[:, None]                                         # Vectorized x_grid
    x_test = np.hstack((T,X,Y))                                            # Vectorized whole domain
    x_test = torch.tensor(x_test, dtype=torch.float32).to(device)
    u = to_numpy(model(x_test))
    #Xp,Yp = meshgrid(x,y)
    
    
    x_test = np.hstack((T,X,Y))                                            # Vectorized whole domain
    ue = np.zeros((Nd,Nd))
    for j in range(0,Nd):
        for i in range(0,Nd):
            ue[i,j] = u[i*Nd+j,0]
            x1 = x_test[i*Nd+j,1] 
            y1 = x_test[i*Nd+j,2] 
            if ((x1 - 1.0)**2 +(y1-1.0)**2< 0.25**2):
                ue[i,j] = 0.0
                
    uo1 = ue.flatten()[:,None]
    ue = np.zeros((Nd,Nd))
    for j in range(0,Nd):
        for i in range(0,Nd):
            ue[i,j] = u[i*Nd+j,1]
            x1 = x_test[i*Nd+j,1] 
            y1 = x_test[i*Nd+j,2] 
            if ((x1 - 1.0)**2 +(y1-1.0)**2< 0.25**2):
                ue[i,j] = 0.0
    uo2 = ue.flatten()[:,None]
    ue = np.zeros((Nd,Nd))
    for j in range(0,Nd):
        for i in range(0,Nd):
            ue[i,j] = u[i*Nd+j,2]
            x1 = x_test[i*Nd+j,1] 
            y1 = x_test[i*Nd+j,2] 
            if ((x1 - 1.0)**2 +(y1-1.0)**2< 0.25**2):
                ue[i,j] = 0.0
            
    uo3 = ue.flatten()[:,None]
    ue = np.zeros((Nd,Nd))
    for j in range(0,Nd):
        for i in range(0,Nd):
            ue[i,j] = u[i*Nd+j,3]
            x1 = x_test[i*Nd+j,1] 
            y1 = x_test[i*Nd+j,2] 
            if ((x1 - 1.0)**2 +(y1-1.0)**2< 0.25**2):
                ue[i,j] = 0.0
    uo4 = ue.flatten()[:,None]
    filename = "shock{}.dat".format(k) 
    uxy= np.hstack((X, Y,uo1,uo2,uo3,uo4)) 
    f = open(filename,'w')
    f.write(var2)
    np.savetxt(f, uxy)# Vectorized whole domain
    f.close()

# %%
Nd = 600
T = 0.4
t = np.linspace(T, T,1)                                   # Partitioned spatial axis
x = np.linspace(0.0,Lx,Nd)                                   # Partitioned spatial axis
y = np.linspace(0.0,Ly,Nd)                                   # Partitioned spatial axis
t_grid,x_grid,y_grid = np.meshgrid(t,x,y)                                    # (t,x) in [0,0.2]x[a,b]
T = t_grid.flatten()[:, None]                                         # Vectorized x_grid
X = x_grid.flatten()[:, None]                                         # Vectorized x_grid
Y = y_grid.flatten()[:, None]                                         # Vectorized x_grid
x_test = np.hstack((T,X,Y))                                            # Vectorized whole domain
x_test = torch.tensor(x_test, dtype=torch.float32).to(device)
u = to_numpy(model(x_test))
#Xp,Yp = meshgrid(x,y)


x_test = np.hstack((T,X,Y))                                            # Vectorized whole domain
ue = np.zeros((Nd,Nd))
for j in range(0,Nd):
    for i in range(0,Nd):
        ue[i,j] = u[i*Nd+j,0]
        x1 = x_test[i*Nd+j,1] 
        y1 = x_test[i*Nd+j,2] 
        if ((x1 - rx)**2 +(y1-ry)**2< rd**2):
            ue[i,j] = 0.0
            
uo1 = ue.flatten()[:,None]
ue = np.zeros((Nd,Nd))
for j in range(0,Nd):
    for i in range(0,Nd):
        ue[i,j] = u[i*Nd+j,1]
        x1 = x_test[i*Nd+j,1] 
        y1 = x_test[i*Nd+j,2] 
        if ((x1 - rx)**2 +(y1-ry)**2< rd**2):
            ue[i,j] = 0.0
uo2 = ue.flatten()[:,None]
ue = np.zeros((Nd,Nd))
for j in range(0,Nd):
    for i in range(0,Nd):
        ue[i,j] = u[i*Nd+j,2]
        x1 = x_test[i*Nd+j,1] 
        y1 = x_test[i*Nd+j,2] 
        if ((x1 - rx)**2 +(y1-ry)**2< rd**2):
            ue[i,j] = 0.0
        
uo3 = ue.flatten()[:,None]
ue = np.zeros((Nd,Nd))
for j in range(0,Nd):
    for i in range(0,Nd):
        ue[i,j] = u[i*Nd+j,0]
        x1 = x_test[i*Nd+j,1] 
        y1 = x_test[i*Nd+j,2] 
        if ((x1 - rx)**2 +(y1-ry)**2< rd**2):
            ue[i,j] = 1.0
#uo4 = ue.flatten()[:,None]
#filename = "temp{}.dat".format(44) 
#uxy= np.hstack((X, Y,uo1,uo2,uo3,uo4)) 
#f = open(filename,'w')
#f.write(var2)
#np.savetxt(f, uxy)# Vectorized whole domain
#f.close()

# %%
var2 = """TITLE="Euler"
 VARIABLES="x","y","rou"，"u","v","p"
ZONE I=         400 J=         400 F=POINT
"""

# %%
model
# Out:
# DNN(
#   (net): Sequential(
#     (Linear_layer_1): Linear(in_features=3, out_features=90, bias=True)
#     (Tanh_layer_1): Tanh()
#     (Linear_layer_2): Linear(in_features=90, out_features=90, bias=True)
#     (Tanh_layer_2): Tanh()
#     (Linear_layer_3): Linear(in_features=90, out_features=90, bias=True)
#     (Tanh_layer_3): Tanh()
#     (Linear_layer_4): Linear(in_features=90, out_features=90, bias=True)
#     (Tanh_layer_4): Tanh()
#     (Linear_layer_5): Linear(in_features=90, out_features=90, bias=True)
#     (Tanh_layer_5): Tanh()
#     (Linear_layer_6): Linear(in_features=90, out_features=90, bias=True)
#     (Tanh_layer_6): Tanh()
#     (Linear_layer_final): Linear(in_features=90, out_features=4, bias=True)
#   )
# )

# %%
filename = '1.dat'
with open(filename, 'r', encoding='utf-8') as fileobj:
    for line in fileobj:
        print(var2)
# Out:
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
# ...
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT
#
# TITLE="Euler"
#  VARIABLES="x","y","rou"，"u","v","p"
# ZONE I=         600 J=         600 F=POINT

# %%
plt.figure()
plt.contourf(x_grid[:,0,:],y_grid[:,0,:],ue,20)
#plt.pcolor(x_grid[:,0,:],y_grid[:,0,:],ue)
#plt.colorbar(x_grid[:,0,:],y_grid[:,0,:],ue)
#plt.scatter(x_int_train[:,1],)
#plt.pcolor(x[:],u[:,1])
#plt.pcolor(x[:],u[:,2])
ax = plt.gca()
ax.set_aspect(1)
plt.show()
plt.savefig("Riemann2.pdf", dpi=150)

# %%
            #fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
#surf = ax.plot_surface(x_grid[:,0,:], y_grid[:,0,:], ue, cmap=cm.coolwarm,
#                       linewidth=0, antialiased=False)
#
## Customize the z axis.
#ax.set_zlim(0, 1.01)
#ax.zaxis.set_major_locator(LinearLocator(10))
## A StrMethodFormatter is used automatically
#ax.zaxis.set_major_formatter('{x:.02f}')
#
## Add a color bar which maps values to colors.
#fig.colorbar(surf, shrink=0.5, aspect=5)
#plt.show()

# %%
xlimits = np.array([[0.,Tend],[0.0, 3], [0.0,3]])  #interal
sampling = LHS(xlimits=xlimits)
x_int_train = sampling(num_int)
A = []
for i in range(num_int):
    x = x_int_train[i,1]
    y = x_int_train[i,2]
    if (x< 0.5 and y< 1.5):
        A.append(i)
x_int_train = np.delete(x_int_train,A,axis=0)

# %%
plt.figure()
plt.scatter(x_int_train[1:1000,1],x_int_train[1:1000,2])
#plt.pcolor(x_grid[:,0,:],y_grid[:,0,:],ue)
#plt.colorbar(x_grid[:,0,:],y_grid[:,0,:],ue)
#plt.scatter(x_int_train[:,1],)
#plt.pcolor(x[:],u[:,1])
#plt.pcolor(x[:],u[:,2])
ax = plt.gca()
ax.set_aspect(1)
plt.show()

# %%
torch.save(model,'2DRiemanncase8.pt')

# %%
model

# %%
#device1 = torch.device("cpu")
#model.load_state_dict(torch.load(PATH))
#model = model.to(device1)
#torch.save(model,'2DRiemanncase8.pt')
model = torch.load('2DRiemanncase8.pt')

# %%
model
