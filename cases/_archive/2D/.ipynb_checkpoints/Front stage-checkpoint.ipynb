# %%
import torch
import torch.nn as nn
import numpy as np
import time
import scipy.io
import matplotlib.pyplot as plt
from numpy import arange, meshgrid
#
from smt.sampling_methods import LHS
# Seeds
torch.manual_seed(123)
np.random.seed(123)
def train(epoch):
    model.train()
    def closure():
        optimizer.zero_grad()                                                     # Optimizer
        loss_pde = model.loss_pde(x_int_train)                                    # Loss function of PDE
        loss_ic = model.loss_ic(x_ic_train, rho_ic_train,u_ic_train,v_ic_train,p_ic_train)   # Loss function of IC
        loss_bdL = model.loss_bc(x_bcL_train, rho_bcL_train,u_bcL_train,v_bcL_train,p_bcL_train)   # Loss function of IC
        loss_bdR = model.loss_bc1(x_bcR_train,rho_bcR_train,u_bcR_train,v_bcR_train,p_bcR_train)   # Loss function of IC
        loss_cut = model.loss_bc1(x_cut_train,rho_cut_train,u_cut_train,v_cut_train,p_cut_train) 
        loss_bdI = model.bd_B(x_bcI_train, sin_bcI_train,cos_bcI_train)  

        loss_ib = loss_ic + loss_bdL + loss_bdI
        loss = loss_pde + 10*loss_ib

        # Print iteration, loss of PDE and ICs
        print(f'epoch {epoch} loss_pde:{loss_pde:.8f}, loss_ib:{loss_ib:.8f}')
        loss.backward()
        return loss

    # Optimize loss function
    loss = optimizer.step(closure)
    loss_value = loss.item() if not isinstance(loss, float) else loss
    # Print total loss
    print(f'epoch {epoch}: loss {loss_value:.6f}')
    
# Calculate gradients using torch.autograd.grad
def gradients(outputs, inputs):
    return torch.autograd.grad(outputs, inputs,grad_outputs=torch.ones_like(outputs), create_graph=True)

# Convert torch tensor into np.array
def to_numpy(input):
    if isinstance(input, torch.Tensor):
        return input.detach().cpu().numpy()
    elif isinstance(input, np.ndarray):
        return input
    else:
        raise TypeError('Unknown type of input, expected torch.Tensor or ' \
                        'np.ndarray, but got {}'.format(type(input)))
def IC(x):
    N =x.shape[0]
    rho_init = np.zeros((x.shape[0]))                                              # rho - initial condition
    u_init = np.zeros((x.shape[0]))                                                # u - initial condition
    v_init = np.zeros((x.shape[0]))                                                # u - initial condition
    p_init = np.zeros((x.shape[0]))                                                # p - initial condition
    
    gamma = 1.4
    ms = 3.0
    rho1 = 1.0
    p1 = 0.71429
    v1 = 0.0
    #u1 = ms*npsqrt(gamma)
    u1 = 3.0
    # rho, p - initial condition
    for i in range(N):
        rho_init[i] = rho1
        u_init[i] =   u1
        v_init[i] =  v1
        p_init[i] =  p1

    return rho_init, u_init, v_init,p_init

def BC_L(x):
    N =x.shape[0]
    rho_init = np.zeros((x.shape[0]))                                              # rho - initial condition
    u_init = np.zeros((x.shape[0]))                                                # u - initial condition
    v_init = np.zeros((x.shape[0]))                                                # u - initial condition
    p_init = np.zeros((x.shape[0]))                                                # p - initial condition
    
    gamma = 1.4
    ms = 3.0
    rho1 = 12.25
    p1 = 1.012536
    v1 = 0.0
    #u1 = ms*np.sqrt(gamma)
    u1 = 1.3606963
    #gamma = 1.4
    #ms = 3.0
    #rho1 = 1.0
    #p1 = 1.0
    #v1 = 0.0
    #u1 = ms*np.sqrt(gamma)
    # rho, p - initial condition
    for i in range(N):
        #rho_init[i] = rho1
        #u_init[i] = u1
        #v_init[i] = v1
        #p_init[i] = p1
        
        rho_init[i] = 1.6298
        u_init[i] =  1.15467
        v_init[i] = 0
        p_init[i] = 15.91

    return rho_init, u_init, v_init,p_init
def BC_R(x):
    N =x.shape[0]
    rho_init = np.zeros((x.shape[0]))                                              # rho - initial condition
    u_init = np.zeros((x.shape[0]))                                                # u - initial condition
    v_init = np.zeros((x.shape[0]))                                                # u - initial condition
    p_init = np.zeros((x.shape[0]))                                                # p - initial condition
    
    gamma = 1.4
    ms = 2.0
    rho1 = 1.0
    p1 = 1.0
    v1 = 0.0
    u1 = 0
    # rho, p - initial condition
    for i in range(N):
        rho_init[i] = rho1
        u_init[i] = u1
        v_init[i] = v1
        p_init[i] = p1

    return rho_init, u_init, v_init,p_init
def BC_Cut(x):
    N =x.shape[0]
    rho_init = np.zeros((x.shape[0]))
    u_init = np.zeros((x.shape[0]))
    v_init = np.zeros((x.shape[0]))
    p_init = np.zeros((x.shape[0]))
    
    gamma = 1.4
    ms = 2.0
    rho1 = 1.0
    p1 = 1.0
    v1 = 0.0
    u1 = 0
    # rho, p - initial condition
    for i in range(N):
        rho_init[i] = 10.01
        u_init[i] =  0
        v_init[i] = 0
        p_init[i] = 10.01

    return rho_init, u_init, v_init,p_init
    
class DNN(nn.Module):

    def __init__(self):
        super(DNN, self).__init__()
        self.net = nn.Sequential()                                                  # Define neural network
        self.net.add_module('Linear_layer_1', nn.Linear(3, 90))                     # First linear layer
        self.net.add_module('Tanh_layer_1', nn.Tanh())                              # First activation Layer

        for num in range(2, 7):                                                     # Number of layers (2 through 7)
            self.net.add_module('Linear_layer_%d' % (num), nn.Linear(90, 90))       # Linear layer
            self.net.add_module('Tanh_layer_%d' % (num), nn.Tanh())                 # Activation Layer
        self.net.add_module('Linear_layer_final', nn.Linear(90, 4))                 # Output Layer

    # Forward Feed
    def forward(self, x):
        return self.net(x)

    def bd_B(self,x,sin,cos):
        yb = self.net(x)
        rhob,pb,ub,vb = yb[:, 0:1], yb[:, 1:2], yb[:, 2:3],yb[:,3:]
        drhob_g = gradients(rhob, x)[0]                                      # Gradient [u_t, u_x]
        rhob_x, rhob_y = drhob_g[:, 1:2], drhob_g[:, 2:3]                            # Partial derivatives u_t, u_x
        dub_g = gradients(ub, x)[0]                                      # Gradient [u_t, u_x]
        ub_x, ub_y = dub_g[:, 1:2], dub_g[:, 2:3]                            # Partial derivatives u_t, u_x
        dvb_g = gradients(vb, x)[0]                                      # Gradient [u_t, u_x]
        vb_x, vb_y = dvb_g[:, 1:2], dvb_g[:, 2:3]                            # Partial derivatives u_t, u_x
        dpb_g = gradients(pb, x)[0]                                      # Gradient [p_t, p_x]
        pb_x, pb_y = dpb_g[:, 1:2], dpb_g[:, 2:3]                            # Partial derivatives p_t, p_x
        
        #deltau = ub_x + vb_y
        #lam = 0.1*(abs(deltau) - deltau) + 1
        #lam = (deltau) - deltau) + 1
        
        fb = (((ub*cos + vb*sin))**2).mean() +\
            (((pb_x*cos + pb_y*sin))**2).mean() #+\
            #(((rhob_x*cos + rhob_y*sin))**2).mean()
        return fb
    def bd_OY(self,x):
        y = self.net(x)
        rho,p,u,v = y[:, 0:1], y[:, 1:2], y[:, 2:3],y[:,3:]
        
        drho_g = gradients(rho, x)[0]                                  # Gradient [rho_t, rho_x]
        rho_x,rho_y = drho_g[:, :1], drho_g[:, 1:2]                    # Partial derivatives rho_t, rho_x
        du_g = gradients(u, x)[0]                                      # Gradient [u_t, u_x]
        u_x, u_y = du_g[:, :1], du_g[:, 1:2]                            # Partial derivatives u_t, u_x
        dv_g = gradients(v, x)[0]                                      # Gradient [u_t, u_x]
        v_x, v_y = dv_g[:, :1], dv_g[:, 1:2]                            # Partial derivatives u_t, u_x
        dp_g = gradients(p, x)[0]                                      # Gradient [p_t, p_x]
        p_x, p_y = dp_g[:, :1], dp_g[:, 1:2]                            # Partial derivatives p_t, p_x
        
        deltau = u_x + v_y
        lam = 0.1*(abs(deltau) - deltau) + 1
        
        f = ((( u_y)/lam)**2).mean() +\
            ((( v_y)/lam)**2).mean() +\
            ((( p_y)/lam)**2).mean() +\
            ((( rho_y)/lam)**2).mean()
        return f
    
    def bd_OX(self,x):
        y = self.net(x)
        rho,p,u,v = y[:, 0:1], y[:, 1:2], y[:, 2:3],y[:,3:]
        
        drho_g = gradients(rho, x)[0]                                  # Gradient [rho_t, rho_x]
        rho_x,rho_y = drho_g[:, :1], drho_g[:, 1:2]                    # Partial derivatives rho_t, rho_x
        du_g = gradients(u, x)[0]                                      # Gradient [u_t, u_x]
        u_x, u_y = du_g[:, :1], du_g[:, 1:2]                            # Partial derivatives u_t, u_x
        dv_g = gradients(v, x)[0]                                      # Gradient [u_t, u_x]
        v_x, v_y = dv_g[:, :1], dv_g[:, 1:2]                            # Partial derivatives u_t, u_x
        dp_g = gradients(p, x)[0]                                      # Gradient [p_t, p_x]
        p_x, p_y = dp_g[:, :1], dp_g[:, 1:2]                            # Partial derivatives p_t, p_x
        
        deltau = u_x + v_y
        lam = 0.1*(abs(deltau) - deltau) + 1
        
        f = ((( u_x)/lam)**2).mean() +\
            ((( v_x)/lam)**2).mean() +\
            ((( p_x)/lam)**2).mean() +\
            ((( rho_x)/lam)**2).mean()
        return f
     
    # Loss function for PDE
    def loss_pde(self, x):
        y = self.net(x)                                                # Neural network
        rho,p,u,v = y[:, 0:1], y[:, 1:2], y[:, 2:3],y[:,3:]
        gamma = 1.4                                                    # Heat Capacity Ratio
        epsilon = 1e-5
        s = torch.log((abs(p)+epsilon)/(abs(rho)+epsilon)**1.4)
        eta = -rho*s
        phi1 = -rho*u*s
        phi2 = -rho*v*s
        
        drho_g = gradients(rho, x)[0]                                  # Gradient [rho_t, rho_x]
        rho_t, rho_x,rho_y = drho_g[:, :1], drho_g[:, 1:2],drho_g[:,2:]
        du_g = gradients(u, x)[0]                                      # Gradient [u_t, u_x]
        u_t, u_x, u_y = du_g[:, :1], du_g[:, 1:2], du_g[:,2:]                            # Partial derivatives u_t, u_x
        dv_g = gradients(v, x)[0]                                      # Gradient [u_t, u_x]
        v_t, v_x, v_y = dv_g[:, :1], dv_g[:, 1:2], dv_g[:,2:]                            # Partial derivatives u_t, u_x
        
        
        deta_g = gradients(eta, x)[0]                                      # Gradient [p_t, p_x]
        eta_t, eta_x,eta_y = deta_g[:, :1], deta_g[:, 1:2],deta_g[2:3]                            # Partial derivatives p_t, p_x
        dphi1_g = gradients(phi1, x)[0]                                      # Gradient [p_t, p_x]
        dphi2_g = gradients(phi2, x)[0]                                      # Gradient [p_t, p_x]
        phi1_t, phi1_x,phi1_y = dphi1_g[:, :1], dphi1_g[:, 1:2],dphi1_g[:,2:3]                           # Partial derivatives p_t, p_x
        phi2_t, phi2_x,phi2_y = dphi2_g[:, :1], dphi2_g[:, 1:2],dphi2_g[:,2:3]                           # Partial derivatives p_t, p_x
        
        deltau = u_x + v_y
        nab = abs(deltau) - deltau
        
        q = 0.1*(rho*nab**2)
        
        lam = 0.1*nab + 1
        
       # p = p+q
        
        dp_g = gradients(p, x)[0]                                      # Gradient [p_t, p_x]
        p_t, p_x, p_y = dp_g[:, :1], dp_g[:, 1:2], dp_g[:,2:]                            # Partial derivatives p_t, p_x
        

        f = (((rho_t+rho*deltau+u*rho_x + v*rho_y)/lam)**2).mean() +\
            (((rho*u_t+rho*u*u_x+rho*v*u_y+p_x)/lam)**2).mean() +\
            (((rho*v_t+rho*u*v_x+rho*v*v_y+p_y)/lam)**2).mean() +\
            (((p_t+u*p_x+v*p_y+1.4*p*deltau)/lam)**2).mean() #+ \
            #((abs(rho-12) - (rho-12))**2).mean()  # + \
            #(((abs(eta_t+phi1_x + phi2_y)+eta_t+phi1_x+ phi2_y))**2).mean()
    
        return f

    # Loss function for initial condition
    def loss_ic(self, x_ic, rho_ic, u_ic, v_ic,p_ic):
        U_ic = self.net(x_ic)                                                      # Initial condition
        rho_ic_nn, p_ic_nn,u_ic_nn,v_ic_nn = U_ic[:, 0], U_ic[:, 1], U_ic[:, 2],U_ic[:,3]            # rho, u, p - initial condition

        # Loss function for the initial condition
        loss_ics = ((u_ic_nn - u_ic) ** 2).mean() + \
               ((rho_ic_nn- rho_ic) ** 2).mean()  + \
               ((p_ic_nn - p_ic) ** 2).mean() +\
               ((v_ic_nn - v_ic) ** 2).mean()

        return loss_ics

    def loss_bc(self, x_ic, rho_ic, u_ic, v_ic,p_ic):
        U_ic = self.net(x_ic)                                                      # Initial condition
        rho_ic_nn, p_ic_nn,u_ic_nn,v_ic_nn = U_ic[:, 0], U_ic[:, 1], U_ic[:, 2],U_ic[:,3]            # rho, u, p - initial condition

        # Loss function for the initial condition
        loss_ics = ((u_ic_nn - u_ic) ** 2).mean() + \
               ((rho_ic_nn- rho_ic) ** 2).mean()  + \
               ((p_ic_nn - p_ic) ** 2).mean() +\
               ((v_ic_nn - v_ic) ** 2).mean()

        return loss_ics
    def loss_bc1(self, x_ic, rho_ic, u_ic, v_ic,p_ic):
        U_ic = self.net(x_ic)                                                      # Initial condition
        rho_ic_nn, p_ic_nn,u_ic_nn,v_ic_nn = U_ic[:, 0], U_ic[:, 1], U_ic[:, 2],U_ic[:,3]            # rho, u, p - initial condition

        # Loss function for the initial condition
        loss_ics = ((rho_ic_nn- rho_ic) ** 2).mean()  + \
               ((p_ic_nn - p_ic) ** 2).mean() 

        return loss_ics

def BD_circle(t,xc,yc,r,n):
    x = np.zeros((n,3)) 
    sin = np.zeros((n,1)) 
    cos = np.zeros((n,1)) 

    for i in range(n):
        the = np.random.rand()*np.pi
        xd = np.cos(the + np.pi/2)
        yd = np.sin(the + np.pi/2)
        x[i,0] = np.random.rand()*t
        x[i,1] = xc  + xd*r
        x[i,2] = yc  + yd*r
        cos[i,0] = xd 
        sin[i,0] = yd
        #cos[i,0] = 1
        #sin[i,0] = 0
    return x, sin,cos
def BD_front(n1,n2):
    x = np.zeros((n1+n2,2)) 
    for i in range(n1):
        x[i,0] = 1.0
        x[i,1] = i*(0.2/n1)
    for i in range(n1,n2):
        x[i,0] = 1.0 + (3.0/n1)
        x[i,1] = 0.2
    return x

# Solve Euler equations using PINNs
# def main():
  # Initialization
#device = torch.device('cuda')                                          # Run on CPU
device = torch.device('cuda')                                          # Run on CPU
lr = 0.0001                                                           # Learning rate
num_ib = 1000                                                # Random sampled points from IC0
num_int = 10000                                                # Random sampled points in interior
Tend = 1.0
Lx = 1.0
Ly = 2.0
rx = 1.0
ry = 1.0
rd = 0.3

xlimits = np.array([[0.0,Tend],[0.0, Lx], [0.0,Ly]])  #interal
sampling = LHS(xlimits=xlimits)
x_int_train = sampling(num_int)
A = []
for i in range(num_int):
    x = x_int_train[i,1]
    y = x_int_train[i,2]
    if ((x-rx)**2 + (y-ry)**2 ) < rd**2:
        A.append(i)
x_int_train = np.delete(x_int_train,A,axis=0)

x_cut_train = np.zeros((num_ib,3))
for i in range(num_ib):
    theta = np.random.rand()*np.pi + np.pi/2
    r = np.random.rand()*rd
    x_cut_train[i,1] = r*np.cos(theta) + 2
    x_cut_train[i,2] = r*np.sin(theta) + 1

xlimits = np.array([[0.0,Tend],[0.0, 0.0], [0.0,Ly]])
sampling = LHS(xlimits=xlimits)
x_bcL_train =  sampling(num_ib)

xlimits = np.array([[0.0,Tend], [Lx, Lx], [0.0,Ly]])
sampling = LHS(xlimits=xlimits)
x_bcR_train =  sampling(num_ib)


xlimits = np.array([[0.0,Tend],[0.0, Lx], [Ly,Ly]])
sampling = LHS(xlimits=xlimits)
x_bcU_train =  sampling(num_ib)

xlimits = np.array([[0.0,Tend], [0.0, Lx], [0.0,0.0]])
sampling = LHS(xlimits=xlimits)
x_bcD_train =  sampling(num_ib)                                           # Vectorized whole domain

xlimits = np.array([[0.0,0.0],[0.0, Lx], [0.0,Ly]])
sampling = LHS(xlimits=xlimits)
x_ic_train =  sampling(num_ib)
A = []
for i in range(num_ib):
    x = x_ic_train[i,1]
    y = x_ic_train[i,2]
    if ((x-rx)**2 + (y-ry)**2 ) < rd**2:
        A.append(i)
x_ic_train = np.delete(x_ic_train,A,axis=0)


x_bcI_train,sin_bcI_train,cos_bcI_train = BD_circle(Tend,rx,ry,rd,num_ib)

rho_bcL_train, u_bcL_train,v_bcL_train, p_bcL_train = BC_L(x_bcL_train)  
rho_bcR_train, u_bcR_train,v_bcR_train, p_bcR_train = BC_L(x_bcR_train)  
rho_cut_train, u_cut_train,v_cut_train, p_cut_train = BC_Cut(x_cut_train)  

rho_ic_train, u_ic_train,v_ic_train, p_ic_train = IC(x_ic_train)  


x_int_train = torch.tensor(x_int_train, requires_grad=True, dtype=torch.float32).to(device)

rho_bcL_train = torch.tensor(rho_bcL_train, dtype=torch.float32).to(device)
u_bcL_train = torch.tensor(u_bcL_train, dtype=torch.float32).to(device)
v_bcL_train = torch.tensor(v_bcL_train, dtype=torch.float32).to(device)
p_bcL_train = torch.tensor(p_bcL_train, dtype=torch.float32).to(device)

rho_bcR_train = torch.tensor(rho_bcR_train, dtype=torch.float32).to(device)
u_bcR_train = torch.tensor(u_bcR_train, dtype=torch.float32).to(device)
v_bcR_train = torch.tensor(v_bcR_train, dtype=torch.float32).to(device)
p_bcR_train = torch.tensor(p_bcR_train, dtype=torch.float32).to(device)

x_bcD_train = torch.tensor(x_bcD_train,requires_grad=True, dtype=torch.float32).to(device)
x_bcU_train = torch.tensor(x_bcU_train, requires_grad=True, dtype=torch.float32).to(device)
x_bcR_train = torch.tensor(x_bcR_train, requires_grad=True, dtype=torch.float32).to(device)
x_bcL_train = torch.tensor(x_bcL_train, dtype=torch.float32).to(device)
x_bcI_train = torch.tensor(x_bcI_train, requires_grad=True, dtype=torch.float32).to(device)
sin_bcI_train = torch.tensor(sin_bcI_train, dtype=torch.float32).to(device)
cos_bcI_train = torch.tensor(cos_bcI_train, dtype=torch.float32).to(device)

rho_cut_train = torch.tensor(rho_cut_train, dtype=torch.float32).to(device)
u_cut_train = torch.tensor(u_cut_train, dtype=torch.float32).to(device)
v_cut_train = torch.tensor(v_cut_train, dtype=torch.float32).to(device)
p_cut_train = torch.tensor(p_cut_train, dtype=torch.float32).to(device)
x_cut_train = torch.tensor(x_cut_train, dtype=torch.float32).to(device)

rho_ic_train = torch.tensor(rho_ic_train, dtype=torch.float32).to(device)
u_ic_train = torch.tensor(u_ic_train, dtype=torch.float32).to(device)
v_ic_train = torch.tensor(v_ic_train, dtype=torch.float32).to(device)
p_ic_train = torch.tensor(p_ic_train, dtype=torch.float32).to(device)
x_ic_train = torch.tensor(x_ic_train, dtype=torch.float32).to(device)


#rho_ic_train.clone().detach().requires_grad_(True)
#u_ic_train.clone().detach().requires_grad_(True)
# Initialize neural network

print('Start training...')
# Out:
# Start training...

# %%
model = DNN().to(device)

# %%
lr = 0.001
optimizer = torch.optim.LBFGS(model.parameters(),lr=lr,max_iter=500)
#optimizer = torch.optim.Adam(model.parameters(), lr=lr)

# %%
epochs = 30000
tic = time.time()
for epoch in range(1, epochs+1):
    train(epoch)
toc = time.time()
print(f'Total training time: {toc - tic}')
# Out:
# epoch 1 loss_pde:2.76693463, loss_ib:0.82834744
# epoch 1 loss_pde:2.76718402, loss_ib:0.82829595
# epoch 1 loss_pde:2.76630878, loss_ib:0.82811451
# epoch 1 loss_pde:2.76649284, loss_ib:0.82806408
# epoch 1 loss_pde:2.76663041, loss_ib:0.82801712
# epoch 1 loss_pde:2.76687217, loss_ib:0.82794309
# epoch 1 loss_pde:2.76708245, loss_ib:0.82785881
# epoch 1 loss_pde:2.76730633, loss_ib:0.82778203
# epoch 1 loss_pde:2.76738310, loss_ib:0.82770699
# epoch 1 loss_pde:2.76758885, loss_ib:0.82762933
# epoch 1 loss_pde:2.76780343, loss_ib:0.82754731
# epoch 1 loss_pde:2.76802754, loss_ib:0.82746148
# epoch 1 loss_pde:2.76825476, loss_ib:0.82737088
# epoch 1 loss_pde:2.76848507, loss_ib:0.82727700
# epoch 1 loss_pde:2.76871872, loss_ib:0.82718074
# epoch 1 loss_pde:2.76895046, loss_ib:0.82708198
# epoch 1 loss_pde:2.76918221, loss_ib:0.82698226
# epoch 1 loss_pde:2.76941371, loss_ib:0.82688087
# epoch 1 loss_pde:2.76964116, loss_ib:0.82677883
# epoch 1 loss_pde:2.76986885, loss_ib:0.82667565
# epoch 1 loss_pde:2.77009273, loss_ib:0.82657254
# epoch 1 loss_pde:2.77031159, loss_ib:0.82646859
# epoch 1 loss_pde:2.77053070, loss_ib:0.82636523
# epoch 1 loss_pde:2.77074552, loss_ib:0.82626176
# epoch 1 loss_pde:2.77095556, loss_ib:0.82615817
# epoch 1 loss_pde:2.77116251, loss_ib:0.82605553
# epoch 1 loss_pde:2.77136540, loss_ib:0.82595301
# epoch 1 loss_pde:2.77156448, loss_ib:0.82585061
# epoch 1 loss_pde:2.77176166, loss_ib:0.82574856
# epoch 1 loss_pde:2.77195501, loss_ib:0.82564729
# epoch 1 loss_pde:2.77214289, loss_ib:0.82554710
# epoch 1 loss_pde:2.77232695, loss_ib:0.82544756
# epoch 1 loss_pde:2.77250624, loss_ib:0.82534885
# epoch 1 loss_pde:2.77268505, loss_ib:0.82525027
# epoch 1 loss_pde:2.77285743, loss_ib:0.82515311
# epoch 1 loss_pde:2.77302766, loss_ib:0.82505596
# epoch 1 loss_pde:2.77319503, loss_ib:0.82496023
# epoch 1 loss_pde:2.77335501, loss_ib:0.82486522
# epoch 1 loss_pde:2.77351713, loss_ib:0.82477117
# epoch 1 loss_pde:2.77367306, loss_ib:0.82467818
# epoch 1 loss_pde:2.77382326, loss_ib:0.82458526
# epoch 1 loss_pde:2.77397203, loss_ib:0.82449383
# epoch 1 loss_pde:2.77411914, loss_ib:0.82440317
# epoch 1 loss_pde:2.77426147, loss_ib:0.82431316
# epoch 1 loss_pde:2.77440047, loss_ib:0.82422423
# epoch 1 loss_pde:2.77453852, loss_ib:0.82413578
# epoch 1 loss_pde:2.77466965, loss_ib:0.82404840
# epoch 1 loss_pde:2.77480698, loss_ib:0.82395911
# epoch 1 loss_pde:2.77493382, loss_ib:0.82387412
# epoch 1 loss_pde:2.77505565, loss_ib:0.82378924
# epoch 1 loss_pde:2.77518082, loss_ib:0.82370460
# epoch 1 loss_pde:2.77530098, loss_ib:0.82362103
# epoch 1 loss_pde:2.77541542, loss_ib:0.82353818
# epoch 1 loss_pde:2.77552938, loss_ib:0.82345629
# epoch 1 loss_pde:2.77564597, loss_ib:0.82337505
# epoch 1 loss_pde:2.77575970, loss_ib:0.82329196
# epoch 1 loss_pde:2.77586746, loss_ib:0.82321227
# epoch 1 loss_pde:2.77597356, loss_ib:0.82313251
# epoch 1 loss_pde:2.77607775, loss_ib:0.82305384
# epoch 1 loss_pde:2.77618217, loss_ib:0.82297564
# epoch 1 loss_pde:2.77628732, loss_ib:0.82289708
# epoch 1 loss_pde:2.77639341, loss_ib:0.82281840
# epoch 1 loss_pde:2.77649450, loss_ib:0.82274002
# epoch 1 loss_pde:2.77659369, loss_ib:0.82266319
# epoch 1 loss_pde:2.77668905, loss_ib:0.82258677
# epoch 1 loss_pde:2.77678323, loss_ib:0.82251120
# epoch 1 loss_pde:2.77686882, loss_ib:0.82243657
# epoch 1 loss_pde:2.77696157, loss_ib:0.82236171
# epoch 1 loss_pde:2.77704620, loss_ib:0.82228816
# epoch 1 loss_pde:2.77713251, loss_ib:0.82221484
# epoch 1 loss_pde:2.77721977, loss_ib:0.82214159
# epoch 1 loss_pde:2.77729535, loss_ib:0.82206905
# epoch 1 loss_pde:2.77738476, loss_ib:0.82199526
# epoch 1 loss_pde:2.77745605, loss_ib:0.82192332
# epoch 1 loss_pde:2.77754426, loss_ib:0.82184923
# epoch 1 loss_pde:2.77761221, loss_ib:0.82177526
# epoch 1 loss_pde:2.77770424, loss_ib:0.82170123
# epoch 1 loss_pde:2.77776575, loss_ib:0.82163197
# epoch 1 loss_pde:2.77783394, loss_ib:0.82156193
# epoch 1 loss_pde:2.77789855, loss_ib:0.82149285
# epoch 1 loss_pde:2.77796721, loss_ib:0.82142353
# epoch 1 loss_pde:2.77802873, loss_ib:0.82135546
# epoch 1 loss_pde:2.77809191, loss_ib:0.82128781
# epoch 1 loss_pde:2.77815175, loss_ib:0.82122099
# epoch 1 loss_pde:2.77821279, loss_ib:0.82115412
# epoch 1 loss_pde:2.77826905, loss_ib:0.82108808
# epoch 1 loss_pde:2.77832985, loss_ib:0.82102197
# epoch 1 loss_pde:2.77838397, loss_ib:0.82095695
# epoch 1 loss_pde:2.77844262, loss_ib:0.82089192
# epoch 1 loss_pde:2.77849436, loss_ib:0.82082844
# epoch 1 loss_pde:2.77854562, loss_ib:0.82076424
# epoch 1 loss_pde:2.77859974, loss_ib:0.82070076
# epoch 1 loss_pde:2.77865338, loss_ib:0.82063770
# epoch 1 loss_pde:2.77870369, loss_ib:0.82057506
# epoch 1 loss_pde:2.77875423, loss_ib:0.82051253
# epoch 1 loss_pde:2.77880764, loss_ib:0.82045019
# epoch 1 loss_pde:2.77886200, loss_ib:0.82038808
# epoch 1 loss_pde:2.77890778, loss_ib:0.82032657
# epoch 1 loss_pde:2.77896380, loss_ib:0.82026350
# epoch 1 loss_pde:2.77901220, loss_ib:0.82020247
# epoch 1 loss_pde:2.77907014, loss_ib:0.82013988
# epoch 1 loss_pde:2.77911520, loss_ib:0.82007825
# epoch 1 loss_pde:2.77917361, loss_ib:0.82001513
# epoch 1 loss_pde:2.77949834, loss_ib:0.81992543
# epoch 1 loss_pde:2.77956367, loss_ib:0.81986415
# epoch 1 loss_pde:2.77963519, loss_ib:0.81980127
# epoch 1 loss_pde:2.77958107, loss_ib:0.81975043
# epoch 1 loss_pde:2.77965188, loss_ib:0.81968617
# epoch 1 loss_pde:2.77896285, loss_ib:0.81968647
# epoch 1 loss_pde:2.77902007, loss_ib:0.81962711
# epoch 1 loss_pde:2.77903104, loss_ib:0.81957543
# epoch 1 loss_pde:2.77913094, loss_ib:0.81951237
# epoch 1 loss_pde:2.77877855, loss_ib:0.81946659
# epoch 1 loss_pde:2.77882361, loss_ib:0.81941390
# epoch 1 loss_pde:2.77886748, loss_ib:0.81936193
# epoch 1 loss_pde:2.77891803, loss_ib:0.81930900
# epoch 1 loss_pde:2.77894163, loss_ib:0.81925857
# epoch 1 loss_pde:2.77899528, loss_ib:0.81920469
# epoch 1 loss_pde:2.77895117, loss_ib:0.81915820
# epoch 1 loss_pde:2.77896976, loss_ib:0.81910992
# epoch 1 loss_pde:2.77904701, loss_ib:0.81905258
# epoch 1 loss_pde:2.77901220, loss_ib:0.81900358
# epoch 1 loss_pde:2.77903271, loss_ib:0.81895387
# epoch 1 loss_pde:2.77908230, loss_ib:0.81889975
# epoch 1 loss_pde:2.77910018, loss_ib:0.81884813
# epoch 1 loss_pde:2.77919531, loss_ib:0.81878477
# epoch 1 loss_pde:2.77909875, loss_ib:0.81872463
# epoch 1 loss_pde:2.77912831, loss_ib:0.81866908
# epoch 1 loss_pde:2.77915788, loss_ib:0.81861401
# epoch 1 loss_pde:2.77918458, loss_ib:0.81855834
# epoch 1 loss_pde:2.77922273, loss_ib:0.81849933
# epoch 1 loss_pde:2.77917576, loss_ib:0.81844389
# epoch 1 loss_pde:2.77917647, loss_ib:0.81838739
# epoch 1 loss_pde:2.77919674, loss_ib:0.81832743
# epoch 1 loss_pde:2.77919483, loss_ib:0.81826741
# epoch 1 loss_pde:2.77920842, loss_ib:0.81820142
# epoch 1 loss_pde:2.77920437, loss_ib:0.81813490
# epoch 1 loss_pde:2.77920127, loss_ib:0.81807184
# epoch 1 loss_pde:2.77919412, loss_ib:0.81800842
# epoch 1 loss_pde:2.77919459, loss_ib:0.81794357
# epoch 1 loss_pde:2.77918100, loss_ib:0.81787884
# epoch 1 loss_pde:2.77931070, loss_ib:0.81779385
# epoch 1 loss_pde:2.77934432, loss_ib:0.81772733
# epoch 1 loss_pde:2.77933168, loss_ib:0.81765735
# epoch 1 loss_pde:2.77936840, loss_ib:0.81758100
# epoch 1 loss_pde:2.77907062, loss_ib:0.81751603
# epoch 1 loss_pde:2.77904463, loss_ib:0.81744885
# epoch 1 loss_pde:2.77903438, loss_ib:0.81737554
# epoch 1 loss_pde:2.77902365, loss_ib:0.81730103
# epoch 1 loss_pde:2.77899361, loss_ib:0.81722540
# epoch 1 loss_pde:2.77895975, loss_ib:0.81714797
# epoch 1 loss_pde:2.77892184, loss_ib:0.81706989
# epoch 1 loss_pde:2.77887774, loss_ib:0.81699169
# epoch 1 loss_pde:2.77883458, loss_ib:0.81691289
# epoch 1 loss_pde:2.77878428, loss_ib:0.81683439
# epoch 1 loss_pde:2.77872992, loss_ib:0.81675589
# epoch 1 loss_pde:2.77867556, loss_ib:0.81667751
# epoch 1 loss_pde:2.77861667, loss_ib:0.81659901
# epoch 1 loss_pde:2.77855706, loss_ib:0.81652021
# epoch 1 loss_pde:2.77849030, loss_ib:0.81644225
# epoch 1 loss_pde:2.77842498, loss_ib:0.81636417
# epoch 1 loss_pde:2.77835321, loss_ib:0.81628644
# epoch 1 loss_pde:2.77828312, loss_ib:0.81620812
# epoch 1 loss_pde:2.77820826, loss_ib:0.81613016
# epoch 1 loss_pde:2.77813387, loss_ib:0.81605291
# epoch 1 loss_pde:2.77805567, loss_ib:0.81597519
# epoch 1 loss_pde:2.77797818, loss_ib:0.81589735
# epoch 1 loss_pde:2.77789640, loss_ib:0.81582022
# epoch 1 loss_pde:2.77781510, loss_ib:0.81574321
# epoch 1 loss_pde:2.77772832, loss_ib:0.81566632
# epoch 1 loss_pde:2.77764773, loss_ib:0.81558919
# epoch 1 loss_pde:2.77754521, loss_ib:0.81551325
# epoch 1 loss_pde:2.77747393, loss_ib:0.81543368
# epoch 1 loss_pde:2.77713418, loss_ib:0.81536877
# epoch 1 loss_pde:2.77706122, loss_ib:0.81529725
# epoch 1 loss_pde:2.77699614, loss_ib:0.81523383
# epoch 1 loss_pde:2.77692866, loss_ib:0.81517017
# epoch 1 loss_pde:2.77686620, loss_ib:0.81510651
# epoch 1 loss_pde:2.77679753, loss_ib:0.81504309
# epoch 1 loss_pde:2.77673030, loss_ib:0.81497937
# epoch 1 loss_pde:2.77666306, loss_ib:0.81491584
# epoch 1 loss_pde:2.77659559, loss_ib:0.81485271
# epoch 1 loss_pde:2.77652764, loss_ib:0.81478947
# epoch 1 loss_pde:2.77645779, loss_ib:0.81472588
# epoch 1 loss_pde:2.77639031, loss_ib:0.81466234
# epoch 1 loss_pde:2.77632284, loss_ib:0.81459987
# epoch 1 loss_pde:2.77625513, loss_ib:0.81453657
# epoch 1 loss_pde:2.77618790, loss_ib:0.81447333
# epoch 1 loss_pde:2.77612066, loss_ib:0.81440997
# epoch 1 loss_pde:2.77605200, loss_ib:0.81434721
# epoch 1 loss_pde:2.77598596, loss_ib:0.81428409
# epoch 1 loss_pde:2.77591610, loss_ib:0.81422096
# epoch 1 loss_pde:2.77585125, loss_ib:0.81415749
# epoch 1 loss_pde:2.77578282, loss_ib:0.81409478
# epoch 1 loss_pde:2.77571535, loss_ib:0.81403160
# epoch 1 loss_pde:2.77565002, loss_ib:0.81396860
# epoch 1 loss_pde:2.77557993, loss_ib:0.81390542
# epoch 1 loss_pde:2.77551389, loss_ib:0.81384254
# epoch 1 loss_pde:2.77544570, loss_ib:0.81377959
# epoch 1 loss_pde:2.77537918, loss_ib:0.81371659
# epoch 1 loss_pde:2.77531290, loss_ib:0.81365389
# epoch 1 loss_pde:2.77524805, loss_ib:0.81359076
# epoch 1 loss_pde:2.77517843, loss_ib:0.81352818
# epoch 1 loss_pde:2.77511549, loss_ib:0.81346500
# epoch 1 loss_pde:2.77504325, loss_ib:0.81340277
# epoch 1 loss_pde:2.77498555, loss_ib:0.81333894
# epoch 1 loss_pde:2.77486110, loss_ib:0.81327999
# epoch 1 loss_pde:2.77477264, loss_ib:0.81321800
# epoch 1 loss_pde:2.77466750, loss_ib:0.81315947
# epoch 1 loss_pde:2.77462578, loss_ib:0.81309402
# epoch 1 loss_pde:2.77382994, loss_ib:0.81295788
# epoch 1 loss_pde:2.77372050, loss_ib:0.81290197
# epoch 1 loss_pde:2.77363873, loss_ib:0.81284583
# epoch 1 loss_pde:2.77407980, loss_ib:0.81272936
# epoch 1 loss_pde:2.77399802, loss_ib:0.81266838
# epoch 1 loss_pde:2.77393866, loss_ib:0.81260991
# epoch 1 loss_pde:2.77392173, loss_ib:0.81254447
# epoch 1 loss_pde:2.77391744, loss_ib:0.81248003
# epoch 1 loss_pde:2.77386236, loss_ib:0.81241930
# epoch 1 loss_pde:2.77381420, loss_ib:0.81235719
# epoch 1 loss_pde:2.77425957, loss_ib:0.81222647
# epoch 1 loss_pde:2.77420878, loss_ib:0.81216609
# epoch 1 loss_pde:2.77415085, loss_ib:0.81210607
# epoch 1 loss_pde:2.77409458, loss_ib:0.81204569
# epoch 1 loss_pde:2.77403307, loss_ib:0.81198502
# epoch 1 loss_pde:2.77396989, loss_ib:0.81192422
# epoch 1 loss_pde:2.77390456, loss_ib:0.81186330
# epoch 1 loss_pde:2.77384114, loss_ib:0.81180155
# epoch 1 loss_pde:2.77384925, loss_ib:0.81173086
# epoch 1 loss_pde:2.77378345, loss_ib:0.81166267
# epoch 1 loss_pde:2.77372766, loss_ib:0.81159651
# epoch 1 loss_pde:2.77366877, loss_ib:0.81153256
# epoch 1 loss_pde:2.77359438, loss_ib:0.81146586
# epoch 1 loss_pde:2.77350187, loss_ib:0.81139874
# epoch 1 loss_pde:2.77341986, loss_ib:0.81132931
# epoch 1 loss_pde:2.77334499, loss_ib:0.81125939
# epoch 1 loss_pde:2.77323866, loss_ib:0.81119263
# epoch 1 loss_pde:2.77316713, loss_ib:0.81112152
# epoch 1 loss_pde:2.77292013, loss_ib:0.81105673
# epoch 1 loss_pde:2.77284288, loss_ib:0.81099379
# epoch 1 loss_pde:2.77275205, loss_ib:0.81092548
# epoch 1 loss_pde:2.77264786, loss_ib:0.81085861
# epoch 1 loss_pde:2.77261996, loss_ib:0.81078124
# epoch 1 loss_pde:2.77235293, loss_ib:0.81070465
# epoch 1 loss_pde:2.77224731, loss_ib:0.81063563
# epoch 1 loss_pde:2.77215219, loss_ib:0.81056511
# epoch 1 loss_pde:2.77204537, loss_ib:0.81049514
# epoch 1 loss_pde:2.77211952, loss_ib:0.81040418
# epoch 1 loss_pde:2.77111435, loss_ib:0.81029916
# epoch 1 loss_pde:2.77099419, loss_ib:0.81022942
# epoch 1 loss_pde:2.77089167, loss_ib:0.81015897
# epoch 1 loss_pde:2.77078652, loss_ib:0.81008559
# epoch 1 loss_pde:2.77067304, loss_ib:0.81001043
# epoch 1 loss_pde:2.77066398, loss_ib:0.80990934
# epoch 1 loss_pde:2.77054048, loss_ib:0.80984306
# epoch 1 loss_pde:2.77041912, loss_ib:0.80976707
# epoch 1 loss_pde:2.77029467, loss_ib:0.80968958
# epoch 1 loss_pde:2.77017665, loss_ib:0.80961013
# epoch 1 loss_pde:2.77005148, loss_ib:0.80952942
# epoch 1 loss_pde:2.76991963, loss_ib:0.80944675
# epoch 1 loss_pde:2.76970220, loss_ib:0.80935764
# epoch 1 loss_pde:2.76951075, loss_ib:0.80927789
# epoch 1 loss_pde:2.76931858, loss_ib:0.80919325
# epoch 1 loss_pde:2.76913738, loss_ib:0.80910546
# epoch 1 loss_pde:2.76904321, loss_ib:0.80900133
# epoch 1 loss_pde:2.76892281, loss_ib:0.80890948
# epoch 1 loss_pde:2.76863527, loss_ib:0.80881643
# epoch 1 loss_pde:2.76865220, loss_ib:0.80866015
# epoch 1 loss_pde:2.76846123, loss_ib:0.80856586
# epoch 1 loss_pde:2.76826239, loss_ib:0.80846858
# epoch 1 loss_pde:2.76805639, loss_ib:0.80836928
# epoch 1 loss_pde:2.76785183, loss_ib:0.80826890
# epoch 1 loss_pde:2.76763892, loss_ib:0.80816782
# epoch 1 loss_pde:2.76742148, loss_ib:0.80806559
# epoch 1 loss_pde:2.76940727, loss_ib:0.80770314
# epoch 1 loss_pde:2.76917839, loss_ib:0.80759501
# epoch 1 loss_pde:2.76885581, loss_ib:0.80744278
# epoch 1 loss_pde:2.76852393, loss_ib:0.80729234
# epoch 1 loss_pde:2.76818585, loss_ib:0.80714267
# epoch 1 loss_pde:2.76784110, loss_ib:0.80699492
# epoch 1 loss_pde:2.76749158, loss_ib:0.80684876
# epoch 1 loss_pde:2.76713943, loss_ib:0.80670369
# epoch 1 loss_pde:2.76678371, loss_ib:0.80656040
# epoch 1 loss_pde:2.76642609, loss_ib:0.80641806
# epoch 1 loss_pde:2.76606488, loss_ib:0.80627704
# epoch 1 loss_pde:2.76569533, loss_ib:0.80613655
# epoch 1 loss_pde:2.76533103, loss_ib:0.80599791
# epoch 1 loss_pde:2.76496434, loss_ib:0.80586171
# epoch 1 loss_pde:2.76459694, loss_ib:0.80572522
# epoch 1 loss_pde:2.76422787, loss_ib:0.80559123
# epoch 1 loss_pde:2.76386094, loss_ib:0.80545801
# epoch 1 loss_pde:2.76349258, loss_ib:0.80532587
# epoch 1 loss_pde:2.76312184, loss_ib:0.80519450
# epoch 1 loss_pde:2.76275206, loss_ib:0.80506450
# epoch 1 loss_pde:2.76238537, loss_ib:0.80493498
# epoch 1 loss_pde:2.76201534, loss_ib:0.80480617
# epoch 1 loss_pde:2.76164627, loss_ib:0.80467927
# epoch 1 loss_pde:2.76127625, loss_ib:0.80455303
# epoch 1 loss_pde:2.76091123, loss_ib:0.80442673
# epoch 1 loss_pde:2.76053953, loss_ib:0.80430233
# epoch 1 loss_pde:2.76017666, loss_ib:0.80417764
# epoch 1 loss_pde:2.75980496, loss_ib:0.80405480
# epoch 1 loss_pde:2.75944901, loss_ib:0.80392909
# epoch 1 loss_pde:2.75901937, loss_ib:0.80380476
# epoch 1 loss_pde:2.75864959, loss_ib:0.80365551
# epoch 1 loss_pde:2.75823402, loss_ib:0.80352831
# epoch 1 loss_pde:2.75786233, loss_ib:0.80339944
# epoch 1 loss_pde:2.75749993, loss_ib:0.80326653
# epoch 1 loss_pde:2.75720072, loss_ib:0.80314761
# epoch 1 loss_pde:2.75683832, loss_ib:0.80301988
# epoch 1 loss_pde:2.75648856, loss_ib:0.80289322
# epoch 1 loss_pde:2.75612903, loss_ib:0.80276799
# epoch 1 loss_pde:2.75557756, loss_ib:0.80261481
# epoch 1 loss_pde:2.75516295, loss_ib:0.80247617
# epoch 1 loss_pde:2.75478768, loss_ib:0.80235660
# epoch 1 loss_pde:2.75441074, loss_ib:0.80223596
# epoch 1 loss_pde:2.75391936, loss_ib:0.80204433
# epoch 1 loss_pde:2.75355029, loss_ib:0.80193055
# epoch 1 loss_pde:2.75320482, loss_ib:0.80182242
# epoch 1 loss_pde:2.75285912, loss_ib:0.80171388
# epoch 1 loss_pde:2.75250769, loss_ib:0.80160570
# epoch 1 loss_pde:2.75216198, loss_ib:0.80149758
# epoch 1 loss_pde:2.75174570, loss_ib:0.80139291
# epoch 1 loss_pde:2.75141811, loss_ib:0.80128527
# epoch 1 loss_pde:2.75131130, loss_ib:0.80107439
# epoch 1 loss_pde:2.75091934, loss_ib:0.80096841
# epoch 1 loss_pde:2.75052738, loss_ib:0.80085170
# epoch 1 loss_pde:2.75013018, loss_ib:0.80073839
# epoch 1 loss_pde:2.74974251, loss_ib:0.80062366
# epoch 1 loss_pde:2.74935031, loss_ib:0.80051076
# epoch 1 loss_pde:2.74896526, loss_ib:0.80039769
# epoch 1 loss_pde:2.74857903, loss_ib:0.80028528
# epoch 1 loss_pde:2.74819613, loss_ib:0.80017376
# epoch 1 loss_pde:2.74781346, loss_ib:0.80006301
# epoch 1 loss_pde:2.74743485, loss_ib:0.79995251
# epoch 1 loss_pde:2.74705553, loss_ib:0.79984260
# epoch 1 loss_pde:2.74667788, loss_ib:0.79973304
# epoch 1 loss_pde:2.74630332, loss_ib:0.79962468
# epoch 1 loss_pde:2.74592495, loss_ib:0.79951668
# epoch 1 loss_pde:2.74558353, loss_ib:0.79940492
# epoch 1 loss_pde:2.73997116, loss_ib:0.79953593
# epoch 1 loss_pde:2.73957372, loss_ib:0.79943907
# epoch 1 loss_pde:2.73930335, loss_ib:0.79936719
# epoch 1 loss_pde:2.73905993, loss_ib:0.79928935
# epoch 1 loss_pde:2.73879409, loss_ib:0.79920447
# epoch 1 loss_pde:2.73851800, loss_ib:0.79912055
# epoch 1 loss_pde:2.73824215, loss_ib:0.79903877
# epoch 1 loss_pde:2.73800826, loss_ib:0.79894722
# epoch 1 loss_pde:2.73767781, loss_ib:0.79886085
# epoch 1 loss_pde:2.73746037, loss_ib:0.79875338
# epoch 1 loss_pde:2.73711729, loss_ib:0.79867041
# epoch 1 loss_pde:2.73702931, loss_ib:0.79855943
# epoch 1 loss_pde:2.73671198, loss_ib:0.79847181
# epoch 1 loss_pde:2.73649669, loss_ib:0.79837716
# epoch 1 loss_pde:2.73611069, loss_ib:0.79829472
# epoch 1 loss_pde:2.73592544, loss_ib:0.79816687
# epoch 1 loss_pde:2.73558164, loss_ib:0.79807878
# epoch 1 loss_pde:2.73531818, loss_ib:0.79798758
# epoch 1 loss_pde:2.73499203, loss_ib:0.79789972
# epoch 1 loss_pde:2.73469114, loss_ib:0.79780567
# epoch 1 loss_pde:2.73438811, loss_ib:0.79771280
# epoch 1 loss_pde:2.73415661, loss_ib:0.79760838
# epoch 1 loss_pde:2.73386598, loss_ib:0.79751784
# epoch 1 loss_pde:2.73354506, loss_ib:0.79742563
# epoch 1 loss_pde:2.73432255, loss_ib:0.79714859
# epoch 1 loss_pde:2.73403049, loss_ib:0.79705465
# epoch 1 loss_pde:2.73371863, loss_ib:0.79695731
# epoch 1 loss_pde:2.73334122, loss_ib:0.79686284
# epoch 1 loss_pde:2.73299098, loss_ib:0.79676509
# epoch 1 loss_pde:2.73261094, loss_ib:0.79666519
# epoch 1 loss_pde:2.73227692, loss_ib:0.79656243
# epoch 1 loss_pde:2.73183990, loss_ib:0.79646170
# epoch 1 loss_pde:2.73147321, loss_ib:0.79636681
# epoch 1 loss_pde:2.73143935, loss_ib:0.79615033
# epoch 1 loss_pde:2.73108792, loss_ib:0.79604399
# epoch 1 loss_pde:2.72999096, loss_ib:0.79599470
# epoch 1 loss_pde:2.72948098, loss_ib:0.79584718
# epoch 1 loss_pde:2.72912383, loss_ib:0.79573882
# epoch 1 loss_pde:2.72874212, loss_ib:0.79563123
# epoch 1 loss_pde:2.72834659, loss_ib:0.79551631
# epoch 1 loss_pde:2.72793269, loss_ib:0.79540956
# epoch 1 loss_pde:2.72757006, loss_ib:0.79529166
# epoch 1 loss_pde:2.72698379, loss_ib:0.79518616
# epoch 1 loss_pde:2.72656584, loss_ib:0.79506433
# epoch 1 loss_pde:2.72616506, loss_ib:0.79493529
# epoch 1 loss_pde:2.72577834, loss_ib:0.79481006
# epoch 1 loss_pde:2.72491050, loss_ib:0.79466271
# epoch 1 loss_pde:2.72444248, loss_ib:0.79452592
# epoch 1 loss_pde:2.72397470, loss_ib:0.79439402
# epoch 1 loss_pde:2.72351623, loss_ib:0.79425585
# epoch 1 loss_pde:2.72301602, loss_ib:0.79411983
# epoch 1 loss_pde:2.72256565, loss_ib:0.79397202
# epoch 1 loss_pde:2.72206736, loss_ib:0.79382932
# epoch 1 loss_pde:2.72155213, loss_ib:0.79368383
# epoch 1 loss_pde:2.72103453, loss_ib:0.79353511
# epoch 1 loss_pde:2.72050571, loss_ib:0.79338682
# epoch 1 loss_pde:2.71997428, loss_ib:0.79323530
# epoch 1 loss_pde:2.71943426, loss_ib:0.79308337
# epoch 1 loss_pde:2.71888876, loss_ib:0.79292947
# epoch 1 loss_pde:2.71833682, loss_ib:0.79277539
# epoch 1 loss_pde:2.71778321, loss_ib:0.79261953
# epoch 1 loss_pde:2.71722269, loss_ib:0.79246199
# epoch 1 loss_pde:2.71666265, loss_ib:0.79230499
# epoch 1 loss_pde:2.71609092, loss_ib:0.79214633
# epoch 1 loss_pde:2.71552253, loss_ib:0.79198766
# epoch 1 loss_pde:2.71494746, loss_ib:0.79182804
# epoch 1 loss_pde:2.71439147, loss_ib:0.79166448
# epoch 1 loss_pde:2.71375990, loss_ib:0.79150426
# epoch 1 loss_pde:2.71319818, loss_ib:0.79133701
# epoch 1 loss_pde:2.71255231, loss_ib:0.79118013
# epoch 1 loss_pde:2.71199775, loss_ib:0.79101783
# epoch 1 loss_pde:2.71139598, loss_ib:0.79086149
# epoch 1 loss_pde:2.71083689, loss_ib:0.79069400
# epoch 1 loss_pde:2.71022272, loss_ib:0.79054141
# epoch 1 loss_pde:2.70984268, loss_ib:0.79029042
# epoch 1 loss_pde:2.70930862, loss_ib:0.79012907
# epoch 1 loss_pde:2.70872927, loss_ib:0.78996885
# epoch 1 loss_pde:2.70814323, loss_ib:0.78980517
# epoch 1 loss_pde:2.70739603, loss_ib:0.78959417
# epoch 1 loss_pde:2.70679998, loss_ib:0.78943253
# epoch 1 loss_pde:2.70619726, loss_ib:0.78925252
# epoch 1 loss_pde:2.70563078, loss_ib:0.78909922
# epoch 1 loss_pde:2.70507765, loss_ib:0.78894269
# epoch 1 loss_pde:2.70445299, loss_ib:0.78877342
# epoch 1 loss_pde:2.70386410, loss_ib:0.78862315
# epoch 1 loss_pde:2.70349455, loss_ib:0.78843063
# epoch 1 loss_pde:2.70296907, loss_ib:0.78827357
# epoch 1 loss_pde:2.70249391, loss_ib:0.78809333
# epoch 1 loss_pde:2.70193553, loss_ib:0.78791678
# epoch 1 loss_pde:2.70140362, loss_ib:0.78775966
# epoch 1 loss_pde:2.70088506, loss_ib:0.78759760
# epoch 1 loss_pde:2.70033836, loss_ib:0.78743649
# epoch 1 loss_pde:2.69981599, loss_ib:0.78727102
# epoch 1 loss_pde:2.69926047, loss_ib:0.78710657
# epoch 1 loss_pde:2.69874191, loss_ib:0.78693897
# epoch 1 loss_pde:2.69819474, loss_ib:0.78677469
# epoch 1 loss_pde:2.69768524, loss_ib:0.78660572
# epoch 1 loss_pde:2.69714236, loss_ib:0.78644145
# epoch 1 loss_pde:2.69663310, loss_ib:0.78627098
# epoch 1 loss_pde:2.69608307, loss_ib:0.78610480
# epoch 1 loss_pde:2.69558430, loss_ib:0.78593332
# epoch 1 loss_pde:2.69418812, loss_ib:0.78580678
# epoch 1 loss_pde:2.69364333, loss_ib:0.78562373
# epoch 1 loss_pde:2.69306850, loss_ib:0.78544796
# epoch 1 loss_pde:2.69222951, loss_ib:0.78528959
# epoch 1 loss_pde:2.69164753, loss_ib:0.78510451
# epoch 1 loss_pde:2.69106030, loss_ib:0.78492540
# epoch 1 loss_pde:2.69054270, loss_ib:0.78473854
# epoch 1 loss_pde:2.68995810, loss_ib:0.78455853
# epoch 1 loss_pde:2.68941283, loss_ib:0.78437543
# epoch 1 loss_pde:2.68879652, loss_ib:0.78419751
# epoch 1 loss_pde:2.68833351, loss_ib:0.78399742
# epoch 1 loss_pde:2.68773961, loss_ib:0.78381085
# epoch 1 loss_pde:2.68719864, loss_ib:0.78362834
# epoch 1 loss_pde:2.68663549, loss_ib:0.78344983
# epoch 1 loss_pde:2.68609190, loss_ib:0.78326797
# epoch 1 loss_pde:2.68553948, loss_ib:0.78308690
# epoch 1 loss_pde:2.68497586, loss_ib:0.78291124
# epoch 1 loss_pde:2.68453145, loss_ib:0.78272086
# epoch 1 loss_pde:2.68399668, loss_ib:0.78254837
# epoch 1 loss_pde:2.68343306, loss_ib:0.78238070
# epoch 1 loss_pde:2.68308520, loss_ib:0.78218532
# epoch 1 loss_pde:2.68259263, loss_ib:0.78201675
# epoch 1 loss_pde:2.68203187, loss_ib:0.78184944
# epoch 1 loss_pde:2.68201876, loss_ib:0.78159976
# epoch 1 loss_pde:2.68153095, loss_ib:0.78144884
# epoch 1 loss_pde:2.68148446, loss_ib:0.78123790
# epoch 1 loss_pde:2.68106771, loss_ib:0.78108841
# epoch 1 loss_pde:2.67969871, loss_ib:0.78096873
# epoch 1 loss_pde:2.67927408, loss_ib:0.78080785
# epoch 1 loss_pde:2.67881942, loss_ib:0.78065711
# epoch 1 loss_pde:2.67836618, loss_ib:0.78050888
# epoch 1 loss_pde:2.67792177, loss_ib:0.78036022
# epoch 1 loss_pde:2.67747164, loss_ib:0.78021240
# epoch 1 loss_pde:2.67703772, loss_ib:0.78006518
# epoch 1 loss_pde:2.67660451, loss_ib:0.77991897
# epoch 1 loss_pde:2.67616940, loss_ib:0.77977395
# epoch 1 loss_pde:2.67575312, loss_ib:0.77962863
# epoch 1 loss_pde:2.67533064, loss_ib:0.77948588
# epoch 1 loss_pde:2.67492700, loss_ib:0.77934182
# epoch 1 loss_pde:2.67450690, loss_ib:0.77920020
# epoch 1 loss_pde:2.67411065, loss_ib:0.77905732
# epoch 1 loss_pde:2.67370772, loss_ib:0.77891749
# epoch 1 loss_pde:2.67333102, loss_ib:0.77877676
# epoch 1 loss_pde:2.67293382, loss_ib:0.77863967
# epoch 1 loss_pde:2.67254090, loss_ib:0.77850556
# epoch 1 loss_pde:2.67214322, loss_ib:0.77837288
# epoch 1 loss_pde:2.67177558, loss_ib:0.77823842
# epoch 1 loss_pde:2.67139125, loss_ib:0.77810693
# epoch 1 loss_pde:2.67104840, loss_ib:0.77797127
# epoch 1 loss_pde:2.67067862, loss_ib:0.77784050
# epoch 1 loss_pde:2.67031860, loss_ib:0.77770972
# epoch 1 loss_pde:2.66994119, loss_ib:0.77758336
# epoch 1 loss_pde:2.66958761, loss_ib:0.77745759
# epoch 1 loss_pde:2.66922259, loss_ib:0.77733314
# epoch 1 loss_pde:2.66887808, loss_ib:0.77720881
# epoch 1 loss_pde:2.66852307, loss_ib:0.77708638
# epoch 1 loss_pde:2.66819119, loss_ib:0.77696341
# epoch 1 loss_pde:2.66784406, loss_ib:0.77684283
# epoch 1 loss_pde:2.66751814, loss_ib:0.77672166
# epoch 1: loss 11.050408
# epoch 2 loss_pde:2.66717792, loss_ib:0.77660251
# epoch 2 loss_pde:2.66685939, loss_ib:0.77648306
# epoch 2 loss_pde:2.66652369, loss_ib:0.77636611
# epoch 2 loss_pde:2.66621065, loss_ib:0.77624762
# epoch 2 loss_pde:2.66587806, loss_ib:0.77613211
# epoch 2 loss_pde:2.66556025, loss_ib:0.77601624
# epoch 2 loss_pde:2.66523004, loss_ib:0.77590287
# epoch 2 loss_pde:2.66492748, loss_ib:0.77578747
# epoch 2 loss_pde:2.66460681, loss_ib:0.77567494
# epoch 2 loss_pde:2.66429543, loss_ib:0.77556264
# epoch 2 loss_pde:2.66397548, loss_ib:0.77545172
# epoch 2 loss_pde:2.66367269, loss_ib:0.77534074
# epoch 2 loss_pde:2.66335964, loss_ib:0.77523041
# epoch 2 loss_pde:2.66305542, loss_ib:0.77512062
# epoch 2 loss_pde:2.66273785, loss_ib:0.77501237
# epoch 2 loss_pde:2.66246295, loss_ib:0.77489948
# epoch 2 loss_pde:2.66054797, loss_ib:0.77468121
# epoch 2 loss_pde:2.66029716, loss_ib:0.77457416
# epoch 2 loss_pde:2.66004825, loss_ib:0.77448112
# epoch 2 loss_pde:2.65979743, loss_ib:0.77438867
# epoch 2 loss_pde:2.65954089, loss_ib:0.77429700
# epoch 2 loss_pde:2.65926719, loss_ib:0.77420616
# epoch 2 loss_pde:2.65886545, loss_ib:0.77401030
# epoch 2 loss_pde:2.65863657, loss_ib:0.77391696
# epoch 2 loss_pde:2.65840173, loss_ib:0.77382797
# epoch 2 loss_pde:2.65816236, loss_ib:0.77374005
# epoch 2 loss_pde:2.65780687, loss_ib:0.77366084
# epoch 2 loss_pde:2.65754461, loss_ib:0.77356184
# epoch 2 loss_pde:2.65728831, loss_ib:0.77347463
# epoch 2 loss_pde:2.65700102, loss_ib:0.77315831
# epoch 2 loss_pde:2.65678048, loss_ib:0.77307272
# epoch 2 loss_pde:2.65657544, loss_ib:0.77299988
# epoch 2 loss_pde:2.65636444, loss_ib:0.77292728
# epoch 2 loss_pde:2.65613270, loss_ib:0.77283990
# epoch 2 loss_pde:2.65592742, loss_ib:0.77276927
# epoch 2 loss_pde:2.65571237, loss_ib:0.77269852
# epoch 2 loss_pde:2.65550089, loss_ib:0.77262604
# epoch 2 loss_pde:2.65525341, loss_ib:0.77255297
# epoch 2 loss_pde:2.65507388, loss_ib:0.77246171
# epoch 2 loss_pde:2.65474463, loss_ib:0.77237713
# epoch 2 loss_pde:2.65453005, loss_ib:0.77230185
# epoch 2 loss_pde:2.65430951, loss_ib:0.77222717
# epoch 2 loss_pde:2.65378618, loss_ib:0.77217823
# epoch 2 loss_pde:2.65357232, loss_ib:0.77210593
# epoch 2 loss_pde:2.65332651, loss_ib:0.77202863
# epoch 2 loss_pde:2.65306139, loss_ib:0.77195752
# epoch 2 loss_pde:2.65366316, loss_ib:0.77170837
# epoch 2 loss_pde:2.65341830, loss_ib:0.77163398
# epoch 2 loss_pde:2.65322757, loss_ib:0.77155375
# epoch 2 loss_pde:2.65289783, loss_ib:0.77148533
# epoch 2 loss_pde:2.65270829, loss_ib:0.77140266
# epoch 2 loss_pde:2.65237117, loss_ib:0.77133250
# epoch 2 loss_pde:2.65215468, loss_ib:0.77125132
# epoch 2 loss_pde:2.65186644, loss_ib:0.77117759
# epoch 2 loss_pde:2.65164256, loss_ib:0.77109635
# epoch 2 loss_pde:2.65139127, loss_ib:0.77101916
# epoch 2 loss_pde:2.65114379, loss_ib:0.77093816
# epoch 2 loss_pde:2.65089703, loss_ib:0.77086031
# epoch 2 loss_pde:2.65064597, loss_ib:0.77078170
# epoch 2 loss_pde:2.65040112, loss_ib:0.77070212
# epoch 2 loss_pde:2.65014100, loss_ib:0.77062237
# epoch 2 loss_pde:2.64989114, loss_ib:0.77054191
# epoch 2 loss_pde:2.64964533, loss_ib:0.77045894
# epoch 2 loss_pde:2.64939451, loss_ib:0.77037573
# epoch 2 loss_pde:2.64913011, loss_ib:0.77029234
# epoch 2 loss_pde:2.64889646, loss_ib:0.77020502
# epoch 2 loss_pde:2.64814639, loss_ib:0.77011395
# epoch 2 loss_pde:2.64795184, loss_ib:0.77001172
# epoch 2 loss_pde:2.64768457, loss_ib:0.76992750
# epoch 2 loss_pde:2.64495087, loss_ib:0.77006876
# epoch 2 loss_pde:2.64469695, loss_ib:0.76998395
# epoch 2 loss_pde:2.64441705, loss_ib:0.76989442
# epoch 2 loss_pde:2.64414668, loss_ib:0.76980305
# epoch 2 loss_pde:2.64385176, loss_ib:0.76971233
# epoch 2 loss_pde:2.64357114, loss_ib:0.76961803
# epoch 2 loss_pde:2.64326143, loss_ib:0.76952642
# epoch 2 loss_pde:2.64299774, loss_ib:0.76942635
# epoch 2 loss_pde:2.64268899, loss_ib:0.76932907
# epoch 2 loss_pde:2.64236307, loss_ib:0.76923323
# epoch 2 loss_pde:2.64205194, loss_ib:0.76913410
# epoch 2 loss_pde:2.64169645, loss_ib:0.76903552
# epoch 2 loss_pde:2.64165401, loss_ib:0.76888907
# epoch 2 loss_pde:2.64136815, loss_ib:0.76879871
# epoch 2 loss_pde:2.64094925, loss_ib:0.76868713
# epoch 2 loss_pde:2.64059663, loss_ib:0.76858902
# epoch 2 loss_pde:2.64022279, loss_ib:0.76848543
# epoch 2 loss_pde:2.63983917, loss_ib:0.76838076
# epoch 2 loss_pde:2.63944888, loss_ib:0.76827401
# epoch 2 loss_pde:2.63900924, loss_ib:0.76816809
# epoch 2 loss_pde:2.63884211, loss_ib:0.76801252
# epoch 2 loss_pde:2.63848877, loss_ib:0.76789939
# epoch 2 loss_pde:2.63804984, loss_ib:0.76778519
# epoch 2 loss_pde:2.63754654, loss_ib:0.76766527
# epoch 2 loss_pde:2.63703775, loss_ib:0.76753783
# epoch 2 loss_pde:2.63653612, loss_ib:0.76741701
# epoch 2 loss_pde:2.63601828, loss_ib:0.76728857
# epoch 2 loss_pde:2.63546228, loss_ib:0.76716805
# epoch 2 loss_pde:2.63491201, loss_ib:0.76703894
# epoch 2 loss_pde:2.63436222, loss_ib:0.76690477
# epoch 2 loss_pde:2.63378453, loss_ib:0.76677442
# epoch 2 loss_pde:2.63314533, loss_ib:0.76662028
# epoch 2 loss_pde:2.63265061, loss_ib:0.76646876
# epoch 2 loss_pde:2.63168359, loss_ib:0.76631290
# epoch 2 loss_pde:2.63097334, loss_ib:0.76616025
# epoch 2 loss_pde:2.63014150, loss_ib:0.76598644
# epoch 2 loss_pde:2.62888837, loss_ib:0.76578891
# epoch 2 loss_pde:2.62803912, loss_ib:0.76561832
# epoch 2 loss_pde:2.62706041, loss_ib:0.76544225
# epoch 2 loss_pde:2.62616491, loss_ib:0.76526797
# epoch 2 loss_pde:2.62520909, loss_ib:0.76508427
# epoch 2 loss_pde:2.62421346, loss_ib:0.76489627
# epoch 2 loss_pde:2.62318921, loss_ib:0.76470840
# epoch 2 loss_pde:2.62214279, loss_ib:0.76451576
# epoch 2 loss_pde:2.62106872, loss_ib:0.76432347
# epoch 2 loss_pde:2.61997747, loss_ib:0.76412868
# epoch 2 loss_pde:2.61886120, loss_ib:0.76393306
# epoch 2 loss_pde:2.61773014, loss_ib:0.76373589
# epoch 2 loss_pde:2.61654234, loss_ib:0.76354170
# epoch 2 loss_pde:2.61520410, loss_ib:0.76306558
# epoch 2 loss_pde:2.61404800, loss_ib:0.76287794
# epoch 2 loss_pde:2.61300063, loss_ib:0.76270533
# epoch 2 loss_pde:2.61194825, loss_ib:0.76253313
# epoch 2 loss_pde:2.61090207, loss_ib:0.76236081
# epoch 2 loss_pde:2.60984540, loss_ib:0.76218897
# epoch 2 loss_pde:2.60878444, loss_ib:0.76201773
# epoch 2 loss_pde:2.60766363, loss_ib:0.76183057
# epoch 2 loss_pde:2.60603189, loss_ib:0.76158679
# epoch 2 loss_pde:2.60497022, loss_ib:0.76141322
# epoch 2 loss_pde:2.60340714, loss_ib:0.76127541
# epoch 2 loss_pde:2.60236192, loss_ib:0.76112294
# epoch 2 loss_pde:2.60132074, loss_ib:0.76097113
# epoch 2 loss_pde:2.58771706, loss_ib:0.75917208
# epoch 2 loss_pde:2.58676171, loss_ib:0.75904930
# epoch 2 loss_pde:2.58607054, loss_ib:0.75894600
# epoch 2 loss_pde:2.58530569, loss_ib:0.75883996
# epoch 2 loss_pde:2.58457732, loss_ib:0.75872064
# epoch 2 loss_pde:2.58381653, loss_ib:0.75861096
# epoch 2 loss_pde:2.58309841, loss_ib:0.75849330
# epoch 2 loss_pde:2.58231497, loss_ib:0.75837749
# epoch 2 loss_pde:2.58156419, loss_ib:0.75825465
# epoch 2 loss_pde:2.58075070, loss_ib:0.75813246
# epoch 2 loss_pde:2.57995534, loss_ib:0.75800395
# epoch 2 loss_pde:2.57912660, loss_ib:0.75787723
# epoch 2 loss_pde:2.57819772, loss_ib:0.75774175
# epoch 2 loss_pde:2.57724214, loss_ib:0.75761604
# epoch 2 loss_pde:2.57646227, loss_ib:0.75747359
# epoch 2 loss_pde:2.57558942, loss_ib:0.75734484
# epoch 2 loss_pde:2.57489347, loss_ib:0.75716031
# epoch 2 loss_pde:2.57378578, loss_ib:0.75700599
# epoch 2 loss_pde:2.57293153, loss_ib:0.75687039
# epoch 2 loss_pde:2.57200909, loss_ib:0.75673652
# epoch 2 loss_pde:2.57107878, loss_ib:0.75659966
# epoch 2 loss_pde:2.57012296, loss_ib:0.75646365
# epoch 2 loss_pde:2.56916928, loss_ib:0.75632471
# epoch 2 loss_pde:2.56819201, loss_ib:0.75618649
# epoch 2 loss_pde:2.56720972, loss_ib:0.75604784
# epoch 2 loss_pde:2.56621885, loss_ib:0.75590909
# epoch 2 loss_pde:2.56520987, loss_ib:0.75576985
# epoch 2 loss_pde:2.56421280, loss_ib:0.75563043
# epoch 2 loss_pde:2.56318712, loss_ib:0.75549293
# epoch 2 loss_pde:2.56217766, loss_ib:0.75535297
# epoch 2 loss_pde:2.56113410, loss_ib:0.75521588
# epoch 2 loss_pde:2.56011939, loss_ib:0.75507641
# epoch 2 loss_pde:2.55908608, loss_ib:0.75494039
# epoch 2 loss_pde:2.55806899, loss_ib:0.75480402
# epoch 2 loss_pde:2.55704355, loss_ib:0.75466824
# epoch 2 loss_pde:2.55602026, loss_ib:0.75453389
# epoch 2 loss_pde:2.55498528, loss_ib:0.75440121
# epoch 2 loss_pde:2.55394745, loss_ib:0.75425911
# epoch 2 loss_pde:2.55269098, loss_ib:0.75412285
# epoch 2 loss_pde:2.55166316, loss_ib:0.75398558
# epoch 2 loss_pde:2.55024004, loss_ib:0.75388503
# epoch 2 loss_pde:2.54226899, loss_ib:0.75264359
# epoch 2 loss_pde:2.54139423, loss_ib:0.75252813
# epoch 2 loss_pde:2.54053736, loss_ib:0.75242937
# epoch 2 loss_pde:2.53985405, loss_ib:0.75230652
# epoch 2 loss_pde:2.53898716, loss_ib:0.75220025
# epoch 2 loss_pde:2.53814435, loss_ib:0.75209236
# epoch 2 loss_pde:2.53726554, loss_ib:0.75198931
# epoch 2 loss_pde:2.53645754, loss_ib:0.75187051
# epoch 2 loss_pde:2.53551650, loss_ib:0.75176430
# epoch 2 loss_pde:2.53454494, loss_ib:0.75165403
# epoch 2 loss_pde:2.53358340, loss_ib:0.75155079
# epoch 2 loss_pde:2.53176022, loss_ib:0.75145859
# epoch 2 loss_pde:2.53083563, loss_ib:0.75135469
# epoch 2 loss_pde:2.52987123, loss_ib:0.75125265
# epoch 2 loss_pde:2.52885985, loss_ib:0.75112855
# epoch 2 loss_pde:2.52784872, loss_ib:0.75101882
# epoch 2 loss_pde:2.52691555, loss_ib:0.75091839
# epoch 2 loss_pde:2.52600479, loss_ib:0.75081348
# epoch 2 loss_pde:2.52507710, loss_ib:0.75070918
# epoch 2 loss_pde:2.52329540, loss_ib:0.75066108
# epoch 2 loss_pde:2.52231002, loss_ib:0.75055587
# epoch 2 loss_pde:2.52135205, loss_ib:0.75045985
# epoch 2 loss_pde:2.52071238, loss_ib:0.75030845
# epoch 2 loss_pde:2.51984000, loss_ib:0.75021929
# epoch 2 loss_pde:2.51894236, loss_ib:0.75011170
# epoch 2 loss_pde:2.51798916, loss_ib:0.75001025
# epoch 2 loss_pde:2.51737618, loss_ib:0.74984568
# epoch 2 loss_pde:2.51649714, loss_ib:0.74974447
# epoch 2 loss_pde:2.51537943, loss_ib:0.74964106
# epoch 2 loss_pde:2.51436853, loss_ib:0.74953556
# epoch 2 loss_pde:2.51336432, loss_ib:0.74942982
# epoch 2 loss_pde:2.51232529, loss_ib:0.74932671
# epoch 2 loss_pde:2.51134372, loss_ib:0.74921608
# epoch 2 loss_pde:2.51018572, loss_ib:0.74911439
# epoch 2 loss_pde:2.50919938, loss_ib:0.74898601
# epoch 2 loss_pde:2.50652766, loss_ib:0.74881810
# epoch 2 loss_pde:2.50551462, loss_ib:0.74871027
# epoch 2 loss_pde:2.50452685, loss_ib:0.74861145
# epoch 2 loss_pde:2.50354481, loss_ib:0.74851269
# epoch 2 loss_pde:2.50255346, loss_ib:0.74841487
# epoch 2 loss_pde:2.50156426, loss_ib:0.74831665
# epoch 2 loss_pde:2.50056601, loss_ib:0.74821872
# epoch 2 loss_pde:2.49956846, loss_ib:0.74812090
# epoch 2 loss_pde:2.49855804, loss_ib:0.74802381
# epoch 2 loss_pde:2.49754953, loss_ib:0.74792695
# epoch 2 loss_pde:2.49652100, loss_ib:0.74783045
# epoch 2 loss_pde:2.49548936, loss_ib:0.74773371
# epoch 2 loss_pde:2.49427795, loss_ib:0.74764776
# epoch 2 loss_pde:2.49247980, loss_ib:0.74745977
# epoch 2 loss_pde:2.49134731, loss_ib:0.74736047
# epoch 2 loss_pde:2.49031115, loss_ib:0.74726522
# epoch 2 loss_pde:2.48920321, loss_ib:0.74717152
# epoch 2 loss_pde:2.48814869, loss_ib:0.74707651
# epoch 2 loss_pde:2.48705816, loss_ib:0.74698699
# epoch 2 loss_pde:2.48598480, loss_ib:0.74689269
# epoch 2 loss_pde:2.48480988, loss_ib:0.74679983
# epoch 2 loss_pde:2.48360610, loss_ib:0.74668938
# epoch 2 loss_pde:2.48251343, loss_ib:0.74659383
# epoch 2 loss_pde:2.47596312, loss_ib:0.74659729
# epoch 2 loss_pde:2.47493362, loss_ib:0.74650300
# epoch 2 loss_pde:2.47385645, loss_ib:0.74642015
# epoch 2 loss_pde:2.47278619, loss_ib:0.74632609
# epoch 2 loss_pde:2.46998334, loss_ib:0.74609542
# epoch 2 loss_pde:2.46895719, loss_ib:0.74601424
# epoch 2 loss_pde:2.46803045, loss_ib:0.74592537
# epoch 2 loss_pde:2.46704721, loss_ib:0.74584150
# epoch 2 loss_pde:2.46610284, loss_ib:0.74575567
# epoch 2 loss_pde:2.46512818, loss_ib:0.74567360
# epoch 2 loss_pde:2.46401739, loss_ib:0.74560058
# epoch 2 loss_pde:2.46293330, loss_ib:0.74551934
# epoch 2 loss_pde:2.46184349, loss_ib:0.74544239
# epoch 2 loss_pde:2.46086359, loss_ib:0.74535263
# epoch 2 loss_pde:2.45974565, loss_ib:0.74526465
# epoch 2 loss_pde:2.45861602, loss_ib:0.74516845
# epoch 2 loss_pde:2.45752573, loss_ib:0.74508470
# epoch 2 loss_pde:2.45647025, loss_ib:0.74499989
# epoch 2 loss_pde:2.45543289, loss_ib:0.74492431
# epoch 2 loss_pde:2.45449448, loss_ib:0.74481726
# epoch 2 loss_pde:2.45361471, loss_ib:0.74474275
# epoch 2 loss_pde:2.45170665, loss_ib:0.74469137
# epoch 2 loss_pde:2.45070100, loss_ib:0.74461472
# epoch 2 loss_pde:2.44966221, loss_ib:0.74453861
# epoch 2 loss_pde:2.44808745, loss_ib:0.74444914
# epoch 2 loss_pde:2.44706464, loss_ib:0.74437416
# epoch 2 loss_pde:2.44607663, loss_ib:0.74430370
# epoch 2 loss_pde:2.44510174, loss_ib:0.74422979
# epoch 2 loss_pde:2.44410849, loss_ib:0.74415737
# epoch 2 loss_pde:2.44301319, loss_ib:0.74409032
# epoch 2 loss_pde:2.44193769, loss_ib:0.74400795
# epoch 2 loss_pde:2.44086409, loss_ib:0.74392951
# epoch 2 loss_pde:2.43977022, loss_ib:0.74385238
# epoch 2 loss_pde:2.43860984, loss_ib:0.74377310
# epoch 2 loss_pde:2.43740630, loss_ib:0.74364769
# epoch 2 loss_pde:2.43634748, loss_ib:0.74356842
# epoch 2 loss_pde:2.43499994, loss_ib:0.74346828
# epoch 2 loss_pde:2.43381739, loss_ib:0.74338847
# epoch 2 loss_pde:2.43231201, loss_ib:0.74328327
# epoch 2 loss_pde:2.43079758, loss_ib:0.74318016
# epoch 2 loss_pde:2.42954111, loss_ib:0.74309009
# epoch 2 loss_pde:2.42826223, loss_ib:0.74300158
# epoch 2 loss_pde:2.42699385, loss_ib:0.74290860
# epoch 2 loss_pde:2.42560101, loss_ib:0.74281919
# epoch 2 loss_pde:2.42428803, loss_ib:0.74273032
# epoch 2 loss_pde:2.42296433, loss_ib:0.74264061
# epoch 2 loss_pde:2.42139816, loss_ib:0.74252856
# epoch 2 loss_pde:2.42019415, loss_ib:0.74244839
# epoch 2 loss_pde:2.41887975, loss_ib:0.74236059
# epoch 2 loss_pde:2.41753054, loss_ib:0.74227488
# epoch 2 loss_pde:2.41637111, loss_ib:0.74215841
# epoch 2 loss_pde:2.41507459, loss_ib:0.74207973
# epoch 2 loss_pde:2.41377616, loss_ib:0.74198294
# epoch 2 loss_pde:2.41257358, loss_ib:0.74189198
# epoch 2 loss_pde:2.41130996, loss_ib:0.74180371
# epoch 2 loss_pde:2.40955806, loss_ib:0.74174732
# epoch 2 loss_pde:2.40836525, loss_ib:0.74166638
# epoch 2 loss_pde:2.40703893, loss_ib:0.74158323
# epoch 2 loss_pde:2.40552068, loss_ib:0.74149024
# epoch 2 loss_pde:2.40418625, loss_ib:0.74140716
# epoch 2 loss_pde:2.40286970, loss_ib:0.74132693
# epoch 2 loss_pde:2.40153837, loss_ib:0.74124944
# epoch 2 loss_pde:2.40026665, loss_ib:0.74115944
# epoch 2 loss_pde:2.39841986, loss_ib:0.74106055
# epoch 2 loss_pde:2.39703751, loss_ib:0.74097836
# epoch 2 loss_pde:2.39563060, loss_ib:0.74090779
# epoch 2 loss_pde:2.39481473, loss_ib:0.74070978
# epoch 2 loss_pde:2.39360023, loss_ib:0.74063408
# epoch 2 loss_pde:2.39228892, loss_ib:0.74056637
# epoch 2 loss_pde:2.39056492, loss_ib:0.74051619
# epoch 2 loss_pde:2.38907337, loss_ib:0.74038059
# epoch 2 loss_pde:2.38782787, loss_ib:0.74031103
# epoch 2 loss_pde:2.38647866, loss_ib:0.74024975
# epoch 2 loss_pde:2.38497734, loss_ib:0.74007362
# epoch 2 loss_pde:2.38377285, loss_ib:0.74000329
# epoch 2 loss_pde:2.38252711, loss_ib:0.73994017
# epoch 2 loss_pde:2.38161850, loss_ib:0.73979092
# epoch 2 loss_pde:2.38054323, loss_ib:0.73972142
# epoch 2 loss_pde:2.37897635, loss_ib:0.73967546
# epoch 2 loss_pde:2.37780333, loss_ib:0.73961329
# epoch 2 loss_pde:2.37648773, loss_ib:0.73954457
# epoch 2 loss_pde:2.37518215, loss_ib:0.73947632
# epoch 2 loss_pde:2.37390685, loss_ib:0.73940820
# epoch 2 loss_pde:2.37253499, loss_ib:0.73934138
# epoch 2 loss_pde:2.37130666, loss_ib:0.73927045
# epoch 2 loss_pde:2.37000132, loss_ib:0.73920739
# epoch 2 loss_pde:2.36876798, loss_ib:0.73913658
# epoch 2 loss_pde:2.36747599, loss_ib:0.73907232
# epoch 2 loss_pde:2.36623096, loss_ib:0.73900241
# epoch 2 loss_pde:2.36490083, loss_ib:0.73893917
# epoch 2 loss_pde:2.36364436, loss_ib:0.73886764
# epoch 2 loss_pde:2.36225176, loss_ib:0.73880422
# epoch 2 loss_pde:2.36096430, loss_ib:0.73873246
# epoch 2 loss_pde:2.35961723, loss_ib:0.73866910
# epoch 2 loss_pde:2.35834837, loss_ib:0.73860025
# epoch 2 loss_pde:2.35699391, loss_ib:0.73853779
# epoch 2 loss_pde:2.35571432, loss_ib:0.73846734
# epoch 2 loss_pde:2.35435653, loss_ib:0.73840487
# epoch 2 loss_pde:2.35308123, loss_ib:0.73833507
# epoch 2 loss_pde:2.35172224, loss_ib:0.73827493
# epoch 2 loss_pde:2.35046554, loss_ib:0.73820657
# epoch 2 loss_pde:2.34908581, loss_ib:0.73815203
# epoch 2 loss_pde:2.34714270, loss_ib:0.73793995
# epoch 2 loss_pde:2.34582806, loss_ib:0.73787671
# epoch 2 loss_pde:2.34462166, loss_ib:0.73781347
# epoch 2 loss_pde:2.34345007, loss_ib:0.73775220
# epoch 2 loss_pde:2.34224939, loss_ib:0.73769104
# epoch 2 loss_pde:2.34097123, loss_ib:0.73763096
# epoch 2 loss_pde:2.33965993, loss_ib:0.73755985
# epoch 2 loss_pde:2.33839607, loss_ib:0.73750073
# epoch 2 loss_pde:2.33718824, loss_ib:0.73743629
# epoch 2 loss_pde:2.33596778, loss_ib:0.73737872
# epoch 2 loss_pde:2.33480382, loss_ib:0.73731828
# epoch 2 loss_pde:2.33360720, loss_ib:0.73726141
# epoch 2 loss_pde:2.33245468, loss_ib:0.73720253
# epoch 2 loss_pde:2.33125257, loss_ib:0.73714620
# epoch 2 loss_pde:2.33009982, loss_ib:0.73708534
# epoch 2 loss_pde:2.32889271, loss_ib:0.73702991
# epoch 2 loss_pde:2.32774591, loss_ib:0.73696899
# epoch 2 loss_pde:2.32654905, loss_ib:0.73691380
# epoch 2 loss_pde:2.32540751, loss_ib:0.73685336
# epoch 2 loss_pde:2.32421398, loss_ib:0.73679793
# epoch 2 loss_pde:2.32310271, loss_ib:0.73673308
# epoch 2 loss_pde:2.32153177, loss_ib:0.73666996
# epoch 2 loss_pde:2.32036114, loss_ib:0.73660970
# epoch 2 loss_pde:2.31925750, loss_ib:0.73655623
# epoch 2 loss_pde:2.31769896, loss_ib:0.73650706
# epoch 2 loss_pde:2.31623745, loss_ib:0.73642695
# epoch 2 loss_pde:2.31500030, loss_ib:0.73637414
# epoch 2 loss_pde:2.31390452, loss_ib:0.73631972
# epoch 2 loss_pde:2.31280947, loss_ib:0.73627055
# epoch 2 loss_pde:2.31175685, loss_ib:0.73621535
# epoch 2 loss_pde:2.31066608, loss_ib:0.73616600
# epoch 2 loss_pde:2.30962563, loss_ib:0.73611152
# epoch 2 loss_pde:2.30854416, loss_ib:0.73606241
# epoch 2 loss_pde:2.30751204, loss_ib:0.73600942
# epoch 2 loss_pde:2.30645561, loss_ib:0.73595667
# epoch 2 loss_pde:2.30543208, loss_ib:0.73590457
# epoch 2 loss_pde:2.30443096, loss_ib:0.73585427
# epoch 2 loss_pde:2.30343103, loss_ib:0.73580205
# epoch 2 loss_pde:2.30242443, loss_ib:0.73575079
# epoch 2 loss_pde:2.30142307, loss_ib:0.73569775
# epoch 2 loss_pde:2.30040598, loss_ib:0.73564637
# epoch 2 loss_pde:2.29934287, loss_ib:0.73558784
# epoch 2 loss_pde:2.29832649, loss_ib:0.73553783
# epoch 2 loss_pde:2.29733443, loss_ib:0.73548043
# epoch 2 loss_pde:2.29626775, loss_ib:0.73542720
# epoch 2 loss_pde:2.29524755, loss_ib:0.73537081
# epoch 2 loss_pde:2.29412460, loss_ib:0.73531240
# epoch 2 loss_pde:2.29315209, loss_ib:0.73525536
# epoch 2 loss_pde:2.29215598, loss_ib:0.73520219
# epoch 2 loss_pde:2.29102492, loss_ib:0.73514646
# epoch 2 loss_pde:2.29001880, loss_ib:0.73509812
# epoch 2 loss_pde:2.28905082, loss_ib:0.73504382
# epoch 2 loss_pde:2.28788090, loss_ib:0.73500329
# epoch 2 loss_pde:2.28674603, loss_ib:0.73493844
# epoch 2 loss_pde:2.28568053, loss_ib:0.73488796
# epoch 2 loss_pde:2.28565121, loss_ib:0.73468739
# epoch 2 loss_pde:2.28465390, loss_ib:0.73463428
# epoch 2 loss_pde:2.28378224, loss_ib:0.73455000
# epoch 2 loss_pde:2.28284049, loss_ib:0.73449707
# epoch 2 loss_pde:2.28187943, loss_ib:0.73443794
# epoch 2 loss_pde:2.28086400, loss_ib:0.73438096
# epoch 2 loss_pde:2.27989626, loss_ib:0.73432326
# epoch 2 loss_pde:2.27892232, loss_ib:0.73426503
# epoch 2 loss_pde:2.27792430, loss_ib:0.73420596
# epoch 2 loss_pde:2.27691531, loss_ib:0.73414612
# epoch 2 loss_pde:2.27608013, loss_ib:0.73406398
# epoch 2 loss_pde:2.27458954, loss_ib:0.73400074
# epoch 2 loss_pde:2.27362919, loss_ib:0.73393500
# epoch 2 loss_pde:2.27239943, loss_ib:0.73389518
# epoch 2 loss_pde:2.27144766, loss_ib:0.73383021
# epoch 2 loss_pde:2.27026701, loss_ib:0.73378712
# epoch 2 loss_pde:2.26937056, loss_ib:0.73373073
# epoch 2 loss_pde:2.27211809, loss_ib:0.73314691
# epoch 2 loss_pde:2.27118111, loss_ib:0.73309362
# epoch 2 loss_pde:2.27028322, loss_ib:0.73303854
# epoch 2 loss_pde:2.27152157, loss_ib:0.73273903
# epoch 2 loss_pde:2.27062273, loss_ib:0.73268372
# epoch 2 loss_pde:2.26969290, loss_ib:0.73262596
# epoch 2 loss_pde:2.26869464, loss_ib:0.73256540
# epoch 2 loss_pde:2.26783705, loss_ib:0.73250932
# epoch 2 loss_pde:2.26621914, loss_ib:0.73246098
# epoch 2 loss_pde:2.26526499, loss_ib:0.73240435
# epoch 2 loss_pde:2.26430511, loss_ib:0.73234153
# epoch 2 loss_pde:2.26253057, loss_ib:0.73230410
# epoch 2 loss_pde:2.26156545, loss_ib:0.73224384
# epoch 2 loss_pde:2.26060462, loss_ib:0.73218262
# epoch 2 loss_pde:2.25965619, loss_ib:0.73211658
# epoch 2 loss_pde:2.25851130, loss_ib:0.73205012
# epoch 2 loss_pde:2.25749302, loss_ib:0.73198330
# epoch 2 loss_pde:2.25646567, loss_ib:0.73191941
# epoch 2 loss_pde:2.25547242, loss_ib:0.73185366
# epoch 2 loss_pde:2.25445795, loss_ib:0.73178875
# epoch 2 loss_pde:2.25345087, loss_ib:0.73172009
# epoch 2 loss_pde:2.25133133, loss_ib:0.73169595
# epoch 2 loss_pde:2.25032640, loss_ib:0.73163074
# epoch 2 loss_pde:2.24942946, loss_ib:0.73157072
# epoch 2 loss_pde:2.24852562, loss_ib:0.73151016
# epoch 2 loss_pde:2.24761963, loss_ib:0.73144960
# epoch 2 loss_pde:2.24669170, loss_ib:0.73138827
# epoch 2 loss_pde:2.24576473, loss_ib:0.73132545
# epoch 2 loss_pde:2.24482775, loss_ib:0.73126292
# epoch 2 loss_pde:2.24389887, loss_ib:0.73119974
# epoch 2 loss_pde:2.24305177, loss_ib:0.73112702
# epoch 2 loss_pde:2.24211764, loss_ib:0.73106200
# epoch 2 loss_pde:2.24123335, loss_ib:0.73099113
# epoch 2 loss_pde:2.24017382, loss_ib:0.73092490
# epoch 2 loss_pde:2.23923969, loss_ib:0.73085576
# epoch 2 loss_pde:2.23821831, loss_ib:0.73079205
# epoch 2 loss_pde:2.23717022, loss_ib:0.73071074
# epoch 2 loss_pde:2.23621941, loss_ib:0.73064280
# epoch 2 loss_pde:2.23529625, loss_ib:0.73057950
# epoch 2 loss_pde:2.23437810, loss_ib:0.73050272
# epoch 2 loss_pde:2.23351097, loss_ib:0.73043817
# epoch 2 loss_pde:2.23251915, loss_ib:0.73038030
# epoch 2 loss_pde:2.23161316, loss_ib:0.73031569
# epoch 2 loss_pde:2.23067951, loss_ib:0.73025262
# epoch 2 loss_pde:2.22978687, loss_ib:0.73018384
# epoch 2 loss_pde:2.22877741, loss_ib:0.73012018
# epoch 2 loss_pde:2.22794199, loss_ib:0.73005307
# epoch 2 loss_pde:2.22701573, loss_ib:0.72998375
# epoch 2 loss_pde:2.22611475, loss_ib:0.72992438
# epoch 2 loss_pde:2.22524571, loss_ib:0.72986156
# epoch 2 loss_pde:2.22434688, loss_ib:0.72979784
# epoch 2 loss_pde:2.22347021, loss_ib:0.72972953
# epoch 2 loss_pde:2.22245717, loss_ib:0.72966504
# epoch 2 loss_pde:2.22162318, loss_ib:0.72960067
# epoch 2 loss_pde:2.22074389, loss_ib:0.72953641
# epoch 2 loss_pde:2.21981883, loss_ib:0.72946048
# epoch 2 loss_pde:2.21843815, loss_ib:0.72937232
# epoch 2 loss_pde:2.21760917, loss_ib:0.72930765
# epoch 2 loss_pde:2.21679473, loss_ib:0.72924513
# epoch 2 loss_pde:2.21600080, loss_ib:0.72917700
# epoch 2 loss_pde:2.21508265, loss_ib:0.72911108
# epoch 2 loss_pde:2.21424675, loss_ib:0.72903961
# epoch 2 loss_pde:2.21337271, loss_ib:0.72897607
# epoch 2 loss_pde:2.21256399, loss_ib:0.72890627
# epoch 2 loss_pde:2.21172285, loss_ib:0.72884321
# epoch 2 loss_pde:2.21094489, loss_ib:0.72877353
# epoch 2 loss_pde:2.21012664, loss_ib:0.72871006
# epoch 2 loss_pde:2.20936584, loss_ib:0.72864175
# epoch 2 loss_pde:2.20855546, loss_ib:0.72857833
# epoch 2 loss_pde:2.20780325, loss_ib:0.72850847
# epoch 2 loss_pde:2.20699430, loss_ib:0.72844470
# epoch 2 loss_pde:2.20624876, loss_ib:0.72835207
# epoch 2 loss_pde:2.20550704, loss_ib:0.72829068
# epoch 2 loss_pde:2.20474458, loss_ib:0.72822666
# epoch 2 loss_pde:2.20398688, loss_ib:0.72816277
# epoch 2 loss_pde:2.20322323, loss_ib:0.72809768
# epoch 2 loss_pde:2.20235682, loss_ib:0.72801924
# epoch 2 loss_pde:2.20161033, loss_ib:0.72795367
# epoch 2 loss_pde:2.19988179, loss_ib:0.72787964
# epoch 2 loss_pde:2.19908810, loss_ib:0.72781467
# epoch 2 loss_pde:2.19837379, loss_ib:0.72775179
# epoch 2 loss_pde:2.19764566, loss_ib:0.72767675
# epoch 2 loss_pde:2.19689512, loss_ib:0.72760296
# epoch 2 loss_pde:2.19611526, loss_ib:0.72753102
# epoch 2 loss_pde:2.19536757, loss_ib:0.72745478
# epoch 2 loss_pde:2.19412518, loss_ib:0.72742307
# epoch 2 loss_pde:2.19328475, loss_ib:0.72731537
# epoch 2 loss_pde:2.19237733, loss_ib:0.72721922
# epoch 2 loss_pde:2.19156647, loss_ib:0.72713804
# epoch 2 loss_pde:2.19086385, loss_ib:0.72705019
# epoch 2 loss_pde:2.18986702, loss_ib:0.72697926
# epoch 2 loss_pde:2.18910050, loss_ib:0.72688699
# epoch 2 loss_pde:2.18824959, loss_ib:0.72681028
# epoch 2 loss_pde:2.18749619, loss_ib:0.72671938
# epoch 2 loss_pde:2.18669677, loss_ib:0.72663701
# ...
# epoch 60 loss_pde:0.72694898, loss_ib:0.53515983
# epoch 60 loss_pde:0.72694683, loss_ib:0.53515983
# epoch 60 loss_pde:0.72694516, loss_ib:0.53515983
# epoch 60 loss_pde:0.72694206, loss_ib:0.53515965
# epoch 60 loss_pde:0.72693956, loss_ib:0.53515959
# epoch 60 loss_pde:0.72693843, loss_ib:0.53515929
# epoch 60 loss_pde:0.72693622, loss_ib:0.53515953
# epoch 60 loss_pde:0.72693413, loss_ib:0.53515929
# epoch 60 loss_pde:0.72693038, loss_ib:0.53515929
# epoch 60 loss_pde:0.72693044, loss_ib:0.53515911
# epoch 60 loss_pde:0.72692704, loss_ib:0.53515887
# epoch 60 loss_pde:0.72692388, loss_ib:0.53515899
# epoch 60 loss_pde:0.72691995, loss_ib:0.53515887
# epoch 60 loss_pde:0.72691917, loss_ib:0.53515875
# epoch 60 loss_pde:0.72691816, loss_ib:0.53515881
# epoch 60: loss 6.078702
# epoch 61 loss_pde:0.72691816, loss_ib:0.53515881
# epoch 61 loss_pde:0.72691596, loss_ib:0.53515869
# epoch 61 loss_pde:0.72691101, loss_ib:0.53515869
# epoch 61 loss_pde:0.72690928, loss_ib:0.53515851
# epoch 61 loss_pde:0.72690839, loss_ib:0.53515816
# epoch 61 loss_pde:0.72690535, loss_ib:0.53515828
# epoch 61 loss_pde:0.72690427, loss_ib:0.53515804
# epoch 61 loss_pde:0.72690010, loss_ib:0.53515780
# epoch 61 loss_pde:0.72689855, loss_ib:0.53515768
# epoch 61 loss_pde:0.72689354, loss_ib:0.53515780
# epoch 61 loss_pde:0.72689039, loss_ib:0.53515762
# epoch 61 loss_pde:0.72688925, loss_ib:0.53515756
# epoch 61 loss_pde:0.72688532, loss_ib:0.53515750
# epoch 61 loss_pde:0.72688413, loss_ib:0.53515738
# epoch 61 loss_pde:0.72688246, loss_ib:0.53515720
# epoch 61 loss_pde:0.72687954, loss_ib:0.53515720
# epoch 61 loss_pde:0.72687763, loss_ib:0.53515702
# epoch 61 loss_pde:0.72687262, loss_ib:0.53515702
# epoch 61 loss_pde:0.72687179, loss_ib:0.53515708
# epoch 61 loss_pde:0.72686911, loss_ib:0.53515685
# epoch 61 loss_pde:0.72686523, loss_ib:0.53515679
# epoch 61 loss_pde:0.72686219, loss_ib:0.53515679
# epoch 61 loss_pde:0.72686100, loss_ib:0.53515673
# epoch 61 loss_pde:0.72685832, loss_ib:0.53515655
# epoch 61 loss_pde:0.72685653, loss_ib:0.53515649
# epoch 61 loss_pde:0.72685361, loss_ib:0.53515637
# epoch 61 loss_pde:0.72685117, loss_ib:0.53515625
# epoch 61 loss_pde:0.72684783, loss_ib:0.53515625
# epoch 61 loss_pde:0.72684735, loss_ib:0.53515601
# epoch 61 loss_pde:0.72684407, loss_ib:0.53515589
# epoch 61 loss_pde:0.72684216, loss_ib:0.53515595
# epoch 61 loss_pde:0.72684181, loss_ib:0.53515577
# epoch 61 loss_pde:0.72683758, loss_ib:0.53515577
# epoch 61 loss_pde:0.72683519, loss_ib:0.53515565
# epoch 61 loss_pde:0.72683257, loss_ib:0.53515542
# epoch 61 loss_pde:0.72683012, loss_ib:0.53515548
# epoch 61 loss_pde:0.72682852, loss_ib:0.53515524
# epoch 61 loss_pde:0.72682470, loss_ib:0.53515506
# epoch 61 loss_pde:0.72682434, loss_ib:0.53515494
# epoch 61 loss_pde:0.72681934, loss_ib:0.53515494
# epoch 61 loss_pde:0.72681797, loss_ib:0.53515470
# epoch 61 loss_pde:0.72681516, loss_ib:0.53515470
# epoch 61 loss_pde:0.72681278, loss_ib:0.53515440
# epoch 61 loss_pde:0.72680807, loss_ib:0.53515422
# epoch 61 loss_pde:0.72680557, loss_ib:0.53515440
# epoch 61 loss_pde:0.72680372, loss_ib:0.53515404
# epoch 61 loss_pde:0.72679782, loss_ib:0.53515387
# epoch 61 loss_pde:0.72679645, loss_ib:0.53515387
# epoch 61 loss_pde:0.72679293, loss_ib:0.53515357
# epoch 61 loss_pde:0.72678882, loss_ib:0.53515339
# epoch 61 loss_pde:0.72678804, loss_ib:0.53515351
# epoch 61: loss 6.078506
# epoch 62 loss_pde:0.72678804, loss_ib:0.53515351
# epoch 62 loss_pde:0.72678429, loss_ib:0.53515333
# epoch 62 loss_pde:0.72678310, loss_ib:0.53515327
# epoch 62 loss_pde:0.72677773, loss_ib:0.53515303
# epoch 62 loss_pde:0.72677350, loss_ib:0.53515303
# epoch 62 loss_pde:0.72677445, loss_ib:0.53515232
# epoch 62 loss_pde:0.72677124, loss_ib:0.53515220
# epoch 62 loss_pde:0.72677058, loss_ib:0.53515202
# epoch 62 loss_pde:0.72676384, loss_ib:0.53515160
# epoch 62 loss_pde:0.72676075, loss_ib:0.53515160
# epoch 62 loss_pde:0.72675723, loss_ib:0.53515148
# epoch 62 loss_pde:0.72675449, loss_ib:0.53515136
# epoch 62 loss_pde:0.72675097, loss_ib:0.53515136
# epoch 62 loss_pde:0.72675002, loss_ib:0.53515136
# epoch 62 loss_pde:0.72674847, loss_ib:0.53515100
# epoch 62 loss_pde:0.72674507, loss_ib:0.53515100
# epoch 62 loss_pde:0.72674173, loss_ib:0.53515100
# epoch 62 loss_pde:0.72673726, loss_ib:0.53515089
# epoch 62 loss_pde:0.72673678, loss_ib:0.53515071
# epoch 62 loss_pde:0.72673142, loss_ib:0.53515059
# epoch 62 loss_pde:0.72672987, loss_ib:0.53515047
# epoch 62 loss_pde:0.72672582, loss_ib:0.53515017
# epoch 62 loss_pde:0.72672147, loss_ib:0.53515005
# epoch 62 loss_pde:0.72672075, loss_ib:0.53514999
# epoch 62 loss_pde:0.72671759, loss_ib:0.53514981
# epoch 62 loss_pde:0.72671360, loss_ib:0.53514993
# epoch 62 loss_pde:0.72671008, loss_ib:0.53514969
# epoch 62 loss_pde:0.72670811, loss_ib:0.53514963
# epoch 62 loss_pde:0.72670257, loss_ib:0.53514951
# epoch 62 loss_pde:0.72670209, loss_ib:0.53514946
# epoch 62 loss_pde:0.72669697, loss_ib:0.53514922
# epoch 62 loss_pde:0.72669452, loss_ib:0.53514922
# epoch 62 loss_pde:0.72669244, loss_ib:0.53514898
# epoch 62 loss_pde:0.72668844, loss_ib:0.53514886
# epoch 62 loss_pde:0.72668672, loss_ib:0.53514862
# epoch 62 loss_pde:0.72668260, loss_ib:0.53514856
# epoch 62 loss_pde:0.72668159, loss_ib:0.53514850
# epoch 62 loss_pde:0.72667873, loss_ib:0.53514826
# epoch 62 loss_pde:0.72667480, loss_ib:0.53514832
# epoch 62 loss_pde:0.72667229, loss_ib:0.53514814
# epoch 62 loss_pde:0.72666985, loss_ib:0.53514802
# epoch 62 loss_pde:0.72666669, loss_ib:0.53514791
# epoch 62 loss_pde:0.72666299, loss_ib:0.53514773
# epoch 62 loss_pde:0.72666192, loss_ib:0.53514755
# epoch 62 loss_pde:0.72665852, loss_ib:0.53514749
# epoch 62 loss_pde:0.72665709, loss_ib:0.53514731
# epoch 62 loss_pde:0.72665566, loss_ib:0.53514725
# epoch 62 loss_pde:0.72665179, loss_ib:0.53514695
# epoch 62 loss_pde:0.72664696, loss_ib:0.53514695
# epoch 62 loss_pde:0.72664601, loss_ib:0.53514659
# epoch 62 loss_pde:0.72664237, loss_ib:0.53514665
# epoch 62 loss_pde:0.72664207, loss_ib:0.53514636
# epoch 62 loss_pde:0.72663736, loss_ib:0.53514612
# epoch 62 loss_pde:0.72663438, loss_ib:0.53514600
# epoch 62 loss_pde:0.72663069, loss_ib:0.53514588
# epoch 62 loss_pde:0.72662771, loss_ib:0.53514576
# epoch 62 loss_pde:0.72662097, loss_ib:0.53514552
# epoch 62 loss_pde:0.72661841, loss_ib:0.53514522
# epoch 62 loss_pde:0.72661799, loss_ib:0.53514493
# epoch 62 loss_pde:0.72661352, loss_ib:0.53514481
# epoch 62 loss_pde:0.72661173, loss_ib:0.53514457
# epoch 62 loss_pde:0.72660953, loss_ib:0.53514439
# epoch 62 loss_pde:0.72660494, loss_ib:0.53514421
# epoch 62 loss_pde:0.72660297, loss_ib:0.53514397
# epoch 62 loss_pde:0.72659802, loss_ib:0.53514385
# epoch 62 loss_pde:0.72659504, loss_ib:0.53514361
# epoch 62 loss_pde:0.72659343, loss_ib:0.53514361
# epoch 62 loss_pde:0.72659087, loss_ib:0.53514349
# epoch 62 loss_pde:0.72658449, loss_ib:0.53514338
# epoch 62 loss_pde:0.72658217, loss_ib:0.53514338
# epoch 62 loss_pde:0.72658020, loss_ib:0.53514314
# epoch 62 loss_pde:0.72657537, loss_ib:0.53514302
# epoch 62 loss_pde:0.72657293, loss_ib:0.53514290
# epoch 62 loss_pde:0.72656876, loss_ib:0.53514272
# epoch 62 loss_pde:0.72656828, loss_ib:0.53514242
# epoch 62 loss_pde:0.72656476, loss_ib:0.53514218
# epoch 62 loss_pde:0.72656119, loss_ib:0.53514224
# epoch 62 loss_pde:0.72655785, loss_ib:0.53514194
# epoch 62 loss_pde:0.72655386, loss_ib:0.53514183
# epoch 62 loss_pde:0.72655064, loss_ib:0.53514171
# epoch 62 loss_pde:0.72655034, loss_ib:0.53514159
# epoch 62 loss_pde:0.72654229, loss_ib:0.53514123
# epoch 62 loss_pde:0.72654021, loss_ib:0.53514099
# epoch 62 loss_pde:0.72653842, loss_ib:0.53514057
# epoch 62 loss_pde:0.72653514, loss_ib:0.53514051
# epoch 62 loss_pde:0.72653484, loss_ib:0.53513974
# epoch 62 loss_pde:0.72653157, loss_ib:0.53513962
# epoch 62 loss_pde:0.72652781, loss_ib:0.53513944
# epoch 62 loss_pde:0.72652566, loss_ib:0.53513944
# epoch 62 loss_pde:0.72652221, loss_ib:0.53513926
# epoch 62 loss_pde:0.72651821, loss_ib:0.53513908
# epoch 62 loss_pde:0.72651511, loss_ib:0.53513891
# epoch 62 loss_pde:0.72651309, loss_ib:0.53513867
# epoch 62 loss_pde:0.72651041, loss_ib:0.53513825
# epoch 62 loss_pde:0.72650987, loss_ib:0.53513813
# epoch 62 loss_pde:0.72650415, loss_ib:0.53513813
# epoch 62 loss_pde:0.72650409, loss_ib:0.53513765
# epoch 62 loss_pde:0.72650081, loss_ib:0.53513771
# epoch 62 loss_pde:0.72649789, loss_ib:0.53513730
# epoch 62 loss_pde:0.72649372, loss_ib:0.53513730
# epoch 62 loss_pde:0.72648370, loss_ib:0.53513634
# epoch 62 loss_pde:0.72647858, loss_ib:0.53513592
# epoch 62 loss_pde:0.72647595, loss_ib:0.53513581
# epoch 62 loss_pde:0.72647214, loss_ib:0.53513551
# epoch 62 loss_pde:0.72646868, loss_ib:0.53513539
# epoch 62 loss_pde:0.72646630, loss_ib:0.53513515
# epoch 62 loss_pde:0.72646183, loss_ib:0.53513503
# epoch 62 loss_pde:0.72646034, loss_ib:0.53513479
# epoch 62 loss_pde:0.72645473, loss_ib:0.53513485
# epoch 62 loss_pde:0.72645074, loss_ib:0.53513455
# epoch 62 loss_pde:0.72644836, loss_ib:0.53513443
# epoch 62 loss_pde:0.72644413, loss_ib:0.53513426
# epoch 62 loss_pde:0.72644323, loss_ib:0.53513408
# epoch 62 loss_pde:0.72643954, loss_ib:0.53513384
# epoch 62 loss_pde:0.72643745, loss_ib:0.53513354
# epoch 62 loss_pde:0.72643358, loss_ib:0.53513354
# epoch 62 loss_pde:0.72643131, loss_ib:0.53513324
# epoch 62 loss_pde:0.72642934, loss_ib:0.53513288
# epoch 62 loss_pde:0.72642559, loss_ib:0.53513253
# epoch 62 loss_pde:0.72642308, loss_ib:0.53513229
# epoch 62 loss_pde:0.72641850, loss_ib:0.53513223
# epoch 62 loss_pde:0.72641611, loss_ib:0.53513205
# epoch 62 loss_pde:0.72641516, loss_ib:0.53513175
# epoch 62 loss_pde:0.72640890, loss_ib:0.53513157
# epoch 62 loss_pde:0.72640812, loss_ib:0.53513122
# epoch 62 loss_pde:0.72640538, loss_ib:0.53513122
# epoch 62 loss_pde:0.72640049, loss_ib:0.53513098
# epoch 62 loss_pde:0.72639978, loss_ib:0.53513044
# epoch 62 loss_pde:0.72639662, loss_ib:0.53513032
# epoch 62 loss_pde:0.72639591, loss_ib:0.53512990
# epoch 62 loss_pde:0.72639215, loss_ib:0.53512955
# epoch 62 loss_pde:0.72638720, loss_ib:0.53512931
# epoch 62 loss_pde:0.72638416, loss_ib:0.53512913
# epoch 62 loss_pde:0.72638339, loss_ib:0.53512883
# epoch 62 loss_pde:0.72637904, loss_ib:0.53512859
# epoch 62 loss_pde:0.72637826, loss_ib:0.53512830
# epoch 62 loss_pde:0.72637397, loss_ib:0.53512800
# epoch 62 loss_pde:0.72637123, loss_ib:0.53512764
# epoch 62 loss_pde:0.72637022, loss_ib:0.53512746
# epoch 62 loss_pde:0.72636539, loss_ib:0.53512716
# epoch 62 loss_pde:0.72636199, loss_ib:0.53512692
# epoch 62 loss_pde:0.72635919, loss_ib:0.53512669
# epoch 62 loss_pde:0.72635615, loss_ib:0.53512645
# epoch 62 loss_pde:0.72635388, loss_ib:0.53512609
# epoch 62 loss_pde:0.72634816, loss_ib:0.53512573
# epoch 62 loss_pde:0.72634614, loss_ib:0.53512549
# epoch 62 loss_pde:0.72634470, loss_ib:0.53512537
# epoch 62 loss_pde:0.72634041, loss_ib:0.53512502
# epoch 62 loss_pde:0.72633743, loss_ib:0.53512484
# epoch 62 loss_pde:0.72633612, loss_ib:0.53512454
# epoch 62 loss_pde:0.72633165, loss_ib:0.53512418
# epoch 62 loss_pde:0.72632980, loss_ib:0.53512383
# epoch 62 loss_pde:0.72632730, loss_ib:0.53512359
# epoch 62 loss_pde:0.72632414, loss_ib:0.53512347
# epoch 62 loss_pde:0.72632122, loss_ib:0.53512311
# epoch 62 loss_pde:0.72631931, loss_ib:0.53512275
# epoch 62 loss_pde:0.72631615, loss_ib:0.53512251
# epoch 62 loss_pde:0.72631478, loss_ib:0.53512216
# epoch 62 loss_pde:0.72631299, loss_ib:0.53512198
# epoch 62 loss_pde:0.72630596, loss_ib:0.53512144
# epoch 62 loss_pde:0.72630584, loss_ib:0.53512120
# epoch 62 loss_pde:0.72630286, loss_ib:0.53512084
# epoch 62 loss_pde:0.72629231, loss_ib:0.53511918
# epoch 62 loss_pde:0.72628939, loss_ib:0.53511858
# epoch 62 loss_pde:0.72628474, loss_ib:0.53511840
# epoch 62 loss_pde:0.72628164, loss_ib:0.53511804
# epoch 62 loss_pde:0.72627980, loss_ib:0.53511763
# epoch 62 loss_pde:0.72627521, loss_ib:0.53511757
# epoch 62 loss_pde:0.72627497, loss_ib:0.53511631
# epoch 62 loss_pde:0.72627389, loss_ib:0.53511596
# epoch 62 loss_pde:0.72627032, loss_ib:0.53511560
# epoch 62 loss_pde:0.72626740, loss_ib:0.53511536
# epoch 62 loss_pde:0.72626364, loss_ib:0.53511500
# epoch 62 loss_pde:0.72626060, loss_ib:0.53511471
# epoch 62 loss_pde:0.72625923, loss_ib:0.53511429
# epoch 62 loss_pde:0.72625464, loss_ib:0.53511393
# epoch 62 loss_pde:0.72625297, loss_ib:0.53511369
# epoch 62 loss_pde:0.72625011, loss_ib:0.53511226
# epoch 62 loss_pde:0.72624785, loss_ib:0.53511202
# epoch 62 loss_pde:0.72624582, loss_ib:0.53511155
# epoch 62 loss_pde:0.72624129, loss_ib:0.53511113
# epoch 62 loss_pde:0.72623819, loss_ib:0.53511095
# epoch 62 loss_pde:0.72623569, loss_ib:0.53511059
# epoch 62 loss_pde:0.72623420, loss_ib:0.53511012
# epoch 62 loss_pde:0.72622949, loss_ib:0.53510952
# epoch 62 loss_pde:0.72622716, loss_ib:0.53510916
# epoch 62 loss_pde:0.72622120, loss_ib:0.53510892
# epoch 62 loss_pde:0.72622019, loss_ib:0.53510851
# epoch 62 loss_pde:0.72621673, loss_ib:0.53510809
# epoch 62 loss_pde:0.72621316, loss_ib:0.53510785
# epoch 62 loss_pde:0.72621018, loss_ib:0.53510737
# epoch 62 loss_pde:0.72620535, loss_ib:0.53510702
# epoch 62 loss_pde:0.72620249, loss_ib:0.53510666
# epoch 62 loss_pde:0.72619802, loss_ib:0.53510612
# epoch 62 loss_pde:0.72619200, loss_ib:0.53510606
# epoch 62 loss_pde:0.72618997, loss_ib:0.53510535
# epoch 62 loss_pde:0.72618562, loss_ib:0.53510511
# epoch 62 loss_pde:0.72618443, loss_ib:0.53510463
# epoch 62 loss_pde:0.72617835, loss_ib:0.53510427
# epoch 62 loss_pde:0.72617590, loss_ib:0.53510374
# epoch 62 loss_pde:0.72617221, loss_ib:0.53510326
# epoch 62 loss_pde:0.72616851, loss_ib:0.53510284
# epoch 62 loss_pde:0.72616452, loss_ib:0.53510243
# epoch 62 loss_pde:0.72616094, loss_ib:0.53510183
# epoch 62 loss_pde:0.72615439, loss_ib:0.53510129
# epoch 62 loss_pde:0.72615045, loss_ib:0.53510082
# epoch 62 loss_pde:0.72614634, loss_ib:0.53510034
# epoch 62 loss_pde:0.72614288, loss_ib:0.53509980
# epoch 62 loss_pde:0.72613782, loss_ib:0.53509927
# epoch 62 loss_pde:0.72613579, loss_ib:0.53509879
# epoch 62 loss_pde:0.72613174, loss_ib:0.53509831
# epoch 62 loss_pde:0.72612661, loss_ib:0.53509784
# epoch 62 loss_pde:0.72612298, loss_ib:0.53509724
# epoch 62 loss_pde:0.72611880, loss_ib:0.53509670
# epoch 62 loss_pde:0.72611451, loss_ib:0.53509629
# epoch 62 loss_pde:0.72611046, loss_ib:0.53509581
# epoch 62 loss_pde:0.72610569, loss_ib:0.53509504
# epoch 62 loss_pde:0.72610158, loss_ib:0.53509450
# epoch 62 loss_pde:0.72609878, loss_ib:0.53509390
# epoch 62 loss_pde:0.72609323, loss_ib:0.53509343
# epoch 62 loss_pde:0.72608966, loss_ib:0.53509277
# epoch 62 loss_pde:0.72608489, loss_ib:0.53509229
# epoch 62 loss_pde:0.72608179, loss_ib:0.53509176
# epoch 62 loss_pde:0.72607374, loss_ib:0.53509140
# epoch 62 loss_pde:0.72606999, loss_ib:0.53509092
# epoch 62 loss_pde:0.72606528, loss_ib:0.53509021
# epoch 62 loss_pde:0.72606003, loss_ib:0.53508967
# epoch 62 loss_pde:0.72605544, loss_ib:0.53508914
# epoch 62 loss_pde:0.72605109, loss_ib:0.53508848
# epoch 62 loss_pde:0.72604525, loss_ib:0.53508806
# epoch 62 loss_pde:0.72604156, loss_ib:0.53508759
# epoch 62 loss_pde:0.72603548, loss_ib:0.53508669
# epoch 62 loss_pde:0.72603083, loss_ib:0.53508621
# epoch 62 loss_pde:0.72602570, loss_ib:0.53508550
# epoch 62 loss_pde:0.72602201, loss_ib:0.53508496
# epoch 62 loss_pde:0.72601825, loss_ib:0.53508443
# epoch 62 loss_pde:0.72601312, loss_ib:0.53508365
# epoch 62 loss_pde:0.72600853, loss_ib:0.53508294
# epoch 62 loss_pde:0.72600389, loss_ib:0.53508246
# epoch 62 loss_pde:0.72599888, loss_ib:0.53508186
# epoch 62 loss_pde:0.72599059, loss_ib:0.53508157
# epoch 62 loss_pde:0.72598875, loss_ib:0.53508037
# epoch 62 loss_pde:0.72598279, loss_ib:0.53507984
# epoch 62 loss_pde:0.72597980, loss_ib:0.53507924
# epoch 62 loss_pde:0.72597051, loss_ib:0.53507864
# epoch 62 loss_pde:0.72596765, loss_ib:0.53507805
# epoch 62 loss_pde:0.72596294, loss_ib:0.53507745
# epoch 62 loss_pde:0.72595662, loss_ib:0.53507620
# epoch 62 loss_pde:0.72595048, loss_ib:0.53507555
# epoch 62 loss_pde:0.72594696, loss_ib:0.53507495
# epoch 62 loss_pde:0.72594160, loss_ib:0.53507429
# epoch 62 loss_pde:0.72593629, loss_ib:0.53507370
# epoch 62 loss_pde:0.72593027, loss_ib:0.53507298
# epoch 62 loss_pde:0.72592717, loss_ib:0.53507239
# epoch 62 loss_pde:0.72592241, loss_ib:0.53507149
# epoch 62 loss_pde:0.72591716, loss_ib:0.53507113
# epoch 62 loss_pde:0.72590929, loss_ib:0.53506982
# epoch 62 loss_pde:0.72590518, loss_ib:0.53506929
# epoch 62 loss_pde:0.72589743, loss_ib:0.53506875

# %%
# Evaluate on the whole computational domain
for i in range(50):
#u = to_numpy(model(x_test))
#x = to_numpy(x_test)
    x = np.linspace(0.0, 1.0, 401)                                   # Partitioned spatial axis
    y = np.linspace(0.0, 1.0, 400)                                   # Partitioned spatial axis
    t = np.linspace(0.20, 0.20, 1)                                        # Partitioned time axis
    t_grid, x_grid,y_grid = np.meshgrid(t,x,y)                                    # (t,x) in [0,0.2]x[a,b]
    T = t_grid.flatten()[:, None]                                        # Vectorized t_grid
    X = x_grid.flatten()[:, None]                                         # Vectorized x_grid
    Y = y_grid.flatten()[:, None]                                         # Vectorized x_grid
    x_test = np.hstack((T, X, Y))                                            # Vectorized whole domain
    x_test = torch.tensor(x_test, dtype=torch.float32).to(device)
    u = to_numpy(model(x_test))
    #Xp,Yp = meshgrid(x,y)
    
    ue = np.zeros((401,400))
    for i in range(0,401):
        for j in range(0,400):
            ue[i,j] = u[j*400+i,3]
            
    plt.figure()
    plt.contourf(x_grid[:,0,:],y_grid[:,0,:],ue,50)
    #plt.pcolor(x_grid[:,0,:],y_grid[:,0,:],ue)
    #plt.colorbar(x_grid[:,0,:],y_grid[:,0,:],ue)
    #plt.scatter(x_int_train[:,1],)
    #plt.pcolor(x[:],u[:,1])
    #plt.pcolor(x[:],u[:,2])
    ax = plt.gca()
    ax.set_aspect(1)
    plt.savefig("test_rasterization.png", dpi=150)
    plt.show()
 
    #    uo = ue.flatten()[:,None]
    #    uxy= np.hstack((X, Y,uo))                                            # Vectorized whole domain

# %%
#np.savetxt('Riemannv100.txt', uxy)
t = np.linspace(Tend, Tend, 1)                                   # Partitioned spatial axis
x = np.linspace(0.0, Lx, 800)                                   # Partitioned spatial axis
y = np.linspace(0.0, Ly, 800)                                   # Partitioned spatial axis
t_grid,x_grid,y_grid = np.meshgrid(t,x,y)                                    # (t,x) in [0,0.2]x[a,b]
T = t_grid.flatten()[:, None]                                         # Vectorized x_grid
X = x_grid.flatten()[:, None]                                         # Vectorized x_grid
Y = y_grid.flatten()[:, None]                                         # Vectorized x_grid
x_test = np.hstack((T,X,Y))                                            # Vectorized whole domain
x_test = torch.tensor(x_test, dtype=torch.float32).to(device)
u = to_numpy(model(x_test))
#Xp,Yp = meshgrid(x,y)


ue = np.zeros((800,800))
for j in range(0,800):
    for i in range(0,800):
        ue[i,j] = u[i*800+j,0]
uo = ue.flatten()[:,None]
uxy= np.hstack((X, Y,uo))     

np.savetxt('shockCrho.txt', uxy)# Vectorized whole domain

# %%
plt.figure()
plt.contourf(x_grid[:,0,:],y_grid[:,0,:],ue,100)
#plt.pcolor(x_grid[:,0,:],y_grid[:,0,:],ue)
#plt.colorbar(x_grid[:,0,:],y_grid[:,0,:],ue)
#plt.scatter(x_int_train[:,1],)
#plt.pcolor(x[:],u[:,1])
#plt.pcolor(x[:],u[:,2])
ax = plt.gca()
ax.set_aspect(1)
plt.show()
plt.savefig("Riemann2.pdf", dpi=150)

# %%
#fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
#surf = ax.plot_surface(x_grid[:,0,:], y_grid[:,0,:], ue, cmap=cm.coolwarm,
#                       linewidth=0, antialiased=False)
#
## Customize the z axis.
#ax.set_zlim(0, 1.01)
#ax.zaxis.set_major_locator(LinearLocator(10))
## A StrMethodFormatter is used automatically
#ax.zaxis.set_major_formatter('{x:.02f}')
#
## Add a color bar which maps values to colors.
#fig.colorbar(surf, shrink=0.5, aspect=5)
#plt.show()

# %%
torch.save(model,'2DRiemanncase8.pt')

# %%
model

# %%
#device1 = torch.device("cpu")
#model.load_state_dict(torch.load(PATH))
#model = model.to(device1)
#torch.save(model,'2DRiemanncase8.pt')
model = torch.load('2DRiemanncase8.pt')

# %%
model
